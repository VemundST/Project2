# %%
import functions as fx
import log_reg_functions as lrf
import loaddata as ld
import NeuralNetwork as nn
import LogisticRegression as lr

import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, log_loss, f1_score, confusion_matrix, roc_auc_score

# %% [markdown]
# # A )
# Here we will load the dataset, then split it into train, validation and test data.
# As the Credit Card data is biased, we also create a downzised dataset.

# %%
# Reading in credit card dataset.
x,y = ld.load_data(scaler='minmax')

# Splitting data in train and test data
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.20, random_state= 0, shuffle=True)
# Splitting in train and validation
xtrain,xval,ytrain,yval = train_test_split(xtrain,ytrain, test_size=0.125, random_state= 0, shuffle=True)

# Extracting some useful shapes.
nx_train, ny_train = xtrain.shape
nx_test, ny_test = xtest.shape

# %% [markdown]
# # B)
# Egen logistic regression med gradient descent.

# %%
eta = 0.1 # learning rate
Niter=2500
logreg = lr.LOGREG(eta=0.1, doplot = False, doprint=True)
cost_val, cost_train, axis = logreg.fit(xtrain, ytrain, xval, yval, Niter, solver='gd')
classified=logreg.predict(xtest)
# Out:
# Cost validation = [1.45401503]
# Cost validation = [1.43061612]
# Cost validation = [1.40841929]
# Cost validation = [1.38732674]
# Cost validation = [1.36725061]
# Cost validation = [1.34811186]
# Cost validation = [1.32983927]
# Cost validation = [1.3123686]
# Cost validation = [1.29564182]
# Cost validation = [1.27960645]
# Cost validation = [1.26421492]
# Cost validation = [1.24942409]
# Cost validation = [1.23519476]
# Cost validation = [1.22149124]
# Cost validation = [1.20828102]
# Cost validation = [1.19553438]
# Cost validation = [1.18322417]
# Cost validation = [1.17132547]
# Cost validation = [1.15981544]
# Cost validation = [1.14867304]
# Cost validation = [1.13787891]
# Cost validation = [1.12741516]
# Cost validation = [1.11726524]
# Cost validation = [1.10741381]
# Cost validation = [1.09784664]
# Cost validation = [1.08855046]
# Cost validation = [1.07951294]
# Cost validation = [1.07072253]
# Cost validation = [1.06216844]
# Cost validation = [1.05384056]
# Cost validation = [1.0457294]
# Cost validation = [1.03782603]
# Cost validation = [1.03012205]
# Cost validation = [1.02260952]
# Cost validation = [1.01528097]
# Cost validation = [1.00812931]
# Cost validation = [1.00114786]
# Cost validation = [0.99433025]
# Cost validation = [0.98767046]
# Cost validation = [0.98116278]
# Cost validation = [0.97480176]
# Cost validation = [0.96858224]
# Cost validation = [0.96249929]
# Cost validation = [0.95654821]
# Cost validation = [0.95072454]
# Cost validation = [0.94502401]
# Cost validation = [0.93944254]
# Cost validation = [0.93397624]
# Cost validation = [0.92862141]
# Cost validation = [0.92337447]
# Cost validation = [0.91823204]
# Cost validation = [0.91319086]
# Cost validation = [0.90824781]
# Cost validation = [0.90339991]
# Cost validation = [0.8986443]
# Cost validation = [0.89397824]
# Cost validation = [0.88939909]
# Cost validation = [0.88490434]
# Cost validation = [0.88049156]
# Cost validation = [0.87615842]
# Cost validation = [0.8719027]
# Cost validation = [0.86772223]
# Cost validation = [0.86361497]
# Cost validation = [0.85957891]
# Cost validation = [0.85561215]
# Cost validation = [0.85171285]
# Cost validation = [0.84787924]
# Cost validation = [0.8441096]
# Cost validation = [0.8404023]
# Cost validation = [0.83675575]
# Cost validation = [0.83316841]
# Cost validation = [0.82963881]
# Cost validation = [0.82616552]
# Cost validation = [0.82274717]
# Cost validation = [0.81938244]
# Cost validation = [0.81607003]
# Cost validation = [0.8128087]
# Cost validation = [0.80959726]
# Cost validation = [0.80643454]
# Cost validation = [0.80331942]
# Cost validation = [0.80025082]
# Cost validation = [0.79722768]
# Cost validation = [0.79424899]
# Cost validation = [0.79131375]
# Cost validation = [0.78842101]
# Cost validation = [0.78556984]
# Cost validation = [0.78275935]
# Cost validation = [0.77998866]
# Cost validation = [0.77725693]
# Cost validation = [0.77456334]
# Cost validation = [0.77190709]
# Cost validation = [0.7692874]
# Cost validation = [0.76670354]
# Cost validation = [0.76415476]
# Cost validation = [0.76164036]
# Cost validation = [0.75915966]
# Cost validation = [0.75671197]
# Cost validation = [0.75429666]
# Cost validation = [0.75191309]
# Cost validation = [0.74956065]
# Cost validation = [0.74723872]
# Cost validation = [0.74494674]
# Cost validation = [0.74268414]
# Cost validation = [0.74045036]
# Cost validation = [0.73824486]
# Cost validation = [0.73606713]
# Cost validation = [0.73391665]
# Cost validation = [0.73179292]
# Cost validation = [0.72969547]
# Cost validation = [0.72762381]
# Cost validation = [0.72557749]
# Cost validation = [0.72355605]
# Cost validation = [0.72155907]
# Cost validation = [0.71958611]
# Cost validation = [0.71763675]
# Cost validation = [0.71571059]
# Cost validation = [0.71380724]
# Cost validation = [0.7119263]
# Cost validation = [0.71006739]
# Cost validation = [0.70823014]
# Cost validation = [0.7064142]
# Cost validation = [0.70461921]
# Cost validation = [0.70284482]
# Cost validation = [0.7010907]
# Cost validation = [0.69935652]
# Cost validation = [0.69764195]
# Cost validation = [0.69594668]
# Cost validation = [0.69427041]
# Cost validation = [0.69261282]
# Cost validation = [0.69097362]
# Cost validation = [0.68935254]
# Cost validation = [0.68774927]
# Cost validation = [0.68616355]
# Cost validation = [0.6845951]
# Cost validation = [0.68304366]
# Cost validation = [0.68150897]
# Cost validation = [0.67999078]
# Cost validation = [0.67848883]
# Cost validation = [0.67700288]
# Cost validation = [0.67553269]
# Cost validation = [0.67407803]
# Cost validation = [0.67263866]
# Cost validation = [0.67121436]
# Cost validation = [0.66980492]
# Cost validation = [0.6684101]
# Cost validation = [0.66702971]
# Cost validation = [0.66566353]
# Cost validation = [0.66431135]
# Cost validation = [0.66297298]
# Cost validation = [0.66164822]
# Cost validation = [0.66033687]
# Cost validation = [0.65903875]
# Cost validation = [0.65775366]
# Cost validation = [0.65648144]
# Cost validation = [0.65522189]
# Cost validation = [0.65397484]
# Cost validation = [0.65274011]
# Cost validation = [0.65151755]
# Cost validation = [0.65030697]
# Cost validation = [0.64910822]
# Cost validation = [0.64792114]
# Cost validation = [0.64674556]
# Cost validation = [0.64558133]
# Cost validation = [0.6444283]
# Cost validation = [0.64328632]
# Cost validation = [0.64215524]
# Cost validation = [0.64103491]
# Cost validation = [0.63992519]
# Cost validation = [0.63882594]
# Cost validation = [0.63773703]
# Cost validation = [0.63665832]
# Cost validation = [0.63558967]
# Cost validation = [0.63453095]
# Cost validation = [0.63348204]
# Cost validation = [0.6324428]
# Cost validation = [0.63141312]
# Cost validation = [0.63039286]
# Cost validation = [0.62938191]
# Cost validation = [0.62838016]
# Cost validation = [0.62738747]
# Cost validation = [0.62640375]
# Cost validation = [0.62542886]
# Cost validation = [0.62446271]
# Cost validation = [0.62350519]
# Cost validation = [0.62255618]
# Cost validation = [0.62161557]
# Cost validation = [0.62068327]
# Cost validation = [0.61975918]
# Cost validation = [0.61884318]
# Cost validation = [0.61793518]
# Cost validation = [0.61703508]
# Cost validation = [0.61614279]
# Cost validation = [0.61525821]
# Cost validation = [0.61438124]
# Cost validation = [0.6135118]
# Cost validation = [0.61264979]
# Cost validation = [0.61179513]
# Cost validation = [0.61094771]
# Cost validation = [0.61010747]
# Cost validation = [0.60927431]
# Cost validation = [0.60844814]
# Cost validation = [0.6076289]
# Cost validation = [0.60681648]
# Cost validation = [0.60601082]
# Cost validation = [0.60521183]
# Cost validation = [0.60441943]
# Cost validation = [0.60363355]
# Cost validation = [0.60285412]
# Cost validation = [0.60208105]
# Cost validation = [0.60131427]
# Cost validation = [0.60055372]
# Cost validation = [0.59979931]
# Cost validation = [0.59905099]
# Cost validation = [0.59830867]
# Cost validation = [0.59757229]
# Cost validation = [0.59684179]
# Cost validation = [0.59611709]
# Cost validation = [0.59539813]
# Cost validation = [0.59468485]
# Cost validation = [0.59397719]
# Cost validation = [0.59327507]
# Cost validation = [0.59257844]
# Cost validation = [0.59188723]
# Cost validation = [0.59120139]
# Cost validation = [0.59052086]
# Cost validation = [0.58984558]
# Cost validation = [0.58917549]
# Cost validation = [0.58851053]
# Cost validation = [0.58785066]
# Cost validation = [0.5871958]
# Cost validation = [0.58654591]
# Cost validation = [0.58590094]
# Cost validation = [0.58526083]
# Cost validation = [0.58462552]
# Cost validation = [0.58399498]
# Cost validation = [0.58336914]
# Cost validation = [0.58274796]
# Cost validation = [0.58213139]
# Cost validation = [0.58151937]
# Cost validation = [0.58091187]
# Cost validation = [0.58030882]
# Cost validation = [0.5797102]
# Cost validation = [0.57911594]
# Cost validation = [0.57852601]
# Cost validation = [0.57794036]
# Cost validation = [0.57735894]
# Cost validation = [0.57678171]
# Cost validation = [0.57620864]
# Cost validation = [0.57563967]
# Cost validation = [0.57507476]
# Cost validation = [0.57451387]
# Cost validation = [0.57395697]
# Cost validation = [0.57340401]
# Cost validation = [0.57285494]
# Cost validation = [0.57230975]
# Cost validation = [0.57176837]
# Cost validation = [0.57123078]
# Cost validation = [0.57069693]
# Cost validation = [0.5701668]
# Cost validation = [0.56964034]
# Cost validation = [0.56911752]
# Cost validation = [0.5685983]
# Cost validation = [0.56808264]
# Cost validation = [0.56757051]
# Cost validation = [0.56706189]
# Cost validation = [0.56655672]
# Cost validation = [0.56605498]
# Cost validation = [0.56555664]
# Cost validation = [0.56506166]
# Cost validation = [0.56457002]
# Cost validation = [0.56408167]
# Cost validation = [0.56359659]
# Cost validation = [0.56311474]
# Cost validation = [0.5626361]
# Cost validation = [0.56216064]
# Cost validation = [0.56168833]
# Cost validation = [0.56121912]
# Cost validation = [0.56075301]
# Cost validation = [0.56028995]
# Cost validation = [0.55982993]
# Cost validation = [0.5593729]
# Cost validation = [0.55891885]
# Cost validation = [0.55846775]
# Cost validation = [0.55801956]
# Cost validation = [0.55757427]
# Cost validation = [0.55713184]
# Cost validation = [0.55669226]
# Cost validation = [0.55625549]
# Cost validation = [0.55582151]
# Cost validation = [0.55539029]
# Cost validation = [0.55496181]
# Cost validation = [0.55453604]
# Cost validation = [0.55411297]
# Cost validation = [0.55369256]
# Cost validation = [0.5532748]
# Cost validation = [0.55285965]
# Cost validation = [0.5524471]
# Cost validation = [0.55203713]
# Cost validation = [0.5516297]
# Cost validation = [0.55122481]
# Cost validation = [0.55082242]
# Cost validation = [0.55042251]
# Cost validation = [0.55002507]
# Cost validation = [0.54963007]
# Cost validation = [0.5492375]
# Cost validation = [0.54884732]
# Cost validation = [0.54845952]
# Cost validation = [0.54807409]
# Cost validation = [0.54769099]
# Cost validation = [0.54731021]
# Cost validation = [0.54693173]
# Cost validation = [0.54655554]
# Cost validation = [0.5461816]
# Cost validation = [0.54580991]
# Cost validation = [0.54544044]
# Cost validation = [0.54507318]
# Cost validation = [0.54470811]
# Cost validation = [0.5443452]
# Cost validation = [0.54398445]
# Cost validation = [0.54362583]
# Cost validation = [0.54326933]
# Cost validation = [0.54291493]
# Cost validation = [0.5425626]
# Cost validation = [0.54221235]
# Cost validation = [0.54186414]
# Cost validation = [0.54151796]
# Cost validation = [0.5411738]
# Cost validation = [0.54083164]
# Cost validation = [0.54049147]
# Cost validation = [0.54015326]
# Cost validation = [0.539817]
# Cost validation = [0.53948268]
# Cost validation = [0.53915028]
# Cost validation = [0.53881979]
# Cost validation = [0.53849119]
# Cost validation = [0.53816446]
# Cost validation = [0.5378396]
# Cost validation = [0.53751658]
# Cost validation = [0.5371954]
# Cost validation = [0.53687603]
# Cost validation = [0.53655847]
# Cost validation = [0.5362427]
# Cost validation = [0.53592871]
# Cost validation = [0.53561648]
# Cost validation = [0.53530601]
# Cost validation = [0.53499727]
# Cost validation = [0.53469025]
# Cost validation = [0.53438494]
# Cost validation = [0.53408133]
# Cost validation = [0.53377941]
# Cost validation = [0.53347916]
# Cost validation = [0.53318056]
# Cost validation = [0.53288362]
# Cost validation = [0.53258831]
# Cost validation = [0.53229462]
# Cost validation = [0.53200255]
# Cost validation = [0.53171207]
# Cost validation = [0.53142318]
# Cost validation = [0.53113587]
# Cost validation = [0.53085012]
# Cost validation = [0.53056592]
# Cost validation = [0.53028327]
# Cost validation = [0.53000214]
# Cost validation = [0.52972254]
# Cost validation = [0.52944444]
# Cost validation = [0.52916784]
# Cost validation = [0.52889272]
# Cost validation = [0.52861909]
# Cost validation = [0.52834691]
# Cost validation = [0.5280762]
# Cost validation = [0.52780692]
# Cost validation = [0.52753909]
# Cost validation = [0.52727267]
# Cost validation = [0.52700767]
# Cost validation = [0.52674407]
# Cost validation = [0.52648187]
# Cost validation = [0.52622105]
# Cost validation = [0.52596161]
# Cost validation = [0.52570354]
# Cost validation = [0.52544681]
# Cost validation = [0.52519144]
# Cost validation = [0.5249374]
# Cost validation = [0.52468469]
# Cost validation = [0.5244333]
# Cost validation = [0.52418322]
# Cost validation = [0.52393443]
# Cost validation = [0.52368695]
# Cost validation = [0.52344074]
# Cost validation = [0.52319581]
# Cost validation = [0.52295214]
# Cost validation = [0.52270973]
# Cost validation = [0.52246857]
# Cost validation = [0.52222865]
# Cost validation = [0.52198996]
# Cost validation = [0.52175249]
# Cost validation = [0.52151624]
# Cost validation = [0.52128119]
# Cost validation = [0.52104735]
# Cost validation = [0.52081469]
# Cost validation = [0.52058322]
# Cost validation = [0.52035293]
# Cost validation = [0.5201238]
# Cost validation = [0.51989583]
# Cost validation = [0.51966901]
# Cost validation = [0.51944334]
# Cost validation = [0.51921881]
# Cost validation = [0.5189954]
# Cost validation = [0.51877312]
# Cost validation = [0.51855195]
# Cost validation = [0.51833189]
# Cost validation = [0.51811293]
# Cost validation = [0.51789506]
# Cost validation = [0.51767828]
# Cost validation = [0.51746258]
# Cost validation = [0.51724795]
# Cost validation = [0.51703439]
# Cost validation = [0.51682188]
# Cost validation = [0.51661043]
# Cost validation = [0.51640002]
# Cost validation = [0.51619065]
# Cost validation = [0.51598232]
# Cost validation = [0.515775]
# Cost validation = [0.51556871]
# Cost validation = [0.51536343]
# Cost validation = [0.51515915]
# Cost validation = [0.51495588]
# Cost validation = [0.51475359]
# Cost validation = [0.5145523]
# Cost validation = [0.51435198]
# Cost validation = [0.51415264]
# Cost validation = [0.51395427]
# Cost validation = [0.51375686]
# Cost validation = [0.51356041]
# Cost validation = [0.51336491]
# Cost validation = [0.51317035]
# Cost validation = [0.51297673]
# Cost validation = [0.51278404]
# Cost validation = [0.51259228]
# Cost validation = [0.51240145]
# Cost validation = [0.51221152]
# Cost validation = [0.51202251]
# Cost validation = [0.51183441]
# Cost validation = [0.5116472]
# Cost validation = [0.51146088]
# Cost validation = [0.51127546]
# Cost validation = [0.51109091]
# Cost validation = [0.51090725]
# Cost validation = [0.51072445]
# Cost validation = [0.51054252]
# Cost validation = [0.51036146]
# Cost validation = [0.51018125]
# Cost validation = [0.51000189]
# Cost validation = [0.50982337]
# Cost validation = [0.5096457]
# Cost validation = [0.50946886]
# Cost validation = [0.50929286]
# Cost validation = [0.50911768]
# Cost validation = [0.50894332]
# Cost validation = [0.50876977]
# Cost validation = [0.50859704]
# Cost validation = [0.50842511]
# Cost validation = [0.50825398]
# Cost validation = [0.50808365]
# Cost validation = [0.50791411]
# Cost validation = [0.50774536]
# Cost validation = [0.50757739]
# Cost validation = [0.5074102]
# Cost validation = [0.50724378]
# Cost validation = [0.50707814]
# Cost validation = [0.50691325]
# Cost validation = [0.50674912]
# Cost validation = [0.50658575]
# Cost validation = [0.50642313]
# Cost validation = [0.50626126]
# Cost validation = [0.50610012]
# Cost validation = [0.50593973]
# Cost validation = [0.50578007]
# Cost validation = [0.50562113]
# Cost validation = [0.50546293]
# Cost validation = [0.50530544]
# Cost validation = [0.50514866]
# Cost validation = [0.5049926]
# Cost validation = [0.50483725]
# Cost validation = [0.5046826]
# Cost validation = [0.50452865]
# Cost validation = [0.5043754]
# Cost validation = [0.50422284]
# Cost validation = [0.50407097]
# Cost validation = [0.50391977]
# Cost validation = [0.50376926]
# Cost validation = [0.50361943]
# Cost validation = [0.50347027]
# Cost validation = [0.50332177]
# Cost validation = [0.50317394]
# Cost validation = [0.50302677]
# Cost validation = [0.50288025]
# Cost validation = [0.50273439]
# Cost validation = [0.50258918]
# Cost validation = [0.50244461]
# Cost validation = [0.50230069]
# Cost validation = [0.5021574]
# Cost validation = [0.50201475]
# Cost validation = [0.50187273]
# Cost validation = [0.50173133]
# Cost validation = [0.50159056]
# Cost validation = [0.50145041]
# Cost validation = [0.50131087]
# Cost validation = [0.50117195]
# Cost validation = [0.50103364]
# Cost validation = [0.50089593]
# Cost validation = [0.50075883]
# Cost validation = [0.50062233]
# Cost validation = [0.50048642]
# Cost validation = [0.5003511]
# Cost validation = [0.50021638]
# Cost validation = [0.50008224]
# Cost validation = [0.49994868]
# Cost validation = [0.4998157]
# Cost validation = [0.4996833]
# Cost validation = [0.49955147]
# Cost validation = [0.49942021]
# Cost validation = [0.49928952]
# Cost validation = [0.49915939]
# Cost validation = [0.49902982]
# Cost validation = [0.49890081]
# Cost validation = [0.49877235]
# Cost validation = [0.49864444]
# Cost validation = [0.49851708]
# Cost validation = [0.49839027]
# Cost validation = [0.49826399]
# Cost validation = [0.49813826]
# Cost validation = [0.49801306]
# Cost validation = [0.49788839]
# Cost validation = [0.49776426]
# Cost validation = [0.49764065]
# Cost validation = [0.49751756]
# Cost validation = [0.497395]
# Cost validation = [0.49727295]
# Cost validation = [0.49715142]
# Cost validation = [0.4970304]
# Cost validation = [0.49690989]
# Cost validation = [0.49678989]
# Cost validation = [0.49667039]
# Cost validation = [0.49655139]
# Cost validation = [0.4964329]
# Cost validation = [0.49631489]
# Cost validation = [0.49619738]
# Cost validation = [0.49608037]
# Cost validation = [0.49596383]
# Cost validation = [0.49584779]
# Cost validation = [0.49573222]
# Cost validation = [0.49561714]
# Cost validation = [0.49550253]
# Cost validation = [0.4953884]
# Cost validation = [0.49527474]
# Cost validation = [0.49516155]
# Cost validation = [0.49504882]
# Cost validation = [0.49493656]
# Cost validation = [0.49482476]
# Cost validation = [0.49471342]
# Cost validation = [0.49460254]
# Cost validation = [0.49449211]
# Cost validation = [0.49438213]
# Cost validation = [0.49427261]
# Cost validation = [0.49416353]
# Cost validation = [0.49405489]
# Cost validation = [0.4939467]
# Cost validation = [0.49383894]
# Cost validation = [0.49373162]
# Cost validation = [0.49362474]
# Cost validation = [0.49351829]
# Cost validation = [0.49341227]
# Cost validation = [0.49330668]
# Cost validation = [0.49320151]
# Cost validation = [0.49309677]
# Cost validation = [0.49299245]
# Cost validation = [0.49288855]
# Cost validation = [0.49278506]
# Cost validation = [0.49268199]
# Cost validation = [0.49257933]
# Cost validation = [0.49247708]
# Cost validation = [0.49237524]
# Cost validation = [0.4922738]
# Cost validation = [0.49217276]
# Cost validation = [0.49207213]
# Cost validation = [0.4919719]
# Cost validation = [0.49187206]
# Cost validation = [0.49177262]
# Cost validation = [0.49167357]
# Cost validation = [0.49157491]
# Cost validation = [0.49147664]
# Cost validation = [0.49137876]
# Cost validation = [0.49128126]
# Cost validation = [0.49118414]
# Cost validation = [0.49108741]
# Cost validation = [0.49099105]
# Cost validation = [0.49089507]
# Cost validation = [0.49079946]
# Cost validation = [0.49070422]
# Cost validation = [0.49060936]
# Cost validation = [0.49051486]
# Cost validation = [0.49042073]
# Cost validation = [0.49032697]
# Cost validation = [0.49023356]
# Cost validation = [0.49014052]
# Cost validation = [0.49004784]
# Cost validation = [0.48995551]
# Cost validation = [0.48986354]
# Cost validation = [0.48977192]
# Cost validation = [0.48968065]
# Cost validation = [0.48958973]
# Cost validation = [0.48949916]
# Cost validation = [0.48940894]
# Cost validation = [0.48931906]
# Cost validation = [0.48922952]
# Cost validation = [0.48914032]
# Cost validation = [0.48905146]
# Cost validation = [0.48896294]
# Cost validation = [0.48887475]
# Cost validation = [0.4887869]
# Cost validation = [0.48869937]
# Cost validation = [0.48861218]
# Cost validation = [0.48852532]
# Cost validation = [0.48843878]
# Cost validation = [0.48835256]
# Cost validation = [0.48826667]
# Cost validation = [0.4881811]
# Cost validation = [0.48809585]
# Cost validation = [0.48801092]
# Cost validation = [0.48792631]
# Cost validation = [0.48784201]
# Cost validation = [0.48775802]
# Cost validation = [0.48767434]
# Cost validation = [0.48759097]
# Cost validation = [0.48750792]
# Cost validation = [0.48742516]
# Cost validation = [0.48734272]
# Cost validation = [0.48726058]
# Cost validation = [0.48717873]
# Cost validation = [0.48709719]
# Cost validation = [0.48701595]
# Cost validation = [0.48693501]
# Cost validation = [0.48685436]
# Cost validation = [0.486774]
# Cost validation = [0.48669394]
# Cost validation = [0.48661417]
# Cost validation = [0.48653469]
# Cost validation = [0.4864555]
# Cost validation = [0.48637659]
# Cost validation = [0.48629797]
# Cost validation = [0.48621963]
# Cost validation = [0.48614158]
# Cost validation = [0.48606381]
# Cost validation = [0.48598631]
# Cost validation = [0.4859091]
# Cost validation = [0.48583216]
# Cost validation = [0.48575549]
# Cost validation = [0.4856791]
# Cost validation = [0.48560299]
# Cost validation = [0.48552714]
# Cost validation = [0.48545156]
# Cost validation = [0.48537625]
# Cost validation = [0.48530121]
# Cost validation = [0.48522644]
# Cost validation = [0.48515193]
# Cost validation = [0.48507768]
# Cost validation = [0.48500369]
# Cost validation = [0.48492996]
# Cost validation = [0.4848565]
# Cost validation = [0.48478329]
# Cost validation = [0.48471033]
# Cost validation = [0.48463763]
# Cost validation = [0.48456519]
# Cost validation = [0.484493]
# Cost validation = [0.48442106]
# Cost validation = [0.48434937]
# Cost validation = [0.48427792]
# Cost validation = [0.48420673]
# Cost validation = [0.48413578]
# Cost validation = [0.48406508]
# Cost validation = [0.48399462]
# Cost validation = [0.4839244]
# Cost validation = [0.48385443]
# Cost validation = [0.48378469]
# Cost validation = [0.4837152]
# Cost validation = [0.48364594]
# Cost validation = [0.48357691]
# Cost validation = [0.48350813]
# Cost validation = [0.48343958]
# Cost validation = [0.48337126]
# Cost validation = [0.48330317]
# Cost validation = [0.48323531]
# Cost validation = [0.48316769]
# Cost validation = [0.48310029]
# Cost validation = [0.48303312]
# Cost validation = [0.48296617]
# Cost validation = [0.48289945]
# Cost validation = [0.48283296]
# Cost validation = [0.48276668]
# Cost validation = [0.48270063]
# Cost validation = [0.4826348]
# Cost validation = [0.48256919]
# Cost validation = [0.4825038]
# Cost validation = [0.48243863]
# Cost validation = [0.48237367]
# Cost validation = [0.48230893]
# Cost validation = [0.4822444]
# Cost validation = [0.48218008]
# Cost validation = [0.48211598]
# Cost validation = [0.48205209]
# Cost validation = [0.48198841]
# Cost validation = [0.48192493]
# Cost validation = [0.48186167]
# Cost validation = [0.48179861]
# Cost validation = [0.48173576]
# Cost validation = [0.48167312]
# Cost validation = [0.48161067]
# Cost validation = [0.48154844]
# Cost validation = [0.4814864]
# Cost validation = [0.48142456]
# Cost validation = [0.48136293]
# Cost validation = [0.48130149]
# Cost validation = [0.48124025]
# Cost validation = [0.48117921]
# Cost validation = [0.48111837]
# Cost validation = [0.48105772]
# Cost validation = [0.48099726]
# Cost validation = [0.480937]
# Cost validation = [0.48087694]
# Cost validation = [0.48081706]
# Cost validation = [0.48075737]
# Cost validation = [0.48069788]
# Cost validation = [0.48063857]
# Cost validation = [0.48057945]
# Cost validation = [0.48052052]
# Cost validation = [0.48046177]
# Cost validation = [0.48040321]
# Cost validation = [0.48034483]
# Cost validation = [0.48028664]
# Cost validation = [0.48022863]
# Cost validation = [0.4801708]
# Cost validation = [0.48011315]
# Cost validation = [0.48005569]
# Cost validation = [0.4799984]
# Cost validation = [0.47994129]
# Cost validation = [0.47988436]
# Cost validation = [0.4798276]
# Cost validation = [0.47977102]
# Cost validation = [0.47971462]
# Cost validation = [0.47965839]
# Cost validation = [0.47960233]
# Cost validation = [0.47954645]
# Cost validation = [0.47949073]
# Cost validation = [0.47943519]
# Cost validation = [0.47937982]
# Cost validation = [0.47932462]
# Cost validation = [0.47926959]
# Cost validation = [0.47921472]
# Cost validation = [0.47916002]
# Cost validation = [0.47910549]
# Cost validation = [0.47905112]
# Cost validation = [0.47899692]
# Cost validation = [0.47894288]
# Cost validation = [0.47888901]
# Cost validation = [0.47883529]
# Cost validation = [0.47878174]
# Cost validation = [0.47872835]
# Cost validation = [0.47867512]
# Cost validation = [0.47862205]
# Cost validation = [0.47856914]
# Cost validation = [0.47851639]
# Cost validation = [0.47846379]
# Cost validation = [0.47841135]
# Cost validation = [0.47835906]
# Cost validation = [0.47830693]
# Cost validation = [0.47825496]
# Cost validation = [0.47820314]
# Cost validation = [0.47815147]
# Cost validation = [0.47809995]
# Cost validation = [0.47804859]
# Cost validation = [0.47799737]
# Cost validation = [0.47794631]
# Cost validation = [0.47789539]
# Cost validation = [0.47784463]
# Cost validation = [0.47779401]
# Cost validation = [0.47774354]
# Cost validation = [0.47769321]
# Cost validation = [0.47764304]
# Cost validation = [0.477593]
# Cost validation = [0.47754312]
# Cost validation = [0.47749337]
# Cost validation = [0.47744377]
# Cost validation = [0.47739432]
# Cost validation = [0.477345]
# Cost validation = [0.47729583]
# Cost validation = [0.4772468]
# Cost validation = [0.4771979]
# Cost validation = [0.47714915]
# Cost validation = [0.47710054]
# Cost validation = [0.47705206]
# Cost validation = [0.47700372]
# Cost validation = [0.47695552]
# Cost validation = [0.47690746]
# Cost validation = [0.47685953]
# Cost validation = [0.47681174]
# Cost validation = [0.47676408]
# Cost validation = [0.47671656]
# Cost validation = [0.47666917]
# Cost validation = [0.47662191]
# Cost validation = [0.47657479]
# Cost validation = [0.47652779]
# Cost validation = [0.47648093]
# Cost validation = [0.4764342]
# Cost validation = [0.4763876]
# Cost validation = [0.47634112]
# Cost validation = [0.47629478]
# Cost validation = [0.47624857]
# Cost validation = [0.47620248]
# Cost validation = [0.47615652]
# Cost validation = [0.47611069]
# Cost validation = [0.47606498]
# Cost validation = [0.4760194]
# Cost validation = [0.47597394]
# Cost validation = [0.47592861]
# Cost validation = [0.4758834]
# Cost validation = [0.47583831]
# Cost validation = [0.47579335]
# Cost validation = [0.47574851]
# Cost validation = [0.47570379]
# Cost validation = [0.47565919]
# Cost validation = [0.47561472]
# Cost validation = [0.47557036]
# Cost validation = [0.47552612]
# Cost validation = [0.475482]
# Cost validation = [0.47543801]
# Cost validation = [0.47539412]
# Cost validation = [0.47535036]
# Cost validation = [0.47530671]
# Cost validation = [0.47526318]
# Cost validation = [0.47521977]
# Cost validation = [0.47517647]
# Cost validation = [0.47513329]
# Cost validation = [0.47509022]
# Cost validation = [0.47504726]
# Cost validation = [0.47500442]
# Cost validation = [0.4749617]
# Cost validation = [0.47491908]
# Cost validation = [0.47487658]
# Cost validation = [0.47483419]
# Cost validation = [0.47479191]
# Cost validation = [0.47474974]
# Cost validation = [0.47470768]
# Cost validation = [0.47466573]
# Cost validation = [0.47462389]
# Cost validation = [0.47458216]
# Cost validation = [0.47454053]
# Cost validation = [0.47449902]
# Cost validation = [0.47445761]
# Cost validation = [0.47441631]
# Cost validation = [0.47437512]
# Cost validation = [0.47433403]
# Cost validation = [0.47429305]
# Cost validation = [0.47425217]
# Cost validation = [0.4742114]
# Cost validation = [0.47417073]
# Cost validation = [0.47413017]
# Cost validation = [0.47408971]
# Cost validation = [0.47404936]
# Cost validation = [0.4740091]
# Cost validation = [0.47396895]
# Cost validation = [0.4739289]
# Cost validation = [0.47388895]
# Cost validation = [0.4738491]
# Cost validation = [0.47380936]
# Cost validation = [0.47376971]
# Cost validation = [0.47373016]
# Cost validation = [0.47369072]
# Cost validation = [0.47365137]
# Cost validation = [0.47361212]
# Cost validation = [0.47357297]
# Cost validation = [0.47353391]
# Cost validation = [0.47349496]
# Cost validation = [0.4734561]
# Cost validation = [0.47341733]
# Cost validation = [0.47337866]
# Cost validation = [0.47334009]
# Cost validation = [0.47330162]
# Cost validation = [0.47326324]
# Cost validation = [0.47322495]
# Cost validation = [0.47318676]
# Cost validation = [0.47314866]
# Cost validation = [0.47311065]
# Cost validation = [0.47307274]
# Cost validation = [0.47303492]
# Cost validation = [0.4729972]
# Cost validation = [0.47295956]
# Cost validation = [0.47292202]
# Cost validation = [0.47288456]
# Cost validation = [0.4728472]
# Cost validation = [0.47280993]
# Cost validation = [0.47277275]
# Cost validation = [0.47273566]
# Cost validation = [0.47269866]
# Cost validation = [0.47266175]
# Cost validation = [0.47262492]
# Cost validation = [0.47258819]
# Cost validation = [0.47255154]
# Cost validation = [0.47251498]
# Cost validation = [0.47247851]
# Cost validation = [0.47244212]
# Cost validation = [0.47240582]
# Cost validation = [0.47236961]
# Cost validation = [0.47233348]
# Cost validation = [0.47229744]
# Cost validation = [0.47226148]
# Cost validation = [0.47222561]
# Cost validation = [0.47218983]
# Cost validation = [0.47215413]
# Cost validation = [0.47211851]
# Cost validation = [0.47208297]
# Cost validation = [0.47204752]
# Cost validation = [0.47201215]
# Cost validation = [0.47197687]
# Cost validation = [0.47194166]
# Cost validation = [0.47190654]
# Cost validation = [0.4718715]
# Cost validation = [0.47183654]
# Cost validation = [0.47180167]
# Cost validation = [0.47176687]
# Cost validation = [0.47173215]
# Cost validation = [0.47169752]
# Cost validation = [0.47166296]
# Cost validation = [0.47162848]
# Cost validation = [0.47159409]
# Cost validation = [0.47155977]
# Cost validation = [0.47152553]
# Cost validation = [0.47149136]
# Cost validation = [0.47145728]
# Cost validation = [0.47142327]
# Cost validation = [0.47138935]
# Cost validation = [0.47135549]
# Cost validation = [0.47132172]
# Cost validation = [0.47128802]
# Cost validation = [0.4712544]
# Cost validation = [0.47122085]
# Cost validation = [0.47118738]
# Cost validation = [0.47115399]
# Cost validation = [0.47112067]
# Cost validation = [0.47108742]
# Cost validation = [0.47105425]
# Cost validation = [0.47102115]
# Cost validation = [0.47098813]
# Cost validation = [0.47095518]
# Cost validation = [0.47092231]
# Cost validation = [0.4708895]
# Cost validation = [0.47085677]
# Cost validation = [0.47082412]
# Cost validation = [0.47079153]
# Cost validation = [0.47075902]
# Cost validation = [0.47072658]
# Cost validation = [0.47069421]
# Cost validation = [0.47066191]
# Cost validation = [0.47062968]
# Cost validation = [0.47059753]
# Cost validation = [0.47056544]
# Cost validation = [0.47053343]
# Cost validation = [0.47050148]
# Cost validation = [0.4704696]
# Cost validation = [0.4704378]
# Cost validation = [0.47040606]
# Cost validation = [0.47037439]
# Cost validation = [0.47034279]
# Cost validation = [0.47031126]
# Cost validation = [0.4702798]
# Cost validation = [0.4702484]
# Cost validation = [0.47021707]
# Cost validation = [0.47018581]
# Cost validation = [0.47015462]
# Cost validation = [0.47012349]
# Cost validation = [0.47009243]
# Cost validation = [0.47006144]
# Cost validation = [0.47003051]
# Cost validation = [0.46999965]
# Cost validation = [0.46996886]
# Cost validation = [0.46993813]
# Cost validation = [0.46990746]
# Cost validation = [0.46987686]
# Cost validation = [0.46984633]
# Cost validation = [0.46981586]
# Cost validation = [0.46978545]
# Cost validation = [0.46975511]
# Cost validation = [0.46972484]
# Cost validation = [0.46969462]
# Cost validation = [0.46966447]
# Cost validation = [0.46963438]
# Cost validation = [0.46960436]
# Cost validation = [0.4695744]
# Cost validation = [0.4695445]
# Cost validation = [0.46951466]
# Cost validation = [0.46948489]
# Cost validation = [0.46945517]
# Cost validation = [0.46942552]
# Cost validation = [0.46939593]
# Cost validation = [0.4693664]
# Cost validation = [0.46933694]
# Cost validation = [0.46930753]
# Cost validation = [0.46927818]
# Cost validation = [0.4692489]
# Cost validation = [0.46921967]
# Cost validation = [0.46919051]
# Cost validation = [0.4691614]
# Cost validation = [0.46913235]
# Cost validation = [0.46910337]
# Cost validation = [0.46907444]
# Cost validation = [0.46904557]
# Cost validation = [0.46901676]
# Cost validation = [0.46898801]
# Cost validation = [0.46895931]
# Cost validation = [0.46893068]
# Cost validation = [0.4689021]
# Cost validation = [0.46887358]
# Cost validation = [0.46884512]
# Cost validation = [0.46881671]
# Cost validation = [0.46878836]
# Cost validation = [0.46876007]
# Cost validation = [0.46873184]
# Cost validation = [0.46870366]
# Cost validation = [0.46867554]
# Cost validation = [0.46864747]
# Cost validation = [0.46861946]
# Cost validation = [0.46859151]
# Cost validation = [0.46856361]
# Cost validation = [0.46853577]
# Cost validation = [0.46850798]
# Cost validation = [0.46848024]
# Cost validation = [0.46845257]
# Cost validation = [0.46842494]
# Cost validation = [0.46839737]
# Cost validation = [0.46836986]
# Cost validation = [0.4683424]
# Cost validation = [0.46831499]
# Cost validation = [0.46828764]
# Cost validation = [0.46826034]
# Cost validation = [0.46823309]
# Cost validation = [0.4682059]
# Cost validation = [0.46817876]
# Cost validation = [0.46815167]
# Cost validation = [0.46812464]
# Cost validation = [0.46809766]
# Cost validation = [0.46807073]
# Cost validation = [0.46804385]
# Cost validation = [0.46801702]
# Cost validation = [0.46799025]
# Cost validation = [0.46796353]
# Cost validation = [0.46793686]
# Cost validation = [0.46791024]
# Cost validation = [0.46788367]
# Cost validation = [0.46785715]
# Cost validation = [0.46783068]
# Cost validation = [0.46780427]
# Cost validation = [0.4677779]
# Cost validation = [0.46775159]
# Cost validation = [0.46772532]
# Cost validation = [0.4676991]
# Cost validation = [0.46767294]
# Cost validation = [0.46764682]
# Cost validation = [0.46762076]
# Cost validation = [0.46759474]
# Cost validation = [0.46756877]
# Cost validation = [0.46754285]
# Cost validation = [0.46751698]
# Cost validation = [0.46749116]
# Cost validation = [0.46746538]
# Cost validation = [0.46743966]
# Cost validation = [0.46741398]
# Cost validation = [0.46738835]
# Cost validation = [0.46736277]
# Cost validation = [0.46733724]
# Cost validation = [0.46731175]
# Cost validation = [0.46728631]
# Cost validation = [0.46726092]
# Cost validation = [0.46723558]
# Cost validation = [0.46721028]
# Cost validation = [0.46718503]
# Cost validation = [0.46715983]
# Cost validation = [0.46713467]
# Cost validation = [0.46710956]
# Cost validation = [0.4670845]
# Cost validation = [0.46705948]
# Cost validation = [0.4670345]
# Cost validation = [0.46700958]
# Cost validation = [0.4669847]
# Cost validation = [0.46695986]
# Cost validation = [0.46693507]
# Cost validation = [0.46691033]
# Cost validation = [0.46688563]
# Cost validation = [0.46686097]
# Cost validation = [0.46683636]
# Cost validation = [0.46681179]
# Cost validation = [0.46678727]
# Cost validation = [0.4667628]
# Cost validation = [0.46673836]
# Cost validation = [0.46671397]
# Cost validation = [0.46668963]
# Cost validation = [0.46666533]
# Cost validation = [0.46664107]
# Cost validation = [0.46661686]
# Cost validation = [0.46659269]
# Cost validation = [0.46656856]
# Cost validation = [0.46654448]
# Cost validation = [0.46652044]
# Cost validation = [0.46649644]
# Cost validation = [0.46647248]
# Cost validation = [0.46644857]
# Cost validation = [0.4664247]
# Cost validation = [0.46640087]
# Cost validation = [0.46637709]
# Cost validation = [0.46635334]
# Cost validation = [0.46632964]
# Cost validation = [0.46630598]
# Cost validation = [0.46628236]
# Cost validation = [0.46625878]
# Cost validation = [0.46623525]
# Cost validation = [0.46621176]
# Cost validation = [0.4661883]
# Cost validation = [0.46616489]
# Cost validation = [0.46614152]
# Cost validation = [0.46611819]
# Cost validation = [0.4660949]
# Cost validation = [0.46607165]
# Cost validation = [0.46604844]
# Cost validation = [0.46602528]
# Cost validation = [0.46600215]
# Cost validation = [0.46597906]
# Cost validation = [0.46595601]
# Cost validation = [0.46593301]
# Cost validation = [0.46591004]
# Cost validation = [0.46588711]
# Cost validation = [0.46586422]
# Cost validation = [0.46584137]
# Cost validation = [0.46581856]
# Cost validation = [0.46579579]
# Cost validation = [0.46577306]
# Cost validation = [0.46575036]
# Cost validation = [0.46572771]
# Cost validation = [0.46570509]
# Cost validation = [0.46568251]
# Cost validation = [0.46565998]
# Cost validation = [0.46563747]
# Cost validation = [0.46561501]
# Cost validation = [0.46559259]
# Cost validation = [0.4655702]
# Cost validation = [0.46554785]
# Cost validation = [0.46552554]
# Cost validation = [0.46550327]
# Cost validation = [0.46548103]
# Cost validation = [0.46545884]
# Cost validation = [0.46543667]
# Cost validation = [0.46541455]
# Cost validation = [0.46539246]
# Cost validation = [0.46537041]
# Cost validation = [0.4653484]
# Cost validation = [0.46532643]
# Cost validation = [0.46530449]
# Cost validation = [0.46528258]
# Cost validation = [0.46526072]
# Cost validation = [0.46523889]
# Cost validation = [0.46521709]
# Cost validation = [0.46519534]
# Cost validation = [0.46517361]
# Cost validation = [0.46515193]
# Cost validation = [0.46513028]
# Cost validation = [0.46510867]
# Cost validation = [0.46508709]
# Cost validation = [0.46506554]
# Cost validation = [0.46504404]
# Cost validation = [0.46502256]
# Cost validation = [0.46500113]
# Cost validation = [0.46497973]
# Cost validation = [0.46495836]
# Cost validation = [0.46493703]
# Cost validation = [0.46491573]
# Cost validation = [0.46489447]
# Cost validation = [0.46487324]
# Cost validation = [0.46485205]
# Cost validation = [0.46483089]
# Cost validation = [0.46480976]
# Cost validation = [0.46478867]
# Cost validation = [0.46476762]
# Cost validation = [0.46474659]
# Cost validation = [0.46472561]
# Cost validation = [0.46470465]
# Cost validation = [0.46468373]
# Cost validation = [0.46466284]
# Cost validation = [0.46464199]
# Cost validation = [0.46462117]
# Cost validation = [0.46460038]
# Cost validation = [0.46457963]
# Cost validation = [0.46455891]
# Cost validation = [0.46453822]
# Cost validation = [0.46451757]
# Cost validation = [0.46449695]
# Cost validation = [0.46447636]
# Cost validation = [0.4644558]
# Cost validation = [0.46443528]
# Cost validation = [0.46441479]
# Cost validation = [0.46439433]
# Cost validation = [0.46437391]
# Cost validation = [0.46435351]
# Cost validation = [0.46433315]
# Cost validation = [0.46431282]
# Cost validation = [0.46429253]
# Cost validation = [0.46427226]
# Cost validation = [0.46425203]
# Cost validation = [0.46423183]
# Cost validation = [0.46421166]
# Cost validation = [0.46419152]
# Cost validation = [0.46417141]
# Cost validation = [0.46415133]
# Cost validation = [0.46413129]
# Cost validation = [0.46411128]
# Cost validation = [0.46409129]
# Cost validation = [0.46407134]
# Cost validation = [0.46405142]
# Cost validation = [0.46403153]
# Cost validation = [0.46401168]
# Cost validation = [0.46399185]
# Cost validation = [0.46397205]
# Cost validation = [0.46395228]
# Cost validation = [0.46393255]
# Cost validation = [0.46391284]
# Cost validation = [0.46389317]
# Cost validation = [0.46387352]
# Cost validation = [0.46385391]
# Cost validation = [0.46383432]
# Cost validation = [0.46381477]
# Cost validation = [0.46379524]
# Cost validation = [0.46377575]
# Cost validation = [0.46375628]
# Cost validation = [0.46373684]
# Cost validation = [0.46371744]
# Cost validation = [0.46369806]
# Cost validation = [0.46367871]
# Cost validation = [0.4636594]
# Cost validation = [0.46364011]
# Cost validation = [0.46362085]
# Cost validation = [0.46360162]
# Cost validation = [0.46358241]
# Cost validation = [0.46356324]
# Cost validation = [0.4635441]
# Cost validation = [0.46352498]
# Cost validation = [0.4635059]
# Cost validation = [0.46348684]
# Cost validation = [0.46346781]
# Cost validation = [0.46344881]
# Cost validation = [0.46342984]
# Cost validation = [0.46341089]
# Cost validation = [0.46339198]
# Cost validation = [0.46337309]
# Cost validation = [0.46335423]
# Cost validation = [0.4633354]
# Cost validation = [0.4633166]
# Cost validation = [0.46329782]
# Cost validation = [0.46327907]
# Cost validation = [0.46326035]
# Cost validation = [0.46324166]
# Cost validation = [0.463223]
# Cost validation = [0.46320436]
# Cost validation = [0.46318575]
# Cost validation = [0.46316717]
# Cost validation = [0.46314861]
# Cost validation = [0.46313008]
# Cost validation = [0.46311158]
# Cost validation = [0.46309311]
# Cost validation = [0.46307466]
# Cost validation = [0.46305624]
# Cost validation = [0.46303785]
# Cost validation = [0.46301949]
# Cost validation = [0.46300115]
# Cost validation = [0.46298284]
# Cost validation = [0.46296455]
# Cost validation = [0.46294629]
# Cost validation = [0.46292806]
# Cost validation = [0.46290985]
# Cost validation = [0.46289167]
# Cost validation = [0.46287352]
# Cost validation = [0.46285539]
# Cost validation = [0.46283729]
# Cost validation = [0.46281921]
# Cost validation = [0.46280117]
# Cost validation = [0.46278314]
# Cost validation = [0.46276514]
# Cost validation = [0.46274717]
# Cost validation = [0.46272923]
# Cost validation = [0.46271131]
# Cost validation = [0.46269341]
# Cost validation = [0.46267554]
# Cost validation = [0.4626577]
# Cost validation = [0.46263988]
# Cost validation = [0.46262209]
# Cost validation = [0.46260432]
# Cost validation = [0.46258658]
# Cost validation = [0.46256886]
# Cost validation = [0.46255117]
# Cost validation = [0.4625335]
# Cost validation = [0.46251586]
# Cost validation = [0.46249825]
# Cost validation = [0.46248065]
# Cost validation = [0.46246309]
# Cost validation = [0.46244554]
# Cost validation = [0.46242803]
# Cost validation = [0.46241053]
# Cost validation = [0.46239306]
# Cost validation = [0.46237562]
# Cost validation = [0.4623582]
# Cost validation = [0.4623408]
# Cost validation = [0.46232343]
# Cost validation = [0.46230609]
# Cost validation = [0.46228876]
# Cost validation = [0.46227146]
# Cost validation = [0.46225419]
# Cost validation = [0.46223694]
# Cost validation = [0.46221971]
# Cost validation = [0.46220251]
# Cost validation = [0.46218533]
# Cost validation = [0.46216818]
# Cost validation = [0.46215104]
# Cost validation = [0.46213394]
# Cost validation = [0.46211685]
# Cost validation = [0.46209979]
# Cost validation = [0.46208275]
# Cost validation = [0.46206574]
# Cost validation = [0.46204875]
# Cost validation = [0.46203178]
# Cost validation = [0.46201484]
# Cost validation = [0.46199792]
# Cost validation = [0.46198102]
# Cost validation = [0.46196415]
# Cost validation = [0.46194729]
# Cost validation = [0.46193047]
# Cost validation = [0.46191366]
# Cost validation = [0.46189688]
# Cost validation = [0.46188012]
# Cost validation = [0.46186338]
# Cost validation = [0.46184667]
# Cost validation = [0.46182997]
# Cost validation = [0.4618133]
# Cost validation = [0.46179666]
# Cost validation = [0.46178003]
# Cost validation = [0.46176343]
# Cost validation = [0.46174685]
# Cost validation = [0.46173029]
# Cost validation = [0.46171376]
# Cost validation = [0.46169725]
# Cost validation = [0.46168076]
# Cost validation = [0.46166429]
# Cost validation = [0.46164784]
# Cost validation = [0.46163142]
# Cost validation = [0.46161501]
# Cost validation = [0.46159863]
# Cost validation = [0.46158227]
# Cost validation = [0.46156594]
# Cost validation = [0.46154962]
# Cost validation = [0.46153333]
# Cost validation = [0.46151706]
# Cost validation = [0.46150081]
# Cost validation = [0.46148458]
# Cost validation = [0.46146837]
# Cost validation = [0.46145218]
# Cost validation = [0.46143602]
# Cost validation = [0.46141988]
# Cost validation = [0.46140375]
# Cost validation = [0.46138765]
# Cost validation = [0.46137157]
# Cost validation = [0.46135551]
# Cost validation = [0.46133948]
# Cost validation = [0.46132346]
# Cost validation = [0.46130746]
# Cost validation = [0.46129149]
# Cost validation = [0.46127554]
# Cost validation = [0.4612596]
# Cost validation = [0.46124369]
# Cost validation = [0.4612278]
# Cost validation = [0.46121193]
# Cost validation = [0.46119608]
# Cost validation = [0.46118025]
# Cost validation = [0.46116444]
# Cost validation = [0.46114865]
# Cost validation = [0.46113288]
# Cost validation = [0.46111714]
# Cost validation = [0.46110141]
# Cost validation = [0.4610857]
# Cost validation = [0.46107002]
# Cost validation = [0.46105435]
# Cost validation = [0.4610387]
# Cost validation = [0.46102308]
# Cost validation = [0.46100747]
# Cost validation = [0.46099188]
# Cost validation = [0.46097632]
# Cost validation = [0.46096077]
# Cost validation = [0.46094524]
# Cost validation = [0.46092974]
# Cost validation = [0.46091425]
# Cost validation = [0.46089878]
# Cost validation = [0.46088334]
# Cost validation = [0.46086791]
# Cost validation = [0.4608525]
# Cost validation = [0.46083711]
# Cost validation = [0.46082174]
# Cost validation = [0.46080639]
# Cost validation = [0.46079106]
# Cost validation = [0.46077575]
# Cost validation = [0.46076046]
# Cost validation = [0.46074519]
# Cost validation = [0.46072994]
# Cost validation = [0.4607147]
# Cost validation = [0.46069949]
# Cost validation = [0.46068429]
# Cost validation = [0.46066912]
# Cost validation = [0.46065396]
# Cost validation = [0.46063882]
# Cost validation = [0.4606237]
# Cost validation = [0.4606086]
# Cost validation = [0.46059352]
# Cost validation = [0.46057846]
# Cost validation = [0.46056342]
# Cost validation = [0.46054839]
# Cost validation = [0.46053338]
# Cost validation = [0.4605184]
# Cost validation = [0.46050343]
# Cost validation = [0.46048848]
# Cost validation = [0.46047355]
# Cost validation = [0.46045863]
# Cost validation = [0.46044374]
# Cost validation = [0.46042886]
# Cost validation = [0.460414]
# Cost validation = [0.46039916]
# Cost validation = [0.46038434]
# Cost validation = [0.46036954]
# Cost validation = [0.46035475]
# Cost validation = [0.46033999]
# Cost validation = [0.46032524]
# Cost validation = [0.46031051]
# Cost validation = [0.46029579]
# Cost validation = [0.4602811]
# Cost validation = [0.46026642]
# Cost validation = [0.46025176]
# Cost validation = [0.46023712]
# Cost validation = [0.4602225]
# Cost validation = [0.46020789]
# Cost validation = [0.46019331]
# Cost validation = [0.46017874]
# Cost validation = [0.46016418]
# Cost validation = [0.46014965]
# Cost validation = [0.46013513]
# Cost validation = [0.46012063]
# Cost validation = [0.46010615]
# Cost validation = [0.46009169]
# Cost validation = [0.46007724]
# Cost validation = [0.46006281]
# Cost validation = [0.4600484]
# Cost validation = [0.46003401]
# Cost validation = [0.46001963]
# Cost validation = [0.46000527]
# Cost validation = [0.45999093]
# Cost validation = [0.4599766]
# Cost validation = [0.45996229]
# Cost validation = [0.459948]
# Cost validation = [0.45993373]
# Cost validation = [0.45991947]
# Cost validation = [0.45990523]
# Cost validation = [0.45989101]
# Cost validation = [0.4598768]
# Cost validation = [0.45986261]
# Cost validation = [0.45984844]
# Cost validation = [0.45983428]
# Cost validation = [0.45982014]
# Cost validation = [0.45980602]
# Cost validation = [0.45979192]
# Cost validation = [0.45977783]
# Cost validation = [0.45976376]
# Cost validation = [0.4597497]
# Cost validation = [0.45973566]
# Cost validation = [0.45972164]
# Cost validation = [0.45970763]
# Cost validation = [0.45969364]
# Cost validation = [0.45967967]
# Cost validation = [0.45966572]
# Cost validation = [0.45965178]
# Cost validation = [0.45963785]
# Cost validation = [0.45962394]
# Cost validation = [0.45961005]
# Cost validation = [0.45959618]
# Cost validation = [0.45958232]
# Cost validation = [0.45956848]
# Cost validation = [0.45955465]
# Cost validation = [0.45954084]
# Cost validation = [0.45952705]
# Cost validation = [0.45951327]
# Cost validation = [0.45949951]
# Cost validation = [0.45948576]
# Cost validation = [0.45947203]
# Cost validation = [0.45945831]
# Cost validation = [0.45944462]
# Cost validation = [0.45943093]
# Cost validation = [0.45941727]
# Cost validation = [0.45940362]
# Cost validation = [0.45938998]
# Cost validation = [0.45937636]
# Cost validation = [0.45936276]
# Cost validation = [0.45934917]
# Cost validation = [0.45933559]
# Cost validation = [0.45932204]
# Cost validation = [0.4593085]
# Cost validation = [0.45929497]
# Cost validation = [0.45928146]
# Cost validation = [0.45926796]
# Cost validation = [0.45925448]
# Cost validation = [0.45924102]
# Cost validation = [0.45922757]
# Cost validation = [0.45921414]
# Cost validation = [0.45920072]
# Cost validation = [0.45918731]
# Cost validation = [0.45917393]
# Cost validation = [0.45916055]
# Cost validation = [0.45914719]
# Cost validation = [0.45913385]
# Cost validation = [0.45912052]
# Cost validation = [0.45910721]
# Cost validation = [0.45909391]
# Cost validation = [0.45908063]
# Cost validation = [0.45906736]
# Cost validation = [0.45905411]
# Cost validation = [0.45904087]
# Cost validation = [0.45902765]
# Cost validation = [0.45901444]
# Cost validation = [0.45900125]
# Cost validation = [0.45898807]
# Cost validation = [0.45897491]
# Cost validation = [0.45896176]
# Cost validation = [0.45894862]
# Cost validation = [0.4589355]
# Cost validation = [0.4589224]
# Cost validation = [0.45890931]
# Cost validation = [0.45889623]
# Cost validation = [0.45888317]
# Cost validation = [0.45887013]
# Cost validation = [0.45885709]
# Cost validation = [0.45884408]
# Cost validation = [0.45883107]
# Cost validation = [0.45881808]
# Cost validation = [0.45880511]
# Cost validation = [0.45879215]
# ...
# Cost validation = [0.45424521]
# Cost validation = [0.45423655]
# Cost validation = [0.45422789]
# Cost validation = [0.45421924]
# Cost validation = [0.4542106]
# Cost validation = [0.45420196]
# Cost validation = [0.45419333]
# Cost validation = [0.45418471]
# Cost validation = [0.4541761]
# Cost validation = [0.45416749]
# Cost validation = [0.45415888]
# Cost validation = [0.45415029]
# Cost validation = [0.4541417]
# Cost validation = [0.45413312]
# Cost validation = [0.45412454]
# Cost validation = [0.45411598]
# Cost validation = [0.45410741]
# Cost validation = [0.45409886]
# Cost validation = [0.45409031]
# Cost validation = [0.45408177]
# Cost validation = [0.45407323]
# Cost validation = [0.45406471]
# Cost validation = [0.45405619]
# Cost validation = [0.45404767]
# Cost validation = [0.45403916]
# Cost validation = [0.45403066]
# Cost validation = [0.45402217]
# Cost validation = [0.45401368]
# Cost validation = [0.4540052]
# Cost validation = [0.45399672]
# Cost validation = [0.45398825]
# Cost validation = [0.45397979]
# Cost validation = [0.45397134]
# Cost validation = [0.45396289]
# Cost validation = [0.45395445]
# Cost validation = [0.45394601]
# Cost validation = [0.45393758]
# Cost validation = [0.45392916]
# Cost validation = [0.45392075]
# Cost validation = [0.45391234]
# Cost validation = [0.45390394]
# Cost validation = [0.45389554]
# Cost validation = [0.45388715]
# Cost validation = [0.45387877]
# Cost validation = [0.45387039]
# Cost validation = [0.45386202]
# Cost validation = [0.45385366]
# Cost validation = [0.4538453]
# Cost validation = [0.45383695]
# Cost validation = [0.45382861]
# Cost validation = [0.45382027]
# Cost validation = [0.45381194]
# Cost validation = [0.45380361]
# Cost validation = [0.45379529]
# Cost validation = [0.45378698]
# Cost validation = [0.45377867]
# Cost validation = [0.45377038]
# Cost validation = [0.45376208]
# Cost validation = [0.4537538]
# Cost validation = [0.45374552]
# Cost validation = [0.45373724]
# Cost validation = [0.45372897]
# Cost validation = [0.45372071]
# Cost validation = [0.45371246]
# Cost validation = [0.45370421]
# Cost validation = [0.45369597]
# Cost validation = [0.45368773]
# Cost validation = [0.4536795]
# Cost validation = [0.45367128]
# Cost validation = [0.45366306]
# Cost validation = [0.45365485]
# Cost validation = [0.45364665]
# Cost validation = [0.45363845]
# Cost validation = [0.45363025]
# Cost validation = [0.45362207]
# Cost validation = [0.45361389]
# Cost validation = [0.45360572]
# Cost validation = [0.45359755]
# Cost validation = [0.45358939]
# Cost validation = [0.45358123]
# Cost validation = [0.45357308]
# Cost validation = [0.45356494]
# Cost validation = [0.4535568]
# Cost validation = [0.45354867]
# Cost validation = [0.45354055]
# Cost validation = [0.45353243]
# Cost validation = [0.45352432]
# Cost validation = [0.45351621]
# Cost validation = [0.45350811]
# Cost validation = [0.45350002]
# Cost validation = [0.45349193]
# Cost validation = [0.45348385]
# Cost validation = [0.45347578]
# Cost validation = [0.45346771]
# Cost validation = [0.45345964]
# Cost validation = [0.45345159]
# Cost validation = [0.45344354]
# Cost validation = [0.45343549]
# Cost validation = [0.45342745]
# Cost validation = [0.45341942]
# Cost validation = [0.45341139]
# Cost validation = [0.45340337]
# Cost validation = [0.45339536]
# Cost validation = [0.45338735]
# Cost validation = [0.45337935]
# Cost validation = [0.45337135]
# Cost validation = [0.45336336]
# Cost validation = [0.45335537]
# Cost validation = [0.45334739]
# Cost validation = [0.45333942]
# Cost validation = [0.45333145]
# Cost validation = [0.45332349]
# Cost validation = [0.45331554]
# Cost validation = [0.45330759]
# Cost validation = [0.45329964]
# Cost validation = [0.45329171]
# Cost validation = [0.45328377]
# Cost validation = [0.45327585]
# Cost validation = [0.45326793]
# Cost validation = [0.45326001]
# Cost validation = [0.4532521]
# Cost validation = [0.4532442]
# Cost validation = [0.45323631]
# Cost validation = [0.45322842]
# Cost validation = [0.45322053]
# Cost validation = [0.45321265]
# Cost validation = [0.45320478]
# Cost validation = [0.45319691]
# Cost validation = [0.45318905]
# Cost validation = [0.45318119]
# Cost validation = [0.45317334]
# Cost validation = [0.4531655]
# Cost validation = [0.45315766]
# Cost validation = [0.45314983]
# Cost validation = [0.453142]
# Cost validation = [0.45313418]
# Cost validation = [0.45312636]
# Cost validation = [0.45311855]
# Cost validation = [0.45311075]
# Cost validation = [0.45310295]
# Cost validation = [0.45309516]
# Cost validation = [0.45308737]
# Cost validation = [0.45307959]
# Cost validation = [0.45307181]
# Cost validation = [0.45306404]
# Cost validation = [0.45305628]
# Cost validation = [0.45304852]
# Cost validation = [0.45304077]
# Cost validation = [0.45303302]
# Cost validation = [0.45302528]
# Cost validation = [0.45301754]
# Cost validation = [0.45300981]
# Cost validation = [0.45300209]
# Cost validation = [0.45299437]
# Cost validation = [0.45298666]
# Cost validation = [0.45297895]
# Cost validation = [0.45297125]
# Cost validation = [0.45296355]
# Cost validation = [0.45295586]
# Cost validation = [0.45294817]
# Cost validation = [0.45294049]
# Cost validation = [0.45293282]
# Cost validation = [0.45292515]
# Cost validation = [0.45291749]
# Cost validation = [0.45290983]
# Cost validation = [0.45290217]
# Cost validation = [0.45289453]
# Cost validation = [0.45288689]
# Cost validation = [0.45287925]
# Cost validation = [0.45287162]
# Cost validation = [0.452864]
# Cost validation = [0.45285638]
# Cost validation = [0.45284876]
# Cost validation = [0.45284115]
# Cost validation = [0.45283355]
# Cost validation = [0.45282595]
# Cost validation = [0.45281836]
# Cost validation = [0.45281078]
# Cost validation = [0.4528032]
# Cost validation = [0.45279562]
# Cost validation = [0.45278805]
# Cost validation = [0.45278048]
# Cost validation = [0.45277293]
# Cost validation = [0.45276537]
# Cost validation = [0.45275782]
# Cost validation = [0.45275028]
# Cost validation = [0.45274274]
# Cost validation = [0.45273521]
# Cost validation = [0.45272768]
# Cost validation = [0.45272016]
# Cost validation = [0.45271265]
# Cost validation = [0.45270513]
# Cost validation = [0.45269763]
# Cost validation = [0.45269013]
# Cost validation = [0.45268263]
# Cost validation = [0.45267514]
# Cost validation = [0.45266766]
# Cost validation = [0.45266018]
# Cost validation = [0.45265271]
# Cost validation = [0.45264524]
# Cost validation = [0.45263778]
# Cost validation = [0.45263032]
# Cost validation = [0.45262287]
# Cost validation = [0.45261542]
# Cost validation = [0.45260798]
# Cost validation = [0.45260054]
# Cost validation = [0.45259311]
# Cost validation = [0.45258568]
# Cost validation = [0.45257826]
# Cost validation = [0.45257085]
# Cost validation = [0.45256344]
# Cost validation = [0.45255603]
# Cost validation = [0.45254863]
# Cost validation = [0.45254124]
# Cost validation = [0.45253385]
# Cost validation = [0.45252646]
# Cost validation = [0.45251908]
# Cost validation = [0.45251171]
# Cost validation = [0.45250434]
# Cost validation = [0.45249698]
# Cost validation = [0.45248962]
# Cost validation = [0.45248227]
# Cost validation = [0.45247492]
# Cost validation = [0.45246757]
# Cost validation = [0.45246024]
# Cost validation = [0.4524529]
# Cost validation = [0.45244558]
# Cost validation = [0.45243825]
# Cost validation = [0.45243094]
# Cost validation = [0.45242362]
# Cost validation = [0.45241632]
# Cost validation = [0.45240902]
# Cost validation = [0.45240172]
# Cost validation = [0.45239443]
# Cost validation = [0.45238714]
# Cost validation = [0.45237986]
# Cost validation = [0.45237258]
# Cost validation = [0.45236531]
# Cost validation = [0.45235804]
# Cost validation = [0.45235078]
# Cost validation = [0.45234353]
# Cost validation = [0.45233628]
# Cost validation = [0.45232903]
# Cost validation = [0.45232179]
# Cost validation = [0.45231455]
# Cost validation = [0.45230732]
# Cost validation = [0.45230009]
# Cost validation = [0.45229287]
# Cost validation = [0.45228566]
# Cost validation = [0.45227845]
# Cost validation = [0.45227124]
# Cost validation = [0.45226404]
# Cost validation = [0.45225684]
# Cost validation = [0.45224965]
# Cost validation = [0.45224246]
# Cost validation = [0.45223528]
# Cost validation = [0.45222811]
# Cost validation = [0.45222094]
# Cost validation = [0.45221377]
# Cost validation = [0.45220661]
# Cost validation = [0.45219945]
# Cost validation = [0.4521923]
# Cost validation = [0.45218515]
# Cost validation = [0.45217801]
# Cost validation = [0.45217087]
# Cost validation = [0.45216374]
# Cost validation = [0.45215661]
# Cost validation = [0.45214949]
# Cost validation = [0.45214237]
# Cost validation = [0.45213526]
# Cost validation = [0.45212815]
# Cost validation = [0.45212105]
# Cost validation = [0.45211395]
# Cost validation = [0.45210686]
# Cost validation = [0.45209977]
# Cost validation = [0.45209269]
# Cost validation = [0.45208561]
# Cost validation = [0.45207854]
# Cost validation = [0.45207147]
# Cost validation = [0.4520644]
# Cost validation = [0.45205734]
# Cost validation = [0.45205029]
# Cost validation = [0.45204324]
# Cost validation = [0.4520362]
# Cost validation = [0.45202916]
# Cost validation = [0.45202212]
# Cost validation = [0.45201509]
# Cost validation = [0.45200806]
# Cost validation = [0.45200104]
# Cost validation = [0.45199403]
# Cost validation = [0.45198702]
# Cost validation = [0.45198001]
# Cost validation = [0.45197301]
# Cost validation = [0.45196601]
# Cost validation = [0.45195902]
# Cost validation = [0.45195203]
# Cost validation = [0.45194505]
# Cost validation = [0.45193807]
# Cost validation = [0.45193109]
# Cost validation = [0.45192413]
# Cost validation = [0.45191716]
# Cost validation = [0.4519102]
# Cost validation = [0.45190325]
# Cost validation = [0.4518963]
# Cost validation = [0.45188935]
# Cost validation = [0.45188241]
# Cost validation = [0.45187548]
# Cost validation = [0.45186854]
# Cost validation = [0.45186162]
# Cost validation = [0.4518547]
# Cost validation = [0.45184778]
# Cost validation = [0.45184087]
# Cost validation = [0.45183396]
# Cost validation = [0.45182705]
# Cost validation = [0.45182016]
# Cost validation = [0.45181326]
# Cost validation = [0.45180637]
# Cost validation = [0.45179949]
# Cost validation = [0.45179261]
# Cost validation = [0.45178573]
# Cost validation = [0.45177886]
# Cost validation = [0.45177199]
# Cost validation = [0.45176513]
# Cost validation = [0.45175827]
# Cost validation = [0.45175142]
# Cost validation = [0.45174457]
# Cost validation = [0.45173773]
# Cost validation = [0.45173089]
# Cost validation = [0.45172406]
# Cost validation = [0.45171723]
# Cost validation = [0.4517104]
# Cost validation = [0.45170358]
# Cost validation = [0.45169676]
# Cost validation = [0.45168995]
# Cost validation = [0.45168314]
# Cost validation = [0.45167634]
# Cost validation = [0.45166954]
# Cost validation = [0.45166275]
# Cost validation = [0.45165596]
# Cost validation = [0.45164918]
# Cost validation = [0.4516424]
# Cost validation = [0.45163562]
# Cost validation = [0.45162885]
# Cost validation = [0.45162208]
# Cost validation = [0.45161532]
# Cost validation = [0.45160856]
# Cost validation = [0.45160181]
# Cost validation = [0.45159506]
# Cost validation = [0.45158832]
# Cost validation = [0.45158158]
# Cost validation = [0.45157484]
# Cost validation = [0.45156811]
# Cost validation = [0.45156138]
# Cost validation = [0.45155466]
# Cost validation = [0.45154794]
# Cost validation = [0.45154123]
# Cost validation = [0.45153452]
# Cost validation = [0.45152782]
# Cost validation = [0.45152112]
# Cost validation = [0.45151442]
# Cost validation = [0.45150773]
# Cost validation = [0.45150104]
# Cost validation = [0.45149436]
# Cost validation = [0.45148768]
# Cost validation = [0.45148101]
# Cost validation = [0.45147434]
# Cost validation = [0.45146767]
# Cost validation = [0.45146101]
# Cost validation = [0.45145436]
# Cost validation = [0.45144771]
# Cost validation = [0.45144106]
# Cost validation = [0.45143441]
# Cost validation = [0.45142778]
# Cost validation = [0.45142114]
# Cost validation = [0.45141451]
# Cost validation = [0.45140789]
# Cost validation = [0.45140126]
# Cost validation = [0.45139465]
# Cost validation = [0.45138803]
# Cost validation = [0.45138143]
# Cost validation = [0.45137482]
# Cost validation = [0.45136822]
# Cost validation = [0.45136163]
# Cost validation = [0.45135503]
# Cost validation = [0.45134845]
# Cost validation = [0.45134187]
# Cost validation = [0.45133529]
# Cost validation = [0.45132871]
# Cost validation = [0.45132214]
# Cost validation = [0.45131558]
# Cost validation = [0.45130902]
# Cost validation = [0.45130246]
# Cost validation = [0.45129591]
# Cost validation = [0.45128936]
# Cost validation = [0.45128281]
# Cost validation = [0.45127627]
# Cost validation = [0.45126974]
# Cost validation = [0.4512632]
# Cost validation = [0.45125668]
# Cost validation = [0.45125015]
# Cost validation = [0.45124364]
# Cost validation = [0.45123712]
# Cost validation = [0.45123061]
# Cost validation = [0.4512241]
# Cost validation = [0.4512176]
# Cost validation = [0.4512111]
# Cost validation = [0.45120461]
# Cost validation = [0.45119812]
# Cost validation = [0.45119163]
# Cost validation = [0.45118515]
# Cost validation = [0.45117868]
# Cost validation = [0.4511722]
# Cost validation = [0.45116573]
# Cost validation = [0.45115927]
# Cost validation = [0.45115281]
# Cost validation = [0.45114635]
# Cost validation = [0.4511399]
# Cost validation = [0.45113345]
# Cost validation = [0.45112701]
# Cost validation = [0.45112057]
# Cost validation = [0.45111413]
# Cost validation = [0.4511077]
# Cost validation = [0.45110127]
# Cost validation = [0.45109485]
# Cost validation = [0.45108843]
# Cost validation = [0.45108202]
# Cost validation = [0.45107561]
# Cost validation = [0.4510692]
# Cost validation = [0.4510628]
# Cost validation = [0.4510564]
# Cost validation = [0.45105]
# Cost validation = [0.45104361]
# Cost validation = [0.45103723]
# Cost validation = [0.45103084]
# Cost validation = [0.45102447]
# Cost validation = [0.45101809]
# Cost validation = [0.45101172]
# Cost validation = [0.45100535]
# Cost validation = [0.45099899]
# Cost validation = [0.45099263]
# Cost validation = [0.45098628]
# Cost validation = [0.45097993]
# Cost validation = [0.45097358]
# Cost validation = [0.45096724]
# Cost validation = [0.4509609]
# Cost validation = [0.45095457]
# Cost validation = [0.45094824]
# Cost validation = [0.45094192]
# Cost validation = [0.45093559]
# Cost validation = [0.45092928]
# Cost validation = [0.45092296]
# Cost validation = [0.45091665]
# Cost validation = [0.45091035]
# Cost validation = [0.45090404]
# Cost validation = [0.45089775]
# Cost validation = [0.45089145]
# Cost validation = [0.45088516]
# Cost validation = [0.45087888]
# Cost validation = [0.4508726]
# Cost validation = [0.45086632]
# Cost validation = [0.45086004]
# Cost validation = [0.45085377]
# Cost validation = [0.45084751]
# Cost validation = [0.45084125]
# Cost validation = [0.45083499]
# Cost validation = [0.45082873]
# Cost validation = [0.45082248]
# Cost validation = [0.45081624]
# Cost validation = [0.45080999]
# Cost validation = [0.45080375]
# Cost validation = [0.45079752]
# Cost validation = [0.45079129]
# Cost validation = [0.45078506]
# Cost validation = [0.45077884]
# Cost validation = [0.45077262]
# Cost validation = [0.45076641]
# Cost validation = [0.45076019]
# Cost validation = [0.45075399]
# Cost validation = [0.45074778]
# Cost validation = [0.45074158]
# Cost validation = [0.45073539]
# Cost validation = [0.4507292]
# Cost validation = [0.45072301]
# Cost validation = [0.45071683]
# Cost validation = [0.45071065]
# Cost validation = [0.45070447]
# Cost validation = [0.4506983]
# Cost validation = [0.45069213]
# Cost validation = [0.45068596]
# Cost validation = [0.4506798]
# Cost validation = [0.45067365]
# Cost validation = [0.45066749]
# Cost validation = [0.45066134]
# Cost validation = [0.4506552]
# Cost validation = [0.45064906]
# Cost validation = [0.45064292]
# Cost validation = [0.45063678]
# Cost validation = [0.45063065]
# Cost validation = [0.45062453]
# Cost validation = [0.4506184]
# Cost validation = [0.45061229]
# Cost validation = [0.45060617]
# Cost validation = [0.45060006]
# Cost validation = [0.45059395]
# Cost validation = [0.45058785]
# Cost validation = [0.45058175]
# Cost validation = [0.45057565]
# Cost validation = [0.45056956]
# Cost validation = [0.45056347]
# Cost validation = [0.45055739]
# Cost validation = [0.45055131]
# Cost validation = [0.45054523]
# Cost validation = [0.45053916]
# Cost validation = [0.45053309]
# Cost validation = [0.45052702]
# Cost validation = [0.45052096]
# Cost validation = [0.4505149]

# %%
plt.figure(figsize=([8,8]))
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
import seaborn as sns
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)

fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.95789921 0.04210079]
#  [0.68311488 0.31688512]]

# %% [markdown]
# # Accuracy.
# Både egen kode og tester med scikit.

# %%
classes = logreg.predict(xtrain)
print(100*np.sum(classes==ytrain)/len(classes),'% Training Accuracy')
print(f1_score(ytrain, classes))

classes = logreg.predict(xval)
print(100*np.sum(classes==yval)/len(classes),'% Validation Accuracy')
print(f1_score(yval, classes))


classes = logreg.predict(xtest)
print(100*np.sum(classes==ytest)/len(classes),'% Test Accuracy')
print(f1_score(ytest, classes))
# Out:
# 81.36190476190477 % Training Accuracy
# 0.4390942963599886
# 81.0 % Validation Accuracy
# 0.4265593561368209
# 81.93333333333334 % Test Accuracy
# 0.4312696747114375

# %% [markdown]
# # Egen logistisk regresjon med stokastisk gradient descent

# %%
# %matplotlib qt
import LogisticRegression as lr
Niter=2500
logreg = lr.LOGREG(eta=0.1, doplot = False, doprint=True)
cost_val, cost_train, axis = logreg.fit(xtrain, ytrain, xval, yval, Niter, solver='sgd', batch_size=500)
classified = logreg.predict(xtest)
# %matplotlib inline
# Out:
# Cost validation = [0.67965272]
# Cost validation = [0.67618405]
# Cost validation = [0.67072131]
# Cost validation = [0.6667092]
# Cost validation = [0.6621224]
# Cost validation = [0.6578475]
# Cost validation = [0.65371205]
# Cost validation = [0.64886692]
# Cost validation = [0.64523177]
# Cost validation = [0.64141835]
# Cost validation = [0.63726488]
# Cost validation = [0.63309917]
# Cost validation = [0.62936399]
# Cost validation = [0.62447623]
# Cost validation = [0.62100608]
# Cost validation = [0.61664698]
# Cost validation = [0.61376066]
# Cost validation = [0.61038934]
# Cost validation = [0.60698672]
# Cost validation = [0.60446339]
# Cost validation = [0.60153382]
# Cost validation = [0.59868717]
# Cost validation = [0.5958904]
# Cost validation = [0.59209092]
# Cost validation = [0.5891452]
# Cost validation = [0.58654972]
# Cost validation = [0.58342546]
# Cost validation = [0.58121187]
# Cost validation = [0.57874747]
# Cost validation = [0.57645396]
# Cost validation = [0.57345352]
# Cost validation = [0.57086822]
# Cost validation = [0.56822721]
# Cost validation = [0.56539913]
# Cost validation = [0.56315882]
# Cost validation = [0.561131]
# Cost validation = [0.55822325]
# Cost validation = [0.55625471]
# Cost validation = [0.55425457]
# Cost validation = [0.55235902]
# Cost validation = [0.55071629]
# Cost validation = [0.54830774]
# Cost validation = [0.54682111]
# Cost validation = [0.54523902]
# Cost validation = [0.54347862]
# Cost validation = [0.54159248]
# Cost validation = [0.53999175]
# Cost validation = [0.53822941]
# Cost validation = [0.53667758]
# Cost validation = [0.53536141]
# Cost validation = [0.53384772]
# Cost validation = [0.53203258]
# Cost validation = [0.53087258]
# Cost validation = [0.5297301]
# Cost validation = [0.52807523]
# Cost validation = [0.52674223]
# Cost validation = [0.5254438]
# Cost validation = [0.52447339]
# Cost validation = [0.52333863]
# Cost validation = [0.52194861]
# Cost validation = [0.52081716]
# Cost validation = [0.51938143]
# Cost validation = [0.51845848]
# Cost validation = [0.517331]
# Cost validation = [0.51662314]
# Cost validation = [0.51555207]
# Cost validation = [0.51445163]
# Cost validation = [0.51366397]
# Cost validation = [0.51249382]
# Cost validation = [0.51159922]
# Cost validation = [0.51071464]
# Cost validation = [0.50999774]
# Cost validation = [0.50898739]
# Cost validation = [0.50824945]
# Cost validation = [0.50752563]
# Cost validation = [0.50665219]
# Cost validation = [0.50570606]
# Cost validation = [0.50499378]
# Cost validation = [0.50422067]
# Cost validation = [0.50346801]
# Cost validation = [0.5027184]
# Cost validation = [0.50190222]
# Cost validation = [0.50114384]
# Cost validation = [0.50042964]
# Cost validation = [0.49972577]
# Cost validation = [0.49912509]
# Cost validation = [0.49864455]
# Cost validation = [0.49796589]
# Cost validation = [0.49741274]
# Cost validation = [0.49684929]
# Cost validation = [0.49612145]
# Cost validation = [0.49568998]
# Cost validation = [0.49531254]
# Cost validation = [0.49486108]
# Cost validation = [0.4943187]
# Cost validation = [0.49375403]
# Cost validation = [0.4934574]
# Cost validation = [0.49295498]
# Cost validation = [0.49242639]
# Cost validation = [0.49199553]
# Cost validation = [0.49151951]
# Cost validation = [0.49106797]
# Cost validation = [0.49048406]
# Cost validation = [0.49000204]
# Cost validation = [0.4895469]
# Cost validation = [0.48902142]
# Cost validation = [0.48864502]
# Cost validation = [0.48816916]
# Cost validation = [0.48785333]
# Cost validation = [0.48753758]
# Cost validation = [0.48716384]
# Cost validation = [0.48686045]
# Cost validation = [0.48646906]
# Cost validation = [0.48604449]
# Cost validation = [0.48565697]
# Cost validation = [0.48539581]
# Cost validation = [0.48510163]
# Cost validation = [0.48489791]
# Cost validation = [0.48459984]
# Cost validation = [0.48420296]
# Cost validation = [0.48390325]
# Cost validation = [0.48362989]
# Cost validation = [0.48330039]
# Cost validation = [0.4830406]
# Cost validation = [0.48270961]
# Cost validation = [0.48238814]
# Cost validation = [0.48206413]
# Cost validation = [0.4819078]
# Cost validation = [0.48171394]
# Cost validation = [0.4813689]
# Cost validation = [0.48117145]
# Cost validation = [0.48095607]
# Cost validation = [0.48088028]
# Cost validation = [0.48063218]
# Cost validation = [0.48032917]
# Cost validation = [0.48002863]
# Cost validation = [0.47982388]
# Cost validation = [0.47953481]
# Cost validation = [0.47936639]
# Cost validation = [0.47917708]
# Cost validation = [0.47891693]
# Cost validation = [0.47874508]
# Cost validation = [0.47853661]
# Cost validation = [0.47821119]
# Cost validation = [0.47796576]
# Cost validation = [0.47773218]
# Cost validation = [0.47759066]
# Cost validation = [0.47737148]
# Cost validation = [0.47713689]
# Cost validation = [0.47683211]
# Cost validation = [0.47662232]
# Cost validation = [0.47638644]
# Cost validation = [0.47613626]
# Cost validation = [0.47599463]
# Cost validation = [0.47588844]
# Cost validation = [0.4757585]
# Cost validation = [0.47558121]
# Cost validation = [0.47530758]
# Cost validation = [0.47512049]
# Cost validation = [0.47493307]
# Cost validation = [0.47475967]
# Cost validation = [0.47455917]
# Cost validation = [0.47439013]
# Cost validation = [0.47426116]
# Cost validation = [0.47411796]
# Cost validation = [0.47394552]
# Cost validation = [0.47382085]
# Cost validation = [0.47360238]
# Cost validation = [0.4733611]
# Cost validation = [0.47326307]
# Cost validation = [0.47308887]
# Cost validation = [0.47295266]
# Cost validation = [0.47281504]
# Cost validation = [0.47271769]
# Cost validation = [0.47249597]
# Cost validation = [0.47227726]
# Cost validation = [0.47211715]
# Cost validation = [0.47191341]
# Cost validation = [0.47177574]
# Cost validation = [0.47159115]
# Cost validation = [0.47138645]
# Cost validation = [0.4712216]
# Cost validation = [0.47112243]
# Cost validation = [0.47102498]
# Cost validation = [0.47094165]
# Cost validation = [0.47084612]
# Cost validation = [0.47071595]
# Cost validation = [0.4705954]
# Cost validation = [0.47047598]
# Cost validation = [0.47037217]
# Cost validation = [0.47021028]
# Cost validation = [0.47006784]
# Cost validation = [0.46994945]
# Cost validation = [0.46978965]
# Cost validation = [0.46966548]
# Cost validation = [0.4695709]
# Cost validation = [0.46945782]
# Cost validation = [0.46933717]
# Cost validation = [0.46926625]
# Cost validation = [0.46918949]
# Cost validation = [0.46903097]
# Cost validation = [0.46887896]
# Cost validation = [0.46878722]
# Cost validation = [0.46864518]
# Cost validation = [0.46847267]
# Cost validation = [0.46844716]
# Cost validation = [0.46832694]
# Cost validation = [0.46821134]
# Cost validation = [0.46809909]
# Cost validation = [0.46803129]
# Cost validation = [0.46791332]
# Cost validation = [0.46784806]
# Cost validation = [0.4677117]
# Cost validation = [0.46767454]
# Cost validation = [0.46758346]
# Cost validation = [0.46739352]
# Cost validation = [0.4673014]
# Cost validation = [0.46713125]
# Cost validation = [0.4670619]
# Cost validation = [0.46697212]
# Cost validation = [0.46685838]
# Cost validation = [0.46662555]
# Cost validation = [0.4665554]
# Cost validation = [0.46639884]
# Cost validation = [0.46624324]
# Cost validation = [0.46619974]
# Cost validation = [0.46616333]
# Cost validation = [0.46606565]
# Cost validation = [0.46598213]
# Cost validation = [0.46585078]
# Cost validation = [0.46581644]
# Cost validation = [0.46568757]
# Cost validation = [0.46558836]
# Cost validation = [0.46552903]
# Cost validation = [0.46535364]
# Cost validation = [0.46529073]
# Cost validation = [0.46517071]
# Cost validation = [0.46513557]
# Cost validation = [0.46504773]
# Cost validation = [0.46490466]
# Cost validation = [0.46490673]
# Cost validation = [0.46475082]
# Cost validation = [0.4646568]
# Cost validation = [0.46466123]
# Cost validation = [0.46467981]
# Cost validation = [0.46458378]
# Cost validation = [0.46447781]
# Cost validation = [0.46430191]
# Cost validation = [0.46419265]
# Cost validation = [0.46409954]
# Cost validation = [0.46401512]
# Cost validation = [0.46392626]
# Cost validation = [0.46393691]
# Cost validation = [0.46379447]
# Cost validation = [0.46368433]
# Cost validation = [0.46359796]
# Cost validation = [0.4635125]
# Cost validation = [0.46346332]
# Cost validation = [0.4633589]
# Cost validation = [0.46336607]
# Cost validation = [0.46332338]
# Cost validation = [0.46327846]
# Cost validation = [0.46320665]
# Cost validation = [0.46321389]
# Cost validation = [0.46327614]
# Cost validation = [0.46322145]
# Cost validation = [0.46309071]
# Cost validation = [0.4630395]
# Cost validation = [0.46288695]
# Cost validation = [0.46273652]
# Cost validation = [0.46265816]
# Cost validation = [0.46272562]
# Cost validation = [0.46253402]
# Cost validation = [0.46254616]
# Cost validation = [0.46249375]
# Cost validation = [0.46223513]
# Cost validation = [0.46208992]
# Cost validation = [0.4620449]
# Cost validation = [0.46207383]
# Cost validation = [0.46208301]
# Cost validation = [0.46209728]
# Cost validation = [0.4619634]
# Cost validation = [0.46197999]
# Cost validation = [0.4618291]
# Cost validation = [0.46183416]
# Cost validation = [0.46159099]
# Cost validation = [0.46147617]
# Cost validation = [0.46133612]
# Cost validation = [0.46136666]
# Cost validation = [0.46133964]
# Cost validation = [0.46119431]
# Cost validation = [0.46113687]
# Cost validation = [0.46109881]
# Cost validation = [0.46098148]
# Cost validation = [0.46093895]
# Cost validation = [0.46090433]
# Cost validation = [0.46087245]
# Cost validation = [0.46079663]
# Cost validation = [0.46072849]
# Cost validation = [0.4605926]
# Cost validation = [0.4605304]
# Cost validation = [0.46053614]
# Cost validation = [0.46053087]
# Cost validation = [0.46049778]
# Cost validation = [0.4604605]
# Cost validation = [0.46050985]
# Cost validation = [0.46049795]
# Cost validation = [0.46043428]
# Cost validation = [0.46031705]
# Cost validation = [0.46022024]
# Cost validation = [0.46019676]
# Cost validation = [0.46017089]
# Cost validation = [0.46009784]
# Cost validation = [0.46003477]
# Cost validation = [0.45992611]
# Cost validation = [0.45986693]
# Cost validation = [0.45981351]
# Cost validation = [0.45976423]
# Cost validation = [0.45972959]
# Cost validation = [0.45967172]
# Cost validation = [0.45968625]
# Cost validation = [0.45960103]
# Cost validation = [0.45947826]
# Cost validation = [0.4594952]
# Cost validation = [0.45948173]
# Cost validation = [0.45943095]
# Cost validation = [0.45931423]
# Cost validation = [0.45926427]
# Cost validation = [0.45918463]
# Cost validation = [0.45911973]
# Cost validation = [0.45918194]
# Cost validation = [0.45909744]
# Cost validation = [0.45912544]
# Cost validation = [0.45905193]
# Cost validation = [0.45904028]
# Cost validation = [0.45895909]
# Cost validation = [0.45890465]
# Cost validation = [0.45881802]
# Cost validation = [0.45883458]
# Cost validation = [0.45879956]
# Cost validation = [0.45876571]
# Cost validation = [0.45872205]
# Cost validation = [0.4587613]
# Cost validation = [0.45871963]
# Cost validation = [0.45867328]
# Cost validation = [0.45863347]
# Cost validation = [0.45853803]
# Cost validation = [0.45848639]
# Cost validation = [0.45831839]
# Cost validation = [0.4582958]
# Cost validation = [0.4583158]
# Cost validation = [0.45825594]
# Cost validation = [0.45825104]
# Cost validation = [0.4582639]
# Cost validation = [0.45819854]
# Cost validation = [0.4581679]
# Cost validation = [0.45817436]
# Cost validation = [0.45826668]
# Cost validation = [0.45819183]
# Cost validation = [0.45820711]
# Cost validation = [0.45810438]
# Cost validation = [0.45802489]
# Cost validation = [0.45796427]
# Cost validation = [0.45787831]
# Cost validation = [0.45780321]
# Cost validation = [0.45773105]
# Cost validation = [0.45771751]
# Cost validation = [0.45763881]
# Cost validation = [0.45760253]
# Cost validation = [0.45753661]
# Cost validation = [0.45756432]
# Cost validation = [0.45755283]
# Cost validation = [0.45751377]
# Cost validation = [0.45753337]
# Cost validation = [0.45746798]
# Cost validation = [0.45743637]
# Cost validation = [0.45739823]
# Cost validation = [0.45731489]
# Cost validation = [0.45723098]
# Cost validation = [0.45721456]
# Cost validation = [0.45719756]
# Cost validation = [0.45729164]
# Cost validation = [0.4572557]
# Cost validation = [0.45725501]
# Cost validation = [0.45716798]
# Cost validation = [0.45709423]
# Cost validation = [0.4570628]
# Cost validation = [0.45708055]
# Cost validation = [0.45707297]
# Cost validation = [0.45699806]
# Cost validation = [0.4569258]
# Cost validation = [0.45697808]
# Cost validation = [0.45688849]
# Cost validation = [0.45676648]
# Cost validation = [0.45665109]
# Cost validation = [0.4565922]
# Cost validation = [0.45655418]
# Cost validation = [0.45657902]
# Cost validation = [0.45650652]
# Cost validation = [0.45642735]
# Cost validation = [0.45635695]
# Cost validation = [0.45634739]
# Cost validation = [0.45636454]
# Cost validation = [0.45628278]
# Cost validation = [0.45623394]
# Cost validation = [0.45618036]
# Cost validation = [0.4562237]
# Cost validation = [0.4562467]
# Cost validation = [0.45611492]
# Cost validation = [0.45620381]
# Cost validation = [0.45612053]
# Cost validation = [0.45605714]
# Cost validation = [0.45608511]
# Cost validation = [0.4561492]
# Cost validation = [0.45607508]
# Cost validation = [0.45601064]
# Cost validation = [0.45599867]
# Cost validation = [0.455992]
# Cost validation = [0.45600259]
# Cost validation = [0.4558666]
# Cost validation = [0.45574937]
# Cost validation = [0.45571158]
# Cost validation = [0.45567109]
# Cost validation = [0.45562393]
# Cost validation = [0.45560499]
# Cost validation = [0.45560212]
# Cost validation = [0.45556975]
# Cost validation = [0.45560783]
# Cost validation = [0.45552279]
# Cost validation = [0.45547987]
# Cost validation = [0.45545293]
# Cost validation = [0.45546363]
# Cost validation = [0.45540861]
# Cost validation = [0.45532141]
# Cost validation = [0.45519458]
# Cost validation = [0.45519391]
# Cost validation = [0.45521228]
# Cost validation = [0.45517842]
# Cost validation = [0.45517415]
# Cost validation = [0.45523965]
# Cost validation = [0.45515481]
# Cost validation = [0.45518272]
# Cost validation = [0.45510763]
# Cost validation = [0.45512839]
# Cost validation = [0.45512815]
# Cost validation = [0.4551555]
# Cost validation = [0.45506185]
# Cost validation = [0.45505852]
# Cost validation = [0.4550721]
# Cost validation = [0.45504311]
# Cost validation = [0.4550707]
# Cost validation = [0.45510208]
# Cost validation = [0.45507635]
# Cost validation = [0.45516274]
# Cost validation = [0.45503725]
# Cost validation = [0.45497123]
# Cost validation = [0.45501028]
# Cost validation = [0.45502541]
# Cost validation = [0.45498426]
# Cost validation = [0.4549452]
# Cost validation = [0.45496545]
# Cost validation = [0.45501685]
# Cost validation = [0.45506138]
# Cost validation = [0.45509849]
# Cost validation = [0.45490805]
# Cost validation = [0.45489522]
# Cost validation = [0.45491808]
# Cost validation = [0.45487423]
# Cost validation = [0.45489046]
# Cost validation = [0.4548546]
# Cost validation = [0.45483429]
# Cost validation = [0.45485943]
# Cost validation = [0.45483528]
# Cost validation = [0.4548712]
# Cost validation = [0.45491901]
# Cost validation = [0.45484782]
# Cost validation = [0.45479575]
# Cost validation = [0.45471144]
# Cost validation = [0.45469337]
# Cost validation = [0.45459759]
# Cost validation = [0.45449961]
# Cost validation = [0.45442688]
# Cost validation = [0.45437681]
# Cost validation = [0.45430686]
# Cost validation = [0.45438926]
# Cost validation = [0.45439259]
# Cost validation = [0.45428135]
# Cost validation = [0.4542411]
# Cost validation = [0.45415417]
# Cost validation = [0.45413864]
# Cost validation = [0.45423706]
# Cost validation = [0.45425432]
# Cost validation = [0.45429386]
# Cost validation = [0.45419891]
# Cost validation = [0.45416767]
# Cost validation = [0.45414118]
# Cost validation = [0.45403598]
# Cost validation = [0.45399572]
# Cost validation = [0.45397771]
# Cost validation = [0.45392206]
# Cost validation = [0.45387138]
# Cost validation = [0.45377892]
# Cost validation = [0.45369866]
# Cost validation = [0.45368618]
# Cost validation = [0.45366199]
# Cost validation = [0.4536644]
# Cost validation = [0.45359759]
# Cost validation = [0.45360645]
# Cost validation = [0.45361251]
# Cost validation = [0.45362472]
# Cost validation = [0.45360152]
# Cost validation = [0.45361528]
# Cost validation = [0.453653]
# Cost validation = [0.45353905]
# Cost validation = [0.45350574]
# Cost validation = [0.4534227]
# Cost validation = [0.45343738]
# Cost validation = [0.45344802]
# Cost validation = [0.45342902]
# Cost validation = [0.45343131]
# Cost validation = [0.45338788]
# Cost validation = [0.45339135]
# Cost validation = [0.45342792]
# Cost validation = [0.45336466]
# Cost validation = [0.45337319]
# Cost validation = [0.4534129]
# Cost validation = [0.45345226]
# Cost validation = [0.45345153]
# Cost validation = [0.45334741]
# Cost validation = [0.45331655]
# Cost validation = [0.45333685]
# Cost validation = [0.45335428]
# Cost validation = [0.45335316]
# Cost validation = [0.45330801]
# Cost validation = [0.45322659]
# Cost validation = [0.45327032]
# Cost validation = [0.45333925]
# Cost validation = [0.45334305]
# Cost validation = [0.45319112]
# Cost validation = [0.4531077]
# Cost validation = [0.45305073]
# Cost validation = [0.45303805]
# Cost validation = [0.45302954]
# Cost validation = [0.45300073]
# Cost validation = [0.4529285]
# Cost validation = [0.45294945]
# Cost validation = [0.45292521]
# Cost validation = [0.4529768]
# Cost validation = [0.45294973]
# Cost validation = [0.4529039]
# Cost validation = [0.45287061]
# Cost validation = [0.45286523]
# Cost validation = [0.45287368]
# Cost validation = [0.45287897]
# Cost validation = [0.45278495]
# Cost validation = [0.45276363]
# Cost validation = [0.45266624]
# Cost validation = [0.45262413]
# Cost validation = [0.45259476]
# Cost validation = [0.45256794]
# Cost validation = [0.45251652]
# Cost validation = [0.45248105]
# Cost validation = [0.45246082]
# Cost validation = [0.45251261]
# Cost validation = [0.45255326]
# Cost validation = [0.45248922]
# Cost validation = [0.45245546]
# Cost validation = [0.45249597]
# Cost validation = [0.45255849]
# Cost validation = [0.45254289]
# Cost validation = [0.45252129]
# Cost validation = [0.4524928]
# Cost validation = [0.45256324]
# Cost validation = [0.45250296]
# Cost validation = [0.45241825]
# Cost validation = [0.45245051]
# Cost validation = [0.45251832]
# Cost validation = [0.45247658]
# Cost validation = [0.45243108]
# Cost validation = [0.45253136]
# Cost validation = [0.45246338]
# Cost validation = [0.45244939]
# Cost validation = [0.45243789]
# Cost validation = [0.45243952]
# Cost validation = [0.45245994]
# Cost validation = [0.45242752]
# Cost validation = [0.45240877]
# Cost validation = [0.45238208]
# Cost validation = [0.45241822]
# Cost validation = [0.45239572]
# Cost validation = [0.45230119]
# Cost validation = [0.4523557]
# Cost validation = [0.45229385]
# Cost validation = [0.45233033]
# Cost validation = [0.45229285]
# Cost validation = [0.45234233]
# Cost validation = [0.45227505]
# Cost validation = [0.45215156]
# Cost validation = [0.45209323]
# Cost validation = [0.45200378]
# Cost validation = [0.45198089]
# Cost validation = [0.45205962]
# Cost validation = [0.45202804]
# Cost validation = [0.45211011]
# Cost validation = [0.45212245]
# Cost validation = [0.45207255]
# Cost validation = [0.45199766]
# Cost validation = [0.45200171]
# Cost validation = [0.45193839]
# Cost validation = [0.45185615]
# Cost validation = [0.45186384]
# Cost validation = [0.4518567]
# Cost validation = [0.45185585]
# Cost validation = [0.45179705]
# Cost validation = [0.45178643]
# Cost validation = [0.45174024]
# Cost validation = [0.45174611]
# Cost validation = [0.45181291]
# Cost validation = [0.45177512]
# Cost validation = [0.45175285]
# Cost validation = [0.45174503]
# Cost validation = [0.45167351]
# Cost validation = [0.4516906]
# Cost validation = [0.45167456]
# Cost validation = [0.45167875]
# Cost validation = [0.45159245]
# Cost validation = [0.45153043]
# Cost validation = [0.45158853]
# Cost validation = [0.45161491]
# Cost validation = [0.45153433]
# Cost validation = [0.45148715]
# Cost validation = [0.45152281]
# Cost validation = [0.45154585]
# Cost validation = [0.45154757]
# Cost validation = [0.45156272]
# Cost validation = [0.45150059]
# Cost validation = [0.45151286]
# Cost validation = [0.45152914]
# Cost validation = [0.45146606]
# Cost validation = [0.4514304]
# Cost validation = [0.45144015]
# Cost validation = [0.45145534]
# Cost validation = [0.45150073]
# Cost validation = [0.45139948]
# Cost validation = [0.45139045]
# Cost validation = [0.45136982]
# Cost validation = [0.4514119]
# Cost validation = [0.45138798]
# Cost validation = [0.45133319]
# Cost validation = [0.45125882]
# Cost validation = [0.45126728]
# Cost validation = [0.45134624]
# Cost validation = [0.45128639]
# Cost validation = [0.45124403]
# Cost validation = [0.45122075]
# Cost validation = [0.45126931]
# Cost validation = [0.45132698]
# Cost validation = [0.45131122]
# Cost validation = [0.45123596]
# Cost validation = [0.45129297]
# Cost validation = [0.45142412]
# Cost validation = [0.45125326]
# Cost validation = [0.45113268]
# Cost validation = [0.45113136]
# Cost validation = [0.45106673]
# Cost validation = [0.45108078]
# Cost validation = [0.45112301]
# Cost validation = [0.45109191]
# Cost validation = [0.45105552]
# Cost validation = [0.45098781]
# Cost validation = [0.45095084]
# Cost validation = [0.45101031]
# Cost validation = [0.45105571]
# Cost validation = [0.45107655]
# Cost validation = [0.45106157]
# Cost validation = [0.45106458]
# Cost validation = [0.45107007]
# Cost validation = [0.45093817]
# Cost validation = [0.45082547]
# Cost validation = [0.45080041]
# Cost validation = [0.45070496]
# Cost validation = [0.45063239]
# Cost validation = [0.45066521]
# Cost validation = [0.45069954]
# Cost validation = [0.45068235]
# Cost validation = [0.45071389]
# Cost validation = [0.45067349]
# Cost validation = [0.45070584]
# Cost validation = [0.45069327]
# Cost validation = [0.45065944]
# Cost validation = [0.45060304]
# Cost validation = [0.45063869]
# Cost validation = [0.45059902]
# Cost validation = [0.45047715]
# Cost validation = [0.45046233]
# Cost validation = [0.45046859]
# Cost validation = [0.45047933]
# Cost validation = [0.45043478]
# Cost validation = [0.45044433]
# Cost validation = [0.45034943]
# Cost validation = [0.45038289]
# Cost validation = [0.45033057]
# Cost validation = [0.45034634]
# Cost validation = [0.45048999]
# Cost validation = [0.45038477]
# Cost validation = [0.45031197]
# Cost validation = [0.45035237]
# Cost validation = [0.45027307]
# Cost validation = [0.45027604]
# Cost validation = [0.45026632]
# Cost validation = [0.45024076]
# Cost validation = [0.45021782]
# Cost validation = [0.45031085]
# Cost validation = [0.45018756]
# Cost validation = [0.45015817]
# Cost validation = [0.45015786]
# Cost validation = [0.45009845]
# Cost validation = [0.45003919]
# Cost validation = [0.45002352]
# Cost validation = [0.44998931]
# Cost validation = [0.44995379]
# Cost validation = [0.44994901]
# Cost validation = [0.44990359]
# Cost validation = [0.44991183]
# Cost validation = [0.44992726]
# Cost validation = [0.44994474]
# Cost validation = [0.44996337]
# Cost validation = [0.44991343]
# Cost validation = [0.44987938]
# Cost validation = [0.44986266]
# Cost validation = [0.44987766]
# Cost validation = [0.44982873]
# Cost validation = [0.44979246]
# Cost validation = [0.44976881]
# Cost validation = [0.44974049]
# Cost validation = [0.44977881]
# Cost validation = [0.44981368]
# Cost validation = [0.44979806]
# Cost validation = [0.44978304]
# Cost validation = [0.44970873]
# Cost validation = [0.44963639]
# Cost validation = [0.44969233]
# Cost validation = [0.44974519]
# Cost validation = [0.44972108]
# Cost validation = [0.44967357]
# Cost validation = [0.4496983]
# Cost validation = [0.44965638]
# Cost validation = [0.44965423]
# Cost validation = [0.44963168]
# Cost validation = [0.44969429]
# Cost validation = [0.44966931]
# Cost validation = [0.44961748]
# Cost validation = [0.44959904]
# Cost validation = [0.44952198]
# Cost validation = [0.44949778]
# Cost validation = [0.44946662]
# Cost validation = [0.44945755]
# Cost validation = [0.44953533]
# Cost validation = [0.4495152]
# Cost validation = [0.44958118]
# Cost validation = [0.44953883]
# Cost validation = [0.44948564]
# Cost validation = [0.44945077]
# Cost validation = [0.44940046]
# Cost validation = [0.44943707]
# Cost validation = [0.44942589]
# Cost validation = [0.44941067]
# Cost validation = [0.44947655]
# Cost validation = [0.44945162]
# Cost validation = [0.44940953]
# Cost validation = [0.44941747]
# Cost validation = [0.449411]
# Cost validation = [0.44936084]
# Cost validation = [0.44936984]
# Cost validation = [0.44941348]
# Cost validation = [0.44939081]
# Cost validation = [0.44943425]
# Cost validation = [0.44940396]
# Cost validation = [0.44943066]
# Cost validation = [0.44937957]
# Cost validation = [0.44941454]
# Cost validation = [0.44937897]
# Cost validation = [0.44934112]
# Cost validation = [0.44937634]
# Cost validation = [0.44934846]
# Cost validation = [0.44930881]
# Cost validation = [0.4492888]
# Cost validation = [0.44924159]
# Cost validation = [0.44923484]
# Cost validation = [0.44922361]
# Cost validation = [0.44920602]
# Cost validation = [0.44918737]
# Cost validation = [0.44910306]
# Cost validation = [0.44909895]
# Cost validation = [0.44908936]
# Cost validation = [0.44910651]
# Cost validation = [0.44915302]
# Cost validation = [0.44914684]
# Cost validation = [0.44909864]
# Cost validation = [0.44913124]
# Cost validation = [0.44914242]
# Cost validation = [0.44912229]
# Cost validation = [0.4491065]
# Cost validation = [0.4491142]
# Cost validation = [0.44912911]
# Cost validation = [0.44916298]
# Cost validation = [0.4491179]
# Cost validation = [0.44911764]
# Cost validation = [0.44910281]
# Cost validation = [0.44916692]
# Cost validation = [0.44912196]
# Cost validation = [0.44898846]
# Cost validation = [0.44897962]
# Cost validation = [0.44899107]
# Cost validation = [0.44897098]
# Cost validation = [0.44896308]
# Cost validation = [0.44894219]
# Cost validation = [0.44891685]
# Cost validation = [0.44896588]
# Cost validation = [0.44893418]
# Cost validation = [0.44890659]
# Cost validation = [0.4488534]
# Cost validation = [0.44884785]
# Cost validation = [0.44876063]
# Cost validation = [0.44875249]
# Cost validation = [0.44877158]
# Cost validation = [0.44887384]
# Cost validation = [0.44886825]
# Cost validation = [0.4489076]
# Cost validation = [0.4489689]
# Cost validation = [0.44907523]
# Cost validation = [0.44904698]
# Cost validation = [0.44901193]
# Cost validation = [0.4490069]
# Cost validation = [0.44893792]
# Cost validation = [0.4488922]
# Cost validation = [0.4488813]
# Cost validation = [0.44882859]
# Cost validation = [0.44883233]
# Cost validation = [0.44879995]
# Cost validation = [0.4489225]
# Cost validation = [0.44889755]
# Cost validation = [0.44881747]
# Cost validation = [0.44885342]
# Cost validation = [0.44896947]
# Cost validation = [0.44896432]
# Cost validation = [0.44882424]
# Cost validation = [0.44880693]
# Cost validation = [0.44881134]
# Cost validation = [0.44871734]
# Cost validation = [0.44864389]
# Cost validation = [0.44862057]
# Cost validation = [0.44860936]
# Cost validation = [0.44858141]
# Cost validation = [0.44852676]
# Cost validation = [0.44840009]
# Cost validation = [0.44836146]
# Cost validation = [0.44832912]
# Cost validation = [0.44829206]
# Cost validation = [0.44832646]
# Cost validation = [0.44837968]
# Cost validation = [0.44836618]
# Cost validation = [0.44831191]
# Cost validation = [0.44836628]
# Cost validation = [0.44836273]
# Cost validation = [0.44834348]
# Cost validation = [0.44836717]
# Cost validation = [0.44837074]
# Cost validation = [0.4484595]
# Cost validation = [0.44844361]
# Cost validation = [0.44837945]
# Cost validation = [0.44836774]
# Cost validation = [0.44833484]
# Cost validation = [0.44831836]
# Cost validation = [0.44832433]
# Cost validation = [0.44832611]
# Cost validation = [0.44836064]
# Cost validation = [0.44837921]
# Cost validation = [0.44833465]
# Cost validation = [0.44836925]
# Cost validation = [0.4483941]
# Cost validation = [0.44834946]
# Cost validation = [0.44830011]
# Cost validation = [0.44835186]
# Cost validation = [0.4483834]
# Cost validation = [0.44831104]
# Cost validation = [0.44827292]
# Cost validation = [0.44833172]
# Cost validation = [0.4482849]
# Cost validation = [0.44822829]
# Cost validation = [0.44818631]
# Cost validation = [0.44813404]
# Cost validation = [0.44803553]
# Cost validation = [0.44797444]
# Cost validation = [0.44798563]
# Cost validation = [0.44803294]
# Cost validation = [0.44798566]
# Cost validation = [0.44803553]
# Cost validation = [0.44804092]
# Cost validation = [0.44801745]
# Cost validation = [0.447974]
# Cost validation = [0.44800464]
# Cost validation = [0.44801044]
# Cost validation = [0.44796646]
# Cost validation = [0.44799749]
# Cost validation = [0.44795508]
# Cost validation = [0.44801409]
# Cost validation = [0.44806026]
# Cost validation = [0.4480782]
# Cost validation = [0.44810037]
# Cost validation = [0.44804117]
# Cost validation = [0.44798876]
# Cost validation = [0.44794055]
# Cost validation = [0.44786307]
# Cost validation = [0.44784406]
# Cost validation = [0.44779602]
# Cost validation = [0.44783787]
# Cost validation = [0.44778958]
# Cost validation = [0.44784286]
# Cost validation = [0.44784019]
# Cost validation = [0.44785912]
# Cost validation = [0.44781673]
# Cost validation = [0.44780071]
# Cost validation = [0.44782955]
# Cost validation = [0.4477391]
# Cost validation = [0.4477352]
# Cost validation = [0.44775149]
# Cost validation = [0.44780165]
# Cost validation = [0.44783098]
# Cost validation = [0.44783316]
# Cost validation = [0.44775242]
# Cost validation = [0.44770702]
# Cost validation = [0.44772132]
# Cost validation = [0.44771401]
# Cost validation = [0.44775184]
# Cost validation = [0.44773264]
# Cost validation = [0.44769166]
# Cost validation = [0.44772981]
# Cost validation = [0.44770381]
# Cost validation = [0.44774134]
# Cost validation = [0.44772936]
# Cost validation = [0.4476542]
# Cost validation = [0.44765006]
# Cost validation = [0.44764242]
# Cost validation = [0.44762218]
# Cost validation = [0.44759557]
# Cost validation = [0.44759863]
# Cost validation = [0.44753649]
# Cost validation = [0.4474909]
# Cost validation = [0.44750104]
# Cost validation = [0.44746731]
# Cost validation = [0.44744071]
# Cost validation = [0.44747795]
# Cost validation = [0.44749275]
# Cost validation = [0.44745449]
# Cost validation = [0.44750009]
# Cost validation = [0.4475061]
# Cost validation = [0.44751049]
# Cost validation = [0.44750851]
# Cost validation = [0.44752461]
# Cost validation = [0.4475347]
# Cost validation = [0.44748498]
# Cost validation = [0.4474955]
# Cost validation = [0.44742911]
# Cost validation = [0.44746538]
# Cost validation = [0.44748471]
# Cost validation = [0.44745597]
# Cost validation = [0.4474207]
# Cost validation = [0.44740417]
# Cost validation = [0.44746495]
# Cost validation = [0.44745394]
# Cost validation = [0.44747646]
# Cost validation = [0.44758539]
# Cost validation = [0.44755032]
# Cost validation = [0.44750025]
# Cost validation = [0.44745847]
# Cost validation = [0.44745926]
# Cost validation = [0.44741139]
# Cost validation = [0.44745252]
# Cost validation = [0.44747421]
# Cost validation = [0.4474463]
# Cost validation = [0.44755364]
# Cost validation = [0.44757506]
# Cost validation = [0.447535]
# Cost validation = [0.44749936]
# Cost validation = [0.44750377]
# Cost validation = [0.44755999]
# Cost validation = [0.44746448]
# Cost validation = [0.44732056]
# Cost validation = [0.44725247]
# Cost validation = [0.44733501]
# Cost validation = [0.44732807]
# Cost validation = [0.44730915]
# Cost validation = [0.44733013]
# Cost validation = [0.44726847]
# Cost validation = [0.44730555]
# Cost validation = [0.44724491]
# Cost validation = [0.44720907]
# Cost validation = [0.44724392]
# Cost validation = [0.44729441]
# Cost validation = [0.44731989]
# Cost validation = [0.44731457]
# Cost validation = [0.44730796]
# Cost validation = [0.44732768]
# Cost validation = [0.44732575]
# Cost validation = [0.44734808]
# Cost validation = [0.44729944]
# Cost validation = [0.44733659]
# Cost validation = [0.44746525]
# Cost validation = [0.4473653]
# Cost validation = [0.44742452]
# Cost validation = [0.44738706]
# Cost validation = [0.44740999]
# Cost validation = [0.44743776]
# Cost validation = [0.44732315]
# Cost validation = [0.44732322]
# Cost validation = [0.44718192]
# Cost validation = [0.44714493]
# Cost validation = [0.44710076]
# Cost validation = [0.44707151]
# Cost validation = [0.44708727]
# Cost validation = [0.44705433]
# Cost validation = [0.44707592]
# Cost validation = [0.44700568]
# Cost validation = [0.44696082]
# Cost validation = [0.44692518]
# Cost validation = [0.44690837]
# Cost validation = [0.44685717]
# Cost validation = [0.44687039]
# Cost validation = [0.44688884]
# Cost validation = [0.44684616]
# Cost validation = [0.44684349]
# Cost validation = [0.44686163]
# Cost validation = [0.44686804]
# Cost validation = [0.4469031]
# Cost validation = [0.4469065]
# Cost validation = [0.44688049]
# Cost validation = [0.44687821]
# Cost validation = [0.44685433]
# Cost validation = [0.44685182]
# Cost validation = [0.4468182]
# Cost validation = [0.44682678]
# Cost validation = [0.44687265]
# Cost validation = [0.44683296]
# Cost validation = [0.4468091]
# Cost validation = [0.44680431]
# Cost validation = [0.4467618]
# Cost validation = [0.44676568]
# Cost validation = [0.44673746]
# Cost validation = [0.44674789]
# Cost validation = [0.44669562]
# Cost validation = [0.44667021]
# Cost validation = [0.44662118]
# Cost validation = [0.44661481]
# Cost validation = [0.44657024]
# Cost validation = [0.44654612]
# Cost validation = [0.44656561]
# Cost validation = [0.44650488]
# Cost validation = [0.44647327]
# Cost validation = [0.44646554]
# Cost validation = [0.4464223]
# Cost validation = [0.44638299]
# Cost validation = [0.44644084]
# Cost validation = [0.44636769]
# Cost validation = [0.44640761]
# Cost validation = [0.44640745]
# Cost validation = [0.44634199]
# Cost validation = [0.44632201]
# Cost validation = [0.44635081]
# Cost validation = [0.44641954]
# Cost validation = [0.44631431]
# Cost validation = [0.44634707]
# Cost validation = [0.44631773]
# Cost validation = [0.44634274]
# Cost validation = [0.44634424]
# Cost validation = [0.44639542]
# Cost validation = [0.44639704]
# Cost validation = [0.44640725]
# Cost validation = [0.44652059]
# Cost validation = [0.44652967]
# Cost validation = [0.44650661]
# Cost validation = [0.44658236]
# Cost validation = [0.44660391]
# Cost validation = [0.44667729]
# Cost validation = [0.44657142]
# Cost validation = [0.44660541]
# Cost validation = [0.44654114]
# Cost validation = [0.44651827]
# Cost validation = [0.44655938]
# Cost validation = [0.44664492]
# Cost validation = [0.44663471]
# Cost validation = [0.44658514]
# Cost validation = [0.44667547]
# Cost validation = [0.44674335]
# Cost validation = [0.44666307]
# Cost validation = [0.44680683]
# Cost validation = [0.44666561]
# Cost validation = [0.44666564]
# Cost validation = [0.44657172]
# Cost validation = [0.44661431]
# Cost validation = [0.44661207]
# Cost validation = [0.44669832]
# Cost validation = [0.44660826]
# Cost validation = [0.44666512]
# Cost validation = [0.44665706]
# Cost validation = [0.44656221]
# Cost validation = [0.44654357]
# Cost validation = [0.44656701]
# Cost validation = [0.44655201]
# Cost validation = [0.44648971]
# Cost validation = [0.44649336]
# Cost validation = [0.4464571]
# Cost validation = [0.44644406]
# Cost validation = [0.44639684]
# Cost validation = [0.44638495]
# Cost validation = [0.44635333]
# Cost validation = [0.44635902]
# Cost validation = [0.44625604]
# Cost validation = [0.4462055]
# Cost validation = [0.44622738]
# Cost validation = [0.44624016]
# Cost validation = [0.4461894]
# Cost validation = [0.44619241]
# Cost validation = [0.44621727]
# Cost validation = [0.44614318]
# Cost validation = [0.4461703]
# Cost validation = [0.44614769]
# Cost validation = [0.44616813]
# Cost validation = [0.44617467]
# Cost validation = [0.4462227]
# Cost validation = [0.44619871]
# Cost validation = [0.44619317]
# Cost validation = [0.44618171]
# Cost validation = [0.44627994]
# Cost validation = [0.44622338]
# Cost validation = [0.44624328]
# Cost validation = [0.44618535]
# Cost validation = [0.44613447]
# Cost validation = [0.44612614]
# Cost validation = [0.44615464]
# Cost validation = [0.44623504]
# Cost validation = [0.44617763]
# Cost validation = [0.44616128]
# Cost validation = [0.44613278]
# Cost validation = [0.44619349]
# Cost validation = [0.44612712]
# Cost validation = [0.44612404]
# Cost validation = [0.44610834]
# Cost validation = [0.44614125]
# Cost validation = [0.44614221]
# Cost validation = [0.44606558]
# Cost validation = [0.44611543]
# Cost validation = [0.44621265]
# Cost validation = [0.44616261]
# Cost validation = [0.44628553]
# Cost validation = [0.44630453]
# Cost validation = [0.44630971]
# Cost validation = [0.4462797]
# Cost validation = [0.44616405]
# Cost validation = [0.44608262]
# Cost validation = [0.44606823]
# Cost validation = [0.44601374]
# Cost validation = [0.44593975]
# Cost validation = [0.44593924]
# Cost validation = [0.4459277]
# Cost validation = [0.44591805]
# Cost validation = [0.4459078]
# Cost validation = [0.44588622]
# Cost validation = [0.44589661]
# Cost validation = [0.4459667]
# Cost validation = [0.44596931]
# Cost validation = [0.44600809]
# Cost validation = [0.4460074]
# Cost validation = [0.44604368]
# Cost validation = [0.44601664]
# Cost validation = [0.44596727]
# Cost validation = [0.44598525]
# Cost validation = [0.44597802]
# Cost validation = [0.44591286]
# Cost validation = [0.44592281]
# Cost validation = [0.44591669]
# Cost validation = [0.44587995]
# Cost validation = [0.44585232]
# Cost validation = [0.44583119]
# Cost validation = [0.44584191]
# Cost validation = [0.44584117]
# Cost validation = [0.44587403]
# Cost validation = [0.4458398]
# Cost validation = [0.44584475]
# Cost validation = [0.44585789]
# Cost validation = [0.44590739]
# Cost validation = [0.44588979]
# Cost validation = [0.44581599]
# Cost validation = [0.44579581]
# Cost validation = [0.4457628]
# Cost validation = [0.44578518]
# Cost validation = [0.44585834]
# Cost validation = [0.44595027]
# Cost validation = [0.44597277]
# Cost validation = [0.44598459]
# Cost validation = [0.44597828]
# Cost validation = [0.44596269]
# Cost validation = [0.44611613]
# Cost validation = [0.44608985]
# Cost validation = [0.44613513]
# Cost validation = [0.44602508]
# Cost validation = [0.4458234]
# Cost validation = [0.44568257]
# Cost validation = [0.44566159]
# Cost validation = [0.44555419]
# Cost validation = [0.44555888]
# Cost validation = [0.44557581]
# Cost validation = [0.44552473]
# Cost validation = [0.44553302]
# Cost validation = [0.44558764]
# Cost validation = [0.44569072]
# Cost validation = [0.44560419]
# Cost validation = [0.44567245]
# Cost validation = [0.44556881]
# Cost validation = [0.44547292]
# Cost validation = [0.44552415]
# Cost validation = [0.44543688]
# Cost validation = [0.44544441]
# Cost validation = [0.44543493]
# Cost validation = [0.4454113]
# Cost validation = [0.44546081]
# Cost validation = [0.44550099]
# Cost validation = [0.44549304]
# Cost validation = [0.445442]
# Cost validation = [0.44540275]
# Cost validation = [0.44537613]
# Cost validation = [0.44539921]
# Cost validation = [0.44535719]
# Cost validation = [0.44534765]
# Cost validation = [0.44530822]
# Cost validation = [0.44531455]
# Cost validation = [0.44535324]
# Cost validation = [0.44530945]
# Cost validation = [0.445331]
# Cost validation = [0.44527543]
# Cost validation = [0.4452534]
# Cost validation = [0.44524615]
# Cost validation = [0.44524624]
# Cost validation = [0.44517731]
# Cost validation = [0.4451389]
# Cost validation = [0.44519222]
# Cost validation = [0.44519226]
# Cost validation = [0.44525089]
# Cost validation = [0.44524876]
# Cost validation = [0.44527307]
# Cost validation = [0.44526751]
# Cost validation = [0.44528891]
# Cost validation = [0.44531907]
# Cost validation = [0.4453475]
# Cost validation = [0.44531846]
# Cost validation = [0.44529845]
# Cost validation = [0.44525414]
# Cost validation = [0.44526233]
# Cost validation = [0.44528118]
# Cost validation = [0.44524065]
# Cost validation = [0.44524659]
# Cost validation = [0.44527751]
# Cost validation = [0.44522042]
# Cost validation = [0.44521819]
# Cost validation = [0.44520017]
# Cost validation = [0.44519398]
# Cost validation = [0.44528494]
# Cost validation = [0.44536916]
# Cost validation = [0.44540608]
# Cost validation = [0.44528477]
# Cost validation = [0.44525966]
# Cost validation = [0.4452663]
# Cost validation = [0.44523517]
# Cost validation = [0.44521641]
# Cost validation = [0.44515871]
# Cost validation = [0.44518065]
# Cost validation = [0.44516316]
# Cost validation = [0.44513009]
# Cost validation = [0.44511759]
# Cost validation = [0.44512004]
# Cost validation = [0.44514193]
# Cost validation = [0.44514215]
# Cost validation = [0.44510073]
# Cost validation = [0.44515001]
# Cost validation = [0.44506284]
# Cost validation = [0.44498714]
# Cost validation = [0.44494665]
# Cost validation = [0.44497185]
# Cost validation = [0.44496684]
# Cost validation = [0.44497339]
# Cost validation = [0.44496972]
# Cost validation = [0.44503955]
# Cost validation = [0.44505745]
# Cost validation = [0.44506923]
# Cost validation = [0.44514744]
# Cost validation = [0.44511947]
# Cost validation = [0.44532825]
# Cost validation = [0.44529025]
# Cost validation = [0.44530785]
# Cost validation = [0.44524479]
# Cost validation = [0.44515068]
# Cost validation = [0.44526092]
# Cost validation = [0.44526625]
# Cost validation = [0.44532031]
# Cost validation = [0.44526854]
# Cost validation = [0.44533671]
# Cost validation = [0.445285]
# Cost validation = [0.44534195]
# Cost validation = [0.44524927]
# Cost validation = [0.44523404]
# Cost validation = [0.44515178]
# Cost validation = [0.44516969]
# Cost validation = [0.44513474]
# Cost validation = [0.44515479]
# Cost validation = [0.44509627]
# Cost validation = [0.44507841]
# Cost validation = [0.44509155]
# Cost validation = [0.4450662]
# Cost validation = [0.44504993]
# Cost validation = [0.44501773]
# Cost validation = [0.4450486]
# Cost validation = [0.44501484]
# Cost validation = [0.44503529]
# Cost validation = [0.44498778]
# Cost validation = [0.44496279]
# Cost validation = [0.44497183]
# Cost validation = [0.44498022]
# Cost validation = [0.44495907]
# Cost validation = [0.44500088]
# Cost validation = [0.44499631]
# Cost validation = [0.44502427]
# Cost validation = [0.44500605]
# Cost validation = [0.44504185]
# Cost validation = [0.44496991]
# Cost validation = [0.44488939]
# Cost validation = [0.44490844]
# Cost validation = [0.44492459]
# Cost validation = [0.44492399]
# Cost validation = [0.44496037]
# Cost validation = [0.44491545]
# Cost validation = [0.44494567]
# Cost validation = [0.44488774]
# Cost validation = [0.44494051]
# Cost validation = [0.44488226]
# Cost validation = [0.44485031]
# Cost validation = [0.44479034]
# Cost validation = [0.44480989]
# Cost validation = [0.44478276]
# Cost validation = [0.44472965]
# Cost validation = [0.44480046]
# Cost validation = [0.44476216]
# Cost validation = [0.44476116]
# Cost validation = [0.44470289]
# Cost validation = [0.4447208]
# Cost validation = [0.44473921]
# Cost validation = [0.44477363]
# Cost validation = [0.44476164]
# Cost validation = [0.44475037]
# Cost validation = [0.44480667]
# Cost validation = [0.44481741]
# Cost validation = [0.44485484]
# Cost validation = [0.44491114]
# Cost validation = [0.44489125]
# Cost validation = [0.44491911]
# Cost validation = [0.44496297]
# Cost validation = [0.44486367]
# Cost validation = [0.44481441]
# Cost validation = [0.44489909]
# Cost validation = [0.4448834]
# Cost validation = [0.44488492]
# Cost validation = [0.44485617]
# Cost validation = [0.44484446]
# Cost validation = [0.44468946]
# Cost validation = [0.44470221]
# Cost validation = [0.44473617]
# Cost validation = [0.44477094]
# Cost validation = [0.4447669]
# Cost validation = [0.44477055]
# Cost validation = [0.44467401]
# Cost validation = [0.44489479]
# Cost validation = [0.44489811]
# Cost validation = [0.44494272]
# Cost validation = [0.44493312]
# Cost validation = [0.44500807]
# Cost validation = [0.4450148]
# Cost validation = [0.44497847]
# Cost validation = [0.44504231]
# Cost validation = [0.44505247]
# Cost validation = [0.44505527]
# Cost validation = [0.44498712]
# Cost validation = [0.44504465]
# Cost validation = [0.4449834]
# Cost validation = [0.4449736]
# Cost validation = [0.4448007]
# Cost validation = [0.44484041]
# Cost validation = [0.44490444]
# Cost validation = [0.44489504]
# Cost validation = [0.44503044]
# Cost validation = [0.44490093]
# Cost validation = [0.44477873]
# Cost validation = [0.44485534]
# Cost validation = [0.44484035]
# Cost validation = [0.44478518]
# Cost validation = [0.44475411]
# Cost validation = [0.44479115]
# Cost validation = [0.44483583]
# Cost validation = [0.44488589]
# Cost validation = [0.44503703]
# Cost validation = [0.44504924]
# Cost validation = [0.44493872]
# Cost validation = [0.44493981]
# Cost validation = [0.4449123]
# Cost validation = [0.44489644]
# Cost validation = [0.44506514]
# Cost validation = [0.44502993]
# Cost validation = [0.44495428]
# Cost validation = [0.44489245]
# Cost validation = [0.44490375]
# Cost validation = [0.44484118]
# Cost validation = [0.44479831]
# Cost validation = [0.44467394]
# Cost validation = [0.44466684]
# Cost validation = [0.4447026]
# Cost validation = [0.44467086]
# Cost validation = [0.44467426]
# Cost validation = [0.44458186]
# Cost validation = [0.4446161]
# Cost validation = [0.44456416]
# Cost validation = [0.44457179]
# Cost validation = [0.44451097]
# Cost validation = [0.44440614]
# Cost validation = [0.44437151]
# Cost validation = [0.44439506]
# Cost validation = [0.44440356]
# Cost validation = [0.44438589]
# Cost validation = [0.44438286]
# Cost validation = [0.44434709]
# Cost validation = [0.44442678]
# Cost validation = [0.44444603]
# Cost validation = [0.44454671]
# Cost validation = [0.44458681]
# Cost validation = [0.44463484]
# Cost validation = [0.44465689]
# Cost validation = [0.44462047]
# Cost validation = [0.44470528]
# Cost validation = [0.44459958]
# Cost validation = [0.44457226]
# Cost validation = [0.44452543]
# Cost validation = [0.44447896]
# Cost validation = [0.4444359]
# Cost validation = [0.4443293]
# Cost validation = [0.44435652]
# Cost validation = [0.44437871]
# Cost validation = [0.44432593]
# Cost validation = [0.4442894]
# Cost validation = [0.44429895]
# Cost validation = [0.444348]
# Cost validation = [0.4443838]
# Cost validation = [0.44436699]
# Cost validation = [0.44434557]
# Cost validation = [0.44427815]
# Cost validation = [0.44439102]
# Cost validation = [0.44442599]
# Cost validation = [0.44434368]
# Cost validation = [0.44435806]
# Cost validation = [0.44434284]
# Cost validation = [0.44434589]
# Cost validation = [0.44434586]
# Cost validation = [0.44429081]
# Cost validation = [0.44428963]
# Cost validation = [0.44422617]
# Cost validation = [0.44418877]
# Cost validation = [0.4441073]
# Cost validation = [0.44408765]
# Cost validation = [0.44403881]
# Cost validation = [0.4440614]
# Cost validation = [0.44406434]
# Cost validation = [0.44408051]
# Cost validation = [0.444122]
# Cost validation = [0.44404813]
# Cost validation = [0.44410937]
# Cost validation = [0.44408898]
# Cost validation = [0.44412803]
# Cost validation = [0.44418793]
# Cost validation = [0.44412508]
# Cost validation = [0.44407721]
# Cost validation = [0.44402152]
# Cost validation = [0.44398517]
# Cost validation = [0.44403448]
# Cost validation = [0.44407058]
# Cost validation = [0.44404215]
# Cost validation = [0.44403454]
# Cost validation = [0.44403299]
# Cost validation = [0.44404065]
# Cost validation = [0.44405634]
# Cost validation = [0.4440654]
# Cost validation = [0.44404142]
# Cost validation = [0.44404448]
# Cost validation = [0.44402052]
# Cost validation = [0.44404923]
# Cost validation = [0.44405128]
# Cost validation = [0.44411491]
# Cost validation = [0.44406965]
# Cost validation = [0.44403098]
# Cost validation = [0.44406288]
# Cost validation = [0.44405612]
# Cost validation = [0.44405349]
# Cost validation = [0.44397712]
# Cost validation = [0.44403188]
# Cost validation = [0.44404003]
# Cost validation = [0.44406256]
# Cost validation = [0.44406204]
# Cost validation = [0.44407126]
# Cost validation = [0.44412079]
# Cost validation = [0.44408249]
# Cost validation = [0.44407394]
# Cost validation = [0.4440506]
# Cost validation = [0.44407947]
# Cost validation = [0.4440456]
# Cost validation = [0.44405498]
# Cost validation = [0.44412847]
# Cost validation = [0.44417962]
# Cost validation = [0.44416677]
# Cost validation = [0.44420443]
# Cost validation = [0.44409497]
# Cost validation = [0.44405673]
# Cost validation = [0.44411277]
# Cost validation = [0.44411546]
# Cost validation = [0.44409467]
# Cost validation = [0.44408246]
# Cost validation = [0.44400187]
# Cost validation = [0.44406368]
# Cost validation = [0.44410915]
# Cost validation = [0.44416297]
# Cost validation = [0.44408711]
# Cost validation = [0.44395024]
# Cost validation = [0.44398877]
# Cost validation = [0.4438791]
# Cost validation = [0.44385301]
# Cost validation = [0.443891]
# Cost validation = [0.44390451]
# Cost validation = [0.44394025]
# Cost validation = [0.44398823]
# Cost validation = [0.4440604]
# Cost validation = [0.44399182]
# Cost validation = [0.44396002]
# Cost validation = [0.44397539]
# Cost validation = [0.44400826]
# Cost validation = [0.44398379]
# Cost validation = [0.44392218]
# Cost validation = [0.44405302]
# Cost validation = [0.44410133]
# Cost validation = [0.44423312]
# ...
# Cost validation = [0.44253178]
# Cost validation = [0.44247248]
# Cost validation = [0.44247811]
# Cost validation = [0.44245464]
# Cost validation = [0.44244529]
# Cost validation = [0.44248054]
# Cost validation = [0.44254021]
# Cost validation = [0.44265819]
# Cost validation = [0.44277705]
# Cost validation = [0.44273606]
# Cost validation = [0.44273026]
# Cost validation = [0.44272208]
# Cost validation = [0.44267632]
# Cost validation = [0.44269985]
# Cost validation = [0.44268014]
# Cost validation = [0.44266264]
# Cost validation = [0.44256721]
# Cost validation = [0.44263973]
# Cost validation = [0.44252955]
# Cost validation = [0.44248965]
# Cost validation = [0.44251173]
# Cost validation = [0.44244752]
# Cost validation = [0.44232202]
# Cost validation = [0.44233781]
# Cost validation = [0.44227577]
# Cost validation = [0.44225836]
# Cost validation = [0.44228327]
# Cost validation = [0.44225112]
# Cost validation = [0.44229073]
# Cost validation = [0.44237739]
# Cost validation = [0.44230575]
# Cost validation = [0.44234415]
# Cost validation = [0.44228894]
# Cost validation = [0.44222652]
# Cost validation = [0.44219351]
# Cost validation = [0.44218]
# Cost validation = [0.44223908]
# Cost validation = [0.4421952]
# Cost validation = [0.44221074]
# Cost validation = [0.44228134]
# Cost validation = [0.44226795]
# Cost validation = [0.44230663]
# Cost validation = [0.44233365]
# Cost validation = [0.44225417]
# Cost validation = [0.44228834]
# Cost validation = [0.44237095]
# Cost validation = [0.44234944]
# Cost validation = [0.44238804]
# Cost validation = [0.4424651]
# Cost validation = [0.44242005]
# Cost validation = [0.44239234]
# Cost validation = [0.44235924]
# Cost validation = [0.44235081]
# Cost validation = [0.44234287]
# Cost validation = [0.44228125]
# Cost validation = [0.442288]
# Cost validation = [0.44227526]
# Cost validation = [0.44229564]
# Cost validation = [0.44227205]
# Cost validation = [0.44230297]
# Cost validation = [0.44228708]
# Cost validation = [0.44231219]
# Cost validation = [0.44232883]
# Cost validation = [0.4423409]
# Cost validation = [0.44238776]
# Cost validation = [0.4423304]
# Cost validation = [0.4423072]
# Cost validation = [0.44233042]
# Cost validation = [0.4423168]
# Cost validation = [0.4423088]
# Cost validation = [0.44229491]
# Cost validation = [0.44230888]
# Cost validation = [0.44230164]
# Cost validation = [0.44229818]
# Cost validation = [0.4423053]
# Cost validation = [0.44228951]
# Cost validation = [0.44230365]
# Cost validation = [0.44226096]
# Cost validation = [0.44230168]
# Cost validation = [0.44232603]
# Cost validation = [0.44230141]
# Cost validation = [0.4422826]
# Cost validation = [0.44222226]
# Cost validation = [0.44232777]
# Cost validation = [0.44234081]
# Cost validation = [0.44233815]
# Cost validation = [0.44238815]
# Cost validation = [0.44241272]
# Cost validation = [0.44237512]
# Cost validation = [0.44241902]
# Cost validation = [0.44247568]
# Cost validation = [0.44245807]
# Cost validation = [0.44256826]
# Cost validation = [0.44263374]
# Cost validation = [0.442651]
# Cost validation = [0.44260592]
# Cost validation = [0.44256166]
# Cost validation = [0.44257752]
# Cost validation = [0.44246442]
# Cost validation = [0.44251251]
# Cost validation = [0.44246405]
# Cost validation = [0.44240146]
# Cost validation = [0.44236589]
# Cost validation = [0.442316]
# Cost validation = [0.44236761]
# Cost validation = [0.44236537]
# Cost validation = [0.4423006]
# Cost validation = [0.44234148]
# Cost validation = [0.44237653]
# Cost validation = [0.44237357]
# Cost validation = [0.44243196]
# Cost validation = [0.44251825]
# Cost validation = [0.4425011]
# Cost validation = [0.44241297]
# Cost validation = [0.44247488]
# Cost validation = [0.44258462]
# Cost validation = [0.44247084]
# Cost validation = [0.44247226]
# Cost validation = [0.44256624]
# Cost validation = [0.44246925]
# Cost validation = [0.44244141]
# Cost validation = [0.44235083]
# Cost validation = [0.44238335]
# Cost validation = [0.44231059]
# Cost validation = [0.4422947]
# Cost validation = [0.44238571]
# Cost validation = [0.44239615]
# Cost validation = [0.44239173]
# Cost validation = [0.44244354]
# Cost validation = [0.44243178]
# Cost validation = [0.44241373]
# Cost validation = [0.44249856]
# Cost validation = [0.44249405]
# Cost validation = [0.44247457]
# Cost validation = [0.44242122]
# Cost validation = [0.44241858]
# Cost validation = [0.44242097]
# Cost validation = [0.44255322]
# Cost validation = [0.44242129]
# Cost validation = [0.44234605]
# Cost validation = [0.44237551]
# Cost validation = [0.44247582]
# Cost validation = [0.44248854]
# Cost validation = [0.44244314]
# Cost validation = [0.4424275]
# Cost validation = [0.44236542]
# Cost validation = [0.44237224]
# Cost validation = [0.44234427]
# Cost validation = [0.44238089]
# Cost validation = [0.44243229]
# Cost validation = [0.44239188]
# Cost validation = [0.44246011]
# Cost validation = [0.44247936]
# Cost validation = [0.44246244]
# Cost validation = [0.44248241]
# Cost validation = [0.44245496]
# Cost validation = [0.44241632]
# Cost validation = [0.44242907]
# Cost validation = [0.44236575]
# Cost validation = [0.44237478]
# Cost validation = [0.44234081]
# Cost validation = [0.44234547]
# Cost validation = [0.44233252]
# Cost validation = [0.44237875]
# Cost validation = [0.44238265]
# Cost validation = [0.44230714]
# Cost validation = [0.44222179]
# Cost validation = [0.44209018]
# Cost validation = [0.44206406]
# Cost validation = [0.44211048]
# Cost validation = [0.44214797]
# Cost validation = [0.44202774]
# Cost validation = [0.44203377]
# Cost validation = [0.44199593]
# Cost validation = [0.44196399]
# Cost validation = [0.44195946]
# Cost validation = [0.44196717]
# Cost validation = [0.44192002]
# Cost validation = [0.44195203]
# Cost validation = [0.44195997]
# Cost validation = [0.44204376]
# Cost validation = [0.44210731]
# Cost validation = [0.4420763]
# Cost validation = [0.44202944]
# Cost validation = [0.44195352]
# Cost validation = [0.44196024]
# Cost validation = [0.44196981]
# Cost validation = [0.44199051]
# Cost validation = [0.44209455]
# Cost validation = [0.44214074]
# Cost validation = [0.44212923]
# Cost validation = [0.44216921]
# Cost validation = [0.44227073]
# Cost validation = [0.44213132]
# Cost validation = [0.44209259]
# Cost validation = [0.44214207]
# Cost validation = [0.44213057]
# Cost validation = [0.44223016]
# Cost validation = [0.44220091]
# Cost validation = [0.44212502]
# Cost validation = [0.44214977]
# Cost validation = [0.44209061]
# Cost validation = [0.44209248]
# Cost validation = [0.44205397]
# Cost validation = [0.44214878]
# Cost validation = [0.44211367]
# Cost validation = [0.44217336]
# Cost validation = [0.44224529]
# Cost validation = [0.44228263]
# Cost validation = [0.44223262]
# Cost validation = [0.44223516]
# Cost validation = [0.44222372]
# Cost validation = [0.44218025]
# Cost validation = [0.44208541]
# Cost validation = [0.4421273]
# Cost validation = [0.44220126]
# Cost validation = [0.44217602]
# Cost validation = [0.44208591]
# Cost validation = [0.44205382]
# Cost validation = [0.44211631]
# Cost validation = [0.44210216]
# Cost validation = [0.44213415]
# Cost validation = [0.4421689]
# Cost validation = [0.44226261]
# Cost validation = [0.44218482]
# Cost validation = [0.44219885]
# Cost validation = [0.44218369]
# Cost validation = [0.44215919]
# Cost validation = [0.4421142]
# Cost validation = [0.44207958]
# Cost validation = [0.44202573]
# Cost validation = [0.44202133]
# Cost validation = [0.44205548]
# Cost validation = [0.44199804]
# Cost validation = [0.44196607]
# Cost validation = [0.44193497]
# Cost validation = [0.4418815]
# Cost validation = [0.44184692]
# Cost validation = [0.44185795]
# Cost validation = [0.44189819]
# Cost validation = [0.44189738]
# Cost validation = [0.44186252]
# Cost validation = [0.44179988]
# Cost validation = [0.44182741]
# Cost validation = [0.44187054]
# Cost validation = [0.44186344]
# Cost validation = [0.44192789]
# Cost validation = [0.44193342]
# Cost validation = [0.44196843]
# Cost validation = [0.44204087]
# Cost validation = [0.44198604]
# Cost validation = [0.44195319]
# Cost validation = [0.44191156]
# Cost validation = [0.44192164]
# Cost validation = [0.4419279]
# Cost validation = [0.44201495]
# Cost validation = [0.44201552]
# Cost validation = [0.44217412]
# Cost validation = [0.44211786]
# Cost validation = [0.44214009]
# Cost validation = [0.44209995]
# Cost validation = [0.44201393]
# Cost validation = [0.44196674]
# Cost validation = [0.4419353]
# Cost validation = [0.44202585]
# Cost validation = [0.44202091]
# Cost validation = [0.44201033]
# Cost validation = [0.44201202]
# Cost validation = [0.44203453]
# Cost validation = [0.44198018]
# Cost validation = [0.4419236]
# Cost validation = [0.44184784]
# Cost validation = [0.44173737]
# Cost validation = [0.44177477]
# Cost validation = [0.44174216]
# Cost validation = [0.44178092]
# Cost validation = [0.44186019]
# Cost validation = [0.44186448]
# Cost validation = [0.44188269]
# Cost validation = [0.44188928]
# Cost validation = [0.44188908]
# Cost validation = [0.44190814]
# Cost validation = [0.44192527]
# Cost validation = [0.44194418]
# Cost validation = [0.44194909]
# Cost validation = [0.44190594]
# Cost validation = [0.44180465]
# Cost validation = [0.44182515]
# Cost validation = [0.44182748]
# Cost validation = [0.44169849]
# Cost validation = [0.44169326]
# Cost validation = [0.44166142]
# Cost validation = [0.44162835]
# Cost validation = [0.44165218]
# Cost validation = [0.44166768]
# Cost validation = [0.44165117]
# Cost validation = [0.44163807]
# Cost validation = [0.44165746]
# Cost validation = [0.4417155]
# Cost validation = [0.44169828]
# Cost validation = [0.44167822]
# Cost validation = [0.44165147]
# Cost validation = [0.44165377]
# Cost validation = [0.44165971]
# Cost validation = [0.44173249]
# Cost validation = [0.44172757]
# Cost validation = [0.44171363]
# Cost validation = [0.44170021]
# Cost validation = [0.44161658]
# Cost validation = [0.44161188]
# Cost validation = [0.44157601]
# Cost validation = [0.44163074]
# Cost validation = [0.44161922]
# Cost validation = [0.44159018]
# Cost validation = [0.44152722]
# Cost validation = [0.44150054]
# Cost validation = [0.44153436]
# Cost validation = [0.44153802]
# Cost validation = [0.44154131]
# Cost validation = [0.44153605]
# Cost validation = [0.4415676]
# Cost validation = [0.44156894]
# Cost validation = [0.44154259]
# Cost validation = [0.44155284]
# Cost validation = [0.44156548]
# Cost validation = [0.44160411]
# Cost validation = [0.4415381]
# Cost validation = [0.44147154]
# Cost validation = [0.44147656]
# Cost validation = [0.44147518]
# Cost validation = [0.44153874]
# Cost validation = [0.44154826]
# Cost validation = [0.44149671]
# Cost validation = [0.44155091]
# Cost validation = [0.44153088]
# Cost validation = [0.44147774]
# Cost validation = [0.44152866]
# Cost validation = [0.44156154]
# Cost validation = [0.44152798]
# Cost validation = [0.44148205]
# Cost validation = [0.44156437]
# Cost validation = [0.44154546]
# Cost validation = [0.44154306]
# Cost validation = [0.44156266]
# Cost validation = [0.44158603]
# Cost validation = [0.44162643]
# Cost validation = [0.44153414]
# Cost validation = [0.44154594]
# Cost validation = [0.44161102]
# Cost validation = [0.44170893]
# Cost validation = [0.44175282]
# Cost validation = [0.44172336]
# Cost validation = [0.44171337]
# Cost validation = [0.44174712]
# Cost validation = [0.44169494]
# Cost validation = [0.44160877]
# Cost validation = [0.44156999]
# Cost validation = [0.44146498]
# Cost validation = [0.44144624]
# Cost validation = [0.44141764]
# Cost validation = [0.44139796]
# Cost validation = [0.44148336]
# Cost validation = [0.4415381]
# Cost validation = [0.44156083]
# Cost validation = [0.44161674]
# Cost validation = [0.44165926]
# Cost validation = [0.44168654]
# Cost validation = [0.44169137]
# Cost validation = [0.44165245]
# Cost validation = [0.44163283]
# Cost validation = [0.44163408]
# Cost validation = [0.44166701]
# Cost validation = [0.44167345]
# Cost validation = [0.44169169]
# Cost validation = [0.44165211]
# Cost validation = [0.44159393]
# Cost validation = [0.44157103]
# Cost validation = [0.44154088]
# Cost validation = [0.44155455]
# Cost validation = [0.44150942]
# Cost validation = [0.44147467]
# Cost validation = [0.44141913]
# Cost validation = [0.44142637]
# Cost validation = [0.4413863]
# Cost validation = [0.4414619]
# Cost validation = [0.44150802]
# Cost validation = [0.44148259]
# Cost validation = [0.4414645]
# Cost validation = [0.44144379]
# Cost validation = [0.44141283]
# Cost validation = [0.4414164]
# Cost validation = [0.44140398]
# Cost validation = [0.44143083]
# Cost validation = [0.44142764]
# Cost validation = [0.44140448]
# Cost validation = [0.44146084]
# Cost validation = [0.44143738]
# Cost validation = [0.44142216]
# Cost validation = [0.44146088]
# Cost validation = [0.44145508]
# Cost validation = [0.4414075]
# Cost validation = [0.44140753]
# Cost validation = [0.44141216]
# Cost validation = [0.44140607]
# Cost validation = [0.44141436]
# Cost validation = [0.44145478]
# Cost validation = [0.44140652]
# Cost validation = [0.44139839]
# Cost validation = [0.44137709]
# Cost validation = [0.44136364]
# Cost validation = [0.44138617]
# Cost validation = [0.44142761]
# Cost validation = [0.44141334]
# Cost validation = [0.44139195]
# Cost validation = [0.44138121]
# Cost validation = [0.44138949]
# Cost validation = [0.44141141]
# Cost validation = [0.44145099]
# Cost validation = [0.44147651]
# Cost validation = [0.44147549]
# Cost validation = [0.44150964]
# Cost validation = [0.44151894]
# Cost validation = [0.44160861]
# Cost validation = [0.44158486]
# Cost validation = [0.44158464]
# Cost validation = [0.44160568]
# Cost validation = [0.44161847]
# Cost validation = [0.44160245]
# Cost validation = [0.44163372]
# Cost validation = [0.44157933]
# Cost validation = [0.44156136]
# Cost validation = [0.44148854]
# Cost validation = [0.44149215]
# Cost validation = [0.44149718]
# Cost validation = [0.44147487]
# Cost validation = [0.4414996]
# Cost validation = [0.44151463]
# Cost validation = [0.44151466]
# Cost validation = [0.44146315]
# Cost validation = [0.44138052]
# Cost validation = [0.4413803]
# Cost validation = [0.44140038]
# Cost validation = [0.44140388]
# Cost validation = [0.44143364]
# Cost validation = [0.44143705]
# Cost validation = [0.44144945]
# Cost validation = [0.44141027]
# Cost validation = [0.44142184]
# Cost validation = [0.44148269]
# Cost validation = [0.44151789]
# Cost validation = [0.44147754]
# Cost validation = [0.4415092]
# Cost validation = [0.44155621]
# Cost validation = [0.44146094]
# Cost validation = [0.44146862]
# Cost validation = [0.44152048]
# Cost validation = [0.44148227]
# Cost validation = [0.44154381]
# Cost validation = [0.44160132]
# Cost validation = [0.44159253]
# Cost validation = [0.4415784]
# Cost validation = [0.44148883]
# Cost validation = [0.44145051]
# Cost validation = [0.44143668]
# Cost validation = [0.44138392]
# Cost validation = [0.44140539]
# Cost validation = [0.44141129]
# Cost validation = [0.44137374]
# Cost validation = [0.44133453]
# Cost validation = [0.44138522]
# Cost validation = [0.44134473]
# Cost validation = [0.44133835]
# Cost validation = [0.44134405]
# Cost validation = [0.44131649]
# Cost validation = [0.44129106]
# Cost validation = [0.44129767]
# Cost validation = [0.44128114]
# Cost validation = [0.44127882]
# Cost validation = [0.4412591]
# Cost validation = [0.44126965]
# Cost validation = [0.44130729]
# Cost validation = [0.44130588]
# Cost validation = [0.44132167]
# Cost validation = [0.44133434]
# Cost validation = [0.44138636]
# Cost validation = [0.44147909]
# Cost validation = [0.44156088]
# Cost validation = [0.44162071]
# Cost validation = [0.44164558]
# Cost validation = [0.44170201]
# Cost validation = [0.4417628]
# Cost validation = [0.44174042]
# Cost validation = [0.44178716]
# Cost validation = [0.44177365]
# Cost validation = [0.44168745]
# Cost validation = [0.44177021]
# Cost validation = [0.44170821]
# Cost validation = [0.44174957]
# Cost validation = [0.4417619]
# Cost validation = [0.44185171]
# Cost validation = [0.4417126]
# Cost validation = [0.4417399]
# Cost validation = [0.4417543]
# Cost validation = [0.44181409]
# Cost validation = [0.44173935]
# Cost validation = [0.44182456]
# Cost validation = [0.44179322]
# Cost validation = [0.44172358]
# Cost validation = [0.44179464]
# Cost validation = [0.44188145]
# Cost validation = [0.44183583]
# Cost validation = [0.44180931]
# Cost validation = [0.44181603]
# Cost validation = [0.44180017]
# Cost validation = [0.44166275]
# Cost validation = [0.44162495]
# Cost validation = [0.44158298]

# %%
plt.figure(figsize=([8,8]))
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)

fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.9564108  0.0435892 ]
#  [0.64456438 0.35543562]]

# %%
classes = logreg.predict(xtrain)
print(100*np.sum(classes==ytrain)/len(classes),'% Training Accuracy')
print(f1_score(ytrain, classes))

classes = logreg.predict(xval)
print(100*np.sum(classes==yval)/len(classes),'% Validation Accuracy')
print(f1_score(yval, classes))


classes = logreg.predict(xtest)
print(100*np.sum(classes==ytest)/len(classes),'% Test Accuracy')
print(f1_score(ytest, classes))
# Out:
# 81.81904761904762 % Training Accuracy
# 0.4670575097710776
# 81.7 % Validation Accuracy
# 0.46017699115044247
# 82.65 % Test Accuracy
# 0.4696892511462048

# %%
import scikitplot as skplt
from sklearn.metrics import roc_auc_score

y_probas = classified

y_probas = y_probas.flatten()
y_temp = np.zeros((y_probas.shape[0], 2))
y_temp[:,0] = 1-y_probas
y_temp[:,1] = y_probas 
#y_probas = y_temp



y_temp2 = np.zeros((y_probas.shape[0], 2))
y_temp2[:,0] = (1-ytest).ravel()
y_temp2[:,1] = ytest.ravel() 


ting=roc_auc_score(ytest, y_probas)
ting2=roc_auc_score(ytest, ytest)

print(ting)
print(ting2)

skplt.metrics.plot_roc(ytest, y_temp)
skplt.metrics.plot_roc(ytest, y_temp2)
# ikke surr mer med det her
# Out:
# 0.6559232111395292
# 1.0

# %%
def bestCurve(y):
    defaults = sum(y == 1)
    total = len(y)
    x = np.linspace(0, 1, total)
    y1 = np.linspace(0, 1, defaults)
    y2 = np.ones(total-defaults)
    y3 = np.concatenate([y1,y2])
    return x, y3

# %%
model = LogisticRegression()
model.fit(xtrain, ytrain)
predicted_classes = model.predict(xtrain)
accuracy = accuracy_score(ytrain.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(ytrain, predicted_classes)

print(accuracy, '% Training Accuracy')

predicted_classes = model.predict(xval)
accuracy = accuracy_score(yval.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(yval, predicted_classes)

print(accuracy, '% Validation Accuracy')

predicted_classes = model.predict(xtest)
accuracy = accuracy_score(ytest.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(ytest, predicted_classes)

print(accuracy, '% Test Accuracy')
# Out:
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 82.04285714285714 % Training Accuracy
# 81.83333333333334 % Validation Accuracy
# 82.78333333333333 % Test Accuracy

# %% [markdown]
# # C)
# Neural Network.

# %%
epochs=1000
batch_size=int(len(ytrain)/20)
n_features=x.shape[1]
etavec = np.logspace(-6, -1, 6)
lmbvec = np.logspace(-6, -1, 6)
lmbvec[0]=0

activation = [lrf.relu, lrf.sigmoid, lrf.sigmoid]
derivative = [lrf.relu_deriv, lrf.sigmoid_deriv, lrf.sigmoid_deriv]

saved_net = np.zeros((len(etavec), len(lmbvec)), dtype=object)
train_accuracy = np.zeros((len(etavec), len(lmbvec)))
for i, etas in enumerate(etavec):
    for j, lmb in enumerate(lmbvec):
        np.random.seed(2019)
        neural_net = nn.ANN(lmb=lmb, bias=0, eta=etas,early_stop_tol = 0,\
                            early_stop_nochange=200, mode = 'classification', regularization = 'l1')            
        neural_net.add_layers(n_features=[91,50,20], n_neurons = [50,20,1] , n_layers=3)
        
        neural_net.train(epochs, batch_size, xtrain,ytrain,activation,derivative \
                         ,xval,yval, verbose=False)

        pred = neural_net.feed_out(xval, activation)
        val_loss[i,j] =  lrf.cost_log_ols(pred.ravel(),yval.T)
        train_f1[i,j] =  f1_score(yval, np.round(pred))
        
        print('Validation loss for', '\u03B7 =', etas, '&', '\u03BB =', lmb, '=', val_loss [i,j])
# Out:
# Validation loss for η = 1e-06 & λ = 0.0 = 0.8561037586441849
# Validation loss for η = 1e-06 & λ = 1e-05 = 0.8561037587727597
# Validation loss for η = 1e-06 & λ = 0.0001 = 0.8561037599299315
# Validation loss for η = 1e-06 & λ = 0.001 = 0.8561037715026162
# Validation loss for η = 1e-06 & λ = 0.01 = 0.8561038873263519
# Validation loss for η = 1e-06 & λ = 0.1 = 0.8561050552901972
# Validation loss for η = 1e-05 & λ = 0.0 = 0.848774110947204
# Validation loss for η = 1e-05 & λ = 1e-05 = 0.8487741092047537
# Validation loss for η = 1e-05 & λ = 0.0001 = 0.8487740935241959
# Validation loss for η = 1e-05 & λ = 0.001 = 0.8487739368685189
# Validation loss for η = 1e-05 & λ = 0.01 = 0.8487723853113248
# Validation loss for η = 1e-05 & λ = 0.1 = 0.8487583800639116
# Validation loss for η = 0.0001 & λ = 0.0 = 0.7964535332474241
# Validation loss for η = 0.0001 & λ = 1e-05 = 0.7964534334209138
# Validation loss for η = 0.0001 & λ = 0.0001 = 0.7964525355899562
# Validation loss for η = 0.0001 & λ = 0.001 = 0.7964436174560049
# Validation loss for η = 0.0001 & λ = 0.01 = 0.7963604910159162
# Validation loss for η = 0.0001 & λ = 0.1 = 0.7961603942264657
# Validation loss for η = 0.001 & λ = 0.0 = 0.7287122719348812
# Validation loss for η = 0.001 & λ = 1e-05 = 0.7287188903826017
# Validation loss for η = 0.001 & λ = 0.0001 = 0.7287785414415381
# Validation loss for η = 0.001 & λ = 0.001 = 0.729383358659264
# Validation loss for η = 0.001 & λ = 0.01 = 0.7359645638272626
# Validation loss for η = 0.001 & λ = 0.1 = 0.7675375698580081
# Validation loss for η = 0.01 & λ = 0.0 = 0.7316779544435239
# Validation loss for η = 0.01 & λ = 1e-05 = 0.7316350113537331
# Validation loss for η = 0.01 & λ = 0.0001 = 0.7318532354277535
# Validation loss for η = 0.01 & λ = 0.001 = 0.7336531882623385
# Validation loss for η = 0.01 & λ = 0.01 = 0.7494789861510824
# Validation loss for η = 0.01 & λ = 0.1 = 0.7640255038620253
# Validation loss for η = 0.1 & λ = 0.0 = 0.730914236301853
# Validation loss for η = 0.1 & λ = 1e-05 = 0.7309760769829197
# Validation loss for η = 0.1 & λ = 0.0001 = 0.7315034459740473
# Validation loss for η = 0.1 & λ = 0.001 = 0.7359066524104081
# Validation loss for η = 0.1 & λ = 0.01 = 0.7626952927658687
# Validation loss for η = 0.1 & λ = 0.1 = 0.7618213832129872

# %%
val_loss = train_accuracy

import seaborn as sns
train_accuracy[np.isnan(train_accuracy)]=2

yticklabels = etavec
xticklabels = lmbvec
fig, ax = plt.subplots(figsize = (10, 12))
sns.heatmap(val_loss, annot=True, ax=ax, cmap="viridis",\
            yticklabels=yticklabels, xticklabels=xticklabels)
#ax.set_title("Training Accuracy", fontsize=20)
ax.set_ylabel("$\eta$", fontsize=20)
ax.set_xlabel("$\lambda$", fontsize=20)
tmp = np.arange(len(etavec))+0.5
tmp[0] = 0
tmp[-1]+=0.5
ax.set_yticks(tmp)
tmp = np.arange(len(lmbvec)) + 0.5
ax.set_xticks(tmp)
plt.show()

# %%
best_eta_index, best_lmb_index = np.where(val_loss == np.min(val_loss))
best_eta,best_lmb = etavec[best_eta_index], lmbvec[best_lmb_index] 

print('eta=',best_eta)
print('lmb=',best_lmb)
# Out:
# eta= [0.001]
# lmb= [0.]

# %%
np.random.seed(2019)
epochs=20
batch_size=int(len(ytrain)/20)
activation = [lrf.relu, lrf.sigmoid, lrf.sigmoid]
derivative = [lrf.relu_deriv, lrf.sigmoid_deriv, lrf.sigmoid_deriv]

neural_net = nn.ANN(lmb=0, bias=0, eta= 0.1,early_stop_tol = 0,\
                            early_stop_nochange=200, mode = 'classification', regularization = 'l1')            
neural_net.add_layers(n_features=[xtrain.shape[1],50,20], n_neurons = [50,20,1] , n_layers=3)
neural_net.train(epochs, batch_size, xtrain,ytrain,activation,derivative ,xtrain,ytrain, verbose=True)
cost_val, cost_train = neural_net.costs()
neural_net.coefs()
# Out:
# Epoch 1 loss 0.7964660514750733
# Epoch 2 loss 0.7679269363629906
# Epoch 3 loss 0.7531617647036984
# Epoch 4 loss 0.7447579519762336
# Epoch 5 loss 0.7393993282560891
# Epoch 6 loss 0.7357506176314084
# Epoch 7 loss 0.7332877344496578
# Epoch 8 loss 0.7311741606775682
# Epoch 9 loss 0.7297790634196079
# Epoch 10 loss 0.728830906118965
# Epoch 11 loss 0.7282673599418205
# Epoch 12 loss 0.7277524104278217
# Epoch 13 loss 0.7275768017667317
# Epoch 14 loss 0.7278089685652314
# Epoch 15 loss 0.7275864137561668
# Epoch 16 loss 0.7278949185561052
# Epoch 17 loss 0.728272101603924
# Epoch 18 loss 0.72845492615269
# Epoch 19 loss 0.7288604948813852
# Epoch 20 loss 0.7293407827458969
# {'w0': array([[-0.21705654,  0.82908447,  1.48656823, ..., -0.78553688,
#           1.8278106 , -0.4375713 ],
#         [ 1.18363851, -0.5372478 , -1.03344767, ..., -1.86414429,
#           0.27810321, -1.3393833 ],
#         [ 0.10172734,  0.31994297, -0.24081801, ...,  0.44173539,
#           1.95821775,  0.26146996],
#         ...,
#         [ 0.07228804, -0.46664513,  2.54523527, ..., -0.38008988,
#           1.0188979 ,  0.10654457],
#         [ 2.42414777,  0.07914923,  1.85589689, ...,  1.98139573,
#          -1.36014425,  0.22331135],
#         [ 1.95457261, -2.07395689, -0.63646998, ...,  0.28304803,
#          -0.34849249, -0.92114235]]),
#  'b0': array([ 0.02425777,  0.04747476,  0.00288715,  0.01356735,  0.00314021,
#          0.0394709 , -0.00712558, -0.00082557,  0.05201802,  0.00770538,
#          0.03315662,  0.08013335,  0.0077388 ,  0.05567046, -0.08286631,
#          0.01128748, -0.04079271,  0.05362641, -0.03025132, -0.00422318,
#          0.00666808, -0.0267469 , -0.01937835,  0.06153392,  0.0043724 ,
#          0.0517123 , -0.02779841, -0.04096585,  0.00707268,  0.03769205,
#          0.03526136,  0.03703088,  0.03924776,  0.06606222, -0.0478285 ,
#         -0.05256051, -0.01554963,  0.03952669,  0.02996961, -0.01143234,
#          0.0735485 ,  0.01331094, -0.01713132, -0.01414049,  0.00055292,
#         -0.06087815,  0.0601033 , -0.01635663, -0.02279091,  0.01506547]),
#  'w1': array([[ 7.27739966e-01, -8.45281472e-01,  6.79333215e-01,
#          -6.43355137e-01, -1.33687179e+00, -1.88856212e+00,
#           7.79417378e-02,  1.38181062e-01, -1.24512766e+00,
#           2.78653617e+00,  1.03658400e+00,  1.67087541e+00,
#           4.28901634e-01, -1.70566755e+00,  1.11539017e+00,
#           1.49253664e+00, -1.67365506e+00, -6.37625374e-01,
#           1.02472823e+00, -1.94416525e+00],
#         [ 2.33016931e-01,  1.51240123e+00, -1.14583444e+00,
#           5.48743536e-02,  1.03230789e+00, -3.83977857e-01,
#           5.55795959e-01,  4.84947721e-01, -6.16835554e-01,
#           2.33110030e-01, -1.23358235e-01, -1.70201329e-01,
#           8.23815774e-01,  1.08060700e+00, -1.55142156e-01,
#           4.28162548e-01, -1.39060513e+00,  4.84941534e-01,
#           5.45641319e-01,  1.04570032e+00],
#         [-3.72262191e-01,  9.61881812e-01, -5.46063383e-01,
#           2.18722927e+00, -5.58258549e-03, -2.74552180e-01,
#          -1.74416949e+00,  1.35318366e+00,  1.46281283e-01,
#          -7.07821494e-01, -6.62424203e-01, -4.26222935e-01,
#          -3.87346399e-01, -1.16803131e+00,  3.32420446e-01,
#           3.82548259e-02, -4.07869552e-01, -1.14256954e+00,
#           1.77598279e-01, -2.58942189e+00],
#         [-1.06797949e+00,  1.08021965e+00, -9.36909449e-01,
#          -1.21162205e+00, -5.32749403e-01,  4.69389428e-01,
#           3.34413786e-01,  8.27350990e-01,  8.41147828e-01,
#           5.90014866e-01, -1.43732574e+00,  2.01989237e-01,
#           1.54760943e+00,  4.00842046e-01,  1.49561435e-01,
#           1.19168893e+00, -9.33294948e-01,  1.13773264e-01,
#           4.25236542e-01, -8.76098409e-01],
#         [ 6.35315220e-01,  6.94725893e-01, -7.46431348e-01,
#           6.96273866e-01,  1.06567813e+00, -2.07601274e-01,
#           2.54580476e-01, -9.37634057e-01, -4.86905678e-01,
#          -9.72383038e-01,  9.24820646e-01, -3.01821997e-01,
#          -4.90673879e-01, -4.29528823e-01, -8.57795213e-01,
#           4.73881485e-01,  1.07814152e+00, -1.72336772e-02,
#          -1.63878077e+00, -7.17593698e-01],
#         [ 8.68153739e-02,  8.93331143e-01, -4.44046180e-01,
#          -1.93502624e+00, -1.58046684e+00, -4.54520589e-01,
#          -1.66176792e+00,  8.76091448e-01,  8.13317996e-01,
#          -3.85503534e-01, -3.69321882e-02,  2.04446285e+00,
#          -1.55049181e+00, -1.27913079e+00,  1.71317827e-01,
#          -7.35344440e-01,  1.52929283e+00,  2.05850837e-01,
#          -4.86243878e-01, -2.04674989e-01],
#         [-5.83804088e-01,  6.97677576e-01,  1.20836490e-01,
#          -9.69574071e-01, -1.00340891e+00,  1.40399979e+00,
#           2.03480480e-01,  3.29738410e-01,  5.74324895e-01,
#           8.18300292e-01, -8.04758044e-02,  2.47891997e-01,
#           8.81155716e-01, -1.63701275e-01,  3.86053868e-01,
#          -2.61910634e-01,  1.24097602e+00,  1.49709285e+00,
#           2.63618711e-01,  3.62519728e-01],
#         [-4.12477175e-01,  5.36554685e-01,  1.25296253e-02,
#           4.22073828e-01, -1.05871471e+00,  1.01912819e+00,
#           7.43646439e-01, -6.73400579e-01,  5.45315793e-01,
#           5.14896331e-01, -5.77719901e-01, -7.39660129e-01,
#           9.42146062e-01, -8.70123057e-02, -3.36240278e-01,
#          -2.06014307e+00, -4.38335024e-02,  2.07648590e+00,
#           9.91885955e-01,  1.52800228e-01],
#         [-3.96430455e-01,  1.27312591e+00, -4.05014879e-01,
#          -6.59321946e-01, -1.27141524e+00, -1.44253214e+00,
#          -1.16161408e+00,  7.52128781e-01,  2.41324759e+00,
#           4.83772820e-01,  6.13059967e-01, -2.65679805e-01,
#           1.29775807e+00, -9.52082895e-01,  2.70049224e-01,
#          -2.99756595e-01,  6.85636405e-01, -4.42931136e-01,
#           6.27661882e-01, -5.90209314e-01],
#         [ 4.01447233e-01, -3.61157839e-01,  4.40553768e-02,
#          -2.67779187e-01, -3.32124593e-01, -1.44377752e+00,
#          -3.55575736e-01, -2.08149553e-01, -5.06645178e-02,
#          -1.02076790e-02, -3.20798800e-01, -4.37268763e-03,
#          -4.54701638e-03,  4.62512213e-01,  9.48516849e-01,
#           2.08598283e+00, -1.29648611e-01, -6.79579809e-01,
#          -4.43233838e-01, -9.85839989e-01],
#         [-1.32904638e+00,  2.81905756e-01,  4.11934375e-02,
#          -3.71243839e-01, -1.11241715e+00, -9.88230039e-01,
#          -2.94330072e-01,  4.44576052e-01,  7.53648962e-01,
#           6.16732065e-01, -1.33518991e-01,  1.88267254e+00,
#          -1.52844759e-01,  7.68652020e-01,  2.28077281e+00,
#           1.85682293e-02,  2.15363414e-01,  1.09476532e+00,
#           6.63733746e-01,  1.63295010e+00],
#         [-1.07870789e+00,  9.51117469e-01,  8.01457265e-01,
#          -1.02231606e+00, -4.13905752e-01, -1.04058110e+00,
#           1.97274742e+00,  1.19966821e+00,  4.97999374e-01,
#           1.53373335e-01, -1.55817627e+00, -3.23711589e-01,
#          -1.61675938e-01, -1.72537852e-01, -1.98702428e-01,
#           4.02740293e-01, -4.21554224e-01, -8.95914673e-01,
#           3.86311812e-01, -4.14639695e-01],
#         [ 1.59689468e+00,  2.23974150e-01,  3.86761849e-01,
#           1.26719736e+00, -1.28822420e+00, -4.19984721e-01,
#          -6.96211204e-01, -1.61200713e-01,  2.06917005e+00,
#          -1.12949796e+00, -8.35834252e-01, -3.26294700e-01,
#          -1.40659837e-01,  8.46362004e-01,  3.66676104e-01,
#          -1.04655727e+00, -1.19004135e+00, -3.46528964e-01,
#           7.88831036e-01,  2.57307250e-01],
#         [ 1.22456470e+00,  9.81277319e-02,  8.31525568e-02,
#           7.78048965e-01, -1.96377220e+00, -4.37290009e-01,
#           1.07669232e-01,  5.09385009e-01,  4.76742868e-01,
#          -1.41767157e+00,  6.27594023e-01,  1.49176993e-01,
#          -1.93790835e+00,  2.35740910e+00, -2.62068650e-01,
#           8.94323318e-01,  1.13551069e+00,  8.94367427e-01,
#           1.54075529e+00,  6.79878879e-01],
#         [ 5.37770253e-01, -9.76359468e-01, -1.16656486e+00,
#           2.48284165e+00, -9.64131846e-01,  1.24343369e+00,
#           3.18630706e-01,  2.35117621e-01, -4.12262912e-01,
#          -1.01649990e+00, -2.91749555e-01, -1.64127775e+00,
#           1.07346541e+00, -5.54002501e-01, -1.33039448e+00,
#           2.27425940e-01, -3.52692814e-01, -1.02943909e+00,
#           3.15096394e-01, -6.92914142e-01],
#         [-1.19670663e+00,  5.60842765e-02, -4.12137589e-01,
#          -4.14031553e-01,  2.16159213e-01, -5.80914404e-01,
#          -6.06593277e-01, -2.96174999e-01, -2.30476706e-01,
#          -2.58034007e-01,  5.86671429e-01, -5.32163087e-01,
#           8.93944914e-01,  1.41461701e-01, -6.45873565e-01,
#           5.72385999e-02,  2.49919526e+00, -1.87933635e+00,
#           6.09035098e-01, -3.24667287e-01],
#         [ 2.85270082e-01,  5.69317819e-01,  1.30087500e+00,
#           1.43436155e+00,  1.61586519e-01,  8.02543149e-01,
#          -1.44869089e+00,  1.29456200e+00,  6.75923987e-01,
#          -4.34762210e-01,  1.26172618e+00,  2.65983135e+00,
#           7.86070751e-01, -1.91827466e+00, -7.63011700e-01,
#          -1.56027998e+00,  5.85873520e-01,  4.27603754e-01,
#          -9.41821014e-01,  1.54223768e+00],
#         [-1.19094368e+00,  1.00080568e+00, -1.29297268e-02,
#          -1.39470492e+00,  1.31652849e+00,  2.88390118e-01,
#          -8.30972856e-02, -6.34650650e-01,  1.09223659e+00,
#           2.23803321e+00,  1.73766336e+00, -1.37130953e+00,
#          -8.05932600e-02,  3.28246289e-03,  1.26326348e+00,
#           4.39588278e-01, -5.14322144e-01,  1.45874272e-01,
#           8.18123054e-01, -1.40155863e+00],
#         [-1.17781898e+00, -1.47471079e+00, -1.68257784e+00,
#           1.36842544e+00,  1.35671856e-01,  5.40798599e-01,
#           9.44954803e-01,  3.44059727e-01,  2.82545766e-01,
#           5.21042646e-01,  4.72944952e-01, -9.92673040e-02,
#          -1.59158118e+00, -7.04566309e-01, -1.52011811e+00,
#           1.26515331e+00,  3.99723265e-01, -2.19296364e-01,
#           6.30461529e-01,  9.38018909e-01],
#         [-5.61038018e-01, -7.95173940e-01,  3.15400238e-01,
#          -3.88759104e-01, -4.85315154e-01, -1.03921298e+00,
#          -3.19558777e-01, -1.40631246e+00,  8.99849968e-01,
#          -6.72046211e-01, -5.33469948e-01,  1.33593555e+00,
#           4.30743454e-01,  7.67865457e-01,  9.48177907e-02,
#           3.45837811e-02,  1.21945052e+00,  1.20764738e+00,
#           1.37067418e-01, -1.36659557e+00],
#         [-9.07226634e-01, -1.54401319e+00,  4.88560826e-01,
#           1.80006041e-01,  2.13409048e+00, -1.91186567e+00,
#          -2.43738037e-02,  2.63952538e-02,  4.25781812e-01,
#           2.06547141e+00,  6.20286672e-01,  2.54280249e-01,
#          -9.10687845e-01,  4.47328072e-01, -4.17929991e-01,
#          -3.68765768e-01,  7.08836282e-01,  9.15367610e-01,
#          -3.58720550e-01, -9.60275485e-01],
#         [ 4.55390854e-02, -4.53568383e-01,  1.60056109e+00,
#           1.86429626e+00,  2.20842112e-01, -1.71494629e-02,
#           4.79639498e-01, -3.01406439e-01, -8.84593616e-01,
#          -1.35699402e+00,  1.16449796e+00,  2.18921380e+00,
#           1.40579290e+00,  2.75720934e-01,  1.12437465e+00,
#          -1.11143745e+00,  1.48937193e+00, -4.26069625e-01,
#           2.27911819e-01,  6.02230632e-01],
#         [ 1.57609132e+00, -3.71152123e-01, -3.75381044e-01,
#           2.41628682e-01,  1.13913411e+00, -1.86452438e-01,
#          -3.33716322e-01, -7.03761714e-01,  5.99715040e-01,
#           6.90849745e-01,  1.36241238e-01, -3.27103532e-01,
#          -5.25780607e-01, -1.23644288e+00,  1.11910339e-01,
#           1.88227868e-01,  1.58528607e-02, -1.18365674e+00,
#          -9.51247544e-01, -3.72198264e-01],
#         [ 5.39621683e-01,  1.23426533e+00,  1.30534125e+00,
#           4.44492377e-01, -1.15790639e+00, -7.45526998e-01,
#          -1.22113514e+00, -1.49066721e-03,  7.95307159e-01,
#           4.56598015e-01,  7.47501559e-01, -2.48547513e-02,
#          -1.03219937e+00,  5.74702886e-01,  1.30496642e-02,
#           1.28809536e-01, -3.57823778e-01,  6.17683770e-01,
#           8.15168707e-01,  1.09018756e+00],
#         [ 8.65402171e-01,  2.75360514e-01,  4.66753240e-01,
#           1.35930935e+00, -1.01155991e+00,  7.91763661e-01,
#          -4.24194997e-01, -7.69397720e-02,  1.10164203e+00,
#          -1.15864409e-01,  5.76178231e-01,  1.24779594e+00,
#          -6.45424103e-01, -8.14249674e-01,  7.16016944e-01,
#          -6.02724909e-01, -4.23969788e-01, -2.74883695e-01,
#           1.09615864e+00, -6.55358544e-01],
#         [-6.39856648e-01,  1.04259599e+00, -7.80234803e-01,
#           6.14185682e-01, -1.69712436e+00, -1.74391883e+00,
#          -6.39549248e-01, -1.06264050e+00, -5.00764053e-01,
#          -2.01959527e+00,  9.75420564e-01, -2.04229658e-01,
#           8.02022377e-01,  1.18784941e+00, -1.11640128e+00,
#           8.08810948e-02,  4.77700142e-01,  9.33531562e-01,
#           8.74379413e-01,  1.93480097e-01],
#         [ 1.03004758e+00,  1.97901567e-01, -3.81737008e-01,
#           1.40154064e+00, -4.63326693e-01,  5.24816891e-01,
#          -3.63433001e-01, -9.25965081e-01, -9.70364647e-01,
#           4.18386037e-01, -3.54133201e-03,  3.70712865e-01,
#          -5.43712901e-02, -1.16201251e+00, -6.99406336e-01,
#          -6.69270392e-01, -7.00842979e-01,  2.39294374e-02,
#          -3.35911629e-01, -9.73335412e-01],
#         [ 1.06283150e+00, -6.19698786e-01, -4.48080198e-01,
#           9.55366104e-01, -5.35863586e-01,  1.62227873e+00,
#           1.10891535e+00,  8.13357342e-01,  1.10609222e+00,
#           1.79768674e+00, -4.61522077e-01,  3.88595151e-01,
#          -1.25778181e+00, -1.50764521e+00,  8.43237547e-01,
#          -4.40450247e-01,  1.86889988e+00, -2.28770376e-01,
#          -6.51533744e-01,  2.60017089e-01],
#         [ 6.60103226e-01,  5.06064843e-01,  9.49361156e-01,
#           2.88249912e-01, -4.87196322e-01,  1.75968233e-01,
#          -3.58813269e-01, -1.28436922e+00, -2.40626107e-01,
#          -1.27309287e+00,  1.25524163e+00,  1.68371523e-01,
#           3.27779880e-01, -6.18861746e-01, -1.85867144e-01,
#          -1.69560361e+00,  1.73921724e-01,  1.11880239e+00,
#           1.04643709e-01, -1.06713709e+00],
#         [-2.87531156e-01,  1.86443488e+00, -7.90351651e-01,
#          -1.11669568e+00, -2.80504927e-01,  1.36452948e+00,
#           5.62403863e-01,  1.11585243e+00, -2.53929942e-01,
#          -1.26104378e-01, -1.84684361e-01,  6.63815798e-01,
#           3.08254954e-01,  9.76204632e-01,  1.30071904e-02,
#          -6.04732208e-01, -1.54120618e-02,  1.68226734e+00,
#           3.05546683e-01, -3.28977458e-01],
#         [-1.44996102e+00,  1.19877936e-01, -3.13981049e-01,
#          -2.34020907e+00, -5.78334444e-01,  1.43511427e-01,
#           7.60884309e-01,  9.49515110e-01,  1.56124862e-01,
#          -3.29344740e-01, -5.76918010e-01,  7.65911236e-01,
#          -3.38587263e-01,  7.28676701e-01, -4.13369680e-01,
#           2.00932896e+00,  7.68605576e-02,  2.15296583e-01,
#           7.87871440e-01,  1.07719791e+00],
#         [ 6.14309772e-01,  6.34028178e-01,  2.08548062e-01,
#           9.59944688e-01,  1.05589301e+00, -1.27200749e+00,
#           1.56247938e+00,  1.00391030e-01, -6.06393060e-01,
#          -9.49256382e-01,  9.64819075e-02, -3.94497050e-01,
#           4.81857484e-01,  7.57238490e-01,  2.35400834e-01,
#           2.33001624e+00,  1.14457900e+00,  1.42178348e+00,
#          -7.08810647e-01,  4.48010926e-01],
#         [ 1.32246183e+00,  2.16012939e+00, -9.95910440e-01,
#          -3.91097619e-02,  1.99145107e-01,  1.38800174e+00,
#           3.73345246e-01,  1.02168102e+00, -3.63217502e-01,
#           1.03435736e-02, -1.98263324e+00, -1.96798002e-01,
#           4.72254023e-01,  1.72766936e+00, -8.71367407e-01,
#           2.13466018e-01, -7.32093428e-03,  1.17176746e+00,
#           8.20355109e-01,  4.83295993e-01],
#         [ 6.47004638e-01, -1.18234323e+00,  7.75725826e-02,
#          -2.29388609e+00,  6.44642446e-01, -1.89684681e+00,
#           1.35166030e+00,  2.06550971e+00,  1.10172743e+00,
#           2.61046502e-01,  8.62309971e-01, -1.71460529e+00,
#          -1.60456717e+00, -9.29328884e-01, -3.01460976e-01,
#          -2.04236737e+00,  2.22328826e-01, -1.15883303e-01,
#           6.53365333e-01,  3.52551835e-01],
#         [ 4.28199036e-01,  1.03474134e-01, -8.71668413e-01,
#           1.46356397e+00, -1.69793032e+00,  1.45656897e+00,
#          -9.23129708e-03,  1.10792971e+00, -1.70852123e+00,
#           2.45649627e-02,  8.63929986e-01,  7.69661722e-01,
#          -6.67410760e-01,  8.33639753e-01, -2.54018078e-01,
#           2.59202304e-01, -6.07644388e-01, -5.19002645e-01,
#          -8.36565827e-01,  1.93100538e+00],
#         [ 6.61026081e-01, -1.07360110e+00,  6.35232399e-01,
#           9.03239119e-01, -4.59465140e-01,  3.04977616e-02,
#           5.72490914e-01, -8.13972619e-01,  2.72048290e-01,
#          -9.48574570e-01, -1.13910869e+00,  3.97302978e-01,
#           1.05059389e+00,  1.37259118e+00,  6.26417183e-01,
#          -2.37074839e-01,  4.57959618e-01,  3.94437006e-01,
#          -5.03618751e-01, -4.92404222e-01],
#         [-1.56058699e+00, -1.64507147e-01,  7.51280090e-01,
#           2.37635202e-01, -1.24861658e+00,  4.99134825e-01,
#           6.61105436e-01,  6.51393095e-01, -1.87144783e-01,
#           3.35000875e-01,  5.58243914e-02, -6.15433280e-01,
#           3.23065716e-01, -2.39474524e+00, -1.60041683e+00,
#           6.07051299e-01, -7.28883860e-02,  1.16511545e+00,
#           3.94397144e-01,  2.35734140e+00],
#         [-3.29135231e-01, -8.81631372e-02, -1.81573747e-01,
#           5.32494103e-01,  5.06544675e-01, -1.52992872e+00,
#          -7.72332493e-02,  5.46718897e-02,  1.39703309e+00,
#           2.44888033e+00,  2.63122229e-01,  6.61127801e-01,
#          -8.11504680e-01,  4.21730842e-01, -1.73234007e+00,
#           4.63380365e-01, -4.88110692e-01, -7.70710485e-01,
#          -2.33879982e-02, -1.11952791e+00],
#         [-5.87763643e-01, -1.72431780e-01,  6.77651755e-01,
#          -1.20459978e+00,  3.26259978e-01, -1.90010658e+00,
#          -1.34971256e-01,  1.84419702e+00, -4.02437940e-01,
#          -5.35851347e-01,  5.88652541e-01, -6.24528360e-01,
#           5.47572742e-01,  1.82111624e+00,  5.76370253e-01,
#          -8.08751733e-01,  3.67903595e-01, -6.29023269e-01,
#          -6.55006159e-01, -1.16845664e+00],
#         [ 1.00376212e+00,  7.96303541e-01, -1.78579693e-01,
#          -5.28734748e-01, -3.48034603e+00,  1.06238169e+00,
#          -1.39797672e+00,  1.12706694e+00,  3.78171904e-01,
#           1.04955186e+00,  1.42286796e+00, -5.57890131e-01,
#           6.94804682e-01,  4.36577428e-01, -1.09664790e+00,
#           5.57274166e-01, -1.06674935e+00, -2.30947438e-01,
#           4.56058743e-01, -2.42177682e-01],
#         [-1.48225854e-01,  1.28029809e+00, -1.48337958e+00,
#          -1.61909944e+00,  1.06908833e+00, -4.98850068e-01,
#           5.37069652e-01,  1.94992347e+00,  1.33267711e+00,
#          -6.53743064e-01,  2.12325345e+00, -3.81864056e-02,
#          -3.40580743e-01, -3.55826563e-01, -8.07073917e-01,
#          -1.00170789e+00, -7.78030136e-01, -7.64547704e-04,
#           3.70714456e-01, -9.47515177e-01],
#         [ 1.20834705e+00,  1.56175141e+00, -1.22171678e+00,
#           7.74831525e-01,  3.87609199e-01,  5.34286204e-01,
#          -1.25763704e+00, -9.19593950e-01,  8.85865281e-01,
#           1.51233700e+00, -1.40767290e-01,  3.01930550e-01,
#           2.69036911e-01, -3.36771153e-01,  5.10373408e-01,
#           1.49078897e+00,  1.68667562e+00, -2.03884949e+00,
#          -3.24224278e-01, -3.08086199e+00],
#         [ 1.71754382e+00, -3.53499807e-01, -1.00512499e+00,
#           4.59317945e-01, -3.62671254e-02,  5.83585461e-01,
#           4.43121873e-01,  1.28005356e+00,  1.78769806e+00,
#           8.36665650e-01, -2.06744260e-01,  3.76238700e-01,
#           4.75097161e-01,  1.22246087e+00, -1.50416081e+00,
#           1.07594293e+00,  1.99796185e+00,  7.82669232e-01,
#           2.15549248e-01,  6.26918742e-01],
#         [ 8.52990141e-01, -5.35598143e-01,  6.19370430e-01,
#           4.82115723e-01, -1.45267866e+00, -1.70848881e+00,
#          -1.29012057e-01,  1.71612828e-01,  1.17091345e+00,
#           5.27295453e-01, -1.46865082e+00,  2.13062369e+00,
#          -5.91874681e-01, -8.40252365e-01,  9.18000836e-01,
#          -9.28858829e-01,  2.06475133e-01,  4.27656721e-01,
#          -2.01661830e+00,  1.04620745e-01],
#         [ 1.08965402e+00,  9.37369315e-01, -4.94206806e-01,
#           1.11754821e+00, -8.83398798e-01,  6.03650983e-01,
#          -9.98817788e-01,  1.00707704e+00, -1.42130247e-01,
#           1.44607309e+00,  1.46332149e+00, -1.97544572e+00,
#          -6.78384168e-01,  7.15487159e-02,  2.03503751e+00,
#          -7.57949757e-01,  5.04209098e-01, -5.83998612e-01,
#          -3.62327308e-01,  7.00310053e-01],
#         [ 8.76502005e-01, -4.96021714e-01, -7.38119996e-01,
#           2.08616279e+00,  7.46771787e-01,  1.14235135e+00,
#          -7.69700759e-01,  5.12526591e-01,  1.97680587e-01,
#           1.18839851e+00, -6.94578876e-01,  7.89309351e-01,
#           5.71277308e-01,  5.06400090e-01, -1.50600196e+00,
#          -1.19745424e+00,  1.10708765e+00, -1.23305213e+00,
#          -1.79899656e-01, -3.38712859e+00],
#         [ 2.83978502e-01,  9.83307237e-01, -2.75024212e-01,
#          -1.10194496e+00,  7.11268942e-01, -1.04734290e+00,
#          -1.78683765e-01,  4.84617336e-01, -1.99999234e-01,
#          -8.72075855e-01, -1.07561820e-01, -5.98018732e-01,
#          -3.55608961e-01, -1.01782803e+00,  1.84006952e+00,
#          -3.87204972e-01,  6.05720612e-01, -9.38645720e-01,
#           3.50892972e-01,  1.30596764e+00],
#         [-1.43474653e+00, -1.31039298e+00, -4.89100067e-01,
#          -1.53399134e+00,  4.06509637e-01, -6.91079742e-01,
#          -2.52973218e-01, -1.58907503e+00,  6.41943937e-01,
#           6.88440472e-01, -4.23118475e-01, -5.04770802e-01,
#          -1.62184959e+00,  1.36766258e-01, -4.17551211e-01,
#          -7.83587447e-01,  9.14815011e-01,  4.30663958e-01,
#          -1.41066373e+00, -1.18270258e+00],
#         [ 9.30092380e-01, -2.13819428e+00,  2.52613671e+00,
#          -1.00671263e-01,  1.03478040e-01,  8.80341683e-02,
#          -4.96926533e-01,  3.89906157e-01,  6.62234424e-01,
#           2.08751560e-01, -1.44818152e+00,  1.24927263e+00,
#          -6.39153844e-01,  1.83357455e-01,  1.30096033e+00,
#           1.14290193e+00, -5.56911798e-01, -1.19253561e+00,
#           2.00949559e+00, -1.21541931e+00],
#         [-1.43134514e+00, -9.47512634e-01,  1.30967918e+00,
#           4.74733234e-02, -9.34634287e-02, -9.40432882e-01,
#          -1.04508917e+00, -5.45362881e-01,  7.48181888e-01,
#           5.72769761e-01,  2.36409074e-01,  9.08419879e-02,
#          -9.50917331e-01,  5.26385358e-01,  2.75448825e-01,
#          -5.47807890e-02, -2.98704330e-01,  1.40405338e+00,
#           1.27620401e+00,  6.60993457e-01]]),
#  'b1': array([ 2.00014796e-05,  2.86505251e-02,  3.63036591e-03, -7.15778601e-03,
#          1.90281325e-03, -1.88220314e-02,  1.00078481e-02,  2.47346621e-04,
#          1.22456926e-03,  8.76682258e-04,  2.72635957e-03,  3.90662381e-04,
#         -1.24363385e-02,  1.49433992e-03, -1.09274260e-03, -1.25913046e-04,
#          2.20645777e-03, -8.63986602e-04,  1.49127158e-02, -7.96824178e-04]),
#  'w2': array([[-0.00522725],
#         [-1.59130755],
#         [-1.15561533],
#         [ 0.87380926],
#         [-0.90264103],
#         [ 1.51401828],
#         [-0.88389628],
#         [ 0.34507386],
#         [-0.62126761],
#         [ 1.06556101],
#         [ 0.39142511],
#         [-0.17858114],
#         [-1.87010938],
#         [ 0.26567301],
#         [-0.20869605],
#         [ 0.00479287],
#         [ 0.75277303],
#         [ 0.04032445],
#         [-1.2876579 ],
#         [-0.53233282]]),
#  'b2': array([-0.1445453])}

# %%
plt.figure(figsize=([8,8]))
axis = np.arange(len(cost_val))+1
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
import seaborn as sns

classified=np.round(neural_net.feed_out(xtest, activation))
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)
fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show() 
print(f1_score(ytest, classified)) 
print(100*np.sum(classified==ytest)/len(ytest),'% training Accuracy')
# Out:
# Normalized confusion matrix
# [[0.98128854 0.01871146]
#  [0.98612182 0.01387818]]
# 0.025659301496792585
# 77.21666666666667 % training Accuracy

# %%
classified=np.round(neural_net.feed_out(xtrain, activation))
norm = fx.norm_confusion_matrix(ytrain, classified, normalize=True)
fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show() 

activ=neural_net.feed_out(xtrain, activation)

classes=np.round(activ)

print(100*np.sum(classes==ytrain)/len(activ),'% training Accuracy')
print(f1_score(ytrain, classes)) 

cm = fx.norm_confusion_matrix(ytrain , classes, normalize=True)
# Out:
# Normalized confusion matrix
# [[0.95369066 0.04630934]
#  [0.66780749 0.33219251]]
# 81.53333333333333 % training Accuracy
# 0.44473081328751435
# Normalized confusion matrix
# [[0.95369066 0.04630934]
#  [0.66780749 0.33219251]]

# %%
from sklearn.neural_network import MLPClassifier



#print("Test set score: %f" % mlp.score(xtest, ytest))
epochs=1000
batch_size=500
n_features=x.shape[1]
etavec = np.logspace(-4, -1, 4)
lmbvec = np.logspace(-7, -3, 5)
lmbvec[0]=0


train_accuracy = np.zeros((len(etavec), len(lmbvec)))
for i, etas in enumerate(etavec):
    for j, lmb in enumerate(lmbvec):
        print(lmb)
        mlp = MLPClassifier(hidden_layer_sizes=(50,20,), max_iter=2000, alpha=lmb,
                    solver='sgd', verbose=0, tol=1e-4,batch_size=500, random_state=1,
                    learning_rate_init=etas)

        mlp.fit(xtrain, ytrain.ravel())
        print("Training set score: %f" % mlp.score(xval, yval))
        pred = mlp.predict(xval)
        train_accuracy[i,j] =  lrf.cost_log_ols(pred.ravel(),yval.T)
        print('Validation f1_score for', '\u03B7 =', etas, '&', '\u03BB =', lmb, '=', train_accuracy [i,j])
# Out:
# 0.0
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 0.0 = 0.691117638862135
# 1e-06
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 1e-06 = 0.691117638862135
# 1e-05
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 1e-05 = 0.691117638862135
# 0.0001
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 0.0001 = 0.691117638862135
# 0.001
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 0.001 = 0.691117638862135
# 0.0
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 0.0 = 0.6903877407375498
# 1e-06
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 1e-06 = 0.6903877407375498
# 1e-05
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 1e-05 = 0.6903877407375498
# 0.0001
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 0.0001 = 0.6903877407375498
# 0.001
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 0.001 = 0.6903877407375498
# 0.0
# Training set score: 0.815000
# Validation f1_score for η = 0.01 & λ = 0.0 = 0.6903151326149523
# 1e-06
# Training set score: 0.814333
# Validation f1_score for η = 0.01 & λ = 1e-06 = 0.6908086186242299
# 1e-05
# Training set score: 0.815000
# Validation f1_score for η = 0.01 & λ = 1e-05 = 0.6902350562769801
# 0.0001
# Training set score: 0.814000
# Validation f1_score for η = 0.01 & λ = 0.0001 = 0.6907750944459661
# 0.001
# Training set score: 0.814333
# Validation f1_score for η = 0.01 & λ = 0.001 = 0.6895273972166751
# 0.0
# Training set score: 0.801333
# Validation f1_score for η = 0.1 & λ = 0.0 = 0.6978291148210491
# 1e-06
# Training set score: 0.797000
# Validation f1_score for η = 0.1 & λ = 1e-06 = 0.7002760486706185
# 1e-05
# Training set score: 0.801667
# Validation f1_score for η = 0.1 & λ = 1e-05 = 0.6985032497030905
# 0.0001
# Training set score: 0.796667
# Validation f1_score for η = 0.1 & λ = 0.0001 = 0.6974398526633283
# 0.001
# Training set score: 0.814000
# Validation f1_score for η = 0.1 & λ = 0.001 = 0.6912555524737993

# %%
import seaborn as sns
train_accuracy[np.isnan(train_accuracy)]=2

yticklabels = etavec
xticklabels = lmbvec
fig, ax = plt.subplots(figsize = (10, 12))
sns.heatmap(train_accuracy, annot=True, ax=ax, cmap="viridis",\
            yticklabels=yticklabels, xticklabels=xticklabels)
ax.set_title("Training Accuracy")
ax.set_ylabel("$\eta$")
ax.set_xlabel("$\lambda$")
tmp = np.arange(len(etavec))+0.5
tmp[0] = 0
tmp[-1]+=0.5
ax.set_yticks(tmp)
tmp = np.arange(len(lmbvec)) + 0.5
ax.set_xticks(tmp)
plt.show()

# %%
best_eta_index, best_lmb_index = np.where(train_accuracy == np.min(train_accuracy))
best_eta,best_lmb = etavec[best_eta_index], lmbvec[best_lmb_index] 

print('eta=',best_eta)
print('lmb=',best_lmb)
# Out:
# eta= [0.01]
# lmb= [0.0001]

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50,20,), max_iter=2000, alpha=best_lmb,
                    solver='sgd', verbose=0, tol=1e-4,batch_size=500, random_state=1,
                    learning_rate_init=best_eta)

mlp.fit(xtrain, ytrain.ravel())
print("Training set score: %f" % mlp.score(xval, yval))
# Out:
# Training set score: 0.814000

# %%
pred = mlp.predict(xtest)
accuracy = accuracy_score(ytest.flatten(),pred)
accuracy = accuracy * 100
print(accuracy)
print(f1_score(ytest, pred)) 

cm = fx.norm_confusion_matrix(ytest , pred, normalize=True)
# Out:
# 81.6
# 0.467695274831244
# Normalized confusion matrix
# [[0.93791197 0.06208803]
#  [0.62606014 0.37393986]]

# %%
pred = mlp.predict(xtrain)
accuracy = accuracy_score(ytrain.flatten(),pred)
accuracy = accuracy * 100
print(accuracy)
print(f1_score(ytrain, pred)) 

cm = fx.norm_confusion_matrix(ytrain , pred normalize=True)
# Out:
# 83.75714285714285
# 0.54404491378158
# [[15554   771]
#  [ 2640  2035]]

# %% [markdown]
# # Cancer data

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import MinMaxScaler

xtrain,ytrain = load_breast_cancer(return_X_y=True)
scaler = MinMaxScaler()
indx = np.arange(xtrain.shape[1])
scaler.fit(xtrain[:,indx])
xtrain = scaler.transform(xtrain[:,indx])
ytrain=ytrain.reshape([len(ytrain),1])
