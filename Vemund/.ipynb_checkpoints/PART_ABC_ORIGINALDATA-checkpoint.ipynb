# %%
import functions as fx
import log_reg_functions as lrf
import loaddata as ld
import NeuralNetwork as nn
import LogisticRegression as lr

import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, log_loss, f1_score, confusion_matrix, roc_auc_score

# %% [markdown]
# # A )
# Here we will load the dataset, then split it into train, validation and test data.
# As the Credit Card data is biased, we also create a downzised dataset.

# %%
# Reading in credit card dataset.
x,y = ld.load_data(scaler='minmax')

# Splitting data in train and test data
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.20, random_state= 0, shuffle=True)
# Splitting in train and validation
xtrain,xval,ytrain,yval = train_test_split(xtrain,ytrain, test_size=0.125, random_state= 0, shuffle=True)

# Extracting some useful shapes.
nx_train, ny_train = xtrain.shape
nx_test, ny_test = xtest.shape

# %% [markdown]
# # B)
# Egen logistic regression med gradient descent.

# %%
eta = 0.1 # learning rate
Niter=2500
logreg = lr.LOGREG(eta=0.1, doplot = False, doprint=True)
cost_val, cost_train, axis = logreg.fit(xtrain, ytrain, xval, yval, Niter, solver='gd')
classified=logreg.predict(xtest)
# Out:
# Cost validation = [1.83157254]
# Cost validation = [1.71571625]
# Cost validation = [1.60883548]
# Cost validation = [1.51076238]
# Cost validation = [1.42122278]
# Cost validation = [1.33986621]
# Cost validation = [1.26629134]
# Cost validation = [1.20006325]
# Cost validation = [1.14072326]
# Cost validation = [1.08779419]
# Cost validation = [1.04078427]
# Cost validation = [0.99919233]
# Cost validation = [0.9625149]
# Cost validation = [0.93025523]
# Cost validation = [0.90193268]
# Cost validation = [0.87709148]
# Cost validation = [0.85530764]
# Cost validation = [0.83619352]
# Cost validation = [0.81940015]
# Cost validation = [0.80461739]
# Cost validation = [0.79157251]
# Cost validation = [0.78002773]
# Cost validation = [0.7697771]
# Cost validation = [0.76064309]
# Cost validation = [0.75247318]
# Cost validation = [0.74513666]
# Cost validation = [0.73852162]
# Cost validation = [0.73253232]
# Cost validation = [0.7270868]
# Cost validation = [0.72211486]
# Cost validation = [0.71755631]
# Cost validation = [0.71335949]
# Cost validation = [0.70947993]
# Cost validation = [0.70587933]
# Cost validation = [0.70252464]
# Cost validation = [0.69938724]
# Cost validation = [0.69644234]
# Cost validation = [0.69366841]
# Cost validation = [0.6910467]
# Cost validation = [0.68856086]
# Cost validation = [0.68619661]
# Cost validation = [0.68394143]
# Cost validation = [0.68178435]
# Cost validation = [0.6797157]
# Cost validation = [0.677727]
# Cost validation = [0.67581074]
# Cost validation = [0.67396029]
# Cost validation = [0.67216979]
# Cost validation = [0.67043402]
# Cost validation = [0.66874837]
# Cost validation = [0.66710871]
# Cost validation = [0.66551138]
# Cost validation = [0.6639531]
# Cost validation = [0.66243094]
# Cost validation = [0.66094229]
# Cost validation = [0.6594848]
# Cost validation = [0.65805634]
# Cost validation = [0.65665503]
# Cost validation = [0.65527916]
# Cost validation = [0.65392718]
# Cost validation = [0.6525977]
# Cost validation = [0.65128947]
# Cost validation = [0.65000133]
# Cost validation = [0.64873226]
# Cost validation = [0.64748131]
# Cost validation = [0.64624763]
# Cost validation = [0.64503044]
# Cost validation = [0.64382902]
# Cost validation = [0.64264273]
# Cost validation = [0.64147098]
# Cost validation = [0.6403132]
# Cost validation = [0.63916891]
# Cost validation = [0.63803764]
# Cost validation = [0.63691896]
# Cost validation = [0.63581249]
# Cost validation = [0.63471785]
# Cost validation = [0.63363471]
# Cost validation = [0.63256276]
# Cost validation = [0.63150171]
# Cost validation = [0.63045129]
# Cost validation = [0.62941123]
# Cost validation = [0.62838132]
# Cost validation = [0.62736131]
# Cost validation = [0.62635102]
# Cost validation = [0.62535023]
# Cost validation = [0.62435876]
# Cost validation = [0.62337645]
# Cost validation = [0.62240312]
# Cost validation = [0.62143862]
# Cost validation = [0.62048279]
# Cost validation = [0.61953551]
# Cost validation = [0.61859662]
# Cost validation = [0.617666]
# Cost validation = [0.61674354]
# Cost validation = [0.6158291]
# Cost validation = [0.61492258]
# Cost validation = [0.61402386]
# Cost validation = [0.61313284]
# Cost validation = [0.61224943]
# Cost validation = [0.61137351]
# Cost validation = [0.610505]
# Cost validation = [0.60964379]
# Cost validation = [0.60878982]
# Cost validation = [0.60794297]
# Cost validation = [0.60710318]
# Cost validation = [0.60627036]
# Cost validation = [0.60544442]
# Cost validation = [0.60462529]
# Cost validation = [0.6038129]
# Cost validation = [0.60300717]
# Cost validation = [0.60220801]
# Cost validation = [0.60141538]
# Cost validation = [0.60062918]
# Cost validation = [0.59984936]
# Cost validation = [0.59907585]
# Cost validation = [0.59830857]
# Cost validation = [0.59754747]
# Cost validation = [0.59679249]
# Cost validation = [0.59604354]
# Cost validation = [0.59530059]
# Cost validation = [0.59456356]
# Cost validation = [0.59383239]
# Cost validation = [0.59310703]
# Cost validation = [0.59238741]
# Cost validation = [0.59167349]
# Cost validation = [0.59096519]
# Cost validation = [0.59026248]
# Cost validation = [0.58956528]
# Cost validation = [0.58887355]
# Cost validation = [0.58818724]
# Cost validation = [0.58750628]
# Cost validation = [0.58683063]
# Cost validation = [0.58616024]
# Cost validation = [0.58549505]
# Cost validation = [0.58483501]
# Cost validation = [0.58418008]
# Cost validation = [0.5835302]
# Cost validation = [0.58288533]
# Cost validation = [0.58224542]
# Cost validation = [0.58161041]
# Cost validation = [0.58098027]
# Cost validation = [0.58035494]
# Cost validation = [0.57973438]
# Cost validation = [0.57911855]
# Cost validation = [0.57850739]
# Cost validation = [0.57790087]
# Cost validation = [0.57729893]
# Cost validation = [0.57670154]
# Cost validation = [0.57610866]
# Cost validation = [0.57552023]
# Cost validation = [0.57493622]
# Cost validation = [0.57435659]
# Cost validation = [0.57378129]
# Cost validation = [0.57321028]
# Cost validation = [0.57264352]
# Cost validation = [0.57208098]
# Cost validation = [0.5715226]
# Cost validation = [0.57096836]
# Cost validation = [0.57041821]
# Cost validation = [0.56987212]
# Cost validation = [0.56933005]
# Cost validation = [0.56879195]
# Cost validation = [0.56825779]
# Cost validation = [0.56772754]
# Cost validation = [0.56720115]
# Cost validation = [0.5666786]
# Cost validation = [0.56615984]
# Cost validation = [0.56564484]
# Cost validation = [0.56513357]
# Cost validation = [0.56462598]
# Cost validation = [0.56412205]
# Cost validation = [0.56362174]
# Cost validation = [0.56312502]
# Cost validation = [0.56263185]
# Cost validation = [0.5621422]
# Cost validation = [0.56165604]
# Cost validation = [0.56117334]
# Cost validation = [0.56069405]
# Cost validation = [0.56021816]
# Cost validation = [0.55974563]
# Cost validation = [0.55927642]
# Cost validation = [0.55881052]
# Cost validation = [0.55834788]
# Cost validation = [0.55788847]
# Cost validation = [0.55743228]
# Cost validation = [0.55697926]
# Cost validation = [0.55652939]
# Cost validation = [0.55608263]
# Cost validation = [0.55563897]
# Cost validation = [0.55519837]
# Cost validation = [0.5547608]
# Cost validation = [0.55432624]
# Cost validation = [0.55389465]
# Cost validation = [0.55346602]
# Cost validation = [0.55304031]
# Cost validation = [0.55261749]
# Cost validation = [0.55219755]
# Cost validation = [0.55178045]
# Cost validation = [0.55136616]
# Cost validation = [0.55095467]
# Cost validation = [0.55054595]
# Cost validation = [0.55013997]
# Cost validation = [0.5497367]
# Cost validation = [0.54933613]
# Cost validation = [0.54893822]
# Cost validation = [0.54854296]
# Cost validation = [0.54815032]
# Cost validation = [0.54776027]
# Cost validation = [0.5473728]
# Cost validation = [0.54698788]
# Cost validation = [0.54660548]
# Cost validation = [0.54622558]
# Cost validation = [0.54584817]
# Cost validation = [0.54547321]
# Cost validation = [0.54510069]
# Cost validation = [0.54473059]
# Cost validation = [0.54436288]
# Cost validation = [0.54399754]
# Cost validation = [0.54363456]
# Cost validation = [0.5432739]
# Cost validation = [0.54291555]
# Cost validation = [0.54255949]
# Cost validation = [0.5422057]
# Cost validation = [0.54185415]
# Cost validation = [0.54150484]
# Cost validation = [0.54115773]
# Cost validation = [0.54081281]
# Cost validation = [0.54047007]
# Cost validation = [0.54012947]
# Cost validation = [0.539791]
# Cost validation = [0.53945465]
# Cost validation = [0.53912039]
# Cost validation = [0.53878821]
# Cost validation = [0.53845809]
# Cost validation = [0.53813001]
# Cost validation = [0.53780394]
# Cost validation = [0.53747989]
# Cost validation = [0.53715782]
# Cost validation = [0.53683772]
# Cost validation = [0.53651957]
# Cost validation = [0.53620336]
# Cost validation = [0.53588907]
# Cost validation = [0.53557669]
# Cost validation = [0.53526618]
# Cost validation = [0.53495755]
# Cost validation = [0.53465078]
# Cost validation = [0.53434584]
# Cost validation = [0.53404272]
# Cost validation = [0.53374141]
# Cost validation = [0.53344189]
# Cost validation = [0.53314415]
# Cost validation = [0.53284817]
# Cost validation = [0.53255394]
# Cost validation = [0.53226143]
# Cost validation = [0.53197065]
# Cost validation = [0.53168156]
# Cost validation = [0.53139417]
# Cost validation = [0.53110845]
# Cost validation = [0.53082438]
# Cost validation = [0.53054197]
# Cost validation = [0.53026118]
# Cost validation = [0.52998201]
# Cost validation = [0.52970445]
# Cost validation = [0.52942848]
# Cost validation = [0.52915409]
# Cost validation = [0.52888126]
# Cost validation = [0.52860998]
# Cost validation = [0.52834024]
# Cost validation = [0.52807203]
# Cost validation = [0.52780533]
# Cost validation = [0.52754014]
# Cost validation = [0.52727643]
# Cost validation = [0.5270142]
# Cost validation = [0.52675343]
# Cost validation = [0.52649412]
# Cost validation = [0.52623625]
# Cost validation = [0.5259798]
# Cost validation = [0.52572478]
# Cost validation = [0.52547116]
# Cost validation = [0.52521893]
# Cost validation = [0.52496809]
# Cost validation = [0.52471861]
# Cost validation = [0.5244705]
# Cost validation = [0.52422374]
# Cost validation = [0.52397832]
# Cost validation = [0.52373423]
# Cost validation = [0.52349145]
# Cost validation = [0.52324998]
# Cost validation = [0.52300981]
# Cost validation = [0.52277092]
# Cost validation = [0.52253331]
# Cost validation = [0.52229697]
# Cost validation = [0.52206188]
# Cost validation = [0.52182804]
# Cost validation = [0.52159543]
# Cost validation = [0.52136405]
# Cost validation = [0.52113389]
# Cost validation = [0.52090493]
# Cost validation = [0.52067717]
# Cost validation = [0.5204506]
# Cost validation = [0.52022521]
# Cost validation = [0.52000099]
# Cost validation = [0.51977793]
# Cost validation = [0.51955602]
# Cost validation = [0.51933525]
# Cost validation = [0.51911562]
# Cost validation = [0.51889711]
# Cost validation = [0.51867972]
# Cost validation = [0.51846344]
# Cost validation = [0.51824826]
# Cost validation = [0.51803416]
# Cost validation = [0.51782115]
# Cost validation = [0.51760922]
# Cost validation = [0.51739835]
# Cost validation = [0.51718854]
# Cost validation = [0.51697977]
# Cost validation = [0.51677205]
# Cost validation = [0.51656537]
# Cost validation = [0.51635971]
# Cost validation = [0.51615507]
# Cost validation = [0.51595144]
# Cost validation = [0.51574881]
# Cost validation = [0.51554718]
# Cost validation = [0.51534654]
# Cost validation = [0.51514688]
# Cost validation = [0.51494819]
# Cost validation = [0.51475047]
# Cost validation = [0.51455371]
# Cost validation = [0.5143579]
# Cost validation = [0.51416304]
# Cost validation = [0.51396911]
# Cost validation = [0.51377611]
# Cost validation = [0.51358404]
# Cost validation = [0.51339289]
# Cost validation = [0.51320265]
# Cost validation = [0.51301331]
# Cost validation = [0.51282487]
# Cost validation = [0.51263732]
# Cost validation = [0.51245066]
# Cost validation = [0.51226487]
# Cost validation = [0.51207996]
# Cost validation = [0.51189591]
# Cost validation = [0.51171272]
# Cost validation = [0.51153038]
# Cost validation = [0.51134889]
# Cost validation = [0.51116824]
# Cost validation = [0.51098843]
# Cost validation = [0.51080944]
# Cost validation = [0.51063128]
# Cost validation = [0.51045394]
# Cost validation = [0.5102774]
# Cost validation = [0.51010168]
# Cost validation = [0.50992675]
# Cost validation = [0.50975262]
# Cost validation = [0.50957927]
# Cost validation = [0.50940671]
# Cost validation = [0.50923493]
# Cost validation = [0.50906392]
# Cost validation = [0.50889367]
# Cost validation = [0.50872419]
# Cost validation = [0.50855546]
# Cost validation = [0.50838749]
# Cost validation = [0.50822026]
# Cost validation = [0.50805377]
# Cost validation = [0.50788801]
# Cost validation = [0.50772299]
# Cost validation = [0.50755869]
# Cost validation = [0.50739511]
# Cost validation = [0.50723225]
# Cost validation = [0.5070701]
# Cost validation = [0.50690865]
# Cost validation = [0.50674791]
# Cost validation = [0.50658786]
# Cost validation = [0.5064285]
# Cost validation = [0.50626983]
# Cost validation = [0.50611184]
# Cost validation = [0.50595453]
# Cost validation = [0.50579789]
# Cost validation = [0.50564192]
# Cost validation = [0.50548662]
# Cost validation = [0.50533197]
# Cost validation = [0.50517798]
# Cost validation = [0.50502464]
# Cost validation = [0.50487195]
# Cost validation = [0.50471989]
# Cost validation = [0.50456848]
# Cost validation = [0.5044177]
# Cost validation = [0.50426755]
# Cost validation = [0.50411803]
# Cost validation = [0.50396912]
# Cost validation = [0.50382084]
# Cost validation = [0.50367316]
# Cost validation = [0.5035261]
# Cost validation = [0.50337964]
# Cost validation = [0.50323378]
# Cost validation = [0.50308852]
# Cost validation = [0.50294386]
# Cost validation = [0.50279978]
# Cost validation = [0.50265629]
# Cost validation = [0.50251338]
# Cost validation = [0.50237105]
# Cost validation = [0.50222929]
# Cost validation = [0.50208811]
# Cost validation = [0.50194749]
# Cost validation = [0.50180743]
# Cost validation = [0.50166794]
# Cost validation = [0.501529]
# Cost validation = [0.50139062]
# Cost validation = [0.50125278]
# Cost validation = [0.50111549]
# Cost validation = [0.50097875]
# Cost validation = [0.50084254]
# Cost validation = [0.50070687]
# Cost validation = [0.50057173]
# Cost validation = [0.50043712]
# Cost validation = [0.50030304]
# Cost validation = [0.50016948]
# Cost validation = [0.50003643]
# Cost validation = [0.49990391]
# Cost validation = [0.4997719]
# Cost validation = [0.49964039]
# Cost validation = [0.4995094]
# Cost validation = [0.4993789]
# Cost validation = [0.49924891]
# Cost validation = [0.49911942]
# Cost validation = [0.49899042]
# Cost validation = [0.49886191]
# Cost validation = [0.49873389]
# Cost validation = [0.49860635]
# Cost validation = [0.4984793]
# Cost validation = [0.49835272]
# Cost validation = [0.49822663]
# Cost validation = [0.498101]
# Cost validation = [0.49797585]
# Cost validation = [0.49785117]
# Cost validation = [0.49772695]
# Cost validation = [0.49760319]
# Cost validation = [0.49747989]
# Cost validation = [0.49735705]
# Cost validation = [0.49723467]
# Cost validation = [0.49711273]
# Cost validation = [0.49699125]
# Cost validation = [0.49687021]
# Cost validation = [0.49674962]
# Cost validation = [0.49662946]
# Cost validation = [0.49650974]
# Cost validation = [0.49639046]
# Cost validation = [0.49627162]
# Cost validation = [0.4961532]
# Cost validation = [0.49603521]
# Cost validation = [0.49591765]
# Cost validation = [0.49580051]
# Cost validation = [0.4956838]
# Cost validation = [0.4955675]
# Cost validation = [0.49545161]
# Cost validation = [0.49533614]
# Cost validation = [0.49522108]
# Cost validation = [0.49510643]
# Cost validation = [0.49499219]
# Cost validation = [0.49487835]
# Cost validation = [0.49476492]
# Cost validation = [0.49465188]
# Cost validation = [0.49453924]
# Cost validation = [0.49442699]
# Cost validation = [0.49431514]
# Cost validation = [0.49420368]
# Cost validation = [0.49409261]
# Cost validation = [0.49398192]
# Cost validation = [0.49387162]
# Cost validation = [0.4937617]
# Cost validation = [0.49365216]
# Cost validation = [0.49354299]
# Cost validation = [0.4934342]
# Cost validation = [0.49332579]
# Cost validation = [0.49321775]
# Cost validation = [0.49311008]
# Cost validation = [0.49300277]
# Cost validation = [0.49289583]
# Cost validation = [0.49278925]
# Cost validation = [0.49268304]
# Cost validation = [0.49257718]
# Cost validation = [0.49247168]
# Cost validation = [0.49236654]
# Cost validation = [0.49226175]
# Cost validation = [0.49215731]
# Cost validation = [0.49205322]
# Cost validation = [0.49194948]
# Cost validation = [0.49184608]
# Cost validation = [0.49174303]
# Cost validation = [0.49164032]
# Cost validation = [0.49153795]
# Cost validation = [0.49143592]
# Cost validation = [0.49133423]
# Cost validation = [0.49123287]
# Cost validation = [0.49113185]
# Cost validation = [0.49103115]
# Cost validation = [0.49093079]
# Cost validation = [0.49083075]
# Cost validation = [0.49073104]
# Cost validation = [0.49063165]
# Cost validation = [0.49053259]
# Cost validation = [0.49043385]
# Cost validation = [0.49033542]
# Cost validation = [0.49023732]
# Cost validation = [0.49013953]
# Cost validation = [0.49004205]
# Cost validation = [0.48994489]
# Cost validation = [0.48984804]
# Cost validation = [0.4897515]
# Cost validation = [0.48965526]
# Cost validation = [0.48955933]
# Cost validation = [0.48946371]
# Cost validation = [0.48936839]
# Cost validation = [0.48927337]
# Cost validation = [0.48917865]
# Cost validation = [0.48908423]
# Cost validation = [0.48899011]
# Cost validation = [0.48889628]
# Cost validation = [0.48880275]
# Cost validation = [0.4887095]
# Cost validation = [0.48861655]
# Cost validation = [0.48852389]
# Cost validation = [0.48843152]
# Cost validation = [0.48833943]
# Cost validation = [0.48824763]
# Cost validation = [0.48815611]
# Cost validation = [0.48806488]
# Cost validation = [0.48797392]
# Cost validation = [0.48788325]
# Cost validation = [0.48779285]
# Cost validation = [0.48770273]
# Cost validation = [0.48761288]
# Cost validation = [0.48752331]
# Cost validation = [0.48743401]
# Cost validation = [0.48734499]
# Cost validation = [0.48725623]
# Cost validation = [0.48716774]
# Cost validation = [0.48707952]
# Cost validation = [0.48699156]
# Cost validation = [0.48690387]
# Cost validation = [0.48681644]
# Cost validation = [0.48672928]
# Cost validation = [0.48664237]
# Cost validation = [0.48655573]
# Cost validation = [0.48646934]
# Cost validation = [0.48638321]
# Cost validation = [0.48629734]
# Cost validation = [0.48621172]
# Cost validation = [0.48612635]
# Cost validation = [0.48604124]
# Cost validation = [0.48595637]
# Cost validation = [0.48587176]
# Cost validation = [0.48578739]
# Cost validation = [0.48570328]
# Cost validation = [0.48561941]
# Cost validation = [0.48553578]
# Cost validation = [0.4854524]
# Cost validation = [0.48536926]
# Cost validation = [0.48528636]
# Cost validation = [0.4852037]
# Cost validation = [0.48512128]
# Cost validation = [0.4850391]
# Cost validation = [0.48495716]
# Cost validation = [0.48487545]
# Cost validation = [0.48479398]
# Cost validation = [0.48471274]
# Cost validation = [0.48463174]
# Cost validation = [0.48455096]
# Cost validation = [0.48447042]
# Cost validation = [0.4843901]
# Cost validation = [0.48431002]
# Cost validation = [0.48423016]
# Cost validation = [0.48415053]
# Cost validation = [0.48407112]
# Cost validation = [0.48399194]
# Cost validation = [0.48391298]
# Cost validation = [0.48383424]
# Cost validation = [0.48375572]
# Cost validation = [0.48367743]
# Cost validation = [0.48359935]
# Cost validation = [0.48352149]
# Cost validation = [0.48344385]
# Cost validation = [0.48336643]
# Cost validation = [0.48328922]
# Cost validation = [0.48321222]
# Cost validation = [0.48313544]
# Cost validation = [0.48305887]
# Cost validation = [0.48298251]
# Cost validation = [0.48290636]
# Cost validation = [0.48283043]
# Cost validation = [0.4827547]
# Cost validation = [0.48267917]
# Cost validation = [0.48260386]
# Cost validation = [0.48252875]
# Cost validation = [0.48245385]
# Cost validation = [0.48237914]
# Cost validation = [0.48230465]
# Cost validation = [0.48223035]
# Cost validation = [0.48215626]
# Cost validation = [0.48208237]
# Cost validation = [0.48200867]
# Cost validation = [0.48193518]
# Cost validation = [0.48186188]
# Cost validation = [0.48178878]
# Cost validation = [0.48171588]
# Cost validation = [0.48164317]
# Cost validation = [0.48157066]
# Cost validation = [0.48149834]
# Cost validation = [0.48142621]
# Cost validation = [0.48135428]
# Cost validation = [0.48128253]
# Cost validation = [0.48121098]
# Cost validation = [0.48113962]
# Cost validation = [0.48106844]
# Cost validation = [0.48099746]
# Cost validation = [0.48092666]
# Cost validation = [0.48085604]
# Cost validation = [0.48078561]
# Cost validation = [0.48071537]
# Cost validation = [0.48064531]
# Cost validation = [0.48057544]
# Cost validation = [0.48050574]
# Cost validation = [0.48043623]
# Cost validation = [0.4803669]
# Cost validation = [0.48029775]
# Cost validation = [0.48022878]
# Cost validation = [0.48015999]
# Cost validation = [0.48009137]
# Cost validation = [0.48002294]
# Cost validation = [0.47995468]
# Cost validation = [0.47988659]
# Cost validation = [0.47981868]
# Cost validation = [0.47975095]
# Cost validation = [0.47968339]
# Cost validation = [0.479616]
# Cost validation = [0.47954878]
# Cost validation = [0.47948174]
# Cost validation = [0.47941486]
# Cost validation = [0.47934816]
# Cost validation = [0.47928162]
# Cost validation = [0.47921526]
# Cost validation = [0.47914906]
# Cost validation = [0.47908303]
# Cost validation = [0.47901716]
# Cost validation = [0.47895147]
# Cost validation = [0.47888593]
# Cost validation = [0.47882057]
# Cost validation = [0.47875536]
# Cost validation = [0.47869032]
# Cost validation = [0.47862544]
# Cost validation = [0.47856073]
# Cost validation = [0.47849617]
# Cost validation = [0.47843178]
# Cost validation = [0.47836755]
# Cost validation = [0.47830347]
# Cost validation = [0.47823956]
# Cost validation = [0.4781758]
# Cost validation = [0.4781122]
# Cost validation = [0.47804876]
# Cost validation = [0.47798548]
# Cost validation = [0.47792235]
# Cost validation = [0.47785937]
# Cost validation = [0.47779655]
# Cost validation = [0.47773389]
# Cost validation = [0.47767137]
# Cost validation = [0.47760901]
# Cost validation = [0.47754681]
# Cost validation = [0.47748475]
# Cost validation = [0.47742285]
# Cost validation = [0.47736109]
# Cost validation = [0.47729949]
# Cost validation = [0.47723803]
# Cost validation = [0.47717672]
# Cost validation = [0.47711557]
# Cost validation = [0.47705456]
# Cost validation = [0.47699369]
# Cost validation = [0.47693297]
# Cost validation = [0.4768724]
# Cost validation = [0.47681198]
# Cost validation = [0.4767517]
# Cost validation = [0.47669156]
# Cost validation = [0.47663157]
# Cost validation = [0.47657172]
# Cost validation = [0.47651201]
# Cost validation = [0.47645244]
# Cost validation = [0.47639302]
# Cost validation = [0.47633374]
# Cost validation = [0.4762746]
# Cost validation = [0.47621559]
# Cost validation = [0.47615673]
# Cost validation = [0.47609801]
# Cost validation = [0.47603942]
# Cost validation = [0.47598097]
# Cost validation = [0.47592267]
# Cost validation = [0.47586449]
# Cost validation = [0.47580646]
# Cost validation = [0.47574856]
# Cost validation = [0.47569079]
# Cost validation = [0.47563316]
# Cost validation = [0.47557566]
# Cost validation = [0.4755183]
# Cost validation = [0.47546107]
# Cost validation = [0.47540398]
# Cost validation = [0.47534702]
# Cost validation = [0.47529018]
# Cost validation = [0.47523349]
# Cost validation = [0.47517692]
# Cost validation = [0.47512048]
# Cost validation = [0.47506417]
# Cost validation = [0.47500799]
# Cost validation = [0.47495194]
# Cost validation = [0.47489602]
# Cost validation = [0.47484023]
# Cost validation = [0.47478457]
# Cost validation = [0.47472903]
# Cost validation = [0.47467362]
# Cost validation = [0.47461834]
# Cost validation = [0.47456318]
# Cost validation = [0.47450815]
# Cost validation = [0.47445324]
# Cost validation = [0.47439846]
# Cost validation = [0.4743438]
# Cost validation = [0.47428927]
# Cost validation = [0.47423486]
# Cost validation = [0.47418057]
# Cost validation = [0.4741264]
# Cost validation = [0.47407236]
# Cost validation = [0.47401844]
# Cost validation = [0.47396464]
# Cost validation = [0.47391096]
# Cost validation = [0.4738574]
# Cost validation = [0.47380396]
# Cost validation = [0.47375064]
# Cost validation = [0.47369744]
# Cost validation = [0.47364436]
# Cost validation = [0.47359139]
# Cost validation = [0.47353855]
# Cost validation = [0.47348582]
# Cost validation = [0.47343321]
# Cost validation = [0.47338071]
# Cost validation = [0.47332834]
# Cost validation = [0.47327607]
# Cost validation = [0.47322393]
# Cost validation = [0.4731719]
# Cost validation = [0.47311998]
# Cost validation = [0.47306818]
# Cost validation = [0.47301649]
# Cost validation = [0.47296491]
# Cost validation = [0.47291345]
# Cost validation = [0.4728621]
# Cost validation = [0.47281086]
# Cost validation = [0.47275974]
# Cost validation = [0.47270873]
# Cost validation = [0.47265783]
# Cost validation = [0.47260703]
# Cost validation = [0.47255635]
# Cost validation = [0.47250578]
# Cost validation = [0.47245532]
# Cost validation = [0.47240497]
# Cost validation = [0.47235473]
# Cost validation = [0.4723046]
# Cost validation = [0.47225457]
# Cost validation = [0.47220466]
# Cost validation = [0.47215485]
# Cost validation = [0.47210515]
# Cost validation = [0.47205555]
# Cost validation = [0.47200606]
# Cost validation = [0.47195668]
# Cost validation = [0.47190741]
# Cost validation = [0.47185824]
# Cost validation = [0.47180917]
# Cost validation = [0.47176021]
# Cost validation = [0.47171136]
# Cost validation = [0.4716626]
# Cost validation = [0.47161396]
# Cost validation = [0.47156541]
# Cost validation = [0.47151697]
# Cost validation = [0.47146863]
# Cost validation = [0.4714204]
# Cost validation = [0.47137227]
# Cost validation = [0.47132423]
# Cost validation = [0.47127631]
# Cost validation = [0.47122848]
# Cost validation = [0.47118075]
# Cost validation = [0.47113312]
# Cost validation = [0.4710856]
# Cost validation = [0.47103817]
# Cost validation = [0.47099084]
# Cost validation = [0.47094361]
# Cost validation = [0.47089648]
# Cost validation = [0.47084945]
# Cost validation = [0.47080252]
# Cost validation = [0.47075569]
# Cost validation = [0.47070895]
# Cost validation = [0.47066231]
# Cost validation = [0.47061577]
# Cost validation = [0.47056933]
# Cost validation = [0.47052298]
# Cost validation = [0.47047673]
# Cost validation = [0.47043057]
# Cost validation = [0.47038451]
# Cost validation = [0.47033855]
# Cost validation = [0.47029268]
# Cost validation = [0.4702469]
# Cost validation = [0.47020122]
# Cost validation = [0.47015564]
# Cost validation = [0.47011014]
# Cost validation = [0.47006475]
# Cost validation = [0.47001944]
# Cost validation = [0.46997423]
# Cost validation = [0.46992911]
# Cost validation = [0.46988408]
# Cost validation = [0.46983915]
# Cost validation = [0.4697943]
# Cost validation = [0.46974955]
# Cost validation = [0.46970489]
# Cost validation = [0.46966032]
# Cost validation = [0.46961584]
# Cost validation = [0.46957145]
# Cost validation = [0.46952716]
# Cost validation = [0.46948295]
# Cost validation = [0.46943883]
# Cost validation = [0.4693948]
# Cost validation = [0.46935086]
# Cost validation = [0.46930701]
# Cost validation = [0.46926325]
# Cost validation = [0.46921958]
# Cost validation = [0.46917599]
# Cost validation = [0.46913249]
# Cost validation = [0.46908908]
# Cost validation = [0.46904576]
# Cost validation = [0.46900253]
# Cost validation = [0.46895938]
# Cost validation = [0.46891631]
# Cost validation = [0.46887334]
# Cost validation = [0.46883045]
# Cost validation = [0.46878764]
# Cost validation = [0.46874492]
# Cost validation = [0.46870229]
# Cost validation = [0.46865974]
# Cost validation = [0.46861728]
# Cost validation = [0.4685749]
# Cost validation = [0.4685326]
# Cost validation = [0.46849039]
# Cost validation = [0.46844827]
# Cost validation = [0.46840622]
# Cost validation = [0.46836426]
# Cost validation = [0.46832238]
# Cost validation = [0.46828059]
# Cost validation = [0.46823888]
# Cost validation = [0.46819725]
# Cost validation = [0.4681557]
# Cost validation = [0.46811424]
# Cost validation = [0.46807285]
# Cost validation = [0.46803155]
# Cost validation = [0.46799033]
# Cost validation = [0.46794919]
# Cost validation = [0.46790813]
# Cost validation = [0.46786715]
# Cost validation = [0.46782625]
# Cost validation = [0.46778543]
# Cost validation = [0.46774469]
# Cost validation = [0.46770403]
# Cost validation = [0.46766345]
# Cost validation = [0.46762295]
# Cost validation = [0.46758253]
# Cost validation = [0.46754218]
# Cost validation = [0.46750192]
# Cost validation = [0.46746173]
# Cost validation = [0.46742162]
# Cost validation = [0.46738159]
# Cost validation = [0.46734164]
# Cost validation = [0.46730176]
# Cost validation = [0.46726196]
# Cost validation = [0.46722224]
# Cost validation = [0.46718259]
# Cost validation = [0.46714302]
# Cost validation = [0.46710353]
# Cost validation = [0.46706411]
# Cost validation = [0.46702477]
# Cost validation = [0.4669855]
# Cost validation = [0.46694631]
# Cost validation = [0.4669072]
# Cost validation = [0.46686816]
# Cost validation = [0.46682919]
# Cost validation = [0.4667903]
# Cost validation = [0.46675149]
# Cost validation = [0.46671274]
# Cost validation = [0.46667408]
# Cost validation = [0.46663548]
# Cost validation = [0.46659696]
# Cost validation = [0.46655851]
# Cost validation = [0.46652014]
# Cost validation = [0.46648184]
# Cost validation = [0.46644361]
# Cost validation = [0.46640545]
# Cost validation = [0.46636737]
# Cost validation = [0.46632936]
# Cost validation = [0.46629142]
# Cost validation = [0.46625355]
# Cost validation = [0.46621576]
# Cost validation = [0.46617803]
# Cost validation = [0.46614038]
# Cost validation = [0.4661028]
# Cost validation = [0.46606528]
# Cost validation = [0.46602784]
# Cost validation = [0.46599047]
# Cost validation = [0.46595317]
# Cost validation = [0.46591594]
# Cost validation = [0.46587878]
# Cost validation = [0.46584169]
# Cost validation = [0.46580467]
# Cost validation = [0.46576772]
# Cost validation = [0.46573084]
# Cost validation = [0.46569402]
# Cost validation = [0.46565728]
# Cost validation = [0.4656206]
# Cost validation = [0.46558399]
# Cost validation = [0.46554745]
# Cost validation = [0.46551098]
# Cost validation = [0.46547458]
# Cost validation = [0.46543824]
# Cost validation = [0.46540197]
# Cost validation = [0.46536577]
# Cost validation = [0.46532964]
# Cost validation = [0.46529357]
# Cost validation = [0.46525757]
# Cost validation = [0.46522164]
# Cost validation = [0.46518577]
# Cost validation = [0.46514997]
# Cost validation = [0.46511424]
# Cost validation = [0.46507857]
# Cost validation = [0.46504296]
# Cost validation = [0.46500743]
# Cost validation = [0.46497195]
# Cost validation = [0.46493655]
# Cost validation = [0.46490121]
# Cost validation = [0.46486593]
# Cost validation = [0.46483072]
# Cost validation = [0.46479557]
# Cost validation = [0.46476049]
# Cost validation = [0.46472547]
# Cost validation = [0.46469051]
# Cost validation = [0.46465562]
# Cost validation = [0.4646208]
# Cost validation = [0.46458603]
# Cost validation = [0.46455133]
# Cost validation = [0.4645167]
# Cost validation = [0.46448212]
# Cost validation = [0.46444761]
# Cost validation = [0.46441316]
# Cost validation = [0.46437878]
# Cost validation = [0.46434446]
# Cost validation = [0.4643102]
# Cost validation = [0.464276]
# Cost validation = [0.46424186]
# Cost validation = [0.46420779]
# Cost validation = [0.46417377]
# Cost validation = [0.46413982]
# Cost validation = [0.46410593]
# Cost validation = [0.4640721]
# Cost validation = [0.46403834]
# Cost validation = [0.46400463]
# Cost validation = [0.46397098]
# Cost validation = [0.4639374]
# Cost validation = [0.46390387]
# Cost validation = [0.46387041]
# Cost validation = [0.46383701]
# Cost validation = [0.46380366]
# Cost validation = [0.46377038]
# Cost validation = [0.46373715]
# Cost validation = [0.46370399]
# Cost validation = [0.46367088]
# Cost validation = [0.46363783]
# Cost validation = [0.46360485]
# Cost validation = [0.46357192]
# Cost validation = [0.46353905]
# Cost validation = [0.46350624]
# Cost validation = [0.46347349]
# Cost validation = [0.46344079]
# Cost validation = [0.46340816]
# Cost validation = [0.46337558]
# Cost validation = [0.46334306]
# Cost validation = [0.4633106]
# Cost validation = [0.46327819]
# Cost validation = [0.46324585]
# Cost validation = [0.46321356]
# Cost validation = [0.46318133]
# Cost validation = [0.46314915]
# Cost validation = [0.46311703]
# Cost validation = [0.46308497]
# Cost validation = [0.46305297]
# Cost validation = [0.46302102]
# Cost validation = [0.46298913]
# Cost validation = [0.46295729]
# Cost validation = [0.46292552]
# Cost validation = [0.46289379]
# Cost validation = [0.46286213]
# Cost validation = [0.46283051]
# Cost validation = [0.46279896]
# Cost validation = [0.46276746]
# Cost validation = [0.46273601]
# Cost validation = [0.46270462]
# Cost validation = [0.46267329]
# Cost validation = [0.46264201]
# Cost validation = [0.46261079]
# Cost validation = [0.46257962]
# Cost validation = [0.4625485]
# Cost validation = [0.46251744]
# Cost validation = [0.46248643]
# Cost validation = [0.46245548]
# Cost validation = [0.46242458]
# Cost validation = [0.46239374]
# Cost validation = [0.46236295]
# Cost validation = [0.46233221]
# Cost validation = [0.46230153]
# Cost validation = [0.4622709]
# Cost validation = [0.46224032]
# Cost validation = [0.46220979]
# Cost validation = [0.46217932]
# Cost validation = [0.46214891]
# Cost validation = [0.46211854]
# Cost validation = [0.46208823]
# Cost validation = [0.46205797]
# Cost validation = [0.46202776]
# Cost validation = [0.46199761]
# Cost validation = [0.4619675]
# Cost validation = [0.46193745]
# Cost validation = [0.46190745]
# Cost validation = [0.4618775]
# Cost validation = [0.46184761]
# Cost validation = [0.46181776]
# Cost validation = [0.46178797]
# Cost validation = [0.46175823]
# Cost validation = [0.46172854]
# Cost validation = [0.4616989]
# Cost validation = [0.46166931]
# Cost validation = [0.46163978]
# Cost validation = [0.46161029]
# Cost validation = [0.46158085]
# Cost validation = [0.46155147]
# Cost validation = [0.46152213]
# Cost validation = [0.46149285]
# Cost validation = [0.46146361]
# Cost validation = [0.46143443]
# Cost validation = [0.46140529]
# Cost validation = [0.46137621]
# Cost validation = [0.46134717]
# Cost validation = [0.46131819]
# Cost validation = [0.46128925]
# Cost validation = [0.46126036]
# Cost validation = [0.46123152]
# Cost validation = [0.46120274]
# Cost validation = [0.461174]
# Cost validation = [0.46114531]
# Cost validation = [0.46111666]
# Cost validation = [0.46108807]
# Cost validation = [0.46105952]
# Cost validation = [0.46103103]
# Cost validation = [0.46100258]
# Cost validation = [0.46097418]
# Cost validation = [0.46094583]
# Cost validation = [0.46091752]
# Cost validation = [0.46088927]
# Cost validation = [0.46086106]
# Cost validation = [0.4608329]
# Cost validation = [0.46080479]
# Cost validation = [0.46077672]
# Cost validation = [0.4607487]
# Cost validation = [0.46072073]
# Cost validation = [0.46069281]
# Cost validation = [0.46066493]
# Cost validation = [0.4606371]
# Cost validation = [0.46060932]
# Cost validation = [0.46058158]
# Cost validation = [0.46055389]
# Cost validation = [0.46052625]
# Cost validation = [0.46049865]
# Cost validation = [0.4604711]
# Cost validation = [0.4604436]
# Cost validation = [0.46041614]
# Cost validation = [0.46038873]
# Cost validation = [0.46036136]
# Cost validation = [0.46033404]
# Cost validation = [0.46030677]
# Cost validation = [0.46027954]
# Cost validation = [0.46025236]
# Cost validation = [0.46022522]
# Cost validation = [0.46019812]
# Cost validation = [0.46017108]
# Cost validation = [0.46014407]
# Cost validation = [0.46011712]
# Cost validation = [0.4600902]
# Cost validation = [0.46006333]
# Cost validation = [0.46003651]
# Cost validation = [0.46000973]
# Cost validation = [0.459983]
# Cost validation = [0.45995631]
# Cost validation = [0.45992966]
# Cost validation = [0.45990306]
# Cost validation = [0.4598765]
# Cost validation = [0.45984999]
# Cost validation = [0.45982352]
# Cost validation = [0.4597971]
# Cost validation = [0.45977071]
# Cost validation = [0.45974438]
# Cost validation = [0.45971808]
# Cost validation = [0.45969183]
# Cost validation = [0.45966562]
# Cost validation = [0.45963946]
# Cost validation = [0.45961334]
# Cost validation = [0.45958726]
# Cost validation = [0.45956122]
# Cost validation = [0.45953523]
# Cost validation = [0.45950928]
# Cost validation = [0.45948337]
# Cost validation = [0.45945751]
# Cost validation = [0.45943168]
# Cost validation = [0.45940591]
# Cost validation = [0.45938017]
# Cost validation = [0.45935447]
# Cost validation = [0.45932882]
# Cost validation = [0.45930321]
# Cost validation = [0.45927764]
# Cost validation = [0.45925211]
# Cost validation = [0.45922663]
# Cost validation = [0.45920118]
# Cost validation = [0.45917578]
# Cost validation = [0.45915042]
# Cost validation = [0.4591251]
# Cost validation = [0.45909982]
# Cost validation = [0.45907459]
# Cost validation = [0.45904939]
# Cost validation = [0.45902424]
# Cost validation = [0.45899912]
# Cost validation = [0.45897405]
# Cost validation = [0.45894902]
# Cost validation = [0.45892403]
# Cost validation = [0.45889908]
# Cost validation = [0.45887417]
# Cost validation = [0.4588493]
# Cost validation = [0.45882447]
# Cost validation = [0.45879968]
# Cost validation = [0.45877493]
# Cost validation = [0.45875022]
# Cost validation = [0.45872556]
# Cost validation = [0.45870093]
# Cost validation = [0.45867634]
# Cost validation = [0.45865179]
# Cost validation = [0.45862728]
# Cost validation = [0.45860281]
# Cost validation = [0.45857838]
# Cost validation = [0.45855399]
# Cost validation = [0.45852964]
# Cost validation = [0.45850533]
# Cost validation = [0.45848105]
# Cost validation = [0.45845682]
# Cost validation = [0.45843263]
# Cost validation = [0.45840847]
# Cost validation = [0.45838435]
# Cost validation = [0.45836028]
# Cost validation = [0.45833624]
# Cost validation = [0.45831224]
# Cost validation = [0.45828827]
# Cost validation = [0.45826435]
# Cost validation = [0.45824047]
# Cost validation = [0.45821662]
# Cost validation = [0.45819281]
# Cost validation = [0.45816904]
# Cost validation = [0.45814531]
# Cost validation = [0.45812161]
# Cost validation = [0.45809796]
# Cost validation = [0.45807434]
# Cost validation = [0.45805076]
# Cost validation = [0.45802721]
# Cost validation = [0.45800371]
# Cost validation = [0.45798024]
# Cost validation = [0.45795681]
# Cost validation = [0.45793341]
# Cost validation = [0.45791006]
# Cost validation = [0.45788674]
# Cost validation = [0.45786346]
# Cost validation = [0.45784021]
# Cost validation = [0.457817]
# Cost validation = [0.45779383]
# Cost validation = [0.4577707]
# Cost validation = [0.4577476]
# Cost validation = [0.45772454]
# Cost validation = [0.45770152]
# Cost validation = [0.45767853]
# Cost validation = [0.45765558]
# Cost validation = [0.45763267]
# Cost validation = [0.45760979]
# Cost validation = [0.45758694]
# Cost validation = [0.45756414]
# Cost validation = [0.45754137]
# Cost validation = [0.45751864]
# Cost validation = [0.45749594]
# Cost validation = [0.45747328]
# Cost validation = [0.45745065]
# Cost validation = [0.45742806]
# Cost validation = [0.4574055]
# Cost validation = [0.45738298]
# Cost validation = [0.4573605]
# Cost validation = [0.45733805]
# Cost validation = [0.45731564]
# Cost validation = [0.45729326]
# Cost validation = [0.45727092]
# Cost validation = [0.45724861]
# Cost validation = [0.45722634]
# Cost validation = [0.4572041]
# Cost validation = [0.4571819]
# Cost validation = [0.45715973]
# Cost validation = [0.4571376]
# Cost validation = [0.4571155]
# Cost validation = [0.45709344]
# Cost validation = [0.45707141]
# Cost validation = [0.45704941]
# Cost validation = [0.45702746]
# Cost validation = [0.45700553]
# Cost validation = [0.45698364]
# Cost validation = [0.45696178]
# Cost validation = [0.45693996]
# Cost validation = [0.45691817]
# Cost validation = [0.45689642]
# Cost validation = [0.45687469]
# Cost validation = [0.45685301]
# Cost validation = [0.45683136]
# Cost validation = [0.45680974]
# Cost validation = [0.45678815]
# Cost validation = [0.4567666]
# Cost validation = [0.45674508]
# Cost validation = [0.4567236]
# Cost validation = [0.45670214]
# Cost validation = [0.45668073]
# Cost validation = [0.45665934]
# Cost validation = [0.45663799]
# Cost validation = [0.45661667]
# Cost validation = [0.45659539]
# Cost validation = [0.45657413]
# Cost validation = [0.45655292]
# Cost validation = [0.45653173]
# Cost validation = [0.45651058]
# Cost validation = [0.45648945]
# Cost validation = [0.45646837]
# Cost validation = [0.45644731]
# Cost validation = [0.45642629]
# Cost validation = [0.4564053]
# Cost validation = [0.45638434]
# Cost validation = [0.45636342]
# Cost validation = [0.45634252]
# Cost validation = [0.45632166]
# Cost validation = [0.45630083]
# Cost validation = [0.45628004]
# Cost validation = [0.45625927]
# Cost validation = [0.45623854]
# Cost validation = [0.45621784]
# Cost validation = [0.45619717]
# Cost validation = [0.45617653]
# Cost validation = [0.45615593]
# Cost validation = [0.45613535]
# Cost validation = [0.45611481]
# Cost validation = [0.4560943]
# Cost validation = [0.45607382]
# Cost validation = [0.45605338]
# Cost validation = [0.45603296]
# Cost validation = [0.45601258]
# Cost validation = [0.45599222]
# Cost validation = [0.4559719]
# Cost validation = [0.45595161]
# Cost validation = [0.45593135]
# Cost validation = [0.45591112]
# Cost validation = [0.45589092]
# Cost validation = [0.45587076]
# Cost validation = [0.45585062]
# Cost validation = [0.45583052]
# Cost validation = [0.45581044]
# Cost validation = [0.4557904]
# Cost validation = [0.45577038]
# Cost validation = [0.4557504]
# Cost validation = [0.45573045]
# Cost validation = [0.45571053]
# Cost validation = [0.45569063]
# Cost validation = [0.45567077]
# Cost validation = [0.45565094]
# Cost validation = [0.45563114]
# Cost validation = [0.45561137]
# Cost validation = [0.45559163]
# Cost validation = [0.45557192]
# Cost validation = [0.45555224]
# Cost validation = [0.45553259]
# Cost validation = [0.45551297]
# Cost validation = [0.45549338]
# Cost validation = [0.45547382]
# Cost validation = [0.45545428]
# Cost validation = [0.45543478]
# Cost validation = [0.45541531]
# Cost validation = [0.45539587]
# Cost validation = [0.45537645]
# Cost validation = [0.45535707]
# Cost validation = [0.45533771]
# Cost validation = [0.45531839]
# Cost validation = [0.45529909]
# Cost validation = [0.45527983]
# Cost validation = [0.45526059]
# Cost validation = [0.45524138]
# Cost validation = [0.4552222]
# Cost validation = [0.45520305]
# Cost validation = [0.45518393]
# Cost validation = [0.45516483]
# Cost validation = [0.45514577]
# Cost validation = [0.45512673]
# Cost validation = [0.45510772]
# Cost validation = [0.45508875]
# Cost validation = [0.4550698]
# Cost validation = [0.45505088]
# Cost validation = [0.45503198]
# Cost validation = [0.45501312]
# Cost validation = [0.45499428]
# Cost validation = [0.45497547]
# Cost validation = [0.45495669]
# Cost validation = [0.45493794]
# Cost validation = [0.45491922]
# Cost validation = [0.45490052]
# Cost validation = [0.45488186]
# Cost validation = [0.45486322]
# Cost validation = [0.45484461]
# Cost validation = [0.45482602]
# Cost validation = [0.45480747]
# Cost validation = [0.45478894]
# Cost validation = [0.45477044]
# Cost validation = [0.45475197]
# Cost validation = [0.45473352]
# Cost validation = [0.4547151]
# Cost validation = [0.45469671]
# Cost validation = [0.45467835]
# Cost validation = [0.45466002]
# Cost validation = [0.45464171]
# Cost validation = [0.45462343]
# Cost validation = [0.45460518]
# Cost validation = [0.45458695]
# Cost validation = [0.45456875]
# Cost validation = [0.45455058]
# Cost validation = [0.45453244]
# Cost validation = [0.45451432]
# Cost validation = [0.45449623]
# Cost validation = [0.45447816]
# Cost validation = [0.45446013]
# Cost validation = [0.45444212]
# Cost validation = [0.45442413]
# Cost validation = [0.45440618]
# Cost validation = [0.45438825]
# Cost validation = [0.45437034]
# Cost validation = [0.45435247]
# Cost validation = [0.45433462]
# Cost validation = [0.45431679]
# Cost validation = [0.45429899]
# Cost validation = [0.45428122]
# Cost validation = [0.45426348]
# Cost validation = [0.45424576]
# Cost validation = [0.45422807]
# Cost validation = [0.4542104]
# Cost validation = [0.45419276]
# Cost validation = [0.45417515]
# Cost validation = [0.45415756]
# Cost validation = [0.45414]
# Cost validation = [0.45412246]
# Cost validation = [0.45410495]
# Cost validation = [0.45408747]
# Cost validation = [0.45407001]
# Cost validation = [0.45405257]
# Cost validation = [0.45403517]
# Cost validation = [0.45401779]
# Cost validation = [0.45400043]
# Cost validation = [0.4539831]
# Cost validation = [0.45396579]
# Cost validation = [0.45394851]
# Cost validation = [0.45393126]
# Cost validation = [0.45391403]
# Cost validation = [0.45389683]
# Cost validation = [0.45387965]
# Cost validation = [0.4538625]
# Cost validation = [0.45384537]
# Cost validation = [0.45382827]
# Cost validation = [0.45381119]
# Cost validation = [0.45379414]
# Cost validation = [0.45377711]
# Cost validation = [0.4537601]
# Cost validation = [0.45374313]
# Cost validation = [0.45372617]
# Cost validation = [0.45370925]
# Cost validation = [0.45369234]
# Cost validation = [0.45367546]
# Cost validation = [0.45365861]
# Cost validation = [0.45364178]
# Cost validation = [0.45362497]
# Cost validation = [0.45360819]
# Cost validation = [0.45359144]
# Cost validation = [0.45357471]
# Cost validation = [0.453558]
# Cost validation = [0.45354132]
# Cost validation = [0.45352466]
# Cost validation = [0.45350802]
# Cost validation = [0.45349141]
# Cost validation = [0.45347483]
# Cost validation = [0.45345827]
# Cost validation = [0.45344173]
# Cost validation = [0.45342522]
# Cost validation = [0.45340873]
# Cost validation = [0.45339226]
# Cost validation = [0.45337582]
# Cost validation = [0.4533594]
# Cost validation = [0.45334301]
# Cost validation = [0.45332664]
# Cost validation = [0.45331029]
# Cost validation = [0.45329397]
# Cost validation = [0.45327767]
# Cost validation = [0.45326139]
# Cost validation = [0.45324514]
# Cost validation = [0.45322891]
# Cost validation = [0.45321271]
# Cost validation = [0.45319653]
# Cost validation = [0.45318037]
# Cost validation = [0.45316424]
# Cost validation = [0.45314812]
# Cost validation = [0.45313204]
# Cost validation = [0.45311597]
# Cost validation = [0.45309993]
# Cost validation = [0.45308391]
# Cost validation = [0.45306792]
# Cost validation = [0.45305194]
# Cost validation = [0.45303599]
# Cost validation = [0.45302007]
# Cost validation = [0.45300416]
# Cost validation = [0.45298828]
# Cost validation = [0.45297243]
# Cost validation = [0.45295659]
# Cost validation = [0.45294078]
# Cost validation = [0.45292499]
# Cost validation = [0.45290922]
# Cost validation = [0.45289348]
# Cost validation = [0.45287776]
# Cost validation = [0.45286206]
# Cost validation = [0.45284638]
# Cost validation = [0.45283073]
# Cost validation = [0.4528151]
# Cost validation = [0.45279949]
# Cost validation = [0.4527839]
# Cost validation = [0.45276834]
# Cost validation = [0.4527528]
# Cost validation = [0.45273728]
# Cost validation = [0.45272178]
# Cost validation = [0.45270631]
# Cost validation = [0.45269085]
# Cost validation = [0.45267542]
# Cost validation = [0.45266001]
# Cost validation = [0.45264463]
# Cost validation = [0.45262926]
# Cost validation = [0.45261392]
# Cost validation = [0.4525986]
# Cost validation = [0.4525833]
# Cost validation = [0.45256802]
# Cost validation = [0.45255277]
# Cost validation = [0.45253753]
# Cost validation = [0.45252232]
# Cost validation = [0.45250713]
# Cost validation = [0.45249196]
# Cost validation = [0.45247682]
# Cost validation = [0.45246169]
# Cost validation = [0.45244659]
# Cost validation = [0.4524315]
# Cost validation = [0.45241644]
# Cost validation = [0.4524014]
# Cost validation = [0.45238639]
# Cost validation = [0.45237139]
# Cost validation = [0.45235641]
# Cost validation = [0.45234146]
# Cost validation = [0.45232653]
# Cost validation = [0.45231161]
# Cost validation = [0.45229672]
# Cost validation = [0.45228185]
# Cost validation = [0.452267]
# Cost validation = [0.45225218]
# Cost validation = [0.45223737]
# Cost validation = [0.45222258]
# Cost validation = [0.45220782]
# Cost validation = [0.45219308]
# Cost validation = [0.45217835]
# Cost validation = [0.45216365]
# Cost validation = [0.45214897]
# Cost validation = [0.45213431]
# Cost validation = [0.45211967]
# Cost validation = [0.45210505]
# Cost validation = [0.45209045]
# Cost validation = [0.45207587]
# Cost validation = [0.45206132]
# Cost validation = [0.45204678]
# Cost validation = [0.45203226]
# Cost validation = [0.45201777]
# Cost validation = [0.45200329]
# Cost validation = [0.45198884]
# Cost validation = [0.4519744]
# Cost validation = [0.45195999]
# Cost validation = [0.45194559]
# Cost validation = [0.45193122]
# Cost validation = [0.45191687]
# Cost validation = [0.45190253]
# Cost validation = [0.45188822]
# Cost validation = [0.45187393]
# Cost validation = [0.45185965]
# Cost validation = [0.4518454]
# Cost validation = [0.45183117]
# Cost validation = [0.45181695]
# Cost validation = [0.45180276]
# Cost validation = [0.45178859]
# Cost validation = [0.45177443]
# Cost validation = [0.4517603]
# Cost validation = [0.45174618]
# Cost validation = [0.45173209]
# Cost validation = [0.45171802]
# Cost validation = [0.45170396]
# Cost validation = [0.45168993]
# Cost validation = [0.45167591]
# Cost validation = [0.45166191]
# Cost validation = [0.45164794]
# Cost validation = [0.45163398]
# Cost validation = [0.45162004]
# Cost validation = [0.45160613]
# Cost validation = [0.45159223]
# Cost validation = [0.45157835]
# Cost validation = [0.45156449]
# Cost validation = [0.45155065]
# Cost validation = [0.45153683]
# Cost validation = [0.45152303]
# Cost validation = [0.45150924]
# Cost validation = [0.45149548]
# Cost validation = [0.45148173]
# Cost validation = [0.45146801]
# Cost validation = [0.4514543]
# Cost validation = [0.45144062]
# Cost validation = [0.45142695]
# Cost validation = [0.4514133]
# Cost validation = [0.45139967]
# Cost validation = [0.45138606]
# Cost validation = [0.45137247]
# Cost validation = [0.45135889]
# Cost validation = [0.45134534]
# Cost validation = [0.4513318]
# Cost validation = [0.45131828]
# Cost validation = [0.45130479]
# Cost validation = [0.45129131]
# Cost validation = [0.45127785]
# Cost validation = [0.4512644]
# ...
# Cost validation = [0.44685579]
# Cost validation = [0.44684811]
# Cost validation = [0.44684044]
# Cost validation = [0.44683278]
# Cost validation = [0.44682513]
# Cost validation = [0.44681749]
# Cost validation = [0.44680986]
# Cost validation = [0.44680224]
# Cost validation = [0.44679462]
# Cost validation = [0.44678702]
# Cost validation = [0.44677942]
# Cost validation = [0.44677184]
# Cost validation = [0.44676426]
# Cost validation = [0.4467567]
# Cost validation = [0.44674914]
# Cost validation = [0.44674159]
# Cost validation = [0.44673405]
# Cost validation = [0.44672652]
# Cost validation = [0.446719]
# Cost validation = [0.44671148]
# Cost validation = [0.44670398]
# Cost validation = [0.44669649]
# Cost validation = [0.446689]
# Cost validation = [0.44668152]
# Cost validation = [0.44667406]
# Cost validation = [0.4466666]
# Cost validation = [0.44665915]
# Cost validation = [0.44665171]
# Cost validation = [0.44664428]
# Cost validation = [0.44663686]
# Cost validation = [0.44662944]
# Cost validation = [0.44662204]
# Cost validation = [0.44661464]
# Cost validation = [0.44660725]
# Cost validation = [0.44659988]
# Cost validation = [0.44659251]
# Cost validation = [0.44658515]
# Cost validation = [0.4465778]
# Cost validation = [0.44657045]
# Cost validation = [0.44656312]
# Cost validation = [0.44655579]
# Cost validation = [0.44654848]
# Cost validation = [0.44654117]
# Cost validation = [0.44653387]
# Cost validation = [0.44652658]
# Cost validation = [0.4465193]
# Cost validation = [0.44651203]
# Cost validation = [0.44650476]
# Cost validation = [0.44649751]
# Cost validation = [0.44649026]
# Cost validation = [0.44648302]
# Cost validation = [0.44647579]
# Cost validation = [0.44646857]
# Cost validation = [0.44646136]
# Cost validation = [0.44645416]
# Cost validation = [0.44644696]
# Cost validation = [0.44643978]
# Cost validation = [0.4464326]
# Cost validation = [0.44642543]
# Cost validation = [0.44641827]
# Cost validation = [0.44641112]
# Cost validation = [0.44640398]
# Cost validation = [0.44639684]
# Cost validation = [0.44638971]
# Cost validation = [0.4463826]
# Cost validation = [0.44637549]
# Cost validation = [0.44636839]
# Cost validation = [0.44636129]
# Cost validation = [0.44635421]
# Cost validation = [0.44634713]
# Cost validation = [0.44634007]
# Cost validation = [0.44633301]
# Cost validation = [0.44632596]
# Cost validation = [0.44631891]
# Cost validation = [0.44631188]
# Cost validation = [0.44630485]
# Cost validation = [0.44629784]
# Cost validation = [0.44629083]
# Cost validation = [0.44628383]
# Cost validation = [0.44627684]
# Cost validation = [0.44626985]
# Cost validation = [0.44626288]
# Cost validation = [0.44625591]
# Cost validation = [0.44624895]
# Cost validation = [0.446242]
# Cost validation = [0.44623506]
# Cost validation = [0.44622812]
# Cost validation = [0.44622119]
# Cost validation = [0.44621428]
# Cost validation = [0.44620737]
# Cost validation = [0.44620046]
# Cost validation = [0.44619357]
# Cost validation = [0.44618668]
# Cost validation = [0.44617981]
# Cost validation = [0.44617294]
# Cost validation = [0.44616608]
# Cost validation = [0.44615922]
# Cost validation = [0.44615238]
# Cost validation = [0.44614554]
# Cost validation = [0.44613871]
# Cost validation = [0.44613189]
# Cost validation = [0.44612508]
# Cost validation = [0.44611827]
# Cost validation = [0.44611148]
# Cost validation = [0.44610469]
# Cost validation = [0.44609791]
# Cost validation = [0.44609113]
# Cost validation = [0.44608437]
# Cost validation = [0.44607761]
# Cost validation = [0.44607086]
# Cost validation = [0.44606412]
# Cost validation = [0.44605739]
# Cost validation = [0.44605066]
# Cost validation = [0.44604395]
# Cost validation = [0.44603724]
# Cost validation = [0.44603053]
# Cost validation = [0.44602384]
# Cost validation = [0.44601715]
# Cost validation = [0.44601048]
# Cost validation = [0.44600381]
# Cost validation = [0.44599714]
# Cost validation = [0.44599049]
# Cost validation = [0.44598384]
# Cost validation = [0.4459772]
# Cost validation = [0.44597057]
# Cost validation = [0.44596395]
# Cost validation = [0.44595733]
# Cost validation = [0.44595072]
# Cost validation = [0.44594412]
# Cost validation = [0.44593753]
# Cost validation = [0.44593094]
# Cost validation = [0.44592437]
# Cost validation = [0.4459178]
# Cost validation = [0.44591124]
# Cost validation = [0.44590468]
# Cost validation = [0.44589813]
# Cost validation = [0.44589159]
# Cost validation = [0.44588506]
# Cost validation = [0.44587854]
# Cost validation = [0.44587202]
# Cost validation = [0.44586551]
# Cost validation = [0.44585901]
# Cost validation = [0.44585252]
# Cost validation = [0.44584603]
# Cost validation = [0.44583955]
# Cost validation = [0.44583308]
# Cost validation = [0.44582662]
# Cost validation = [0.44582016]
# Cost validation = [0.44581371]
# Cost validation = [0.44580727]
# Cost validation = [0.44580084]
# Cost validation = [0.44579441]
# Cost validation = [0.44578799]
# Cost validation = [0.44578158]
# Cost validation = [0.44577518]
# Cost validation = [0.44576878]
# Cost validation = [0.44576239]
# Cost validation = [0.44575601]
# Cost validation = [0.44574964]
# Cost validation = [0.44574327]
# Cost validation = [0.44573691]
# Cost validation = [0.44573056]
# Cost validation = [0.44572421]
# Cost validation = [0.44571788]
# Cost validation = [0.44571155]
# Cost validation = [0.44570522]
# Cost validation = [0.44569891]
# Cost validation = [0.4456926]
# Cost validation = [0.4456863]
# Cost validation = [0.44568]
# Cost validation = [0.44567372]
# Cost validation = [0.44566744]
# Cost validation = [0.44566117]
# Cost validation = [0.4456549]
# Cost validation = [0.44564864]
# Cost validation = [0.44564239]
# Cost validation = [0.44563615]
# Cost validation = [0.44562991]
# Cost validation = [0.44562368]
# Cost validation = [0.44561746]
# Cost validation = [0.44561125]
# Cost validation = [0.44560504]
# Cost validation = [0.44559884]
# Cost validation = [0.44559265]
# Cost validation = [0.44558646]
# Cost validation = [0.44558028]
# Cost validation = [0.44557411]
# Cost validation = [0.44556795]
# Cost validation = [0.44556179]
# Cost validation = [0.44555564]
# Cost validation = [0.44554949]
# Cost validation = [0.44554336]
# Cost validation = [0.44553723]
# Cost validation = [0.4455311]
# Cost validation = [0.44552499]
# Cost validation = [0.44551888]
# Cost validation = [0.44551278]
# Cost validation = [0.44550668]
# Cost validation = [0.4455006]
# Cost validation = [0.44549452]
# Cost validation = [0.44548844]
# Cost validation = [0.44548237]
# Cost validation = [0.44547631]
# Cost validation = [0.44547026]
# Cost validation = [0.44546422]
# Cost validation = [0.44545818]
# Cost validation = [0.44545214]
# Cost validation = [0.44544612]
# Cost validation = [0.4454401]
# Cost validation = [0.44543409]
# Cost validation = [0.44542808]
# Cost validation = [0.44542209]
# Cost validation = [0.44541609]
# Cost validation = [0.44541011]
# Cost validation = [0.44540413]
# Cost validation = [0.44539816]
# Cost validation = [0.4453922]
# Cost validation = [0.44538624]
# Cost validation = [0.44538029]
# Cost validation = [0.44537435]
# Cost validation = [0.44536841]
# Cost validation = [0.44536248]
# Cost validation = [0.44535655]
# Cost validation = [0.44535064]
# Cost validation = [0.44534473]
# Cost validation = [0.44533882]
# Cost validation = [0.44533293]
# Cost validation = [0.44532704]
# Cost validation = [0.44532115]
# Cost validation = [0.44531528]
# Cost validation = [0.44530941]
# Cost validation = [0.44530354]
# Cost validation = [0.44529769]
# Cost validation = [0.44529184]
# Cost validation = [0.44528599]
# Cost validation = [0.44528016]
# Cost validation = [0.44527433]
# Cost validation = [0.4452685]
# Cost validation = [0.44526269]
# Cost validation = [0.44525688]
# Cost validation = [0.44525107]
# Cost validation = [0.44524527]
# Cost validation = [0.44523948]
# Cost validation = [0.4452337]
# Cost validation = [0.44522792]
# Cost validation = [0.44522215]
# Cost validation = [0.44521638]
# Cost validation = [0.44521063]
# Cost validation = [0.44520487]
# Cost validation = [0.44519913]
# Cost validation = [0.44519339]
# Cost validation = [0.44518766]
# Cost validation = [0.44518193]
# Cost validation = [0.44517621]
# Cost validation = [0.4451705]
# Cost validation = [0.44516479]
# Cost validation = [0.44515909]
# Cost validation = [0.4451534]
# Cost validation = [0.44514771]
# Cost validation = [0.44514203]
# Cost validation = [0.44513635]
# Cost validation = [0.44513068]
# Cost validation = [0.44512502]
# Cost validation = [0.44511937]
# Cost validation = [0.44511372]
# Cost validation = [0.44510807]
# Cost validation = [0.44510244]
# Cost validation = [0.44509681]
# Cost validation = [0.44509118]
# Cost validation = [0.44508556]
# Cost validation = [0.44507995]
# Cost validation = [0.44507435]
# Cost validation = [0.44506875]
# Cost validation = [0.44506316]
# Cost validation = [0.44505757]
# Cost validation = [0.44505199]
# Cost validation = [0.44504641]
# Cost validation = [0.44504085]
# Cost validation = [0.44503528]
# Cost validation = [0.44502973]
# Cost validation = [0.44502418]
# Cost validation = [0.44501864]
# Cost validation = [0.4450131]
# Cost validation = [0.44500757]
# Cost validation = [0.44500204]
# Cost validation = [0.44499653]
# Cost validation = [0.44499101]
# Cost validation = [0.44498551]
# Cost validation = [0.44498001]
# Cost validation = [0.44497451]
# Cost validation = [0.44496902]
# Cost validation = [0.44496354]
# Cost validation = [0.44495807]
# Cost validation = [0.4449526]
# Cost validation = [0.44494713]
# Cost validation = [0.44494168]
# Cost validation = [0.44493622]
# Cost validation = [0.44493078]
# Cost validation = [0.44492534]
# Cost validation = [0.44491991]
# Cost validation = [0.44491448]
# Cost validation = [0.44490906]
# Cost validation = [0.44490364]
# Cost validation = [0.44489823]
# Cost validation = [0.44489283]
# Cost validation = [0.44488743]
# Cost validation = [0.44488204]
# Cost validation = [0.44487666]
# Cost validation = [0.44487128]
# Cost validation = [0.4448659]
# Cost validation = [0.44486054]
# Cost validation = [0.44485517]
# Cost validation = [0.44484982]
# Cost validation = [0.44484447]
# Cost validation = [0.44483912]
# Cost validation = [0.44483379]
# Cost validation = [0.44482845]
# Cost validation = [0.44482313]
# Cost validation = [0.44481781]
# Cost validation = [0.44481249]
# Cost validation = [0.44480718]
# Cost validation = [0.44480188]
# Cost validation = [0.44479658]
# Cost validation = [0.44479129]
# Cost validation = [0.44478601]
# Cost validation = [0.44478073]
# Cost validation = [0.44477545]
# Cost validation = [0.44477019]
# Cost validation = [0.44476492]
# Cost validation = [0.44475967]
# Cost validation = [0.44475442]
# Cost validation = [0.44474917]
# Cost validation = [0.44474393]
# Cost validation = [0.4447387]
# Cost validation = [0.44473347]
# Cost validation = [0.44472825]
# Cost validation = [0.44472303]
# Cost validation = [0.44471782]
# Cost validation = [0.44471262]
# Cost validation = [0.44470742]
# Cost validation = [0.44470223]
# Cost validation = [0.44469704]
# Cost validation = [0.44469186]
# Cost validation = [0.44468668]
# Cost validation = [0.44468151]
# Cost validation = [0.44467634]
# Cost validation = [0.44467118]
# Cost validation = [0.44466603]
# Cost validation = [0.44466088]
# Cost validation = [0.44465574]
# Cost validation = [0.4446506]
# Cost validation = [0.44464547]
# Cost validation = [0.44464035]
# Cost validation = [0.44463523]
# Cost validation = [0.44463011]
# Cost validation = [0.444625]
# Cost validation = [0.4446199]
# Cost validation = [0.4446148]
# Cost validation = [0.44460971]
# Cost validation = [0.44460462]
# Cost validation = [0.44459954]
# Cost validation = [0.44459446]
# Cost validation = [0.44458939]
# Cost validation = [0.44458433]
# Cost validation = [0.44457927]
# Cost validation = [0.44457422]
# Cost validation = [0.44456917]
# Cost validation = [0.44456413]
# Cost validation = [0.44455909]
# Cost validation = [0.44455406]
# Cost validation = [0.44454903]
# Cost validation = [0.44454401]
# Cost validation = [0.44453899]
# Cost validation = [0.44453398]
# Cost validation = [0.44452898]
# Cost validation = [0.44452398]
# Cost validation = [0.44451899]
# Cost validation = [0.444514]
# Cost validation = [0.44450901]
# Cost validation = [0.44450404]
# Cost validation = [0.44449907]
# Cost validation = [0.4444941]
# Cost validation = [0.44448914]
# Cost validation = [0.44448418]
# Cost validation = [0.44447923]
# Cost validation = [0.44447428]
# Cost validation = [0.44446934]
# Cost validation = [0.44446441]
# Cost validation = [0.44445948]
# Cost validation = [0.44445456]
# Cost validation = [0.44444964]
# Cost validation = [0.44444472]
# Cost validation = [0.44443982]
# Cost validation = [0.44443491]
# Cost validation = [0.44443001]
# Cost validation = [0.44442512]
# Cost validation = [0.44442024]
# Cost validation = [0.44441535]
# Cost validation = [0.44441048]
# Cost validation = [0.44440561]
# Cost validation = [0.44440074]
# Cost validation = [0.44439588]
# Cost validation = [0.44439102]
# Cost validation = [0.44438617]
# Cost validation = [0.44438133]
# Cost validation = [0.44437649]
# Cost validation = [0.44437165]
# Cost validation = [0.44436682]
# Cost validation = [0.444362]
# Cost validation = [0.44435718]
# Cost validation = [0.44435236]
# Cost validation = [0.44434755]
# Cost validation = [0.44434275]
# Cost validation = [0.44433795]
# Cost validation = [0.44433316]
# Cost validation = [0.44432837]
# Cost validation = [0.44432359]
# Cost validation = [0.44431881]
# Cost validation = [0.44431403]
# Cost validation = [0.44430927]
# Cost validation = [0.4443045]
# Cost validation = [0.44429975]
# Cost validation = [0.44429499]
# Cost validation = [0.44429024]
# Cost validation = [0.4442855]
# Cost validation = [0.44428076]
# Cost validation = [0.44427603]
# Cost validation = [0.4442713]
# Cost validation = [0.44426658]
# Cost validation = [0.44426186]
# Cost validation = [0.44425715]
# Cost validation = [0.44425244]
# Cost validation = [0.44424774]
# Cost validation = [0.44424304]
# Cost validation = [0.44423835]
# Cost validation = [0.44423366]
# Cost validation = [0.44422898]
# Cost validation = [0.4442243]
# Cost validation = [0.44421963]
# Cost validation = [0.44421496]
# Cost validation = [0.4442103]
# Cost validation = [0.44420564]
# Cost validation = [0.44420099]
# Cost validation = [0.44419634]
# Cost validation = [0.4441917]
# Cost validation = [0.44418706]
# Cost validation = [0.44418243]
# Cost validation = [0.4441778]
# Cost validation = [0.44417318]
# Cost validation = [0.44416856]
# Cost validation = [0.44416395]
# Cost validation = [0.44415934]
# Cost validation = [0.44415473]
# Cost validation = [0.44415013]
# Cost validation = [0.44414554]
# Cost validation = [0.44414095]
# Cost validation = [0.44413637]
# Cost validation = [0.44413179]
# Cost validation = [0.44412721]
# Cost validation = [0.44412264]
# Cost validation = [0.44411808]
# Cost validation = [0.44411352]
# Cost validation = [0.44410896]
# Cost validation = [0.44410441]
# Cost validation = [0.44409987]
# Cost validation = [0.44409532]
# Cost validation = [0.44409079]
# Cost validation = [0.44408626]
# Cost validation = [0.44408173]
# Cost validation = [0.44407721]
# Cost validation = [0.44407269]
# Cost validation = [0.44406818]
# Cost validation = [0.44406367]
# Cost validation = [0.44405917]
# Cost validation = [0.44405467]
# Cost validation = [0.44405018]
# Cost validation = [0.44404569]
# Cost validation = [0.4440412]
# Cost validation = [0.44403672]
# Cost validation = [0.44403225]
# Cost validation = [0.44402778]
# Cost validation = [0.44402331]
# Cost validation = [0.44401885]
# Cost validation = [0.4440144]
# Cost validation = [0.44400995]
# Cost validation = [0.4440055]
# Cost validation = [0.44400106]
# Cost validation = [0.44399662]
# Cost validation = [0.44399219]
# Cost validation = [0.44398776]
# Cost validation = [0.44398334]
# Cost validation = [0.44397892]
# Cost validation = [0.4439745]
# Cost validation = [0.44397009]
# Cost validation = [0.44396569]
# Cost validation = [0.44396129]
# Cost validation = [0.44395689]
# Cost validation = [0.4439525]
# Cost validation = [0.44394811]
# Cost validation = [0.44394373]
# Cost validation = [0.44393935]
# Cost validation = [0.44393498]
# Cost validation = [0.44393061]
# Cost validation = [0.44392625]
# Cost validation = [0.44392189]
# Cost validation = [0.44391753]
# Cost validation = [0.44391318]
# Cost validation = [0.44390884]
# Cost validation = [0.4439045]
# Cost validation = [0.44390016]
# Cost validation = [0.44389583]
# Cost validation = [0.4438915]
# Cost validation = [0.44388718]
# Cost validation = [0.44388286]
# Cost validation = [0.44387854]
# Cost validation = [0.44387423]
# Cost validation = [0.44386993]

# %%
plt.figure(figsize=([8,8]))
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
import seaborn as sns
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)

fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.95811184 0.04188816]
#  [0.66383963 0.33616037]]

# %% [markdown]
# # Accuracy.
# Både egen kode og tester med scikit.

# %%
classes = logreg.predict(xtrain)
print(100*np.sum(classes==ytrain)/len(classes),'% Training Accuracy')
print(f1_score(ytrain, classes))

classes = logreg.predict(xval)
print(100*np.sum(classes==yval)/len(classes),'% Validation Accuracy')
print(f1_score(yval, classes))


classes = logreg.predict(xtest)
print(100*np.sum(classes==ytest)/len(classes),'% Test Accuracy')
print(f1_score(ytest, classes))
# Out:
# 81.54285714285714 % Training Accuracy
# 0.44501718213058417
# 81.43333333333334 % Validation Accuracy
# 0.44244244244244246
# 82.36666666666666 % Test Accuracy
# 0.45181347150259066

# %% [markdown]
# # Egen logistisk regresjon med stokastisk gradient descent

# %%
# %matplotlib qt
import LogisticRegression as lr
Niter=2500
logreg = lr.LOGREG(eta=0.1, doplot = False, doprint=True)
cost_val, cost_train, axis = logreg.fit(xtrain, ytrain, xval, yval, Niter, solver='sgd', batch_size=500)
classified = logreg.predict(xtest)
# %matplotlib inline
# Out:
# Cost validation = [1.29420548]
# Cost validation = [1.2812297]
# Cost validation = [1.26591036]
# Cost validation = [1.25286682]
# Cost validation = [1.23838964]
# Cost validation = [1.2233923]
# Cost validation = [1.21002654]
# Cost validation = [1.19732337]
# Cost validation = [1.18481399]
# Cost validation = [1.170283]
# Cost validation = [1.15441819]
# Cost validation = [1.14257766]
# Cost validation = [1.13059689]
# Cost validation = [1.11794709]
# Cost validation = [1.10701683]
# Cost validation = [1.09347402]
# Cost validation = [1.08061185]
# Cost validation = [1.07061964]
# Cost validation = [1.05914214]
# Cost validation = [1.04866451]
# Cost validation = [1.03821687]
# Cost validation = [1.02698067]
# Cost validation = [1.01721194]
# Cost validation = [1.0083727]
# Cost validation = [0.99947099]
# Cost validation = [0.99008616]
# Cost validation = [0.98099668]
# Cost validation = [0.9696541]
# Cost validation = [0.95985137]
# Cost validation = [0.95058859]
# Cost validation = [0.94154208]
# Cost validation = [0.93469349]
# Cost validation = [0.92620371]
# Cost validation = [0.91730725]
# Cost validation = [0.90930352]
# Cost validation = [0.90094284]
# Cost validation = [0.89281171]
# Cost validation = [0.88649046]
# Cost validation = [0.8785876]
# Cost validation = [0.87250794]
# Cost validation = [0.86606517]
# Cost validation = [0.85982705]
# Cost validation = [0.85333717]
# Cost validation = [0.8485806]
# Cost validation = [0.84193276]
# Cost validation = [0.83489028]
# Cost validation = [0.83022621]
# Cost validation = [0.82535749]
# Cost validation = [0.81968983]
# Cost validation = [0.81479764]
# Cost validation = [0.81041145]
# Cost validation = [0.80601343]
# Cost validation = [0.80129942]
# Cost validation = [0.79693766]
# Cost validation = [0.79311258]
# Cost validation = [0.7889224]
# Cost validation = [0.78484257]
# Cost validation = [0.78088885]
# Cost validation = [0.77644998]
# Cost validation = [0.77365352]
# Cost validation = [0.77017607]
# Cost validation = [0.76632961]
# Cost validation = [0.76343464]
# Cost validation = [0.76001005]
# Cost validation = [0.75616882]
# Cost validation = [0.75243508]
# Cost validation = [0.74849628]
# Cost validation = [0.74605442]
# Cost validation = [0.74288552]
# Cost validation = [0.74019318]
# Cost validation = [0.73704991]
# Cost validation = [0.73478076]
# Cost validation = [0.7324804]
# Cost validation = [0.72968101]
# Cost validation = [0.72727261]
# Cost validation = [0.72468604]
# Cost validation = [0.72252844]
# Cost validation = [0.72047512]
# Cost validation = [0.71722817]
# Cost validation = [0.71499298]
# Cost validation = [0.71319532]
# Cost validation = [0.71083064]
# Cost validation = [0.70918142]
# Cost validation = [0.70644927]
# Cost validation = [0.70392843]
# Cost validation = [0.70184118]
# Cost validation = [0.6999866]
# Cost validation = [0.69790554]
# Cost validation = [0.6959101]
# Cost validation = [0.6942792]
# Cost validation = [0.69241575]
# Cost validation = [0.69031567]
# Cost validation = [0.68837788]
# Cost validation = [0.68636749]
# Cost validation = [0.68445198]
# Cost validation = [0.68292103]
# Cost validation = [0.6813983]
# Cost validation = [0.67972245]
# Cost validation = [0.67782786]
# Cost validation = [0.67666676]
# Cost validation = [0.67544722]
# Cost validation = [0.67334945]
# Cost validation = [0.67200122]
# Cost validation = [0.67060841]
# Cost validation = [0.66875212]
# Cost validation = [0.6674294]
# Cost validation = [0.66602624]
# Cost validation = [0.66398882]
# Cost validation = [0.66174642]
# Cost validation = [0.66033689]
# Cost validation = [0.65944258]
# Cost validation = [0.65781783]
# Cost validation = [0.6562981]
# Cost validation = [0.65454413]
# Cost validation = [0.65317805]
# Cost validation = [0.65149653]
# Cost validation = [0.65019462]
# Cost validation = [0.64863752]
# Cost validation = [0.64688624]
# Cost validation = [0.64533936]
# Cost validation = [0.64370576]
# Cost validation = [0.64243546]
# Cost validation = [0.64120057]
# Cost validation = [0.63943071]
# Cost validation = [0.6379876]
# Cost validation = [0.636362]
# Cost validation = [0.63486862]
# Cost validation = [0.63372283]
# Cost validation = [0.63221386]
# Cost validation = [0.6308246]
# Cost validation = [0.62941407]
# Cost validation = [0.62807347]
# Cost validation = [0.62662921]
# Cost validation = [0.62498555]
# Cost validation = [0.62350249]
# Cost validation = [0.62217143]
# Cost validation = [0.62077163]
# Cost validation = [0.61939811]
# Cost validation = [0.61830376]
# Cost validation = [0.61702457]
# Cost validation = [0.615922]
# Cost validation = [0.6147919]
# Cost validation = [0.61368469]
# Cost validation = [0.61248767]
# Cost validation = [0.61141686]
# Cost validation = [0.61045403]
# Cost validation = [0.60942387]
# Cost validation = [0.60829873]
# Cost validation = [0.60725165]
# Cost validation = [0.60605909]
# Cost validation = [0.60492289]
# Cost validation = [0.60400954]
# Cost validation = [0.60267565]
# Cost validation = [0.60146598]
# Cost validation = [0.60041]
# Cost validation = [0.59949765]
# Cost validation = [0.59842756]
# Cost validation = [0.59757127]
# Cost validation = [0.59669816]
# Cost validation = [0.59551875]
# Cost validation = [0.59453846]
# Cost validation = [0.59341161]
# Cost validation = [0.59255906]
# Cost validation = [0.59194565]
# Cost validation = [0.59126241]
# Cost validation = [0.59048236]
# Cost validation = [0.5898023]
# Cost validation = [0.58898963]
# Cost validation = [0.58831946]
# Cost validation = [0.58743643]
# Cost validation = [0.58642447]
# Cost validation = [0.58572867]
# Cost validation = [0.58473718]
# Cost validation = [0.58389991]
# Cost validation = [0.58282596]
# Cost validation = [0.58197561]
# Cost validation = [0.58104538]
# Cost validation = [0.58013355]
# Cost validation = [0.57936948]
# Cost validation = [0.57852697]
# Cost validation = [0.57777784]
# Cost validation = [0.57715301]
# Cost validation = [0.57610225]
# Cost validation = [0.57522116]
# Cost validation = [0.57439442]
# Cost validation = [0.57370536]
# Cost validation = [0.57306572]
# Cost validation = [0.57219264]
# Cost validation = [0.57146385]
# Cost validation = [0.57054822]
# Cost validation = [0.57008496]
# Cost validation = [0.56933306]
# Cost validation = [0.56850871]
# Cost validation = [0.5677781]
# Cost validation = [0.56712104]
# Cost validation = [0.56650537]
# Cost validation = [0.56594065]
# Cost validation = [0.56502577]
# Cost validation = [0.56438989]
# Cost validation = [0.56378666]
# Cost validation = [0.56320203]
# Cost validation = [0.5627697]
# Cost validation = [0.56220468]
# Cost validation = [0.5616239]
# Cost validation = [0.56117659]
# Cost validation = [0.56062979]
# Cost validation = [0.56001771]
# Cost validation = [0.55915192]
# Cost validation = [0.55854106]
# Cost validation = [0.55766652]
# Cost validation = [0.55707141]
# Cost validation = [0.55636795]
# Cost validation = [0.55578876]
# Cost validation = [0.55525242]
# Cost validation = [0.55481931]
# Cost validation = [0.55427279]
# Cost validation = [0.55378695]
# Cost validation = [0.55312135]
# Cost validation = [0.55257747]
# Cost validation = [0.55206248]
# Cost validation = [0.5513771]
# Cost validation = [0.5509419]
# Cost validation = [0.55048592]
# Cost validation = [0.55000923]
# Cost validation = [0.54952993]
# Cost validation = [0.54893038]
# Cost validation = [0.54833546]
# Cost validation = [0.54767089]
# Cost validation = [0.54717783]
# Cost validation = [0.5465767]
# Cost validation = [0.54606363]
# Cost validation = [0.54564148]
# Cost validation = [0.54526343]
# Cost validation = [0.5447781]
# Cost validation = [0.54417842]
# Cost validation = [0.54368774]
# Cost validation = [0.54310824]
# Cost validation = [0.54257495]
# Cost validation = [0.54199763]
# Cost validation = [0.54144526]
# Cost validation = [0.54102991]
# Cost validation = [0.54064492]
# Cost validation = [0.54023199]
# Cost validation = [0.53971386]
# Cost validation = [0.53926615]
# Cost validation = [0.53875885]
# Cost validation = [0.53826548]
# Cost validation = [0.5377002]
# Cost validation = [0.53720691]
# Cost validation = [0.5367675]
# Cost validation = [0.53637276]
# Cost validation = [0.53590523]
# Cost validation = [0.53545517]
# Cost validation = [0.53504756]
# Cost validation = [0.53477248]
# Cost validation = [0.53450429]
# Cost validation = [0.53421799]
# Cost validation = [0.53379736]
# Cost validation = [0.53334041]
# Cost validation = [0.53290365]
# Cost validation = [0.5325341]
# Cost validation = [0.53230445]
# Cost validation = [0.53193279]
# Cost validation = [0.53151134]
# Cost validation = [0.53119395]
# Cost validation = [0.53088611]
# Cost validation = [0.5304498]
# Cost validation = [0.52991278]
# Cost validation = [0.52975495]
# Cost validation = [0.52929755]
# Cost validation = [0.5289505]
# Cost validation = [0.52867366]
# Cost validation = [0.5283634]
# Cost validation = [0.52796096]
# Cost validation = [0.52760099]
# Cost validation = [0.52722943]
# Cost validation = [0.52687026]
# Cost validation = [0.52668869]
# Cost validation = [0.52627593]
# Cost validation = [0.52599367]
# Cost validation = [0.52559879]
# Cost validation = [0.52507143]
# Cost validation = [0.52477921]
# Cost validation = [0.52452553]
# Cost validation = [0.52427554]
# Cost validation = [0.52406809]
# Cost validation = [0.52366936]
# Cost validation = [0.52324591]
# Cost validation = [0.5229571]
# Cost validation = [0.52270033]
# Cost validation = [0.52240826]
# Cost validation = [0.52203702]
# Cost validation = [0.52166111]
# Cost validation = [0.52134778]
# Cost validation = [0.52091431]
# Cost validation = [0.52067712]
# Cost validation = [0.52046102]
# Cost validation = [0.52011627]
# Cost validation = [0.51973245]
# Cost validation = [0.51948148]
# Cost validation = [0.51919335]
# Cost validation = [0.51898731]
# Cost validation = [0.51884447]
# Cost validation = [0.51858775]
# Cost validation = [0.51835764]
# Cost validation = [0.51801518]
# Cost validation = [0.51784612]
# Cost validation = [0.51752369]
# Cost validation = [0.5172477]
# Cost validation = [0.51689821]
# Cost validation = [0.51659243]
# Cost validation = [0.51641201]
# Cost validation = [0.51612505]
# Cost validation = [0.5159582]
# Cost validation = [0.51561807]
# Cost validation = [0.51540771]
# Cost validation = [0.5152008]
# Cost validation = [0.51479709]
# Cost validation = [0.51470734]
# Cost validation = [0.51446501]
# Cost validation = [0.51414716]
# Cost validation = [0.51376231]
# Cost validation = [0.51350008]
# Cost validation = [0.51335373]
# Cost validation = [0.51315576]
# Cost validation = [0.51295501]
# Cost validation = [0.51271343]
# Cost validation = [0.51250067]
# Cost validation = [0.51219365]
# Cost validation = [0.5120223]
# Cost validation = [0.51186593]
# Cost validation = [0.51166188]
# Cost validation = [0.51139006]
# Cost validation = [0.51115107]
# Cost validation = [0.51098864]
# Cost validation = [0.51073481]
# Cost validation = [0.51055493]
# Cost validation = [0.51026867]
# Cost validation = [0.51007534]
# Cost validation = [0.50988231]
# Cost validation = [0.50971484]
# Cost validation = [0.50963965]
# Cost validation = [0.50946209]
# Cost validation = [0.50938522]
# Cost validation = [0.50917608]
# Cost validation = [0.50904372]
# Cost validation = [0.50881513]
# Cost validation = [0.50864511]
# Cost validation = [0.50850912]
# Cost validation = [0.50828637]
# Cost validation = [0.50816581]
# Cost validation = [0.50796699]
# Cost validation = [0.50766157]
# Cost validation = [0.50748684]
# Cost validation = [0.50743925]
# Cost validation = [0.50727056]
# Cost validation = [0.50706236]
# Cost validation = [0.5067184]
# Cost validation = [0.50656802]
# Cost validation = [0.50631262]
# Cost validation = [0.5060901]
# Cost validation = [0.50586655]
# Cost validation = [0.50562978]
# Cost validation = [0.50536199]
# Cost validation = [0.50514264]
# Cost validation = [0.50495655]
# Cost validation = [0.50465827]
# Cost validation = [0.50443688]
# Cost validation = [0.50422051]
# Cost validation = [0.50415254]
# Cost validation = [0.50389683]
# Cost validation = [0.50368155]
# Cost validation = [0.50351836]
# Cost validation = [0.50335226]
# Cost validation = [0.50307111]
# Cost validation = [0.50306892]
# Cost validation = [0.50288319]
# Cost validation = [0.50275323]
# Cost validation = [0.5025658]
# Cost validation = [0.50230421]
# Cost validation = [0.50214105]
# Cost validation = [0.50189908]
# Cost validation = [0.50169013]
# Cost validation = [0.5015355]
# Cost validation = [0.5012497]
# Cost validation = [0.5010354]
# Cost validation = [0.50082121]
# Cost validation = [0.50066568]
# Cost validation = [0.50046131]
# Cost validation = [0.50032973]
# Cost validation = [0.50031062]
# Cost validation = [0.5001087]
# Cost validation = [0.49980851]
# Cost validation = [0.4996766]
# Cost validation = [0.49953932]
# Cost validation = [0.49943293]
# Cost validation = [0.49936035]
# Cost validation = [0.49910041]
# Cost validation = [0.49903902]
# Cost validation = [0.49891247]
# Cost validation = [0.49867879]
# Cost validation = [0.49840518]
# Cost validation = [0.49829987]
# Cost validation = [0.49805693]
# Cost validation = [0.49787567]
# Cost validation = [0.49776867]
# Cost validation = [0.49760991]
# Cost validation = [0.49750016]
# Cost validation = [0.49738347]
# Cost validation = [0.4974484]
# Cost validation = [0.49738569]
# Cost validation = [0.49725586]
# Cost validation = [0.49715688]
# Cost validation = [0.49694372]
# Cost validation = [0.49686862]
# Cost validation = [0.49684911]
# Cost validation = [0.49666462]
# Cost validation = [0.49648652]
# Cost validation = [0.49615369]
# Cost validation = [0.49601964]
# Cost validation = [0.49584085]
# Cost validation = [0.49572264]
# Cost validation = [0.49566181]
# Cost validation = [0.49547676]
# Cost validation = [0.49529817]
# Cost validation = [0.49510978]
# Cost validation = [0.49494328]
# Cost validation = [0.49493145]
# Cost validation = [0.49466598]
# Cost validation = [0.49461915]
# Cost validation = [0.49449037]
# Cost validation = [0.49449299]
# Cost validation = [0.49438322]
# Cost validation = [0.49423801]
# Cost validation = [0.49396277]
# Cost validation = [0.49382972]
# Cost validation = [0.49374025]
# Cost validation = [0.4936185]
# Cost validation = [0.49349524]
# Cost validation = [0.49330104]
# Cost validation = [0.49318199]
# Cost validation = [0.49295066]
# Cost validation = [0.49290433]
# Cost validation = [0.49282721]
# Cost validation = [0.49278524]
# Cost validation = [0.4926647]
# Cost validation = [0.4925576]
# Cost validation = [0.4924398]
# Cost validation = [0.49242929]
# Cost validation = [0.49225758]
# Cost validation = [0.49215238]
# Cost validation = [0.49190828]
# Cost validation = [0.4917624]
# Cost validation = [0.49166488]
# Cost validation = [0.49161232]
# Cost validation = [0.49163327]
# Cost validation = [0.4914062]
# Cost validation = [0.49134158]
# Cost validation = [0.49129887]
# Cost validation = [0.49109132]
# Cost validation = [0.49106524]
# Cost validation = [0.49105293]
# Cost validation = [0.49098118]
# Cost validation = [0.49090294]
# Cost validation = [0.49078606]
# Cost validation = [0.49069412]
# Cost validation = [0.4906873]
# Cost validation = [0.49060906]
# Cost validation = [0.49059299]
# Cost validation = [0.49036196]
# Cost validation = [0.4902394]
# Cost validation = [0.49017164]
# Cost validation = [0.49006906]
# Cost validation = [0.49000789]
# Cost validation = [0.48988657]
# Cost validation = [0.4898492]
# Cost validation = [0.48976046]
# Cost validation = [0.48985561]
# Cost validation = [0.48984322]
# Cost validation = [0.48952682]
# Cost validation = [0.48933049]
# Cost validation = [0.48922534]
# Cost validation = [0.48912468]
# Cost validation = [0.48899015]
# Cost validation = [0.48893066]
# Cost validation = [0.48877276]
# Cost validation = [0.48863409]
# Cost validation = [0.48854431]
# Cost validation = [0.48838868]
# Cost validation = [0.4882321]
# Cost validation = [0.48822527]
# Cost validation = [0.48823077]
# Cost validation = [0.48820501]
# Cost validation = [0.48804281]
# Cost validation = [0.48796467]
# Cost validation = [0.48787095]
# Cost validation = [0.48776777]
# Cost validation = [0.48764424]
# Cost validation = [0.4875598]
# Cost validation = [0.48747131]
# Cost validation = [0.48748145]
# Cost validation = [0.48730509]
# Cost validation = [0.48716883]
# Cost validation = [0.48706653]
# Cost validation = [0.48705003]
# Cost validation = [0.48700025]
# Cost validation = [0.48686483]
# Cost validation = [0.48680323]
# Cost validation = [0.48666282]
# Cost validation = [0.48649098]
# Cost validation = [0.48637988]
# Cost validation = [0.48632332]
# Cost validation = [0.48624401]
# Cost validation = [0.48624751]
# Cost validation = [0.48622934]
# Cost validation = [0.48612326]
# Cost validation = [0.48609695]
# Cost validation = [0.48595513]
# Cost validation = [0.485789]
# Cost validation = [0.48572216]
# Cost validation = [0.48558329]
# Cost validation = [0.48554736]
# Cost validation = [0.48542487]
# Cost validation = [0.4853298]
# Cost validation = [0.48525808]
# Cost validation = [0.48515217]
# Cost validation = [0.48506532]
# Cost validation = [0.48491709]
# Cost validation = [0.48480311]
# Cost validation = [0.48470479]
# Cost validation = [0.48460872]
# Cost validation = [0.48454669]
# Cost validation = [0.48454836]
# Cost validation = [0.48451946]
# Cost validation = [0.48451254]
# Cost validation = [0.4844787]
# Cost validation = [0.4843461]
# Cost validation = [0.48433407]
# Cost validation = [0.4842996]
# Cost validation = [0.48429143]
# Cost validation = [0.48424064]
# Cost validation = [0.48420202]
# Cost validation = [0.48404488]
# Cost validation = [0.48388875]
# Cost validation = [0.48376806]
# Cost validation = [0.48367717]
# Cost validation = [0.48360041]
# Cost validation = [0.48354368]
# Cost validation = [0.48349997]
# Cost validation = [0.4834585]
# Cost validation = [0.48332201]
# Cost validation = [0.48321798]
# Cost validation = [0.48317923]
# Cost validation = [0.48308997]
# Cost validation = [0.48299768]
# Cost validation = [0.48296289]
# Cost validation = [0.48278833]
# Cost validation = [0.48273867]
# Cost validation = [0.48271138]
# Cost validation = [0.48266541]
# Cost validation = [0.48256004]
# Cost validation = [0.48251944]
# Cost validation = [0.48254715]
# Cost validation = [0.48243401]
# Cost validation = [0.48237957]
# Cost validation = [0.48225742]
# Cost validation = [0.48215165]
# Cost validation = [0.48217608]
# Cost validation = [0.4820947]
# Cost validation = [0.48216689]
# Cost validation = [0.48193914]
# Cost validation = [0.48190121]
# Cost validation = [0.48196436]
# Cost validation = [0.48188263]
# Cost validation = [0.481882]
# Cost validation = [0.48172597]
# Cost validation = [0.48160298]
# Cost validation = [0.48138456]
# Cost validation = [0.48140165]
# Cost validation = [0.48136915]
# Cost validation = [0.48131322]
# Cost validation = [0.4812784]
# Cost validation = [0.48118498]
# Cost validation = [0.48107882]
# Cost validation = [0.48099414]
# Cost validation = [0.48095654]
# Cost validation = [0.48091174]
# Cost validation = [0.48083526]
# Cost validation = [0.48081887]
# Cost validation = [0.48090882]
# Cost validation = [0.48094141]
# Cost validation = [0.48092385]
# Cost validation = [0.48097851]
# Cost validation = [0.48096429]
# Cost validation = [0.48086578]
# Cost validation = [0.48082431]
# Cost validation = [0.48082569]
# Cost validation = [0.48068107]
# Cost validation = [0.4807176]
# Cost validation = [0.48057326]
# Cost validation = [0.48052822]
# Cost validation = [0.48038872]
# Cost validation = [0.48036471]
# Cost validation = [0.4803338]
# Cost validation = [0.48028065]
# Cost validation = [0.48025148]
# Cost validation = [0.4801713]
# Cost validation = [0.48005885]
# Cost validation = [0.47990304]
# Cost validation = [0.4798996]
# Cost validation = [0.47974598]
# Cost validation = [0.4797077]
# Cost validation = [0.47970237]
# Cost validation = [0.4796849]
# Cost validation = [0.4796198]
# Cost validation = [0.47957353]
# Cost validation = [0.47940528]
# Cost validation = [0.47940314]
# Cost validation = [0.47929017]
# Cost validation = [0.47922367]
# Cost validation = [0.47914673]
# Cost validation = [0.47907674]
# Cost validation = [0.47899731]
# Cost validation = [0.47897682]
# Cost validation = [0.47893587]
# Cost validation = [0.47891537]
# Cost validation = [0.47894234]
# Cost validation = [0.47893816]
# Cost validation = [0.47887225]
# Cost validation = [0.47876544]
# Cost validation = [0.4787422]
# Cost validation = [0.47870842]
# Cost validation = [0.47860143]
# Cost validation = [0.47853671]
# Cost validation = [0.47842517]
# Cost validation = [0.47836872]
# Cost validation = [0.47831785]
# Cost validation = [0.47838324]
# Cost validation = [0.47841618]
# Cost validation = [0.4785322]
# Cost validation = [0.47842548]
# Cost validation = [0.47830762]
# Cost validation = [0.47815831]
# Cost validation = [0.47817854]
# Cost validation = [0.47816163]
# Cost validation = [0.47820623]
# Cost validation = [0.47817245]
# Cost validation = [0.47805804]
# Cost validation = [0.47804339]
# Cost validation = [0.47798066]
# Cost validation = [0.47794242]
# Cost validation = [0.47789631]
# Cost validation = [0.47774068]
# Cost validation = [0.4777592]
# Cost validation = [0.47753315]
# Cost validation = [0.47744946]
# Cost validation = [0.47727296]
# Cost validation = [0.47726751]
# Cost validation = [0.4770692]
# Cost validation = [0.47702824]
# Cost validation = [0.47699892]
# Cost validation = [0.47691539]
# Cost validation = [0.47688613]
# Cost validation = [0.47684366]
# Cost validation = [0.47684103]
# Cost validation = [0.4767673]
# Cost validation = [0.47664307]
# Cost validation = [0.47674563]
# Cost validation = [0.47660297]
# Cost validation = [0.47652082]
# Cost validation = [0.47637521]
# Cost validation = [0.47650433]
# Cost validation = [0.47636785]
# Cost validation = [0.47620806]
# Cost validation = [0.47612958]
# Cost validation = [0.47604452]
# Cost validation = [0.47595386]
# Cost validation = [0.47594751]
# Cost validation = [0.47592261]
# Cost validation = [0.4758245]
# Cost validation = [0.47583968]
# Cost validation = [0.47579169]
# Cost validation = [0.47577095]
# Cost validation = [0.47568408]
# Cost validation = [0.4756893]
# Cost validation = [0.47571024]
# Cost validation = [0.47576199]
# Cost validation = [0.47576175]
# Cost validation = [0.47579148]
# Cost validation = [0.47572606]
# Cost validation = [0.47566532]
# Cost validation = [0.47558379]
# Cost validation = [0.47561559]
# Cost validation = [0.47563126]
# Cost validation = [0.47551864]
# Cost validation = [0.47553356]
# Cost validation = [0.47546533]
# Cost validation = [0.47560177]
# Cost validation = [0.47545476]
# Cost validation = [0.47542153]
# Cost validation = [0.47542542]
# Cost validation = [0.47547445]
# Cost validation = [0.47540564]
# Cost validation = [0.47519834]
# Cost validation = [0.47510881]
# Cost validation = [0.47489965]
# Cost validation = [0.47480227]
# Cost validation = [0.47468649]
# Cost validation = [0.47453295]
# Cost validation = [0.47444894]
# Cost validation = [0.47438555]
# Cost validation = [0.47443728]
# Cost validation = [0.47435638]
# Cost validation = [0.47427351]
# Cost validation = [0.47437555]
# Cost validation = [0.4742844]
# Cost validation = [0.47427428]
# Cost validation = [0.47415298]
# Cost validation = [0.47412286]
# Cost validation = [0.47402889]
# Cost validation = [0.47396504]
# Cost validation = [0.47382361]
# Cost validation = [0.473814]
# Cost validation = [0.47386481]
# Cost validation = [0.47381011]
# Cost validation = [0.47377112]
# Cost validation = [0.47373008]
# Cost validation = [0.47368193]
# Cost validation = [0.47361891]
# Cost validation = [0.47356557]
# Cost validation = [0.4735735]
# Cost validation = [0.47352928]
# Cost validation = [0.47351117]
# Cost validation = [0.47350797]
# Cost validation = [0.4733968]
# Cost validation = [0.47350985]
# Cost validation = [0.47344062]
# Cost validation = [0.47340587]
# Cost validation = [0.47336067]
# Cost validation = [0.47336213]
# Cost validation = [0.47350329]
# Cost validation = [0.47346938]
# Cost validation = [0.47346772]
# Cost validation = [0.47341548]
# Cost validation = [0.47331969]
# Cost validation = [0.47323387]
# Cost validation = [0.47314]
# Cost validation = [0.47306112]
# Cost validation = [0.47303765]
# Cost validation = [0.47298501]
# Cost validation = [0.47289004]
# Cost validation = [0.47288612]
# Cost validation = [0.47285289]
# Cost validation = [0.47281607]
# Cost validation = [0.47273194]
# Cost validation = [0.47272749]
# Cost validation = [0.47280568]
# Cost validation = [0.47282621]
# Cost validation = [0.47284024]
# Cost validation = [0.47289073]
# Cost validation = [0.47277679]
# Cost validation = [0.47272445]
# Cost validation = [0.47264688]
# Cost validation = [0.47254029]
# Cost validation = [0.47240772]
# Cost validation = [0.47238047]
# Cost validation = [0.47235781]
# Cost validation = [0.47242505]
# Cost validation = [0.47241839]
# Cost validation = [0.47240902]
# Cost validation = [0.47234395]
# Cost validation = [0.47234943]
# Cost validation = [0.47220412]
# Cost validation = [0.47209732]
# Cost validation = [0.47213695]
# Cost validation = [0.47210125]
# Cost validation = [0.47201957]
# Cost validation = [0.47202793]
# Cost validation = [0.47198531]
# Cost validation = [0.47192937]
# Cost validation = [0.47188161]
# Cost validation = [0.47193743]
# Cost validation = [0.47194432]
# Cost validation = [0.47189564]
# Cost validation = [0.47182036]
# Cost validation = [0.47179642]
# Cost validation = [0.4717324]
# Cost validation = [0.47163236]
# Cost validation = [0.47160665]
# Cost validation = [0.47158025]
# Cost validation = [0.47162358]
# Cost validation = [0.47165397]
# Cost validation = [0.47161211]
# Cost validation = [0.47151856]
# Cost validation = [0.47141608]
# Cost validation = [0.47147238]
# Cost validation = [0.47161267]
# Cost validation = [0.47153138]
# Cost validation = [0.47146221]
# Cost validation = [0.4713733]
# Cost validation = [0.47133666]
# Cost validation = [0.47125531]
# Cost validation = [0.47113805]
# Cost validation = [0.47110603]
# Cost validation = [0.47105988]
# Cost validation = [0.47094581]
# Cost validation = [0.4708687]
# Cost validation = [0.47074039]
# Cost validation = [0.47063496]
# Cost validation = [0.47064316]
# Cost validation = [0.47055707]
# Cost validation = [0.4705447]
# Cost validation = [0.47049736]
# Cost validation = [0.47059391]
# Cost validation = [0.47049778]
# Cost validation = [0.4704025]
# Cost validation = [0.47039939]
# Cost validation = [0.470373]
# Cost validation = [0.47029757]
# Cost validation = [0.47024046]
# Cost validation = [0.47024846]
# Cost validation = [0.47029155]
# Cost validation = [0.47016692]
# Cost validation = [0.47004798]
# Cost validation = [0.47012796]
# Cost validation = [0.47008694]
# Cost validation = [0.47019719]
# Cost validation = [0.47018585]
# Cost validation = [0.47012529]
# Cost validation = [0.47013516]
# Cost validation = [0.47000572]
# Cost validation = [0.46993357]
# Cost validation = [0.46988179]
# Cost validation = [0.46976465]
# Cost validation = [0.46973191]
# Cost validation = [0.46979055]
# Cost validation = [0.46986145]
# Cost validation = [0.46985182]
# Cost validation = [0.46983951]
# Cost validation = [0.46970272]
# Cost validation = [0.46963047]
# Cost validation = [0.46950997]
# Cost validation = [0.46951542]
# Cost validation = [0.46949868]
# Cost validation = [0.46948756]
# Cost validation = [0.46942568]
# Cost validation = [0.46936071]
# Cost validation = [0.46931267]
# Cost validation = [0.46937853]
# Cost validation = [0.46939909]
# Cost validation = [0.46937707]
# Cost validation = [0.46934]
# Cost validation = [0.46924944]
# Cost validation = [0.4692432]
# Cost validation = [0.46925915]
# Cost validation = [0.4692589]
# Cost validation = [0.46923671]
# Cost validation = [0.46932821]
# Cost validation = [0.46934899]
# Cost validation = [0.4693376]
# Cost validation = [0.46927397]
# Cost validation = [0.46913983]
# Cost validation = [0.46911885]
# Cost validation = [0.46913242]
# Cost validation = [0.46901766]
# Cost validation = [0.46896116]
# Cost validation = [0.46893851]
# Cost validation = [0.46891502]
# Cost validation = [0.4689096]
# Cost validation = [0.46886087]
# Cost validation = [0.46889968]
# Cost validation = [0.46893466]
# Cost validation = [0.46876447]
# Cost validation = [0.4686554]
# Cost validation = [0.46863632]
# Cost validation = [0.46852773]
# Cost validation = [0.46853728]
# Cost validation = [0.46849762]
# Cost validation = [0.46848475]
# Cost validation = [0.46854395]
# Cost validation = [0.46853869]
# Cost validation = [0.4684807]
# Cost validation = [0.46860672]
# Cost validation = [0.46866108]
# Cost validation = [0.4686483]
# Cost validation = [0.46863137]
# Cost validation = [0.46851544]
# Cost validation = [0.46859134]
# Cost validation = [0.46855955]
# Cost validation = [0.46861205]
# Cost validation = [0.46845451]
# Cost validation = [0.46846524]
# Cost validation = [0.46841544]
# Cost validation = [0.46841185]
# Cost validation = [0.46838619]
# Cost validation = [0.46825711]
# Cost validation = [0.46817581]
# Cost validation = [0.4681595]
# Cost validation = [0.46817379]
# Cost validation = [0.46812063]
# Cost validation = [0.46813233]
# Cost validation = [0.46808896]
# Cost validation = [0.4680825]
# Cost validation = [0.46804353]
# Cost validation = [0.46814355]
# Cost validation = [0.46814078]
# Cost validation = [0.46811893]
# Cost validation = [0.46803679]
# Cost validation = [0.46812284]
# Cost validation = [0.46801568]
# Cost validation = [0.46792866]
# Cost validation = [0.46788955]
# Cost validation = [0.46791943]
# Cost validation = [0.46794371]
# Cost validation = [0.46790185]
# Cost validation = [0.46791121]
# Cost validation = [0.46785014]
# Cost validation = [0.46774386]
# Cost validation = [0.46765841]
# Cost validation = [0.4675318]
# Cost validation = [0.4676075]
# Cost validation = [0.46775496]
# Cost validation = [0.46769723]
# Cost validation = [0.46767711]
# Cost validation = [0.46764031]
# Cost validation = [0.46757126]
# Cost validation = [0.46747342]
# Cost validation = [0.46740196]
# Cost validation = [0.46747579]
# Cost validation = [0.4673159]
# Cost validation = [0.46719509]
# Cost validation = [0.46716807]
# Cost validation = [0.4671501]
# Cost validation = [0.46721342]
# Cost validation = [0.46715119]
# Cost validation = [0.46710529]
# Cost validation = [0.46706396]
# Cost validation = [0.46705697]
# Cost validation = [0.46701896]
# Cost validation = [0.46703016]
# Cost validation = [0.46698484]
# Cost validation = [0.4669112]
# Cost validation = [0.46678398]
# Cost validation = [0.46673093]
# Cost validation = [0.46678988]
# Cost validation = [0.46681319]
# Cost validation = [0.46684389]
# Cost validation = [0.46691758]
# Cost validation = [0.46684937]
# Cost validation = [0.46685484]
# Cost validation = [0.466849]
# Cost validation = [0.46685833]
# Cost validation = [0.46682627]
# Cost validation = [0.46682234]
# Cost validation = [0.46676721]
# Cost validation = [0.46663399]
# Cost validation = [0.46667257]
# Cost validation = [0.46663258]
# Cost validation = [0.46655725]
# Cost validation = [0.46657194]
# Cost validation = [0.46658188]
# Cost validation = [0.46657325]
# Cost validation = [0.46666328]
# Cost validation = [0.46664608]
# Cost validation = [0.46660386]
# Cost validation = [0.46653094]
# Cost validation = [0.46648226]
# Cost validation = [0.46644894]
# Cost validation = [0.46646026]
# Cost validation = [0.46648074]
# Cost validation = [0.46645213]
# Cost validation = [0.46651763]
# Cost validation = [0.4664423]
# Cost validation = [0.4663901]
# Cost validation = [0.46633692]
# Cost validation = [0.46628197]
# Cost validation = [0.46625389]
# Cost validation = [0.4662912]
# Cost validation = [0.46626188]
# Cost validation = [0.46637186]
# Cost validation = [0.46630139]
# Cost validation = [0.46636678]
# Cost validation = [0.46632971]
# Cost validation = [0.46637056]
# Cost validation = [0.46640506]
# Cost validation = [0.46627162]
# Cost validation = [0.46616481]
# Cost validation = [0.46621103]
# Cost validation = [0.46631482]
# Cost validation = [0.4662846]
# Cost validation = [0.46624996]
# Cost validation = [0.46619661]
# Cost validation = [0.46625871]
# Cost validation = [0.4661616]
# Cost validation = [0.46626472]
# Cost validation = [0.46634766]
# Cost validation = [0.46632142]
# Cost validation = [0.46630132]
# Cost validation = [0.46622592]
# Cost validation = [0.46635561]
# Cost validation = [0.46650266]
# Cost validation = [0.4663971]
# Cost validation = [0.46632704]
# Cost validation = [0.46630613]
# Cost validation = [0.46631045]
# Cost validation = [0.46627534]
# Cost validation = [0.466152]
# Cost validation = [0.46615816]
# Cost validation = [0.4662784]
# Cost validation = [0.46629077]
# Cost validation = [0.46636152]
# Cost validation = [0.46629722]
# Cost validation = [0.46635905]
# Cost validation = [0.4665232]
# Cost validation = [0.46638259]
# Cost validation = [0.46648262]
# Cost validation = [0.46652173]
# Cost validation = [0.46657882]
# Cost validation = [0.46634466]
# Cost validation = [0.46643354]
# Cost validation = [0.4662617]
# Cost validation = [0.46620616]
# Cost validation = [0.46614769]
# Cost validation = [0.46612336]
# Cost validation = [0.46602566]
# Cost validation = [0.46598747]
# Cost validation = [0.46597134]
# Cost validation = [0.4659886]
# Cost validation = [0.4660595]
# Cost validation = [0.46612937]
# Cost validation = [0.46601412]
# Cost validation = [0.46597859]
# Cost validation = [0.46596471]
# Cost validation = [0.4657851]
# Cost validation = [0.46582715]
# Cost validation = [0.46575872]
# Cost validation = [0.46570691]
# Cost validation = [0.46567883]
# Cost validation = [0.46567377]
# Cost validation = [0.46559247]
# Cost validation = [0.46558381]
# Cost validation = [0.46557758]
# Cost validation = [0.46554635]
# Cost validation = [0.46555171]
# Cost validation = [0.46551282]
# Cost validation = [0.46569627]
# Cost validation = [0.46569036]
# Cost validation = [0.46565018]
# Cost validation = [0.46537497]
# Cost validation = [0.46524138]
# Cost validation = [0.46516006]
# Cost validation = [0.46518269]
# Cost validation = [0.46508336]
# Cost validation = [0.46513302]
# Cost validation = [0.46510461]
# Cost validation = [0.46512811]
# Cost validation = [0.46509643]
# Cost validation = [0.46515384]
# Cost validation = [0.46516284]
# Cost validation = [0.46506186]
# Cost validation = [0.46507545]
# Cost validation = [0.46497474]
# Cost validation = [0.46495585]
# Cost validation = [0.46497989]
# Cost validation = [0.46497375]
# Cost validation = [0.46503858]
# Cost validation = [0.46493727]
# Cost validation = [0.46490081]
# Cost validation = [0.464798]
# Cost validation = [0.46485709]
# Cost validation = [0.46490927]
# Cost validation = [0.46488801]
# Cost validation = [0.46481535]
# Cost validation = [0.46473108]
# Cost validation = [0.46472396]
# Cost validation = [0.46476077]
# Cost validation = [0.46472632]
# Cost validation = [0.46477207]
# Cost validation = [0.46480176]
# Cost validation = [0.46474007]
# Cost validation = [0.46478803]
# Cost validation = [0.46456272]
# Cost validation = [0.46457403]
# Cost validation = [0.46448797]
# Cost validation = [0.46446162]
# Cost validation = [0.46445719]
# Cost validation = [0.46451623]
# Cost validation = [0.46448538]
# Cost validation = [0.46431397]
# Cost validation = [0.46435481]
# Cost validation = [0.46432226]
# Cost validation = [0.46437766]
# Cost validation = [0.46437975]
# Cost validation = [0.46437874]
# Cost validation = [0.46430563]
# Cost validation = [0.46427443]
# Cost validation = [0.46431108]
# Cost validation = [0.46430916]
# Cost validation = [0.46436893]
# Cost validation = [0.46431069]
# Cost validation = [0.46440411]
# Cost validation = [0.46439983]
# Cost validation = [0.46430687]
# Cost validation = [0.4642517]
# Cost validation = [0.46411844]
# Cost validation = [0.46405313]
# Cost validation = [0.46398735]
# Cost validation = [0.46389736]
# Cost validation = [0.4638819]
# Cost validation = [0.46392336]
# Cost validation = [0.46389177]
# Cost validation = [0.46387278]
# Cost validation = [0.46377316]
# Cost validation = [0.46378159]
# Cost validation = [0.46377526]
# Cost validation = [0.46373759]
# Cost validation = [0.46380044]
# Cost validation = [0.46392545]
# Cost validation = [0.4639779]
# Cost validation = [0.46397826]
# Cost validation = [0.46386768]
# Cost validation = [0.46383141]
# Cost validation = [0.46376302]
# Cost validation = [0.46371142]
# Cost validation = [0.46364164]
# Cost validation = [0.46358935]
# Cost validation = [0.463623]
# Cost validation = [0.4636911]
# Cost validation = [0.46370314]
# Cost validation = [0.46359684]
# Cost validation = [0.46351621]
# Cost validation = [0.46354187]
# Cost validation = [0.46355393]
# Cost validation = [0.46356875]
# Cost validation = [0.46354182]
# Cost validation = [0.46359262]
# Cost validation = [0.46353742]
# Cost validation = [0.46356491]
# Cost validation = [0.46358875]
# Cost validation = [0.46354217]
# Cost validation = [0.46346461]
# Cost validation = [0.46359882]
# Cost validation = [0.46356584]
# Cost validation = [0.46350342]
# Cost validation = [0.46344778]
# Cost validation = [0.46342229]
# Cost validation = [0.46341694]
# Cost validation = [0.46332229]
# Cost validation = [0.4632795]
# Cost validation = [0.4633156]
# Cost validation = [0.46331371]
# Cost validation = [0.46333908]
# Cost validation = [0.46331625]
# Cost validation = [0.463363]
# Cost validation = [0.46330493]
# Cost validation = [0.46320867]
# Cost validation = [0.46313088]
# Cost validation = [0.46309814]
# Cost validation = [0.46306975]
# Cost validation = [0.46303514]
# Cost validation = [0.46305809]
# Cost validation = [0.46302987]
# Cost validation = [0.46305718]
# Cost validation = [0.46308233]
# Cost validation = [0.46309091]
# Cost validation = [0.46312163]
# Cost validation = [0.46306976]
# Cost validation = [0.46308116]
# Cost validation = [0.46295965]
# Cost validation = [0.46290502]
# Cost validation = [0.46291858]
# Cost validation = [0.46290924]
# Cost validation = [0.46290223]
# Cost validation = [0.46286529]
# Cost validation = [0.46290088]
# Cost validation = [0.46278984]
# Cost validation = [0.4628463]
# Cost validation = [0.46281369]
# Cost validation = [0.46289541]
# Cost validation = [0.46291414]
# Cost validation = [0.46278998]
# Cost validation = [0.4627874]
# Cost validation = [0.46274999]
# Cost validation = [0.46268912]
# Cost validation = [0.46269211]
# Cost validation = [0.46269097]
# Cost validation = [0.46265335]
# Cost validation = [0.46257593]
# Cost validation = [0.46254767]
# Cost validation = [0.46256102]
# Cost validation = [0.46254724]
# Cost validation = [0.46251954]
# Cost validation = [0.46245278]
# Cost validation = [0.46247572]
# Cost validation = [0.4624751]
# Cost validation = [0.46243641]
# Cost validation = [0.46245606]
# Cost validation = [0.46240105]
# Cost validation = [0.46240434]
# Cost validation = [0.46224051]
# Cost validation = [0.46216361]
# Cost validation = [0.46207158]
# Cost validation = [0.46208261]
# Cost validation = [0.4622015]
# Cost validation = [0.4623029]
# Cost validation = [0.46225501]
# Cost validation = [0.4622639]
# Cost validation = [0.46230436]
# Cost validation = [0.46232748]
# Cost validation = [0.4624157]
# Cost validation = [0.46235492]
# Cost validation = [0.46234117]
# Cost validation = [0.46244621]
# Cost validation = [0.46253351]
# Cost validation = [0.4624945]
# Cost validation = [0.46248905]
# Cost validation = [0.46258257]
# Cost validation = [0.46249459]
# Cost validation = [0.46249134]
# Cost validation = [0.46244651]
# Cost validation = [0.46242856]
# Cost validation = [0.46247191]
# Cost validation = [0.46240354]
# Cost validation = [0.46228983]
# Cost validation = [0.46224169]
# Cost validation = [0.46222312]
# Cost validation = [0.46207008]
# Cost validation = [0.46195419]
# Cost validation = [0.46186405]
# Cost validation = [0.46186087]
# Cost validation = [0.46186707]
# Cost validation = [0.46195835]
# Cost validation = [0.46194409]
# Cost validation = [0.46194693]
# Cost validation = [0.4619888]
# Cost validation = [0.46205463]
# Cost validation = [0.46211774]
# Cost validation = [0.46212319]
# Cost validation = [0.4619872]
# Cost validation = [0.46208587]
# Cost validation = [0.46203929]
# Cost validation = [0.46202267]
# Cost validation = [0.46190709]
# Cost validation = [0.46178062]
# Cost validation = [0.46184303]
# Cost validation = [0.4617429]
# Cost validation = [0.46173237]
# Cost validation = [0.46186149]
# Cost validation = [0.4618784]
# Cost validation = [0.46184461]
# Cost validation = [0.46172428]
# Cost validation = [0.46170001]
# Cost validation = [0.46181336]
# Cost validation = [0.4616427]
# Cost validation = [0.46154116]
# Cost validation = [0.46150775]
# Cost validation = [0.46156715]
# Cost validation = [0.46167251]
# Cost validation = [0.46162504]
# Cost validation = [0.46159595]
# Cost validation = [0.46163457]
# Cost validation = [0.46163391]
# Cost validation = [0.46156822]
# Cost validation = [0.46156339]
# Cost validation = [0.46152707]
# Cost validation = [0.46147541]
# Cost validation = [0.46143732]
# Cost validation = [0.4613579]
# Cost validation = [0.46135349]
# Cost validation = [0.46135925]
# Cost validation = [0.46131453]
# Cost validation = [0.46131201]
# Cost validation = [0.46139486]
# Cost validation = [0.46140284]
# Cost validation = [0.46132932]
# Cost validation = [0.46127916]
# Cost validation = [0.4612609]
# Cost validation = [0.46115349]
# Cost validation = [0.46110412]
# Cost validation = [0.46112902]
# Cost validation = [0.46116539]
# Cost validation = [0.46114972]
# Cost validation = [0.46119257]
# Cost validation = [0.46111111]
# Cost validation = [0.4610765]
# Cost validation = [0.46112111]
# Cost validation = [0.46105465]
# Cost validation = [0.4610307]
# Cost validation = [0.46103034]
# Cost validation = [0.46093632]
# Cost validation = [0.46087764]
# Cost validation = [0.46081023]
# Cost validation = [0.46090449]
# Cost validation = [0.46082582]
# Cost validation = [0.46088734]
# Cost validation = [0.46078885]
# Cost validation = [0.46084709]
# Cost validation = [0.46081617]
# Cost validation = [0.46082285]
# Cost validation = [0.46084678]
# Cost validation = [0.46086114]
# Cost validation = [0.46077313]
# Cost validation = [0.46085503]
# Cost validation = [0.4608846]
# Cost validation = [0.46085377]
# Cost validation = [0.46080032]
# Cost validation = [0.46084127]
# Cost validation = [0.46080897]
# Cost validation = [0.46083119]
# Cost validation = [0.46083467]
# Cost validation = [0.46084759]
# Cost validation = [0.46090109]
# Cost validation = [0.46096754]
# Cost validation = [0.46088453]
# Cost validation = [0.46088471]
# Cost validation = [0.46075944]
# Cost validation = [0.46077135]
# Cost validation = [0.46080449]
# Cost validation = [0.46087337]
# Cost validation = [0.46092939]
# Cost validation = [0.46087463]
# Cost validation = [0.4607966]
# Cost validation = [0.46084296]
# Cost validation = [0.46075676]
# Cost validation = [0.46065406]
# Cost validation = [0.46056286]
# Cost validation = [0.46046377]
# Cost validation = [0.46045737]
# Cost validation = [0.46044936]
# Cost validation = [0.46047026]
# Cost validation = [0.46047653]
# Cost validation = [0.46044437]
# Cost validation = [0.46045157]
# Cost validation = [0.46046052]
# Cost validation = [0.46039041]
# Cost validation = [0.46032711]
# Cost validation = [0.46035386]
# Cost validation = [0.46033728]
# Cost validation = [0.46030305]
# Cost validation = [0.46039551]
# Cost validation = [0.46033922]
# Cost validation = [0.46030642]
# Cost validation = [0.46019231]
# Cost validation = [0.46016478]
# Cost validation = [0.46011091]
# Cost validation = [0.46017045]
# Cost validation = [0.46021719]
# Cost validation = [0.46018567]
# Cost validation = [0.46017056]
# Cost validation = [0.46015094]
# Cost validation = [0.46017628]
# Cost validation = [0.46017498]
# Cost validation = [0.4601294]
# Cost validation = [0.46014606]
# Cost validation = [0.46008954]
# Cost validation = [0.46012205]
# Cost validation = [0.4601333]
# Cost validation = [0.46006804]
# Cost validation = [0.46011073]
# Cost validation = [0.46006005]
# Cost validation = [0.46001274]
# Cost validation = [0.45995901]
# Cost validation = [0.4599376]
# Cost validation = [0.45998641]
# Cost validation = [0.45999774]
# Cost validation = [0.46002352]
# Cost validation = [0.46010786]
# Cost validation = [0.46010106]
# Cost validation = [0.46010275]
# Cost validation = [0.460138]
# Cost validation = [0.46010886]
# Cost validation = [0.46018419]
# Cost validation = [0.46015169]
# Cost validation = [0.46011691]
# Cost validation = [0.46008878]
# Cost validation = [0.46016946]
# Cost validation = [0.46011198]
# Cost validation = [0.46012942]
# Cost validation = [0.45999865]
# Cost validation = [0.45993288]
# Cost validation = [0.4599209]
# Cost validation = [0.45989453]
# Cost validation = [0.45993289]
# Cost validation = [0.4600818]
# Cost validation = [0.46011613]
# Cost validation = [0.46009485]
# Cost validation = [0.46015982]
# Cost validation = [0.46016369]
# Cost validation = [0.46020307]
# Cost validation = [0.46018861]
# Cost validation = [0.46023362]
# Cost validation = [0.46023048]
# Cost validation = [0.46010518]
# Cost validation = [0.45999944]
# Cost validation = [0.45995983]
# Cost validation = [0.45996396]
# Cost validation = [0.45993201]
# Cost validation = [0.45988642]
# Cost validation = [0.45984811]
# Cost validation = [0.45986858]
# Cost validation = [0.45977264]
# Cost validation = [0.45981124]
# Cost validation = [0.45984952]
# Cost validation = [0.45981452]
# Cost validation = [0.45981353]
# Cost validation = [0.45986876]
# Cost validation = [0.45981721]
# Cost validation = [0.45979688]
# Cost validation = [0.45978262]
# Cost validation = [0.45981145]
# Cost validation = [0.45979774]
# Cost validation = [0.45978055]
# Cost validation = [0.4596556]
# Cost validation = [0.4597782]
# Cost validation = [0.45967042]
# Cost validation = [0.45965203]
# Cost validation = [0.45971088]
# Cost validation = [0.45973821]
# Cost validation = [0.45975591]
# Cost validation = [0.45972464]
# Cost validation = [0.45975363]
# Cost validation = [0.45973217]
# Cost validation = [0.45976375]
# Cost validation = [0.45972144]
# Cost validation = [0.45964141]
# Cost validation = [0.45962691]
# Cost validation = [0.45961415]
# Cost validation = [0.45956566]
# Cost validation = [0.45958231]
# Cost validation = [0.45959321]
# Cost validation = [0.45952637]
# Cost validation = [0.45951822]
# Cost validation = [0.45951803]
# Cost validation = [0.45950628]
# Cost validation = [0.45949518]
# Cost validation = [0.45946642]
# Cost validation = [0.4594211]
# Cost validation = [0.45941721]
# Cost validation = [0.45947566]
# Cost validation = [0.45946322]
# Cost validation = [0.45949637]
# Cost validation = [0.45947453]
# Cost validation = [0.45940337]
# Cost validation = [0.45937735]
# Cost validation = [0.45941859]
# Cost validation = [0.45941858]
# Cost validation = [0.45935139]
# Cost validation = [0.45933658]
# Cost validation = [0.45931382]
# Cost validation = [0.4592432]
# Cost validation = [0.459233]
# Cost validation = [0.45922439]
# Cost validation = [0.45931523]
# Cost validation = [0.45922311]
# Cost validation = [0.45921542]
# Cost validation = [0.45913236]
# Cost validation = [0.45907481]
# Cost validation = [0.45904697]
# Cost validation = [0.45904286]
# Cost validation = [0.45895169]
# Cost validation = [0.45899289]
# Cost validation = [0.45889417]
# Cost validation = [0.45888914]
# Cost validation = [0.45884317]
# Cost validation = [0.45875196]
# Cost validation = [0.45881288]
# Cost validation = [0.45881621]
# Cost validation = [0.45886292]
# Cost validation = [0.45903744]
# Cost validation = [0.45894961]
# Cost validation = [0.45899608]
# Cost validation = [0.45900246]
# Cost validation = [0.45899834]
# Cost validation = [0.45894019]
# Cost validation = [0.45889312]
# Cost validation = [0.45888602]
# Cost validation = [0.45883036]
# Cost validation = [0.45879953]
# Cost validation = [0.45878777]
# Cost validation = [0.45876012]
# Cost validation = [0.45876179]
# Cost validation = [0.45867821]
# Cost validation = [0.458699]
# Cost validation = [0.45870734]
# Cost validation = [0.45866072]
# Cost validation = [0.45865795]
# Cost validation = [0.45863081]
# Cost validation = [0.45861271]
# Cost validation = [0.45860586]
# Cost validation = [0.45869847]
# Cost validation = [0.45861522]
# Cost validation = [0.45853167]
# Cost validation = [0.45856237]
# Cost validation = [0.45859676]
# Cost validation = [0.45864897]
# Cost validation = [0.45866794]
# Cost validation = [0.4586863]
# Cost validation = [0.45875816]
# Cost validation = [0.45878013]
# Cost validation = [0.45881181]
# Cost validation = [0.45884996]
# Cost validation = [0.45871801]
# Cost validation = [0.45870882]
# Cost validation = [0.45872808]
# Cost validation = [0.45880066]
# Cost validation = [0.45871865]
# Cost validation = [0.45870945]
# Cost validation = [0.45862493]
# Cost validation = [0.45855955]
# Cost validation = [0.45861251]
# Cost validation = [0.45850376]
# Cost validation = [0.45855793]
# Cost validation = [0.45861164]
# Cost validation = [0.45861531]
# Cost validation = [0.45865599]
# Cost validation = [0.45860644]
# Cost validation = [0.45873506]
# Cost validation = [0.45868822]
# Cost validation = [0.45852918]
# Cost validation = [0.45849331]
# Cost validation = [0.45849021]
# Cost validation = [0.45849996]
# Cost validation = [0.45849803]
# Cost validation = [0.45857596]
# Cost validation = [0.45862329]
# Cost validation = [0.45864342]
# Cost validation = [0.45861163]
# Cost validation = [0.45870933]
# Cost validation = [0.45868608]
# Cost validation = [0.4587281]
# Cost validation = [0.45873259]
# Cost validation = [0.45866866]
# Cost validation = [0.45856898]
# Cost validation = [0.45849617]
# Cost validation = [0.45851072]
# Cost validation = [0.45844998]
# Cost validation = [0.45847577]
# Cost validation = [0.45843426]
# Cost validation = [0.45841703]
# Cost validation = [0.45830931]
# Cost validation = [0.45826674]
# Cost validation = [0.45827472]
# Cost validation = [0.45827803]
# Cost validation = [0.45829438]
# Cost validation = [0.45837046]
# Cost validation = [0.45851204]
# Cost validation = [0.45842023]
# Cost validation = [0.45833179]
# Cost validation = [0.4583166]
# Cost validation = [0.45845881]
# Cost validation = [0.45850306]
# Cost validation = [0.45836122]
# Cost validation = [0.45831459]
# Cost validation = [0.45834266]
# ...
# Cost validation = [0.45532169]
# Cost validation = [0.45538056]
# Cost validation = [0.45564861]
# Cost validation = [0.4558042]
# Cost validation = [0.45568679]
# Cost validation = [0.45565588]
# Cost validation = [0.45568167]
# Cost validation = [0.45551637]
# Cost validation = [0.45561919]
# Cost validation = [0.45558943]
# Cost validation = [0.45558549]
# Cost validation = [0.45559148]
# Cost validation = [0.45563548]
# Cost validation = [0.45545854]
# Cost validation = [0.45557353]
# Cost validation = [0.45549298]
# Cost validation = [0.45529611]
# Cost validation = [0.45526334]
# Cost validation = [0.45537898]
# Cost validation = [0.45535769]
# Cost validation = [0.45527337]
# Cost validation = [0.45531257]
# Cost validation = [0.45547165]
# Cost validation = [0.45563958]
# Cost validation = [0.4553939]
# Cost validation = [0.45540626]
# Cost validation = [0.45527174]
# Cost validation = [0.45537907]
# Cost validation = [0.45548711]
# Cost validation = [0.45552735]
# Cost validation = [0.45557774]
# Cost validation = [0.4557809]
# Cost validation = [0.45571669]
# Cost validation = [0.45566991]
# Cost validation = [0.45574749]
# Cost validation = [0.45562014]
# Cost validation = [0.45538732]
# Cost validation = [0.45526962]
# Cost validation = [0.45514633]
# Cost validation = [0.45512384]
# Cost validation = [0.45513753]
# Cost validation = [0.45500474]
# Cost validation = [0.45514119]
# Cost validation = [0.45519149]
# Cost validation = [0.45511753]
# Cost validation = [0.45499515]
# Cost validation = [0.45487096]
# Cost validation = [0.45479589]
# Cost validation = [0.45473691]
# Cost validation = [0.45462589]
# Cost validation = [0.45450238]
# Cost validation = [0.45444741]
# Cost validation = [0.45444651]
# Cost validation = [0.45449466]
# Cost validation = [0.45443346]
# Cost validation = [0.4544003]
# Cost validation = [0.45455255]
# Cost validation = [0.45453379]
# Cost validation = [0.45451918]
# Cost validation = [0.45466948]
# Cost validation = [0.45462748]
# Cost validation = [0.45467341]
# Cost validation = [0.45462309]
# Cost validation = [0.45457209]
# Cost validation = [0.45459718]
# Cost validation = [0.4545278]
# Cost validation = [0.4545106]
# Cost validation = [0.45443403]
# Cost validation = [0.45438699]
# Cost validation = [0.45442374]
# Cost validation = [0.45448127]
# Cost validation = [0.45450213]
# Cost validation = [0.45445502]
# Cost validation = [0.45438274]
# Cost validation = [0.45443249]
# Cost validation = [0.45441424]
# Cost validation = [0.45442509]
# Cost validation = [0.45440756]
# Cost validation = [0.45432281]
# Cost validation = [0.45422245]
# Cost validation = [0.454239]
# Cost validation = [0.45420845]
# Cost validation = [0.45424795]
# Cost validation = [0.45425303]
# Cost validation = [0.45416895]
# Cost validation = [0.45409632]
# Cost validation = [0.45409035]
# Cost validation = [0.45413697]
# Cost validation = [0.45417649]
# Cost validation = [0.45429016]
# Cost validation = [0.45425673]
# Cost validation = [0.45421849]
# Cost validation = [0.45429823]
# Cost validation = [0.45423917]
# Cost validation = [0.45436661]
# Cost validation = [0.45441243]
# Cost validation = [0.45442245]
# Cost validation = [0.45440049]
# Cost validation = [0.45436311]
# Cost validation = [0.45432555]
# Cost validation = [0.45438882]
# Cost validation = [0.45439644]
# Cost validation = [0.45444516]
# Cost validation = [0.45436317]
# Cost validation = [0.45432095]
# Cost validation = [0.45433253]
# Cost validation = [0.45430176]
# Cost validation = [0.45431977]
# Cost validation = [0.45426089]
# Cost validation = [0.4542214]
# Cost validation = [0.45423271]
# Cost validation = [0.45424162]
# Cost validation = [0.45424477]
# Cost validation = [0.45414516]
# Cost validation = [0.45409729]
# Cost validation = [0.45408199]
# Cost validation = [0.45411329]
# Cost validation = [0.45409863]
# Cost validation = [0.45417967]
# Cost validation = [0.45416298]
# Cost validation = [0.45415981]
# Cost validation = [0.45413795]
# Cost validation = [0.45413225]
# Cost validation = [0.45414791]
# Cost validation = [0.45409309]
# Cost validation = [0.4540364]
# Cost validation = [0.45419273]
# Cost validation = [0.45419788]
# Cost validation = [0.45424703]
# Cost validation = [0.45429265]
# Cost validation = [0.45429795]
# Cost validation = [0.45416973]
# Cost validation = [0.45417515]
# Cost validation = [0.45408725]
# Cost validation = [0.45403838]
# Cost validation = [0.45398288]
# Cost validation = [0.45411222]
# Cost validation = [0.4540741]
# Cost validation = [0.45410517]
# Cost validation = [0.45403353]
# Cost validation = [0.45408842]
# Cost validation = [0.45418075]
# Cost validation = [0.4542173]
# Cost validation = [0.45411418]
# Cost validation = [0.45424193]
# Cost validation = [0.45427708]
# Cost validation = [0.45439244]
# Cost validation = [0.45429243]
# Cost validation = [0.45413102]
# Cost validation = [0.45408389]
# Cost validation = [0.45401989]
# Cost validation = [0.45406928]
# Cost validation = [0.45403685]
# Cost validation = [0.45397854]
# Cost validation = [0.45378719]
# Cost validation = [0.45377827]
# Cost validation = [0.45378028]
# Cost validation = [0.45371923]
# Cost validation = [0.45371031]
# Cost validation = [0.45374401]
# Cost validation = [0.45361624]
# Cost validation = [0.45371268]
# Cost validation = [0.45373491]
# Cost validation = [0.45376239]
# Cost validation = [0.45373236]
# Cost validation = [0.45373679]
# Cost validation = [0.45371674]
# Cost validation = [0.45387111]
# Cost validation = [0.45395867]
# Cost validation = [0.45388393]
# Cost validation = [0.4539787]
# Cost validation = [0.45382668]
# Cost validation = [0.45389798]
# Cost validation = [0.45386799]
# Cost validation = [0.45392459]
# Cost validation = [0.45381075]
# Cost validation = [0.45370642]
# Cost validation = [0.45362171]
# Cost validation = [0.4536703]
# Cost validation = [0.45363875]
# Cost validation = [0.45371593]
# Cost validation = [0.45367189]
# Cost validation = [0.45363436]
# Cost validation = [0.45360904]
# Cost validation = [0.45363084]
# Cost validation = [0.45351036]
# Cost validation = [0.45350154]
# Cost validation = [0.45369729]
# Cost validation = [0.45358151]
# Cost validation = [0.4535202]
# Cost validation = [0.45357253]
# Cost validation = [0.45359609]
# Cost validation = [0.45365165]
# Cost validation = [0.45374064]
# Cost validation = [0.45368634]
# Cost validation = [0.45375458]
# Cost validation = [0.45388148]
# Cost validation = [0.45397245]
# Cost validation = [0.45409699]
# Cost validation = [0.45398732]
# Cost validation = [0.45388228]
# Cost validation = [0.45387476]
# Cost validation = [0.45390782]
# Cost validation = [0.4538852]
# Cost validation = [0.45393075]
# Cost validation = [0.45391763]
# Cost validation = [0.4538107]
# Cost validation = [0.45379142]
# Cost validation = [0.45374522]
# Cost validation = [0.45360525]
# Cost validation = [0.45352623]
# Cost validation = [0.45349885]
# Cost validation = [0.45341992]
# Cost validation = [0.45329081]
# Cost validation = [0.45330125]
# Cost validation = [0.45339959]
# Cost validation = [0.45349912]
# Cost validation = [0.45342254]
# Cost validation = [0.45339494]
# Cost validation = [0.45337003]
# Cost validation = [0.45336364]
# Cost validation = [0.4533806]
# Cost validation = [0.4533554]
# Cost validation = [0.45347643]
# Cost validation = [0.45349788]
# Cost validation = [0.453338]
# Cost validation = [0.45322198]
# Cost validation = [0.4531097]
# Cost validation = [0.45317046]
# Cost validation = [0.45319471]
# Cost validation = [0.45321315]
# Cost validation = [0.45324844]
# Cost validation = [0.45310759]
# Cost validation = [0.45310387]
# Cost validation = [0.45311703]
# Cost validation = [0.4531167]
# Cost validation = [0.45302338]
# Cost validation = [0.45300544]
# Cost validation = [0.45304823]
# Cost validation = [0.45313111]
# Cost validation = [0.45298643]
# Cost validation = [0.45295427]
# Cost validation = [0.45297308]
# Cost validation = [0.45310081]
# Cost validation = [0.45301387]
# Cost validation = [0.4529665]
# Cost validation = [0.45290796]
# Cost validation = [0.45288724]
# Cost validation = [0.45282119]
# Cost validation = [0.45294331]
# Cost validation = [0.4530482]
# Cost validation = [0.45319635]
# Cost validation = [0.4532642]
# Cost validation = [0.45312499]
# Cost validation = [0.45302427]
# Cost validation = [0.45297431]
# Cost validation = [0.45295172]
# Cost validation = [0.45300567]
# Cost validation = [0.45293775]
# Cost validation = [0.45293994]
# Cost validation = [0.45293103]
# Cost validation = [0.45297462]
# Cost validation = [0.45291293]
# Cost validation = [0.45295865]
# Cost validation = [0.45298174]
# Cost validation = [0.45287896]
# Cost validation = [0.4528748]
# Cost validation = [0.45277639]
# Cost validation = [0.45271863]
# Cost validation = [0.4526227]
# Cost validation = [0.45265654]
# Cost validation = [0.45264343]
# Cost validation = [0.45259491]
# Cost validation = [0.45259281]
# Cost validation = [0.45264111]
# Cost validation = [0.45267943]
# Cost validation = [0.45274068]
# Cost validation = [0.45267022]
# Cost validation = [0.4527161]
# Cost validation = [0.4526241]
# Cost validation = [0.45264049]
# Cost validation = [0.45259463]
# Cost validation = [0.45259518]
# Cost validation = [0.45260113]
# Cost validation = [0.45261757]
# Cost validation = [0.45257688]
# Cost validation = [0.45258619]
# Cost validation = [0.45253859]
# Cost validation = [0.45254616]
# Cost validation = [0.45258303]
# Cost validation = [0.45254854]
# Cost validation = [0.45259866]
# Cost validation = [0.45254701]
# Cost validation = [0.45251417]
# Cost validation = [0.45254381]
# Cost validation = [0.45257488]
# Cost validation = [0.45260156]
# Cost validation = [0.45257518]
# Cost validation = [0.45254288]
# Cost validation = [0.45253636]
# Cost validation = [0.45249708]
# Cost validation = [0.45249323]
# Cost validation = [0.45249094]
# Cost validation = [0.45247374]
# Cost validation = [0.45251893]
# Cost validation = [0.45250513]
# Cost validation = [0.45250517]
# Cost validation = [0.45245064]
# Cost validation = [0.45249628]
# Cost validation = [0.45249617]
# Cost validation = [0.45247314]
# Cost validation = [0.45251171]
# Cost validation = [0.45252347]
# Cost validation = [0.45249535]
# Cost validation = [0.45249688]
# Cost validation = [0.4525163]
# Cost validation = [0.45257376]
# Cost validation = [0.45263652]
# Cost validation = [0.45270256]
# Cost validation = [0.45266101]
# Cost validation = [0.45275561]
# Cost validation = [0.45268984]
# Cost validation = [0.4527175]
# Cost validation = [0.45269214]
# Cost validation = [0.45274993]
# Cost validation = [0.45261716]
# Cost validation = [0.4526306]
# Cost validation = [0.45264381]
# Cost validation = [0.45258051]
# Cost validation = [0.45264548]
# Cost validation = [0.45265431]
# Cost validation = [0.45270218]
# Cost validation = [0.45275667]
# Cost validation = [0.45268596]
# Cost validation = [0.4527685]
# Cost validation = [0.45271032]
# Cost validation = [0.45266804]
# Cost validation = [0.45265903]
# Cost validation = [0.45259225]
# Cost validation = [0.45245861]
# Cost validation = [0.45249191]
# Cost validation = [0.4524063]
# Cost validation = [0.45254488]
# Cost validation = [0.4525274]
# Cost validation = [0.45258866]
# Cost validation = [0.45254018]
# Cost validation = [0.45260314]
# Cost validation = [0.45257127]
# Cost validation = [0.45262379]
# Cost validation = [0.45250271]
# Cost validation = [0.45249225]
# Cost validation = [0.45249362]
# Cost validation = [0.45240442]
# Cost validation = [0.4524212]
# Cost validation = [0.45241625]
# Cost validation = [0.45227612]
# Cost validation = [0.45229288]
# Cost validation = [0.45232768]
# Cost validation = [0.45236941]
# Cost validation = [0.45237933]
# Cost validation = [0.45231623]
# Cost validation = [0.45239493]
# Cost validation = [0.45234622]
# Cost validation = [0.45228537]
# Cost validation = [0.45225688]
# Cost validation = [0.4522376]
# Cost validation = [0.45214848]
# Cost validation = [0.45209918]
# Cost validation = [0.45209283]
# Cost validation = [0.4519773]
# Cost validation = [0.45194831]
# Cost validation = [0.45197452]
# Cost validation = [0.45197176]
# Cost validation = [0.451943]
# Cost validation = [0.45193674]
# Cost validation = [0.45191037]
# Cost validation = [0.45195322]
# Cost validation = [0.45193506]
# Cost validation = [0.45194357]
# Cost validation = [0.45190928]
# Cost validation = [0.45197161]
# Cost validation = [0.45196268]
# Cost validation = [0.45196808]
# Cost validation = [0.45196361]
# Cost validation = [0.45192301]
# Cost validation = [0.45189058]
# Cost validation = [0.45189536]
# Cost validation = [0.45191956]
# Cost validation = [0.45194643]
# Cost validation = [0.45195037]
# Cost validation = [0.45196373]
# Cost validation = [0.45189932]
# Cost validation = [0.45187659]
# Cost validation = [0.45185127]
# Cost validation = [0.45186788]
# Cost validation = [0.45195013]
# Cost validation = [0.45194593]
# Cost validation = [0.45195203]
# Cost validation = [0.4520463]
# Cost validation = [0.45206824]
# Cost validation = [0.45211235]
# Cost validation = [0.45207864]
# Cost validation = [0.45212336]
# Cost validation = [0.45202291]
# Cost validation = [0.45203213]
# Cost validation = [0.45197234]
# Cost validation = [0.45193625]
# Cost validation = [0.45189718]
# Cost validation = [0.45185797]
# Cost validation = [0.45186322]
# Cost validation = [0.45188302]
# Cost validation = [0.4519]
# Cost validation = [0.45188571]
# Cost validation = [0.45185182]
# Cost validation = [0.4518207]
# Cost validation = [0.45184198]
# Cost validation = [0.45174871]
# Cost validation = [0.45180696]
# Cost validation = [0.45178732]
# Cost validation = [0.45184532]
# Cost validation = [0.45192761]
# Cost validation = [0.45196735]
# Cost validation = [0.45195114]
# Cost validation = [0.45186963]
# Cost validation = [0.45185493]
# Cost validation = [0.45179614]
# Cost validation = [0.45173335]
# Cost validation = [0.45171575]
# Cost validation = [0.45167852]
# Cost validation = [0.45165064]
# Cost validation = [0.45174639]
# Cost validation = [0.45167033]
# Cost validation = [0.45171589]
# Cost validation = [0.45171773]
# Cost validation = [0.45178791]
# Cost validation = [0.45170954]
# Cost validation = [0.45173576]
# Cost validation = [0.45170344]
# Cost validation = [0.45172353]
# Cost validation = [0.45174366]
# Cost validation = [0.45171614]
# Cost validation = [0.45164993]
# Cost validation = [0.45168864]
# Cost validation = [0.4516497]
# Cost validation = [0.45161267]
# Cost validation = [0.45165503]
# Cost validation = [0.45167287]
# Cost validation = [0.45184526]
# Cost validation = [0.45192255]
# Cost validation = [0.45182558]
# Cost validation = [0.45184171]
# Cost validation = [0.4518248]
# Cost validation = [0.45182575]
# Cost validation = [0.45180273]
# Cost validation = [0.45179414]
# Cost validation = [0.45183635]
# Cost validation = [0.45179563]
# Cost validation = [0.45172561]
# Cost validation = [0.45165223]
# Cost validation = [0.45175926]
# Cost validation = [0.45167763]
# Cost validation = [0.45168628]
# Cost validation = [0.45165771]
# Cost validation = [0.45164953]
# Cost validation = [0.45163324]
# Cost validation = [0.45152009]
# Cost validation = [0.45148116]
# Cost validation = [0.45153998]
# Cost validation = [0.45149328]
# Cost validation = [0.45147475]
# Cost validation = [0.45145207]
# Cost validation = [0.45144002]
# Cost validation = [0.45146457]
# Cost validation = [0.45147605]
# Cost validation = [0.45140004]
# Cost validation = [0.45134163]
# Cost validation = [0.45135]
# Cost validation = [0.45137623]
# Cost validation = [0.45139396]
# Cost validation = [0.45139528]
# Cost validation = [0.45130767]
# Cost validation = [0.4513545]
# Cost validation = [0.4513455]
# Cost validation = [0.45129821]
# Cost validation = [0.45131035]
# Cost validation = [0.45129071]
# Cost validation = [0.45124553]
# Cost validation = [0.45126569]
# Cost validation = [0.45119765]
# Cost validation = [0.45118929]
# Cost validation = [0.45119513]
# Cost validation = [0.45118605]
# Cost validation = [0.4511829]
# Cost validation = [0.45120022]
# Cost validation = [0.45116035]
# Cost validation = [0.45118547]
# Cost validation = [0.45114958]
# Cost validation = [0.45118778]
# Cost validation = [0.4512224]
# Cost validation = [0.45120023]
# Cost validation = [0.45109864]
# Cost validation = [0.45109108]
# Cost validation = [0.45119328]
# Cost validation = [0.45125277]
# Cost validation = [0.4512345]
# Cost validation = [0.45125993]
# Cost validation = [0.45125511]
# Cost validation = [0.4513001]
# Cost validation = [0.45140701]
# Cost validation = [0.45134892]
# Cost validation = [0.4513518]
# Cost validation = [0.45128854]
# Cost validation = [0.45126272]
# Cost validation = [0.45133205]
# Cost validation = [0.45137121]
# Cost validation = [0.45124701]
# Cost validation = [0.45121339]
# Cost validation = [0.45126534]

# %%
plt.figure(figsize=([8,8]))
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)

fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.95258346 0.04741654]
#  [0.67232074 0.32767926]]

# %%
classes = logreg.predict(xtrain)
print(100*np.sum(classes==ytrain)/len(classes),'% Training Accuracy')
print(f1_score(ytrain, classes))

classes = logreg.predict(xval)
print(100*np.sum(classes==yval)/len(classes),'% Validation Accuracy')
print(f1_score(yval, classes))


classes = logreg.predict(xtest)
print(100*np.sum(classes==ytest)/len(classes),'% Test Accuracy')
print(f1_score(ytest, classes))
# Out:
# 81.3952380952381 % Training Accuracy
# 0.4462083628632176
# 81.03333333333333 % Validation Accuracy
# 0.4360753221010902
# 81.75 % Test Accuracy
# 0.43701799485861187

# %%
import scikitplot as skplt
from sklearn.metrics import roc_auc_score

y_probas = classified

y_probas = y_probas.flatten()
y_temp = np.zeros((y_probas.shape[0], 2))
y_temp[:,0] = 1-y_probas
y_temp[:,1] = y_probas 
#y_probas = y_temp



y_temp2 = np.zeros((y_probas.shape[0], 2))
y_temp2[:,0] = (1-ytest).ravel()
y_temp2[:,1] = ytest.ravel() 


ting=roc_auc_score(ytest, y_probas)
ting2=roc_auc_score(ytest, ytest)

print(ting)
print(ting2)

skplt.metrics.plot_roc(ytest, y_temp)
skplt.metrics.plot_roc(ytest, y_temp2)
# ikke surr mer med det her
# Out:
# 0.6401313585990079
# 1.0

# %%
def bestCurve(y):
    defaults = sum(y == 1)
    total = len(y)
    x = np.linspace(0, 1, total)
    y1 = np.linspace(0, 1, defaults)
    y2 = np.ones(total-defaults)
    y3 = np.concatenate([y1,y2])
    return x, y3

# %%
model = LogisticRegression()
model.fit(xtrain, ytrain)
predicted_classes = model.predict(xtrain)
accuracy = accuracy_score(ytrain.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(ytrain, predicted_classes)

print(accuracy, '% Training Accuracy')

predicted_classes = model.predict(xval)
accuracy = accuracy_score(yval.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(yval, predicted_classes)

print(accuracy, '% Validation Accuracy')

predicted_classes = model.predict(xtest)
accuracy = accuracy_score(ytest.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(ytest, predicted_classes)

print(accuracy, '% Test Accuracy')
# Out:
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 82.04285714285714 % Training Accuracy
# 81.83333333333334 % Validation Accuracy
# 82.78333333333333 % Test Accuracy

# %% [markdown]
# # C)
# Neural Network.

# %%
epochs=1000
batch_size=int(len(ytrain)/3)
n_features=x.shape[1]
etavec = np.logspace(-4, -1, 4)
lmbvec = np.logspace(-4, 1, 6)
lmbvec[0]=0

activation = [lrf.relu, lrf.sigmoid, lrf.sigmoid]
derivative = [lrf.relu_deriv, lrf.sigmoid_deriv, lrf.sigmoid_deriv]

saved_net = np.zeros((len(etavec), len(lmbvec)), dtype=object)
train_accuracy = np.zeros((len(etavec), len(lmbvec)))
for i, etas in enumerate(etavec):
    for j, lmb in enumerate(lmbvec):
        np.random.seed(2019)
        neural_net = nn.ANN(lmb=lmb, bias=0, eta=etas,early_stop_tol = 0,\
                            early_stop_nochange=50, mode = 'classification')            
        neural_net.add_layers(n_features=[91,50,20], n_neurons = [50,20,1] , n_layers=3)
        
        neural_net.train(epochs, batch_size, xtrain,ytrain,activation,derivative \
                         ,xval,yval, verbose=False)

        pred = neural_net.feed_out(xval, activation)
        train_accuracy[i,j] =  lrf.cost_log_ols(pred.ravel(),yval.T)
        print('Validation loss for', '\u03B7 =', etas, '&', '\u03BB =', lmb, '=', train_accuracy [i,j])
# Out:
# Validation loss for η = 0.0001 & λ = 0.0 = 0.8185404680026922
# Validation loss for η = 0.0001 & λ = 0.001 = 0.8185397912986958
# Validation loss for η = 0.0001 & λ = 0.01 = 0.8185337577925462
# Validation loss for η = 0.0001 & λ = 0.1 = 0.8184790693144732
# Validation loss for η = 0.0001 & λ = 1.0 = 0.818505229961652
# Validation loss for η = 0.0001 & λ = 10.0 = 0.8394899562302365
# Validation loss for η = 0.001 & λ = 0.0 = 0.7662762600754597
# Validation loss for η = 0.001 & λ = 0.001 = 0.7662804725804635
# Validation loss for η = 0.001 & λ = 0.01 = 0.7663215874865396
# Validation loss for η = 0.001 & λ = 0.1 = 0.7670376270928517
# Validation loss for η = 0.001 & λ = 1.0 = 0.7874109090041861
# Validation loss for η = 0.001 & λ = 10.0 = 0.8401933818036296
# Validation loss for η = 0.01 & λ = 0.0 = 0.7380624098790884
# Validation loss for η = 0.01 & λ = 0.001 = 0.7382959046566858
# Validation loss for η = 0.01 & λ = 0.01 = 0.7405923827485698
# Validation loss for η = 0.01 & λ = 0.1 = 0.7562386089672897
# Validation loss for η = 0.01 & λ = 1.0 = 0.7886071943091743
# Validation loss for η = 0.01 & λ = 10.0 = 0.7617223755402878
# Validation loss for η = 0.1 & λ = 0.0 = 0.7362809016348456
# Validation loss for η = 0.1 & λ = 0.001 = 0.7365939314861469
# Validation loss for η = 0.1 & λ = 0.01 = 0.739606014834788
# Validation loss for η = 0.1 & λ = 0.1 = 0.75686016277075
# Validation loss for η = 0.1 & λ = 1.0 = 0.7616107094210985
# Validation loss for η = 0.1 & λ = 10.0 = 0.761285597438768

# %%
import seaborn as sns
train_accuracy[np.isnan(train_accuracy)]=2

yticklabels = etavec
xticklabels = lmbvec
fig, ax = plt.subplots(figsize = (10, 12))
sns.heatmap(train_accuracy, annot=True, ax=ax, cmap="viridis",\
            yticklabels=yticklabels, xticklabels=xticklabels)
ax.set_title("Training Accuracy")
ax.set_ylabel("$\eta$")
ax.set_xlabel("$\lambda$")
tmp = np.arange(len(etavec))+0.5
tmp[0] = 0
tmp[-1]+=0.5
ax.set_yticks(tmp)
tmp = np.arange(len(lmbvec)) + 0.5
ax.set_xticks(tmp)
plt.show()

# %%
best_eta_index, best_lmb_index = np.where(train_accuracy == np.min(train_accuracy))
best_eta,best_lmb = etavec[best_eta_index], lmbvec[best_lmb_index] 

print('eta=',best_eta)
print('lmb=',best_lmb)
# Out:
# eta= [0.1]
# lmb= [0.]

# %%
np.random.seed(2019)
epochs=10000
batch_size=int(len(ytrain)/3)
activation = [lrf.relu, lrf.sigmoid, lrf.sigmoid]
derivative = [lrf.relu_deriv, lrf.sigmoid_deriv, lrf.sigmoid_deriv]

neural_net = nn.ANN(lmb=best_lmb, bias=0.5, eta= best_eta,early_stop_tol = 0,\
                            early_stop_nochange=100, mode = 'classification')            
neural_net.add_layers(n_features=[xtrain.shape[1],50,20], n_neurons = [50,20,1] , n_layers=3)
neural_net.train(epochs, batch_size, xtrain,ytrain,activation,derivative ,xtrain,ytrain, verbose=True)
cost_val, cost_train = neural_net.costs()
# Out:
# Epoch 1 loss 0.8247494681700848
# Epoch 2 loss 0.798594903765277
# Epoch 3 loss 0.7854257822045884
# Epoch 4 loss 0.7779693003592246
# Epoch 5 loss 0.7740134686278817
# Epoch 6 loss 0.7717098734653767
# Epoch 7 loss 0.7695237143840951
# Epoch 8 loss 0.7682702094814791
# Epoch 9 loss 0.7679566831645767
# Epoch 10 loss 0.7669126880281368
# Epoch 11 loss 0.7661281122864244
# Epoch 12 loss 0.765458925054331
# Epoch 13 loss 0.7639266758434701
# Epoch 14 loss 0.7640339637909099
# Epoch 15 loss 0.7630468583583631
# Epoch 16 loss 0.7622694040393153
# Epoch 17 loss 0.7621379039695428
# Epoch 18 loss 0.7611284730154313
# Epoch 19 loss 0.7604327934882863
# Epoch 20 loss 0.7602409466568123
# Epoch 21 loss 0.7598213548249797
# Epoch 22 loss 0.7595007840076354
# Epoch 23 loss 0.7580443726273205
# Epoch 24 loss 0.7577263513055397
# Epoch 25 loss 0.7569011784857541
# Epoch 26 loss 0.7557537553445745
# Epoch 27 loss 0.7551475547912909
# Epoch 28 loss 0.754861830005734
# Epoch 29 loss 0.7541923204049524
# Epoch 30 loss 0.7536983986043381
# Epoch 31 loss 0.7535212971236139
# Epoch 32 loss 0.7530758290108217
# Epoch 33 loss 0.7525097199164518
# Epoch 34 loss 0.7513363437662799
# Epoch 35 loss 0.7505786393591616
# Epoch 36 loss 0.7502708842899807
# Epoch 37 loss 0.7502344748093079
# Epoch 38 loss 0.7497522602212341
# Epoch 39 loss 0.7494994331899613
# Epoch 40 loss 0.7491444071621172
# Epoch 41 loss 0.7488298515360398
# Epoch 42 loss 0.7492700976534766
# Epoch 43 loss 0.748542095670254
# Epoch 44 loss 0.7481219536522328
# Epoch 45 loss 0.7471636110689875
# Epoch 46 loss 0.746707437194309
# Epoch 47 loss 0.7465160547708878
# Epoch 48 loss 0.7465238265987509
# Epoch 49 loss 0.7464272135168265
# Epoch 50 loss 0.7463788547640003
# Epoch 51 loss 0.7458208206370209
# Epoch 52 loss 0.7452768373079667
# Epoch 53 loss 0.7449185722652824
# Epoch 54 loss 0.7447906064705585
# Epoch 55 loss 0.7448282422262913
# Epoch 56 loss 0.744828699588829
# Epoch 57 loss 0.7451276084497744
# Epoch 58 loss 0.7451765309384374
# Epoch 59 loss 0.7445922440747271
# Epoch 60 loss 0.7447739794485326
# Epoch 61 loss 0.7446550054339461
# Epoch 62 loss 0.7439447382260833
# Epoch 63 loss 0.7438194794663345
# Epoch 64 loss 0.74359467640855
# Epoch 65 loss 0.7434934598708709
# Epoch 66 loss 0.7432793149946945
# Epoch 67 loss 0.7433350508806733
# Epoch 68 loss 0.7430234444945252
# Epoch 69 loss 0.7424237980639704
# Epoch 70 loss 0.7429243132841897
# Epoch 71 loss 0.7426069378425254
# Epoch 72 loss 0.7422449183213835
# Epoch 73 loss 0.7418493166317753
# Epoch 74 loss 0.7421208441751205
# Epoch 75 loss 0.7418781280419954
# Epoch 76 loss 0.7422684895860532
# Epoch 77 loss 0.7432122244925705
# Epoch 78 loss 0.7427105289066768
# Epoch 79 loss 0.742223460675471
# Epoch 80 loss 0.7417490640273837
# Epoch 81 loss 0.7411937737083804
# Epoch 82 loss 0.7410541590041576
# Epoch 83 loss 0.7413820325698353
# Epoch 84 loss 0.7412970906308056
# Epoch 85 loss 0.7413000449780032
# Epoch 86 loss 0.7411730496003377
# Epoch 87 loss 0.7409437615731178
# Epoch 88 loss 0.7412532024746756
# Epoch 89 loss 0.7409323956395721
# Epoch 90 loss 0.7404921988319784
# Epoch 91 loss 0.7401320632068439
# Epoch 92 loss 0.740240569918155
# Epoch 93 loss 0.7405408741594115
# Epoch 94 loss 0.7402850347120239
# Epoch 95 loss 0.7400055621271692
# Epoch 96 loss 0.7398329264660379
# Epoch 97 loss 0.7396755100486998
# Epoch 98 loss 0.7401293309215913
# Epoch 99 loss 0.7398241635866323
# Epoch 100 loss 0.7398014581359755
# Epoch 101 loss 0.7399687549828753
# Epoch 102 loss 0.739817240776619
# Epoch 103 loss 0.7401875210597784
# Epoch 104 loss 0.7399396605061634
# Epoch 105 loss 0.7395822616279536
# Epoch 106 loss 0.740043045333444
# Epoch 107 loss 0.7391950968454836
# Epoch 108 loss 0.7394131429344123
# Epoch 109 loss 0.7396885467379323
# Epoch 110 loss 0.7398086805078721
# Epoch 111 loss 0.7392513918902454
# Epoch 112 loss 0.7395804671531012
# Epoch 113 loss 0.7396616796356336
# Epoch 114 loss 0.7392708172462018
# Epoch 115 loss 0.7390885355772838
# Epoch 116 loss 0.7388764869183995
# Epoch 117 loss 0.7389948929332287
# Epoch 118 loss 0.73896714513914
# Epoch 119 loss 0.739302101326244
# Epoch 120 loss 0.7393710618100052
# Epoch 121 loss 0.7386844986195296
# Epoch 122 loss 0.7386923511024515
# Epoch 123 loss 0.7392939651517775
# Epoch 124 loss 0.7391903280350295
# Epoch 125 loss 0.739063361539922
# Epoch 126 loss 0.7388660045699696
# Epoch 127 loss 0.7383220208056347
# Epoch 128 loss 0.7386541915660809
# Epoch 129 loss 0.7386803096474046
# Epoch 130 loss 0.7386872099629013
# Epoch 131 loss 0.7382759252202614
# Epoch 132 loss 0.7379073324638377
# Epoch 133 loss 0.7379776518549356
# Epoch 134 loss 0.7380783306940519
# Epoch 135 loss 0.7383051204468165
# Epoch 136 loss 0.7388665365909707
# Epoch 137 loss 0.7385123601374818
# Epoch 138 loss 0.7382326066698456
# Epoch 139 loss 0.7380306455675307
# Epoch 140 loss 0.7378175833133089
# Epoch 141 loss 0.7378522102816938
# Epoch 142 loss 0.7381212952873644
# Epoch 143 loss 0.7377724241446333
# Epoch 144 loss 0.738263880150735
# Epoch 145 loss 0.7385441671902178
# Epoch 146 loss 0.7382199087925155
# Epoch 147 loss 0.7381456648431857
# Epoch 148 loss 0.7379079776605878
# Epoch 149 loss 0.7383650898875463
# Epoch 150 loss 0.7376634714440079
# Epoch 151 loss 0.7377798626593313
# Epoch 152 loss 0.7377320640153997
# Epoch 153 loss 0.7375877301466661
# Epoch 154 loss 0.7377209235836916
# Epoch 155 loss 0.7380500390999488
# Epoch 156 loss 0.73837870867685
# Epoch 157 loss 0.7382991604759732
# Epoch 158 loss 0.7386948489361286
# Epoch 159 loss 0.7384696690222737
# Epoch 160 loss 0.7381754430509387
# Epoch 161 loss 0.7380681255275937
# Epoch 162 loss 0.737506839766069
# Epoch 163 loss 0.7377041037681755
# Epoch 164 loss 0.7374071673209472
# Epoch 165 loss 0.7367452541511721
# Epoch 166 loss 0.7372986817655232
# Epoch 167 loss 0.7373394459935937
# Epoch 168 loss 0.7371979260266188
# Epoch 169 loss 0.7367685616812909
# Epoch 170 loss 0.7370396985783972
# Epoch 171 loss 0.736908487975284
# Epoch 172 loss 0.7363479540641288
# Epoch 173 loss 0.7368652078588438
# Epoch 174 loss 0.7369685549988529
# Epoch 175 loss 0.7365211269825086
# Epoch 176 loss 0.7365515711677758
# Epoch 177 loss 0.7366300243813328
# Epoch 178 loss 0.7365943382181105
# Epoch 179 loss 0.736848265777119
# Epoch 180 loss 0.7368972877976004
# Epoch 181 loss 0.7369074757990717
# Epoch 182 loss 0.7368668162855868
# Epoch 183 loss 0.7368347729133726
# Epoch 184 loss 0.7369660886704342
# Epoch 185 loss 0.7371979419395208
# Epoch 186 loss 0.7373160014084947
# Epoch 187 loss 0.7369883587824515
# Epoch 188 loss 0.7365260047758976
# Epoch 189 loss 0.7371578685890486
# Epoch 190 loss 0.7372760297435658
# Epoch 191 loss 0.7372341499894973
# Epoch 192 loss 0.7375920153626544
# Epoch 193 loss 0.7372409088637517
# Epoch 194 loss 0.7370983768215629
# Epoch 195 loss 0.7367992890475681
# Epoch 196 loss 0.7369598459445829
# Epoch 197 loss 0.7372580737164842
# Epoch 198 loss 0.7374291617088309
# Epoch 199 loss 0.736571101952433
# Epoch 200 loss 0.7366738218028951
# Epoch 201 loss 0.7364779235682882
# Epoch 202 loss 0.7362961197481869
# Epoch 203 loss 0.7365956406828048
# Epoch 204 loss 0.7362620081770148
# Epoch 205 loss 0.7364714442784003
# Epoch 206 loss 0.7362484215974354
# Epoch 207 loss 0.7361170820698492
# Epoch 208 loss 0.7362521438327777
# Epoch 209 loss 0.7367282516406808
# Epoch 210 loss 0.736722109526422
# Epoch 211 loss 0.7365608152516414
# Epoch 212 loss 0.7365225531155221
# Epoch 213 loss 0.736681589728135
# Epoch 214 loss 0.7362310213882651
# Epoch 215 loss 0.7358936458721983
# Epoch 216 loss 0.7356815773701921
# Epoch 217 loss 0.7356788150059904
# Epoch 218 loss 0.7359143222724996
# Epoch 219 loss 0.7361654812337391
# Epoch 220 loss 0.7363489973796136
# Epoch 221 loss 0.7365325727904737
# Epoch 222 loss 0.7358522869313417
# Epoch 223 loss 0.7359959511394716
# Epoch 224 loss 0.7359202134580094
# Epoch 225 loss 0.7362004350404272
# Epoch 226 loss 0.7360650234329543
# Epoch 227 loss 0.7357114701607617
# Epoch 228 loss 0.7364180726126558
# Epoch 229 loss 0.7364744335322077
# Epoch 230 loss 0.7365218476947059
# Epoch 231 loss 0.7362235989589554
# Epoch 232 loss 0.7367616172397891
# Epoch 233 loss 0.736593426154383
# Epoch 234 loss 0.7364871371522812
# Epoch 235 loss 0.7363896336393858
# Epoch 236 loss 0.7362668104771695
# Epoch 237 loss 0.7363374253988944
# Epoch 238 loss 0.7362785071579666
# Epoch 239 loss 0.7358384645961167
# Epoch 240 loss 0.7364723456059573
# Epoch 241 loss 0.7360588483157562
# Epoch 242 loss 0.7364668313968971
# Epoch 243 loss 0.7361284968012998
# Epoch 244 loss 0.7359512326902077
# Epoch 245 loss 0.735584787905564
# Epoch 246 loss 0.735933022037345
# Epoch 247 loss 0.7357870588943806
# Epoch 248 loss 0.7362863182812313
# Epoch 249 loss 0.7365352494289098
# Epoch 250 loss 0.7361936722741016
# Epoch 251 loss 0.7364572897161694
# Epoch 252 loss 0.7360719955526391
# Epoch 253 loss 0.7357370269819601
# Epoch 254 loss 0.735737191236862
# Epoch 255 loss 0.7358223950006844
# Epoch 256 loss 0.7357136405222908
# Epoch 257 loss 0.7353464670215528
# Epoch 258 loss 0.7356685748771048
# Epoch 259 loss 0.7356328105083133
# Epoch 260 loss 0.7355929782014136
# Epoch 261 loss 0.7355473670850886
# Epoch 262 loss 0.7358610635163886
# Epoch 263 loss 0.735846396966428
# Epoch 264 loss 0.7358072345797865
# Epoch 265 loss 0.7355272805276623
# Epoch 266 loss 0.7360372676124363
# Epoch 267 loss 0.73602931081003
# Epoch 268 loss 0.7366852674825286
# Epoch 269 loss 0.7359795456972805
# Epoch 270 loss 0.7361523721114536
# Epoch 271 loss 0.7365285739388119
# Epoch 272 loss 0.7362747341040347
# Epoch 273 loss 0.735632167007413
# Epoch 274 loss 0.7358759168908034
# Epoch 275 loss 0.7357744438976905
# Epoch 276 loss 0.7356627289397345
# Epoch 277 loss 0.7356307707054169
# Epoch 278 loss 0.7357641786876746
# Epoch 279 loss 0.735605825729524
# Epoch 280 loss 0.7358236435754847
# Epoch 281 loss 0.7356800539064772
# Epoch 282 loss 0.7352782577089392
# Epoch 283 loss 0.7350882411203803
# Epoch 284 loss 0.7353322914866349
# Epoch 285 loss 0.7358772440229573
# Epoch 286 loss 0.7357661230993654
# Epoch 287 loss 0.735409566417765
# Epoch 288 loss 0.7355219410951915
# Epoch 289 loss 0.7351738515722109
# Epoch 290 loss 0.7351691697033834
# Epoch 291 loss 0.7351872796496074
# Epoch 292 loss 0.7348569275983724
# Epoch 293 loss 0.7352299328659117
# Epoch 294 loss 0.735123333584992
# Epoch 295 loss 0.7345886938397179
# Epoch 296 loss 0.735071983277118
# Epoch 297 loss 0.735194473782891
# Epoch 298 loss 0.7350703597879772
# Epoch 299 loss 0.7347894152336328
# Epoch 300 loss 0.7351120907637662
# Epoch 301 loss 0.7348105237554194
# Epoch 302 loss 0.7352908977860694
# Epoch 303 loss 0.7351750272840103
# Epoch 304 loss 0.7350353882923796
# Epoch 305 loss 0.7342786624049569
# Epoch 306 loss 0.7351032823442336
# Epoch 307 loss 0.7352520888764048
# Epoch 308 loss 0.7350811666006607
# Epoch 309 loss 0.7352125943106874
# Epoch 310 loss 0.7354243165000673
# Epoch 311 loss 0.7352850773853602
# Epoch 312 loss 0.7354784257228546
# Epoch 313 loss 0.7352643631641612
# Epoch 314 loss 0.7350857350767169
# Epoch 315 loss 0.7350463185997331
# Epoch 316 loss 0.7351263669184258
# Epoch 317 loss 0.7347051781249638
# Epoch 318 loss 0.7348436870393293
# Epoch 319 loss 0.7346867043782072
# Epoch 320 loss 0.7348430387876188
# Epoch 321 loss 0.7345755338324561
# Epoch 322 loss 0.7348641453305774
# Epoch 323 loss 0.734915525036516
# Epoch 324 loss 0.7347837902411659
# Epoch 325 loss 0.7349046477430076
# Epoch 326 loss 0.7358899029102017
# Epoch 327 loss 0.7355885162186402
# Epoch 328 loss 0.7351745800357
# Epoch 329 loss 0.7352151560729343
# Epoch 330 loss 0.7349303865433184
# Epoch 331 loss 0.7347801095330464
# Epoch 332 loss 0.7349601682862272
# Epoch 333 loss 0.734895612788278
# Epoch 334 loss 0.7349587202170945
# Epoch 335 loss 0.7349121067990108
# Epoch 336 loss 0.7352089128534298
# Epoch 337 loss 0.7356607863393255
# Epoch 338 loss 0.7357067966907542
# Epoch 339 loss 0.7353706387782812
# Epoch 340 loss 0.7351888204040377
# Epoch 341 loss 0.7354932573924047

# %%
plt.figure(figsize=([8,8]))
axis = np.arange(len(cost_val))+1
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
activ=neural_net.feed_out(xtest, activation)
classes=np.round(activ)
print(100*np.sum(classes==ytest)/len(activ),'% Test Accuracy')
print(f1_score(ytest, classes)) 
cm = confusion_matrix(ytest , classes)
print(cm)
# Out:
# 81.28333333333333 % Test Accuracy
# 0.4023416711016498
# [[4499  204]
#  [ 919  378]]

# %%
activ=neural_net.feed_out(xtrain, activation)

classes=np.round(activ)

print(100*np.sum(classes==ytrain)/len(activ),'% training Accuracy')
print(f1_score(ytrain, classes)) 

cm = confusion_matrix(ytrain , classes)
print(cm)
# Out:
# 80.78095238095239 % training Accuracy
# 0.40786384976525825
# [[15574   751]
#  [ 3285  1390]]

# %%
from sklearn.neural_network import MLPClassifier



#print("Test set score: %f" % mlp.score(xtest, ytest))
epochs=1000
batch_size=500
n_features=x.shape[1]
etavec = np.logspace(-4, -1, 4)
lmbvec = np.logspace(-7, -3, 5)
lmbvec[0]=0


train_accuracy = np.zeros((len(etavec), len(lmbvec)))
for i, etas in enumerate(etavec):
    for j, lmb in enumerate(lmbvec):
        print(lmb)
        mlp = MLPClassifier(hidden_layer_sizes=(50,20,), max_iter=2000, alpha=lmb,
                    solver='sgd', verbose=0, tol=1e-4,batch_size=500, random_state=1,
                    learning_rate_init=etas)

        mlp.fit(xtrain, ytrain.ravel())
        print("Training set score: %f" % mlp.score(xval, yval))
        pred = mlp.predict(xval)
        train_accuracy[i,j] =  lrf.cost_log_ols(pred.ravel(),yval.T)
        print('Validation f1_score for', '\u03B7 =', etas, '&', '\u03BB =', lmb, '=', train_accuracy [i,j])
# Out:
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 0.0 = 0.691117638862135
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 1e-06 = 0.691117638862135
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 1e-05 = 0.691117638862135
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 0.0001 = 0.691117638862135
# Training set score: 0.804667
# Validation f1_score for η = 0.0001 & λ = 0.001 = 0.691117638862135
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 0.0 = 0.6903877407375498
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 1e-06 = 0.6903877407375498
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 1e-05 = 0.6903877407375498
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 0.0001 = 0.6903877407375498
# Training set score: 0.813333
# Validation f1_score for η = 0.001 & λ = 0.001 = 0.6903877407375498
# Training set score: 0.815000
# Validation f1_score for η = 0.01 & λ = 0.0 = 0.6903151326149523
# Training set score: 0.814333
# Validation f1_score for η = 0.01 & λ = 1e-06 = 0.6908086186242299
# Training set score: 0.815000
# Validation f1_score for η = 0.01 & λ = 1e-05 = 0.6902350562769801
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:568: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Training set score: 0.818333
# Validation f1_score for η = 0.01 & λ = 0.0001 = 0.6877676262305916
# Training set score: 0.814333
# Validation f1_score for η = 0.01 & λ = 0.001 = 0.6895273972166751
# Training set score: 0.801333
# Validation f1_score for η = 0.1 & λ = 0.0 = 0.6978291148210491
# Training set score: 0.797000
# Validation f1_score for η = 0.1 & λ = 1e-06 = 0.7002760486706185
# Training set score: 0.801667
# Validation f1_score for η = 0.1 & λ = 1e-05 = 0.6985032497030905
# Training set score: 0.796667
# Validation f1_score for η = 0.1 & λ = 0.0001 = 0.6974398526633283
# Training set score: 0.814000
# Validation f1_score for η = 0.1 & λ = 0.001 = 0.6912555524737993

# %%
import seaborn as sns
train_accuracy[np.isnan(train_accuracy)]=2

yticklabels = etavec
xticklabels = lmbvec
fig, ax = plt.subplots(figsize = (10, 12))
sns.heatmap(train_accuracy, annot=True, ax=ax, cmap="viridis",\
            yticklabels=yticklabels, xticklabels=xticklabels)
ax.set_title("Training Accuracy")
ax.set_ylabel("$\eta$")
ax.set_xlabel("$\lambda$")
tmp = np.arange(len(etavec))+0.5
tmp[0] = 0
tmp[-1]+=0.5
ax.set_yticks(tmp)
tmp = np.arange(len(lmbvec)) + 0.5
ax.set_xticks(tmp)
plt.show()

# %%
best_eta_index, best_lmb_index = np.where(train_accuracy == np.min(train_accuracy))
best_eta,best_lmb = etavec[best_eta_index], lmbvec[best_lmb_index] 

print('eta=',best_eta)
print('lmb=',best_lmb)
# Out:
# eta= [0.01]
# lmb= [0.0001]

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50,20,), max_iter=2000, alpha=best_lmb,
                    solver='sgd', verbose=0, tol=1e-4,batch_size=500, random_state=1,
                    learning_rate_init=best_eta)

mlp.fit(xtrain, ytrain.ravel())
print("Training set score: %f" % mlp.score(xval, yval))
# Out:
# Training set score: 0.814000

# %%
pred = mlp.predict(xtest)
accuracy = accuracy_score(ytest.flatten(),pred)
accuracy = accuracy * 100
print(accuracy)
print(f1_score(ytest, pred)) 

cm = confusion_matrix(ytest , pred)
print(cm)
# Out:
# 81.6
# 0.467695274831244
# [[4411  292]
#  [ 812  485]]

# %%
pred = mlp.predict(xtrain)
accuracy = accuracy_score(ytrain.flatten(),pred)
accuracy = accuracy * 100
print(accuracy)
print(f1_score(ytrain, pred)) 

cm = confusion_matrix(ytrain , pred)
print(cm)
# Out:
# 83.75714285714285
# 0.54404491378158
# [[15554   771]
#  [ 2640  2035]]

# %% [markdown]
# # Cancer data

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import MinMaxScaler

xtrain,ytrain = load_breast_cancer(return_X_y=True)
scaler = MinMaxScaler()
indx = np.arange(xtrain.shape[1])
scaler.fit(xtrain[:,indx])
xtrain = scaler.transform(xtrain[:,indx])
ytrain=ytrain.reshape([len(ytrain),1])
