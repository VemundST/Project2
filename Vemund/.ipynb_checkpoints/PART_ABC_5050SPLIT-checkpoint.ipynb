# %%
import functions as fx
import log_reg_functions as lrf
import loaddata as ld
import NeuralNetwork as nn
import LogisticRegression as lr

import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, log_loss, f1_score, confusion_matrix, roc_auc_score

# %% [markdown]
# # A )
# Here we will load the dataset, then split it into train, validation and test data.
# As the Credit Card data is biased, we also create a downzised dataset.

# %%
# Reading in credit card dataset.
x,y = ld.load_data(scaler='minmax')

# Extracting all datapoints where the output is 1 (i.e paying credit card dept).
indices = np.where(y == 1)
indices_zero = np.where(y == 0)
# Randomly extracting equal amount of datapoints where the output is 0 (i.e defaulting).
datapoints = np.random.choice(indices_zero[0], size=y[indices[0]].shape[0], replace=False)

#Stacking the two datasets
x_new = np.vstack((x[indices[0],:],x[datapoints,:]))
y_new = np.vstack((y[indices[0]],y[datapoints]))

# Splitting data in train and test data
xtrain,xtest,ytrain,ytest = train_test_split(x_new,y_new, test_size=0.20, random_state= 0, shuffle=True)
# Splitting in train and validation
xtrain,xval,ytrain,yval = train_test_split(xtrain,ytrain, test_size=0.125, random_state= 0, shuffle=True)

# Extracting some useful shapes.
nx_train, ny_train = xtrain.shape
nx_test, ny_test = xtest.shape

# %% [markdown]
# # B)
# Egen logistic regression med gradient descent.

# %%
eta = 0.1 # learning rate
Niter=2500
logreg = lr.LOGREG(eta=0.1, doplot = False, doprint=True)
cost_val, cost_train, axis = logreg.fit(xtrain, ytrain, xval, yval, Niter, solver='gd')
classified=logreg.predict(xtest)
# Out:
# Cost validation = [1.36435631]
# Cost validation = [1.31840801]
# Cost validation = [1.27598465]
# Cost validation = [1.23701716]
# Cost validation = [1.20139157]
# Cost validation = [1.16895524]
# Cost validation = [1.13952477]
# Cost validation = [1.11289462]
# Cost validation = [1.0888458]
# Cost validation = [1.06715387]
# Cost validation = [1.04759576]
# Cost validation = [1.0299553]
# Cost validation = [1.01402736]
# Cost validation = [0.99962063]
# Cost validation = [0.98655927]
# Cost validation = [0.97468362]
# Cost validation = [0.96385021]
# Cost validation = [0.95393118]
# Cost validation = [0.94481343]
# Cost validation = [0.93639746]
# Cost validation = [0.92859622]
# Cost validation = [0.92133381]
# Cost validation = [0.91454431]
# Cost validation = [0.90817056]
# Cost validation = [0.90216316]
# Cost validation = [0.89647944]
# Cost validation = [0.89108262]
# Cost validation = [0.88594098]
# Cost validation = [0.88102723]
# Cost validation = [0.87631784]
# Cost validation = [0.87179254]
# Cost validation = [0.86743388]
# Cost validation = [0.8632268]
# Cost validation = [0.85915829]
# Cost validation = [0.8552171]
# Cost validation = [0.85139349]
# Cost validation = [0.84767902]
# Cost validation = [0.84406633]
# Cost validation = [0.84054899]
# Cost validation = [0.8371214]
# Cost validation = [0.83377862]
# Cost validation = [0.83051631]
# Cost validation = [0.82733062]
# Cost validation = [0.82421811]
# Cost validation = [0.82117572]
# Cost validation = [0.81820071]
# Cost validation = [0.81529058]
# Cost validation = [0.81244308]
# Cost validation = [0.80965612]
# Cost validation = [0.80692782]
# Cost validation = [0.8042564]
# Cost validation = [0.80164023]
# Cost validation = [0.79907778]
# Cost validation = [0.79656761]
# Cost validation = [0.79410836]
# Cost validation = [0.79169872]
# Cost validation = [0.78933748]
# Cost validation = [0.78702345]
# Cost validation = [0.7847555]
# Cost validation = [0.78253254]
# Cost validation = [0.78035351]
# Cost validation = [0.77821739]
# Cost validation = [0.77612321]
# Cost validation = [0.77406999]
# Cost validation = [0.7720568]
# Cost validation = [0.77008273]
# Cost validation = [0.76814689]
# Cost validation = [0.76624842]
# Cost validation = [0.76438647]
# Cost validation = [0.7625602]
# Cost validation = [0.76076883]
# Cost validation = [0.75901154]
# Cost validation = [0.75728757]
# Cost validation = [0.75559616]
# Cost validation = [0.75393658]
# Cost validation = [0.75230809]
# Cost validation = [0.75070999]
# Cost validation = [0.74914159]
# Cost validation = [0.7476022]
# Cost validation = [0.74609117]
# Cost validation = [0.74460784]
# Cost validation = [0.74315158]
# Cost validation = [0.74172177]
# Cost validation = [0.74031781]
# Cost validation = [0.73893909]
# Cost validation = [0.73758505]
# Cost validation = [0.73625511]
# Cost validation = [0.73494872]
# Cost validation = [0.73366534]
# Cost validation = [0.73240445]
# Cost validation = [0.73116553]
# Cost validation = [0.72994806]
# Cost validation = [0.72875157]
# Cost validation = [0.72757558]
# Cost validation = [0.72641961]
# Cost validation = [0.7252832]
# Cost validation = [0.72416592]
# Cost validation = [0.72306732]
# Cost validation = [0.72198699]
# Cost validation = [0.7209245]
# Cost validation = [0.71987945]
# Cost validation = [0.71885145]
# Cost validation = [0.71784012]
# Cost validation = [0.71684507]
# Cost validation = [0.71586595]
# Cost validation = [0.71490239]
# Cost validation = [0.71395405]
# Cost validation = [0.71302059]
# Cost validation = [0.71210168]
# Cost validation = [0.71119699]
# Cost validation = [0.71030621]
# Cost validation = [0.70942904]
# Cost validation = [0.70856517]
# Cost validation = [0.70771431]
# Cost validation = [0.70687619]
# Cost validation = [0.70605051]
# Cost validation = [0.70523702]
# Cost validation = [0.70443544]
# Cost validation = [0.70364552]
# Cost validation = [0.70286702]
# Cost validation = [0.70209968]
# Cost validation = [0.70134326]
# Cost validation = [0.70059755]
# Cost validation = [0.6998623]
# Cost validation = [0.6991373]
# Cost validation = [0.69842233]
# Cost validation = [0.69771719]
# Cost validation = [0.69702166]
# Cost validation = [0.69633555]
# Cost validation = [0.69565866]
# Cost validation = [0.69499081]
# Cost validation = [0.6943318]
# Cost validation = [0.69368146]
# Cost validation = [0.69303961]
# Cost validation = [0.69240608]
# Cost validation = [0.69178069]
# Cost validation = [0.69116329]
# Cost validation = [0.69055372]
# Cost validation = [0.68995182]
# Cost validation = [0.68935744]
# Cost validation = [0.68877042]
# Cost validation = [0.68819063]
# Cost validation = [0.68761793]
# Cost validation = [0.68705216]
# Cost validation = [0.68649321]
# Cost validation = [0.68594093]
# Cost validation = [0.68539521]
# Cost validation = [0.6848559]
# Cost validation = [0.6843229]
# Cost validation = [0.68379608]
# Cost validation = [0.68327532]
# Cost validation = [0.68276052]
# Cost validation = [0.68225155]
# Cost validation = [0.68174831]
# Cost validation = [0.6812507]
# Cost validation = [0.6807586]
# Cost validation = [0.68027193]
# Cost validation = [0.67979057]
# Cost validation = [0.67931444]
# Cost validation = [0.67884343]
# Cost validation = [0.67837745]
# Cost validation = [0.67791643]
# Cost validation = [0.67746025]
# Cost validation = [0.67700885]
# Cost validation = [0.67656213]
# Cost validation = [0.67612001]
# Cost validation = [0.67568242]
# Cost validation = [0.67524927]
# Cost validation = [0.67482048]
# Cost validation = [0.67439598]
# Cost validation = [0.6739757]
# Cost validation = [0.67355956]
# Cost validation = [0.6731475]
# Cost validation = [0.67273944]
# Cost validation = [0.67233532]
# Cost validation = [0.67193506]
# Cost validation = [0.67153862]
# Cost validation = [0.67114591]
# Cost validation = [0.67075688]
# Cost validation = [0.67037148]
# Cost validation = [0.66998963]
# Cost validation = [0.66961129]
# Cost validation = [0.66923639]
# Cost validation = [0.66886488]
# Cost validation = [0.66849671]
# Cost validation = [0.66813182]
# Cost validation = [0.66777016]
# Cost validation = [0.66741168]
# Cost validation = [0.66705632]
# Cost validation = [0.66670405]
# Cost validation = [0.6663548]
# Cost validation = [0.66600854]
# Cost validation = [0.66566522]
# Cost validation = [0.66532479]
# Cost validation = [0.66498721]
# Cost validation = [0.66465244]
# Cost validation = [0.66432043]
# Cost validation = [0.66399114]
# Cost validation = [0.66366453]
# Cost validation = [0.66334056]
# Cost validation = [0.66301919]
# Cost validation = [0.66270038]
# Cost validation = [0.66238411]
# Cost validation = [0.66207032]
# Cost validation = [0.66175898]
# Cost validation = [0.66145006]
# Cost validation = [0.66114352]
# Cost validation = [0.66083933]
# Cost validation = [0.66053745]
# Cost validation = [0.66023786]
# Cost validation = [0.65994051]
# Cost validation = [0.65964538]
# Cost validation = [0.65935244]
# Cost validation = [0.65906166]
# Cost validation = [0.65877301]
# Cost validation = [0.65848645]
# Cost validation = [0.65820196]
# Cost validation = [0.65791952]
# Cost validation = [0.65763908]
# Cost validation = [0.65736064]
# Cost validation = [0.65708415]
# Cost validation = [0.6568096]
# Cost validation = [0.65653696]
# Cost validation = [0.6562662]
# Cost validation = [0.6559973]
# Cost validation = [0.65573023]
# Cost validation = [0.65546497]
# Cost validation = [0.6552015]
# Cost validation = [0.6549398]
# Cost validation = [0.65467984]
# Cost validation = [0.6544216]
# Cost validation = [0.65416505]
# Cost validation = [0.65391018]
# Cost validation = [0.65365697]
# Cost validation = [0.6534054]
# Cost validation = [0.65315544]
# Cost validation = [0.65290707]
# Cost validation = [0.65266029]
# Cost validation = [0.65241505]
# Cost validation = [0.65217136]
# Cost validation = [0.65192919]
# Cost validation = [0.65168852]
# Cost validation = [0.65144933]
# Cost validation = [0.65121161]
# Cost validation = [0.65097533]
# Cost validation = [0.65074049]
# Cost validation = [0.65050707]
# Cost validation = [0.65027504]
# Cost validation = [0.6500444]
# Cost validation = [0.64981512]
# Cost validation = [0.6495872]
# Cost validation = [0.64936061]
# Cost validation = [0.64913534]
# Cost validation = [0.64891138]
# Cost validation = [0.64868872]
# Cost validation = [0.64846733]
# Cost validation = [0.6482472]
# Cost validation = [0.64802832]
# Cost validation = [0.64781068]
# Cost validation = [0.64759427]
# Cost validation = [0.64737906]
# Cost validation = [0.64716505]
# Cost validation = [0.64695223]
# Cost validation = [0.64674057]
# Cost validation = [0.64653008]
# Cost validation = [0.64632073]
# Cost validation = [0.64611252]
# Cost validation = [0.64590543]
# Cost validation = [0.64569946]
# Cost validation = [0.64549458]
# Cost validation = [0.6452908]
# Cost validation = [0.64508809]
# Cost validation = [0.64488645]
# Cost validation = [0.64468587]
# Cost validation = [0.64448633]
# Cost validation = [0.64428783]
# Cost validation = [0.64409036]
# Cost validation = [0.6438939]
# Cost validation = [0.64369845]
# Cost validation = [0.643504]
# Cost validation = [0.64331053]
# Cost validation = [0.64311804]
# Cost validation = [0.64292652]
# Cost validation = [0.64273596]
# Cost validation = [0.64254635]
# Cost validation = [0.64235767]
# Cost validation = [0.64216994]
# Cost validation = [0.64198312]
# Cost validation = [0.64179722]
# Cost validation = [0.64161223]
# Cost validation = [0.64142813]
# Cost validation = [0.64124493]
# Cost validation = [0.64106261]
# Cost validation = [0.64088117]
# Cost validation = [0.64070059]
# Cost validation = [0.64052087]
# Cost validation = [0.640342]
# Cost validation = [0.64016398]
# Cost validation = [0.63998679]
# Cost validation = [0.63981044]
# Cost validation = [0.6396349]
# Cost validation = [0.63946019]
# Cost validation = [0.63928628]
# Cost validation = [0.63911317]
# Cost validation = [0.63894086]
# Cost validation = [0.63876934]
# Cost validation = [0.6385986]
# Cost validation = [0.63842864]
# Cost validation = [0.63825944]
# Cost validation = [0.63809101]
# Cost validation = [0.63792333]
# Cost validation = [0.63775641]
# Cost validation = [0.63759023]
# Cost validation = [0.63742479]
# Cost validation = [0.63726008]
# Cost validation = [0.6370961]
# Cost validation = [0.63693284]
# Cost validation = [0.6367703]
# Cost validation = [0.63660847]
# Cost validation = [0.63644734]
# Cost validation = [0.63628691]
# Cost validation = [0.63612717]
# Cost validation = [0.63596813]
# Cost validation = [0.63580976]
# Cost validation = [0.63565208]
# Cost validation = [0.63549507]
# Cost validation = [0.63533873]
# Cost validation = [0.63518305]
# Cost validation = [0.63502803]
# Cost validation = [0.63487366]
# Cost validation = [0.63471994]
# Cost validation = [0.63456687]
# Cost validation = [0.63441444]
# Cost validation = [0.63426264]
# Cost validation = [0.63411147]
# Cost validation = [0.63396093]
# Cost validation = [0.63381101]
# Cost validation = [0.63366171]
# Cost validation = [0.63351302]
# Cost validation = [0.63336494]
# Cost validation = [0.63321746]
# Cost validation = [0.63307058]
# Cost validation = [0.6329243]
# Cost validation = [0.63277862]
# Cost validation = [0.63263352]
# Cost validation = [0.632489]
# Cost validation = [0.63234507]
# Cost validation = [0.63220171]
# Cost validation = [0.63205892]
# Cost validation = [0.63191671]
# Cost validation = [0.63177505]
# Cost validation = [0.63163396]
# Cost validation = [0.63149343]
# Cost validation = [0.63135345]
# Cost validation = [0.63121403]
# Cost validation = [0.63107515]
# Cost validation = [0.63093681]
# Cost validation = [0.63079902]
# Cost validation = [0.63066176]
# Cost validation = [0.63052503]
# Cost validation = [0.63038884]
# Cost validation = [0.63025317]
# Cost validation = [0.63011802]
# Cost validation = [0.6299834]
# Cost validation = [0.62984929]
# Cost validation = [0.6297157]
# Cost validation = [0.62958261]
# Cost validation = [0.62945004]
# Cost validation = [0.62931797]
# Cost validation = [0.6291864]
# Cost validation = [0.62905533]
# Cost validation = [0.62892475]
# Cost validation = [0.62879467]
# Cost validation = [0.62866508]
# Cost validation = [0.62853598]
# Cost validation = [0.62840736]
# Cost validation = [0.62827922]
# Cost validation = [0.62815156]
# Cost validation = [0.62802437]
# Cost validation = [0.62789766]
# Cost validation = [0.62777142]
# Cost validation = [0.62764565]
# Cost validation = [0.62752034]
# Cost validation = [0.6273955]
# Cost validation = [0.62727111]
# Cost validation = [0.62714719]
# Cost validation = [0.62702371]
# Cost validation = [0.62690069]
# Cost validation = [0.62677812]
# Cost validation = [0.626656]
# Cost validation = [0.62653432]
# Cost validation = [0.62641308]
# Cost validation = [0.62629229]
# Cost validation = [0.62617193]
# Cost validation = [0.62605201]
# Cost validation = [0.62593252]
# Cost validation = [0.62581346]
# Cost validation = [0.62569482]
# Cost validation = [0.62557662]
# Cost validation = [0.62545884]
# Cost validation = [0.62534148]
# Cost validation = [0.62522454]
# Cost validation = [0.62510802]
# Cost validation = [0.62499191]
# Cost validation = [0.62487622]
# Cost validation = [0.62476093]
# Cost validation = [0.62464606]
# Cost validation = [0.62453159]
# Cost validation = [0.62441752]
# Cost validation = [0.62430386]
# Cost validation = [0.6241906]
# Cost validation = [0.62407774]
# Cost validation = [0.62396527]
# Cost validation = [0.6238532]
# Cost validation = [0.62374152]
# Cost validation = [0.62363023]
# Cost validation = [0.62351933]
# Cost validation = [0.62340882]
# Cost validation = [0.62329869]
# Cost validation = [0.62318894]
# Cost validation = [0.62307958]
# Cost validation = [0.62297059]
# Cost validation = [0.62286198]
# Cost validation = [0.62275375]
# Cost validation = [0.62264589]
# Cost validation = [0.6225384]
# Cost validation = [0.62243128]
# Cost validation = [0.62232453]
# Cost validation = [0.62221815]
# Cost validation = [0.62211213]
# Cost validation = [0.62200648]
# Cost validation = [0.62190118]
# Cost validation = [0.62179625]
# Cost validation = [0.62169167]
# Cost validation = [0.62158745]
# Cost validation = [0.62148358]
# Cost validation = [0.62138007]
# Cost validation = [0.62127691]
# Cost validation = [0.6211741]
# Cost validation = [0.62107163]
# Cost validation = [0.62096951]
# Cost validation = [0.62086774]
# Cost validation = [0.62076631]
# Cost validation = [0.62066522]
# Cost validation = [0.62056447]
# Cost validation = [0.62046406]
# Cost validation = [0.62036399]
# Cost validation = [0.62026425]
# Cost validation = [0.62016485]
# Cost validation = [0.62006578]
# Cost validation = [0.61996704]
# Cost validation = [0.61986863]
# Cost validation = [0.61977055]
# Cost validation = [0.61967279]
# Cost validation = [0.61957536]
# Cost validation = [0.61947826]
# Cost validation = [0.61938147]
# Cost validation = [0.61928501]
# Cost validation = [0.61918886]
# Cost validation = [0.61909304]
# Cost validation = [0.61899753]
# Cost validation = [0.61890233]
# Cost validation = [0.61880745]
# Cost validation = [0.61871289]
# Cost validation = [0.61861863]
# Cost validation = [0.61852468]
# Cost validation = [0.61843104]
# Cost validation = [0.61833771]
# Cost validation = [0.61824469]
# Cost validation = [0.61815196]
# Cost validation = [0.61805955]
# Cost validation = [0.61796743]
# Cost validation = [0.61787561]
# Cost validation = [0.6177841]
# Cost validation = [0.61769288]
# Cost validation = [0.61760196]
# Cost validation = [0.61751133]
# Cost validation = [0.617421]
# Cost validation = [0.61733096]
# Cost validation = [0.61724121]
# Cost validation = [0.61715176]
# Cost validation = [0.61706259]
# Cost validation = [0.61697371]
# Cost validation = [0.61688512]
# Cost validation = [0.61679681]
# Cost validation = [0.61670879]
# Cost validation = [0.61662105]
# Cost validation = [0.6165336]
# Cost validation = [0.61644642]
# Cost validation = [0.61635953]
# Cost validation = [0.61627291]
# Cost validation = [0.61618657]
# Cost validation = [0.61610051]
# Cost validation = [0.61601472]
# Cost validation = [0.61592921]
# Cost validation = [0.61584397]
# Cost validation = [0.615759]
# Cost validation = [0.6156743]
# Cost validation = [0.61558987]
# Cost validation = [0.61550572]
# Cost validation = [0.61542182]
# Cost validation = [0.6153382]
# Cost validation = [0.61525484]
# Cost validation = [0.61517174]
# Cost validation = [0.61508891]
# Cost validation = [0.61500634]
# Cost validation = [0.61492403]
# Cost validation = [0.61484198]
# Cost validation = [0.61476019]
# Cost validation = [0.61467866]
# Cost validation = [0.61459738]
# Cost validation = [0.61451636]
# Cost validation = [0.6144356]
# Cost validation = [0.61435509]
# Cost validation = [0.61427483]
# Cost validation = [0.61419483]
# Cost validation = [0.61411507]
# Cost validation = [0.61403557]
# Cost validation = [0.61395631]
# Cost validation = [0.6138773]
# Cost validation = [0.61379854]
# Cost validation = [0.61372002]
# Cost validation = [0.61364175]
# Cost validation = [0.61356373]
# Cost validation = [0.61348594]
# Cost validation = [0.6134084]
# Cost validation = [0.6133311]
# Cost validation = [0.61325404]
# Cost validation = [0.61317722]
# Cost validation = [0.61310064]
# Cost validation = [0.61302429]
# Cost validation = [0.61294818]
# Cost validation = [0.61287231]
# Cost validation = [0.61279667]
# Cost validation = [0.61272127]
# Cost validation = [0.61264609]
# Cost validation = [0.61257115]
# Cost validation = [0.61249644]
# Cost validation = [0.61242197]
# Cost validation = [0.61234772]
# Cost validation = [0.61227369]
# Cost validation = [0.6121999]
# Cost validation = [0.61212633]
# Cost validation = [0.61205299]
# Cost validation = [0.61197987]
# Cost validation = [0.61190698]
# Cost validation = [0.61183431]
# Cost validation = [0.61176187]
# Cost validation = [0.61168964]
# Cost validation = [0.61161763]
# Cost validation = [0.61154585]
# Cost validation = [0.61147428]
# Cost validation = [0.61140293]
# Cost validation = [0.6113318]
# Cost validation = [0.61126089]
# Cost validation = [0.61119019]
# Cost validation = [0.6111197]
# Cost validation = [0.61104943]
# Cost validation = [0.61097937]
# Cost validation = [0.61090953]
# Cost validation = [0.61083989]
# Cost validation = [0.61077047]
# Cost validation = [0.61070126]
# Cost validation = [0.61063225]
# Cost validation = [0.61056346]
# Cost validation = [0.61049487]
# Cost validation = [0.61042649]
# Cost validation = [0.61035831]
# Cost validation = [0.61029034]
# Cost validation = [0.61022258]
# Cost validation = [0.61015501]
# Cost validation = [0.61008766]
# Cost validation = [0.6100205]
# Cost validation = [0.60995354]
# Cost validation = [0.60988679]
# Cost validation = [0.60982023]
# Cost validation = [0.60975388]
# Cost validation = [0.60968772]
# Cost validation = [0.60962176]
# Cost validation = [0.609556]
# Cost validation = [0.60949043]
# Cost validation = [0.60942506]
# Cost validation = [0.60935988]
# Cost validation = [0.6092949]
# Cost validation = [0.60923011]
# Cost validation = [0.60916551]
# Cost validation = [0.60910111]
# Cost validation = [0.60903689]
# Cost validation = [0.60897287]
# Cost validation = [0.60890904]
# Cost validation = [0.60884539]
# Cost validation = [0.60878194]
# Cost validation = [0.60871867]
# Cost validation = [0.60865558]
# Cost validation = [0.60859269]
# Cost validation = [0.60852998]
# Cost validation = [0.60846745]
# Cost validation = [0.60840511]
# Cost validation = [0.60834296]
# Cost validation = [0.60828098]
# Cost validation = [0.60821919]
# Cost validation = [0.60815758]
# Cost validation = [0.60809615]
# Cost validation = [0.6080349]
# Cost validation = [0.60797383]
# Cost validation = [0.60791293]
# Cost validation = [0.60785222]
# Cost validation = [0.60779168]
# Cost validation = [0.60773132]
# Cost validation = [0.60767114]
# Cost validation = [0.60761113]
# Cost validation = [0.6075513]
# Cost validation = [0.60749164]
# Cost validation = [0.60743216]
# Cost validation = [0.60737285]
# Cost validation = [0.60731371]
# Cost validation = [0.60725474]
# Cost validation = [0.60719594]
# Cost validation = [0.60713732]
# Cost validation = [0.60707886]
# Cost validation = [0.60702058]
# Cost validation = [0.60696246]
# Cost validation = [0.60690451]
# Cost validation = [0.60684673]
# Cost validation = [0.60678911]
# Cost validation = [0.60673166]
# Cost validation = [0.60667438]
# Cost validation = [0.60661726]
# Cost validation = [0.6065603]
# Cost validation = [0.60650351]
# Cost validation = [0.60644689]
# Cost validation = [0.60639042]
# Cost validation = [0.60633412]
# Cost validation = [0.60627798]
# Cost validation = [0.606222]
# Cost validation = [0.60616618]
# Cost validation = [0.60611052]
# Cost validation = [0.60605502]
# Cost validation = [0.60599967]
# Cost validation = [0.60594449]
# Cost validation = [0.60588946]
# Cost validation = [0.60583459]
# Cost validation = [0.60577988]
# Cost validation = [0.60572532]
# Cost validation = [0.60567092]
# Cost validation = [0.60561667]
# Cost validation = [0.60556257]
# Cost validation = [0.60550863]
# Cost validation = [0.60545484]
# Cost validation = [0.60540121]
# Cost validation = [0.60534772]
# Cost validation = [0.60529439]
# Cost validation = [0.60524121]
# Cost validation = [0.60518818]
# Cost validation = [0.6051353]
# Cost validation = [0.60508257]
# Cost validation = [0.60502998]
# Cost validation = [0.60497755]
# Cost validation = [0.60492526]
# Cost validation = [0.60487312]
# Cost validation = [0.60482112]
# Cost validation = [0.60476927]
# Cost validation = [0.60471757]
# Cost validation = [0.60466601]
# Cost validation = [0.6046146]
# Cost validation = [0.60456333]
# Cost validation = [0.6045122]
# Cost validation = [0.60446122]
# Cost validation = [0.60441038]
# Cost validation = [0.60435968]
# Cost validation = [0.60430912]
# Cost validation = [0.6042587]
# Cost validation = [0.60420843]
# Cost validation = [0.60415829]
# Cost validation = [0.60410829]
# Cost validation = [0.60405843]
# Cost validation = [0.60400871]
# Cost validation = [0.60395913]
# Cost validation = [0.60390969]
# Cost validation = [0.60386038]
# Cost validation = [0.60381121]
# Cost validation = [0.60376217]
# Cost validation = [0.60371327]
# Cost validation = [0.60366451]
# Cost validation = [0.60361588]
# Cost validation = [0.60356738]
# Cost validation = [0.60351902]
# Cost validation = [0.60347079]
# Cost validation = [0.60342269]
# Cost validation = [0.60337472]
# Cost validation = [0.60332689]
# Cost validation = [0.60327919]
# Cost validation = [0.60323162]
# Cost validation = [0.60318418]
# Cost validation = [0.60313687]
# Cost validation = [0.60308968]
# Cost validation = [0.60304263]
# Cost validation = [0.60299571]
# Cost validation = [0.60294891]
# Cost validation = [0.60290224]
# Cost validation = [0.6028557]
# Cost validation = [0.60280929]
# Cost validation = [0.602763]
# Cost validation = [0.60271684]
# Cost validation = [0.6026708]
# Cost validation = [0.60262489]
# Cost validation = [0.6025791]
# Cost validation = [0.60253344]
# Cost validation = [0.6024879]
# Cost validation = [0.60244248]
# Cost validation = [0.60239718]
# Cost validation = [0.60235201]
# Cost validation = [0.60230696]
# Cost validation = [0.60226203]
# Cost validation = [0.60221723]
# Cost validation = [0.60217254]
# Cost validation = [0.60212797]
# Cost validation = [0.60208353]
# Cost validation = [0.6020392]
# Cost validation = [0.60199499]
# Cost validation = [0.6019509]
# Cost validation = [0.60190693]
# Cost validation = [0.60186308]
# Cost validation = [0.60181934]
# Cost validation = [0.60177572]
# Cost validation = [0.60173222]
# Cost validation = [0.60168883]
# Cost validation = [0.60164556]
# Cost validation = [0.6016024]
# Cost validation = [0.60155936]
# Cost validation = [0.60151643]
# Cost validation = [0.60147362]
# Cost validation = [0.60143092]
# Cost validation = [0.60138834]
# Cost validation = [0.60134586]
# Cost validation = [0.6013035]
# Cost validation = [0.60126126]
# Cost validation = [0.60121912]
# Cost validation = [0.60117709]
# Cost validation = [0.60113518]
# Cost validation = [0.60109338]
# Cost validation = [0.60105169]
# Cost validation = [0.6010101]
# Cost validation = [0.60096863]
# Cost validation = [0.60092726]
# Cost validation = [0.60088601]
# Cost validation = [0.60084486]
# Cost validation = [0.60080382]
# Cost validation = [0.60076289]
# Cost validation = [0.60072206]
# Cost validation = [0.60068135]
# Cost validation = [0.60064073]
# Cost validation = [0.60060023]
# Cost validation = [0.60055983]
# Cost validation = [0.60051954]
# Cost validation = [0.60047935]
# Cost validation = [0.60043926]
# Cost validation = [0.60039928]
# Cost validation = [0.60035941]
# Cost validation = [0.60031963]
# Cost validation = [0.60027996]
# Cost validation = [0.6002404]
# Cost validation = [0.60020093]
# Cost validation = [0.60016157]
# Cost validation = [0.60012231]
# Cost validation = [0.60008316]
# Cost validation = [0.6000441]
# Cost validation = [0.60000514]
# Cost validation = [0.59996629]
# Cost validation = [0.59992753]
# Cost validation = [0.59988887]
# Cost validation = [0.59985032]
# Cost validation = [0.59981186]
# Cost validation = [0.5997735]
# Cost validation = [0.59973524]
# Cost validation = [0.59969708]
# Cost validation = [0.59965902]
# Cost validation = [0.59962105]
# Cost validation = [0.59958318]
# Cost validation = [0.59954541]
# Cost validation = [0.59950773]
# Cost validation = [0.59947015]
# Cost validation = [0.59943267]
# Cost validation = [0.59939528]
# Cost validation = [0.59935798]
# Cost validation = [0.59932078]
# Cost validation = [0.59928368]
# Cost validation = [0.59924667]
# Cost validation = [0.59920975]
# Cost validation = [0.59917293]
# Cost validation = [0.5991362]
# Cost validation = [0.59909956]
# Cost validation = [0.59906302]
# Cost validation = [0.59902657]
# Cost validation = [0.59899021]
# Cost validation = [0.59895394]
# Cost validation = [0.59891776]
# Cost validation = [0.59888168]
# Cost validation = [0.59884568]
# Cost validation = [0.59880978]
# Cost validation = [0.59877396]
# Cost validation = [0.59873824]
# Cost validation = [0.5987026]
# Cost validation = [0.59866706]
# Cost validation = [0.5986316]
# Cost validation = [0.59859623]
# Cost validation = [0.59856095]
# Cost validation = [0.59852576]
# Cost validation = [0.59849066]
# Cost validation = [0.59845564]
# Cost validation = [0.59842071]
# Cost validation = [0.59838587]
# Cost validation = [0.59835111]
# Cost validation = [0.59831644]
# Cost validation = [0.59828186]
# Cost validation = [0.59824736]
# Cost validation = [0.59821295]
# Cost validation = [0.59817862]
# Cost validation = [0.59814438]
# Cost validation = [0.59811022]
# Cost validation = [0.59807615]
# Cost validation = [0.59804216]
# Cost validation = [0.59800825]
# Cost validation = [0.59797443]
# Cost validation = [0.59794069]
# Cost validation = [0.59790704]
# Cost validation = [0.59787346]
# Cost validation = [0.59783997]
# Cost validation = [0.59780656]
# Cost validation = [0.59777324]
# Cost validation = [0.59773999]
# Cost validation = [0.59770683]
# Cost validation = [0.59767374]
# Cost validation = [0.59764074]
# Cost validation = [0.59760782]
# Cost validation = [0.59757498]
# Cost validation = [0.59754222]
# Cost validation = [0.59750953]
# Cost validation = [0.59747693]
# Cost validation = [0.59744441]
# Cost validation = [0.59741196]
# Cost validation = [0.5973796]
# Cost validation = [0.59734731]
# Cost validation = [0.5973151]
# Cost validation = [0.59728297]
# Cost validation = [0.59725092]
# Cost validation = [0.59721894]
# Cost validation = [0.59718704]
# Cost validation = [0.59715522]
# Cost validation = [0.59712347]
# Cost validation = [0.5970918]
# Cost validation = [0.59706021]
# Cost validation = [0.59702869]
# Cost validation = [0.59699725]
# Cost validation = [0.59696588]
# Cost validation = [0.59693459]
# Cost validation = [0.59690338]
# Cost validation = [0.59687223]
# Cost validation = [0.59684117]
# Cost validation = [0.59681017]
# Cost validation = [0.59677925]
# Cost validation = [0.59674841]
# Cost validation = [0.59671763]
# Cost validation = [0.59668694]
# Cost validation = [0.59665631]
# Cost validation = [0.59662576]
# Cost validation = [0.59659527]
# Cost validation = [0.59656487]
# Cost validation = [0.59653453]
# Cost validation = [0.59650426]
# Cost validation = [0.59647407]
# Cost validation = [0.59644395]
# Cost validation = [0.5964139]
# Cost validation = [0.59638392]
# Cost validation = [0.59635401]
# Cost validation = [0.59632417]
# Cost validation = [0.5962944]
# Cost validation = [0.5962647]
# Cost validation = [0.59623507]
# Cost validation = [0.59620551]
# Cost validation = [0.59617602]
# Cost validation = [0.5961466]
# Cost validation = [0.59611724]
# Cost validation = [0.59608796]
# Cost validation = [0.59605874]
# Cost validation = [0.59602959]
# Cost validation = [0.59600051]
# Cost validation = [0.5959715]
# Cost validation = [0.59594256]
# Cost validation = [0.59591368]
# Cost validation = [0.59588487]
# Cost validation = [0.59585612]
# Cost validation = [0.59582745]
# Cost validation = [0.59579884]
# Cost validation = [0.59577029]
# Cost validation = [0.59574181]
# Cost validation = [0.5957134]
# Cost validation = [0.59568505]
# Cost validation = [0.59565677]
# Cost validation = [0.59562856]
# Cost validation = [0.5956004]
# Cost validation = [0.59557232]
# Cost validation = [0.5955443]
# Cost validation = [0.59551634]
# Cost validation = [0.59548844]
# Cost validation = [0.59546061]
# Cost validation = [0.59543285]
# Cost validation = [0.59540515]
# Cost validation = [0.59537751]
# Cost validation = [0.59534993]
# Cost validation = [0.59532242]
# Cost validation = [0.59529497]
# Cost validation = [0.59526758]
# Cost validation = [0.59524025]
# Cost validation = [0.59521299]
# Cost validation = [0.59518579]
# Cost validation = [0.59515865]
# Cost validation = [0.59513157]
# Cost validation = [0.59510455]
# Cost validation = [0.59507759]
# Cost validation = [0.5950507]
# Cost validation = [0.59502386]
# Cost validation = [0.59499709]
# Cost validation = [0.59497038]
# Cost validation = [0.59494372]
# Cost validation = [0.59491713]
# Cost validation = [0.5948906]
# Cost validation = [0.59486412]
# Cost validation = [0.59483771]
# Cost validation = [0.59481135]
# Cost validation = [0.59478506]
# Cost validation = [0.59475882]
# Cost validation = [0.59473264]
# Cost validation = [0.59470652]
# Cost validation = [0.59468046]
# Cost validation = [0.59465446]
# Cost validation = [0.59462851]
# Cost validation = [0.59460262]
# Cost validation = [0.59457679]
# Cost validation = [0.59455102]
# Cost validation = [0.5945253]
# Cost validation = [0.59449965]
# Cost validation = [0.59447404]
# Cost validation = [0.5944485]
# Cost validation = [0.59442301]
# Cost validation = [0.59439758]
# Cost validation = [0.5943722]
# Cost validation = [0.59434688]
# Cost validation = [0.59432162]
# Cost validation = [0.59429641]
# Cost validation = [0.59427126]
# Cost validation = [0.59424616]
# Cost validation = [0.59422112]
# Cost validation = [0.59419613]
# Cost validation = [0.5941712]
# Cost validation = [0.59414632]
# Cost validation = [0.59412149]
# Cost validation = [0.59409672]
# Cost validation = [0.59407201]
# Cost validation = [0.59404735]
# Cost validation = [0.59402274]
# Cost validation = [0.59399819]
# Cost validation = [0.59397369]
# Cost validation = [0.59394924]
# Cost validation = [0.59392484]
# Cost validation = [0.5939005]
# Cost validation = [0.59387622]
# Cost validation = [0.59385198]
# Cost validation = [0.5938278]
# Cost validation = [0.59380367]
# Cost validation = [0.59377959]
# Cost validation = [0.59375556]
# Cost validation = [0.59373159]
# Cost validation = [0.59370766]
# Cost validation = [0.59368379]
# Cost validation = [0.59365997]
# Cost validation = [0.5936362]
# Cost validation = [0.59361248]
# Cost validation = [0.59358882]
# Cost validation = [0.5935652]
# Cost validation = [0.59354163]
# Cost validation = [0.59351812]
# Cost validation = [0.59349465]
# Cost validation = [0.59347124]
# Cost validation = [0.59344787]
# Cost validation = [0.59342456]
# Cost validation = [0.59340129]
# Cost validation = [0.59337808]
# Cost validation = [0.59335491]
# Cost validation = [0.59333179]
# Cost validation = [0.59330872]
# Cost validation = [0.5932857]
# Cost validation = [0.59326273]
# Cost validation = [0.59323981]
# Cost validation = [0.59321694]
# Cost validation = [0.59319411]
# Cost validation = [0.59317134]
# Cost validation = [0.59314861]
# Cost validation = [0.59312593]
# Cost validation = [0.59310329]
# Cost validation = [0.59308071]
# Cost validation = [0.59305817]
# Cost validation = [0.59303568]
# Cost validation = [0.59301323]
# Cost validation = [0.59299084]
# Cost validation = [0.59296849]
# Cost validation = [0.59294618]
# Cost validation = [0.59292393]
# Cost validation = [0.59290172]
# Cost validation = [0.59287955]
# Cost validation = [0.59285743]
# Cost validation = [0.59283536]
# Cost validation = [0.59281334]
# Cost validation = [0.59279136]
# Cost validation = [0.59276942]
# Cost validation = [0.59274753]
# Cost validation = [0.59272569]
# Cost validation = [0.59270389]
# Cost validation = [0.59268214]
# Cost validation = [0.59266043]
# Cost validation = [0.59263877]
# Cost validation = [0.59261715]
# Cost validation = [0.59259558]
# Cost validation = [0.59257405]
# Cost validation = [0.59255256]
# Cost validation = [0.59253112]
# Cost validation = [0.59250972]
# Cost validation = [0.59248837]
# Cost validation = [0.59246706]
# Cost validation = [0.5924458]
# Cost validation = [0.59242457]
# Cost validation = [0.59240339]
# Cost validation = [0.59238226]
# Cost validation = [0.59236117]
# Cost validation = [0.59234012]
# Cost validation = [0.59231911]
# Cost validation = [0.59229815]
# Cost validation = [0.59227723]
# Cost validation = [0.59225635]
# Cost validation = [0.59223551]
# Cost validation = [0.59221472]
# Cost validation = [0.59219397]
# Cost validation = [0.59217326]
# Cost validation = [0.59215259]
# Cost validation = [0.59213196]
# Cost validation = [0.59211138]
# Cost validation = [0.59209083]
# Cost validation = [0.59207033]
# Cost validation = [0.59204987]
# Cost validation = [0.59202945]
# Cost validation = [0.59200907]
# Cost validation = [0.59198874]
# Cost validation = [0.59196844]
# Cost validation = [0.59194818]
# Cost validation = [0.59192797]
# Cost validation = [0.59190779]
# Cost validation = [0.59188766]
# Cost validation = [0.59186757]
# Cost validation = [0.59184751]
# Cost validation = [0.5918275]
# Cost validation = [0.59180752]
# Cost validation = [0.59178759]
# Cost validation = [0.59176769]
# Cost validation = [0.59174784]
# Cost validation = [0.59172802]
# Cost validation = [0.59170824]
# Cost validation = [0.59168851]
# Cost validation = [0.59166881]
# Cost validation = [0.59164915]
# Cost validation = [0.59162953]
# Cost validation = [0.59160994]
# Cost validation = [0.5915904]
# Cost validation = [0.5915709]
# Cost validation = [0.59155143]
# Cost validation = [0.591532]
# Cost validation = [0.59151261]
# Cost validation = [0.59149326]
# Cost validation = [0.59147394]
# Cost validation = [0.59145467]
# Cost validation = [0.59143543]
# Cost validation = [0.59141623]
# Cost validation = [0.59139706]
# Cost validation = [0.59137794]
# Cost validation = [0.59135885]
# Cost validation = [0.59133979]
# Cost validation = [0.59132078]
# Cost validation = [0.5913018]
# Cost validation = [0.59128286]
# Cost validation = [0.59126396]
# Cost validation = [0.59124509]
# Cost validation = [0.59122626]
# Cost validation = [0.59120746]
# Cost validation = [0.5911887]
# Cost validation = [0.59116998]
# Cost validation = [0.5911513]
# Cost validation = [0.59113265]
# Cost validation = [0.59111403]
# Cost validation = [0.59109545]
# Cost validation = [0.59107691]
# Cost validation = [0.5910584]
# Cost validation = [0.59103993]
# Cost validation = [0.5910215]
# Cost validation = [0.5910031]
# Cost validation = [0.59098473]
# Cost validation = [0.5909664]
# Cost validation = [0.59094811]
# Cost validation = [0.59092985]
# Cost validation = [0.59091162]
# Cost validation = [0.59089343]
# Cost validation = [0.59087527]
# Cost validation = [0.59085715]
# Cost validation = [0.59083906]
# Cost validation = [0.59082101]
# Cost validation = [0.59080299]
# Cost validation = [0.59078501]
# Cost validation = [0.59076706]
# Cost validation = [0.59074914]
# Cost validation = [0.59073126]
# Cost validation = [0.59071341]
# Cost validation = [0.59069559]
# Cost validation = [0.59067781]
# Cost validation = [0.59066006]
# Cost validation = [0.59064235]
# Cost validation = [0.59062467]
# Cost validation = [0.59060702]
# Cost validation = [0.5905894]
# Cost validation = [0.59057182]
# Cost validation = [0.59055427]
# Cost validation = [0.59053676]
# Cost validation = [0.59051927]
# Cost validation = [0.59050182]
# Cost validation = [0.5904844]
# Cost validation = [0.59046702]
# Cost validation = [0.59044966]
# Cost validation = [0.59043234]
# Cost validation = [0.59041505]
# Cost validation = [0.59039779]
# Cost validation = [0.59038057]
# Cost validation = [0.59036337]
# Cost validation = [0.59034621]
# Cost validation = [0.59032908]
# Cost validation = [0.59031199]
# Cost validation = [0.59029492]
# Cost validation = [0.59027788]
# Cost validation = [0.59026088]
# Cost validation = [0.59024391]
# Cost validation = [0.59022697]
# Cost validation = [0.59021006]
# Cost validation = [0.59019318]
# Cost validation = [0.59017633]
# Cost validation = [0.59015951]
# Cost validation = [0.59014273]
# Cost validation = [0.59012597]
# Cost validation = [0.59010925]
# Cost validation = [0.59009255]
# Cost validation = [0.59007589]
# Cost validation = [0.59005925]
# Cost validation = [0.59004265]
# Cost validation = [0.59002608]
# Cost validation = [0.59000954]
# Cost validation = [0.58999302]
# Cost validation = [0.58997654]
# Cost validation = [0.58996009]
# Cost validation = [0.58994366]
# Cost validation = [0.58992727]
# Cost validation = [0.58991091]
# Cost validation = [0.58989457]
# Cost validation = [0.58987827]
# Cost validation = [0.58986199]
# Cost validation = [0.58984575]
# Cost validation = [0.58982953]
# Cost validation = [0.58981334]
# Cost validation = [0.58979718]
# Cost validation = [0.58978105]
# Cost validation = [0.58976495]
# Cost validation = [0.58974888]
# Cost validation = [0.58973284]
# Cost validation = [0.58971682]
# Cost validation = [0.58970084]
# Cost validation = [0.58968488]
# Cost validation = [0.58966895]
# Cost validation = [0.58965305]
# Cost validation = [0.58963718]
# Cost validation = [0.58962133]
# Cost validation = [0.58960552]
# Cost validation = [0.58958973]
# Cost validation = [0.58957397]
# Cost validation = [0.58955824]
# Cost validation = [0.58954253]
# Cost validation = [0.58952686]
# Cost validation = [0.58951121]
# Cost validation = [0.58949559]
# Cost validation = [0.58947999]
# Cost validation = [0.58946443]
# Cost validation = [0.58944889]
# Cost validation = [0.58943338]
# Cost validation = [0.5894179]
# Cost validation = [0.58940244]
# Cost validation = [0.58938701]
# Cost validation = [0.58937161]
# Cost validation = [0.58935623]
# Cost validation = [0.58934088]
# Cost validation = [0.58932556]
# Cost validation = [0.58931026]
# Cost validation = [0.589295]
# Cost validation = [0.58927975]
# Cost validation = [0.58926454]
# Cost validation = [0.58924935]
# Cost validation = [0.58923419]
# Cost validation = [0.58921905]
# Cost validation = [0.58920394]
# Cost validation = [0.58918886]
# Cost validation = [0.5891738]
# Cost validation = [0.58915877]
# Cost validation = [0.58914376]
# Cost validation = [0.58912878]
# Cost validation = [0.58911383]
# Cost validation = [0.5890989]
# Cost validation = [0.589084]
# Cost validation = [0.58906912]
# Cost validation = [0.58905427]
# Cost validation = [0.58903945]
# Cost validation = [0.58902464]
# Cost validation = [0.58900987]
# Cost validation = [0.58899512]
# Cost validation = [0.5889804]
# Cost validation = [0.5889657]
# Cost validation = [0.58895102]
# Cost validation = [0.58893637]
# Cost validation = [0.58892175]
# Cost validation = [0.58890715]
# Cost validation = [0.58889258]
# Cost validation = [0.58887803]
# Cost validation = [0.5888635]
# Cost validation = [0.588849]
# Cost validation = [0.58883453]
# Cost validation = [0.58882007]
# Cost validation = [0.58880565]
# Cost validation = [0.58879125]
# Cost validation = [0.58877687]
# Cost validation = [0.58876251]
# Cost validation = [0.58874818]
# Cost validation = [0.58873388]
# Cost validation = [0.5887196]
# Cost validation = [0.58870534]
# Cost validation = [0.58869111]
# Cost validation = [0.5886769]
# Cost validation = [0.58866271]
# Cost validation = [0.58864855]
# Cost validation = [0.58863441]
# Cost validation = [0.5886203]
# Cost validation = [0.58860621]
# Cost validation = [0.58859214]
# Cost validation = [0.5885781]
# Cost validation = [0.58856408]
# Cost validation = [0.58855008]
# Cost validation = [0.5885361]
# Cost validation = [0.58852215]
# Cost validation = [0.58850823]
# Cost validation = [0.58849432]
# Cost validation = [0.58848044]
# Cost validation = [0.58846658]
# Cost validation = [0.58845275]
# Cost validation = [0.58843893]
# Cost validation = [0.58842514]
# Cost validation = [0.58841138]
# Cost validation = [0.58839763]
# Cost validation = [0.58838391]
# Cost validation = [0.58837021]
# Cost validation = [0.58835653]
# Cost validation = [0.58834288]
# Cost validation = [0.58832925]
# Cost validation = [0.58831564]
# Cost validation = [0.58830205]
# Cost validation = [0.58828849]
# Cost validation = [0.58827494]
# Cost validation = [0.58826142]
# Cost validation = [0.58824792]
# Cost validation = [0.58823445]
# Cost validation = [0.58822099]
# Cost validation = [0.58820756]
# Cost validation = [0.58819415]
# Cost validation = [0.58818076]
# Cost validation = [0.58816739]
# Cost validation = [0.58815404]
# Cost validation = [0.58814072]
# Cost validation = [0.58812742]
# Cost validation = [0.58811414]
# Cost validation = [0.58810088]
# Cost validation = [0.58808764]
# Cost validation = [0.58807442]
# Cost validation = [0.58806123]
# Cost validation = [0.58804805]
# Cost validation = [0.5880349]
# Cost validation = [0.58802176]
# Cost validation = [0.58800865]
# Cost validation = [0.58799556]
# Cost validation = [0.58798249]
# Cost validation = [0.58796945]
# Cost validation = [0.58795642]
# Cost validation = [0.58794341]
# Cost validation = [0.58793043]
# Cost validation = [0.58791746]
# Cost validation = [0.58790452]
# Cost validation = [0.58789159]
# Cost validation = [0.58787869]
# Cost validation = [0.58786581]
# Cost validation = [0.58785294]
# Cost validation = [0.5878401]
# Cost validation = [0.58782728]
# Cost validation = [0.58781448]
# Cost validation = [0.5878017]
# Cost validation = [0.58778894]
# Cost validation = [0.5877762]
# Cost validation = [0.58776348]
# Cost validation = [0.58775077]
# Cost validation = [0.58773809]
# Cost validation = [0.58772543]
# Cost validation = [0.58771279]
# Cost validation = [0.58770017]
# Cost validation = [0.58768757]
# Cost validation = [0.58767499]
# Cost validation = [0.58766243]
# Cost validation = [0.58764988]
# Cost validation = [0.58763736]
# Cost validation = [0.58762486]
# Cost validation = [0.58761238]
# Cost validation = [0.58759991]
# Cost validation = [0.58758747]
# Cost validation = [0.58757504]
# Cost validation = [0.58756264]
# Cost validation = [0.58755025]
# Cost validation = [0.58753788]
# Cost validation = [0.58752553]
# Cost validation = [0.5875132]
# Cost validation = [0.58750089]
# Cost validation = [0.5874886]
# Cost validation = [0.58747633]
# Cost validation = [0.58746408]
# Cost validation = [0.58745184]
# Cost validation = [0.58743963]
# Cost validation = [0.58742743]
# Cost validation = [0.58741525]
# Cost validation = [0.58740309]
# Cost validation = [0.58739095]
# Cost validation = [0.58737883]
# Cost validation = [0.58736673]
# Cost validation = [0.58735464]
# Cost validation = [0.58734258]
# Cost validation = [0.58733053]
# Cost validation = [0.5873185]
# Cost validation = [0.58730649]
# Cost validation = [0.5872945]
# Cost validation = [0.58728252]
# Cost validation = [0.58727056]
# Cost validation = [0.58725863]
# Cost validation = [0.58724671]
# Cost validation = [0.5872348]
# Cost validation = [0.58722292]
# Cost validation = [0.58721105]
# Cost validation = [0.58719921]
# Cost validation = [0.58718738]
# Cost validation = [0.58717556]
# Cost validation = [0.58716377]
# Cost validation = [0.58715199]
# Cost validation = [0.58714023]
# Cost validation = [0.58712849]
# Cost validation = [0.58711677]
# Cost validation = [0.58710506]
# Cost validation = [0.58709337]
# Cost validation = [0.5870817]
# Cost validation = [0.58707005]
# Cost validation = [0.58705841]
# Cost validation = [0.58704679]
# Cost validation = [0.58703519]
# Cost validation = [0.58702361]
# Cost validation = [0.58701204]
# Cost validation = [0.58700049]
# Cost validation = [0.58698896]
# Cost validation = [0.58697744]
# Cost validation = [0.58696595]
# Cost validation = [0.58695446]
# Cost validation = [0.586943]
# Cost validation = [0.58693155]
# Cost validation = [0.58692012]
# Cost validation = [0.58690871]
# Cost validation = [0.58689731]
# Cost validation = [0.58688593]
# Cost validation = [0.58687457]
# Cost validation = [0.58686322]
# Cost validation = [0.58685189]
# Cost validation = [0.58684058]
# Cost validation = [0.58682929]
# Cost validation = [0.58681801]
# Cost validation = [0.58680674]
# Cost validation = [0.5867955]
# Cost validation = [0.58678427]
# Cost validation = [0.58677305]
# Cost validation = [0.58676186]
# Cost validation = [0.58675067]
# Cost validation = [0.58673951]
# Cost validation = [0.58672836]
# Cost validation = [0.58671723]
# Cost validation = [0.58670611]
# Cost validation = [0.58669501]
# Cost validation = [0.58668393]
# Cost validation = [0.58667286]
# Cost validation = [0.58666181]
# Cost validation = [0.58665078]
# Cost validation = [0.58663976]
# Cost validation = [0.58662875]
# Cost validation = [0.58661777]
# Cost validation = [0.58660679]
# Cost validation = [0.58659584]
# Cost validation = [0.5865849]
# Cost validation = [0.58657397]
# Cost validation = [0.58656306]
# Cost validation = [0.58655217]
# Cost validation = [0.58654129]
# Cost validation = [0.58653043]
# Cost validation = [0.58651958]
# Cost validation = [0.58650875]
# Cost validation = [0.58649794]
# Cost validation = [0.58648714]
# Cost validation = [0.58647635]
# Cost validation = [0.58646558]
# Cost validation = [0.58645483]
# Cost validation = [0.58644409]
# Cost validation = [0.58643337]
# Cost validation = [0.58642266]
# Cost validation = [0.58641197]
# Cost validation = [0.58640129]
# Cost validation = [0.58639063]
# Cost validation = [0.58637998]
# Cost validation = [0.58636935]
# Cost validation = [0.58635873]
# Cost validation = [0.58634813]
# Cost validation = [0.58633754]
# Cost validation = [0.58632697]
# Cost validation = [0.58631641]
# Cost validation = [0.58630587]
# Cost validation = [0.58629534]
# Cost validation = [0.58628483]
# Cost validation = [0.58627433]
# Cost validation = [0.58626384]
# Cost validation = [0.58625338]
# Cost validation = [0.58624292]
# Cost validation = [0.58623248]
# Cost validation = [0.58622206]
# Cost validation = [0.58621165]
# Cost validation = [0.58620125]
# Cost validation = [0.58619087]
# Cost validation = [0.5861805]
# Cost validation = [0.58617015]
# Cost validation = [0.58615981]
# Cost validation = [0.58614949]
# Cost validation = [0.58613918]
# Cost validation = [0.58612888]
# Cost validation = [0.5861186]
# Cost validation = [0.58610833]
# Cost validation = [0.58609808]
# Cost validation = [0.58608784]
# Cost validation = [0.58607762]
# Cost validation = [0.58606741]
# Cost validation = [0.58605721]
# Cost validation = [0.58604703]
# Cost validation = [0.58603686]
# Cost validation = [0.58602671]
# Cost validation = [0.58601656]
# Cost validation = [0.58600644]
# Cost validation = [0.58599633]
# Cost validation = [0.58598623]
# Cost validation = [0.58597614]
# Cost validation = [0.58596607]
# Cost validation = [0.58595601]
# Cost validation = [0.58594597]
# Cost validation = [0.58593594]
# Cost validation = [0.58592592]
# Cost validation = [0.58591592]
# Cost validation = [0.58590593]
# Cost validation = [0.58589595]
# Cost validation = [0.58588599]
# Cost validation = [0.58587604]
# Cost validation = [0.58586611]
# Cost validation = [0.58585619]
# Cost validation = [0.58584628]
# Cost validation = [0.58583638]
# Cost validation = [0.5858265]
# Cost validation = [0.58581663]
# Cost validation = [0.58580678]
# Cost validation = [0.58579694]
# Cost validation = [0.58578711]
# Cost validation = [0.58577729]
# Cost validation = [0.58576749]
# Cost validation = [0.5857577]
# Cost validation = [0.58574793]
# Cost validation = [0.58573816]
# Cost validation = [0.58572841]
# Cost validation = [0.58571868]
# Cost validation = [0.58570895]
# Cost validation = [0.58569924]
# Cost validation = [0.58568954]
# Cost validation = [0.58567986]
# Cost validation = [0.58567019]
# Cost validation = [0.58566053]
# Cost validation = [0.58565088]
# Cost validation = [0.58564125]
# Cost validation = [0.58563163]
# Cost validation = [0.58562202]
# Cost validation = [0.58561242]
# Cost validation = [0.58560284]
# Cost validation = [0.58559327]
# Cost validation = [0.58558371]
# Cost validation = [0.58557417]
# Cost validation = [0.58556463]
# Cost validation = [0.58555511]
# Cost validation = [0.58554561]
# Cost validation = [0.58553611]
# Cost validation = [0.58552663]
# Cost validation = [0.58551716]
# Cost validation = [0.5855077]
# Cost validation = [0.58549826]
# Cost validation = [0.58548882]
# Cost validation = [0.5854794]
# Cost validation = [0.58547]
# Cost validation = [0.5854606]
# Cost validation = [0.58545122]
# Cost validation = [0.58544184]
# Cost validation = [0.58543248]
# Cost validation = [0.58542314]
# Cost validation = [0.5854138]
# Cost validation = [0.58540448]
# Cost validation = [0.58539517]
# Cost validation = [0.58538587]
# Cost validation = [0.58537658]
# Cost validation = [0.58536731]
# Cost validation = [0.58535805]
# Cost validation = [0.5853488]
# Cost validation = [0.58533956]
# Cost validation = [0.58533033]
# Cost validation = [0.58532111]
# Cost validation = [0.58531191]
# Cost validation = [0.58530272]
# Cost validation = [0.58529354]
# Cost validation = [0.58528437]
# Cost validation = [0.58527522]
# Cost validation = [0.58526607]
# Cost validation = [0.58525694]
# Cost validation = [0.58524782]
# Cost validation = [0.58523871]
# Cost validation = [0.58522961]
# Cost validation = [0.58522052]
# Cost validation = [0.58521145]
# Cost validation = [0.58520239]
# ...
# Cost validation = [0.58212574]
# Cost validation = [0.58212001]
# Cost validation = [0.58211428]
# Cost validation = [0.58210856]
# Cost validation = [0.58210285]
# Cost validation = [0.58209713]
# Cost validation = [0.58209143]
# Cost validation = [0.58208573]
# Cost validation = [0.58208003]
# Cost validation = [0.58207434]
# Cost validation = [0.58206866]
# Cost validation = [0.58206298]
# Cost validation = [0.5820573]
# Cost validation = [0.58205163]
# Cost validation = [0.58204597]
# Cost validation = [0.5820403]
# Cost validation = [0.58203465]
# Cost validation = [0.582029]
# Cost validation = [0.58202335]
# Cost validation = [0.58201771]
# Cost validation = [0.58201208]
# Cost validation = [0.58200645]
# Cost validation = [0.58200082]
# Cost validation = [0.5819952]
# Cost validation = [0.58198959]
# Cost validation = [0.58198397]
# Cost validation = [0.58197837]
# Cost validation = [0.58197277]
# Cost validation = [0.58196717]
# Cost validation = [0.58196158]
# Cost validation = [0.58195599]
# Cost validation = [0.58195041]
# Cost validation = [0.58194484]
# Cost validation = [0.58193926]
# Cost validation = [0.5819337]
# Cost validation = [0.58192813]
# Cost validation = [0.58192258]
# Cost validation = [0.58191703]
# Cost validation = [0.58191148]
# Cost validation = [0.58190593]
# Cost validation = [0.5819004]
# Cost validation = [0.58189486]
# Cost validation = [0.58188934]
# Cost validation = [0.58188381]
# Cost validation = [0.58187829]
# Cost validation = [0.58187278]
# Cost validation = [0.58186727]
# Cost validation = [0.58186176]
# Cost validation = [0.58185626]
# Cost validation = [0.58185077]
# Cost validation = [0.58184528]
# Cost validation = [0.58183979]
# Cost validation = [0.58183431]
# Cost validation = [0.58182884]
# Cost validation = [0.58182336]
# Cost validation = [0.5818179]
# Cost validation = [0.58181244]
# Cost validation = [0.58180698]
# Cost validation = [0.58180152]
# Cost validation = [0.58179608]
# Cost validation = [0.58179063]
# Cost validation = [0.58178519]
# Cost validation = [0.58177976]
# Cost validation = [0.58177433]
# Cost validation = [0.5817689]
# Cost validation = [0.58176348]
# Cost validation = [0.58175807]
# Cost validation = [0.58175266]
# Cost validation = [0.58174725]
# Cost validation = [0.58174185]
# Cost validation = [0.58173645]
# Cost validation = [0.58173106]
# Cost validation = [0.58172567]
# Cost validation = [0.58172029]
# Cost validation = [0.58171491]
# Cost validation = [0.58170953]
# Cost validation = [0.58170416]
# Cost validation = [0.5816988]
# Cost validation = [0.58169343]
# Cost validation = [0.58168808]
# Cost validation = [0.58168273]
# Cost validation = [0.58167738]
# Cost validation = [0.58167203]
# Cost validation = [0.5816667]
# Cost validation = [0.58166136]
# Cost validation = [0.58165603]
# Cost validation = [0.58165071]
# Cost validation = [0.58164539]
# Cost validation = [0.58164007]
# Cost validation = [0.58163476]
# Cost validation = [0.58162945]
# Cost validation = [0.58162415]
# Cost validation = [0.58161885]
# Cost validation = [0.58161355]
# Cost validation = [0.58160826]
# Cost validation = [0.58160298]
# Cost validation = [0.5815977]
# Cost validation = [0.58159242]
# Cost validation = [0.58158715]
# Cost validation = [0.58158188]
# Cost validation = [0.58157662]
# Cost validation = [0.58157136]
# Cost validation = [0.5815661]
# Cost validation = [0.58156085]
# Cost validation = [0.58155561]
# Cost validation = [0.58155037]
# Cost validation = [0.58154513]
# Cost validation = [0.58153989]
# Cost validation = [0.58153467]
# Cost validation = [0.58152944]
# Cost validation = [0.58152422]
# Cost validation = [0.58151901]
# Cost validation = [0.58151379]
# Cost validation = [0.58150859]
# Cost validation = [0.58150338]
# Cost validation = [0.58149818]
# Cost validation = [0.58149299]
# Cost validation = [0.5814878]
# Cost validation = [0.58148261]
# Cost validation = [0.58147743]
# Cost validation = [0.58147225]
# Cost validation = [0.58146708]
# Cost validation = [0.58146191]
# Cost validation = [0.58145675]
# Cost validation = [0.58145159]
# Cost validation = [0.58144643]
# Cost validation = [0.58144128]
# Cost validation = [0.58143613]
# Cost validation = [0.58143099]
# Cost validation = [0.58142585]
# Cost validation = [0.58142071]
# Cost validation = [0.58141558]
# Cost validation = [0.58141045]
# Cost validation = [0.58140533]
# Cost validation = [0.58140021]
# Cost validation = [0.58139509]
# Cost validation = [0.58138998]
# Cost validation = [0.58138488]
# Cost validation = [0.58137977]
# Cost validation = [0.58137468]
# Cost validation = [0.58136958]
# Cost validation = [0.58136449]
# Cost validation = [0.58135941]
# Cost validation = [0.58135432]
# Cost validation = [0.58134925]
# Cost validation = [0.58134417]
# Cost validation = [0.5813391]
# Cost validation = [0.58133404]
# Cost validation = [0.58132898]
# Cost validation = [0.58132392]
# Cost validation = [0.58131886]
# Cost validation = [0.58131382]
# Cost validation = [0.58130877]
# Cost validation = [0.58130373]
# Cost validation = [0.58129869]
# Cost validation = [0.58129366]
# Cost validation = [0.58128863]
# Cost validation = [0.5812836]
# Cost validation = [0.58127858]
# Cost validation = [0.58127356]
# Cost validation = [0.58126855]
# Cost validation = [0.58126354]
# Cost validation = [0.58125854]
# Cost validation = [0.58125354]
# Cost validation = [0.58124854]
# Cost validation = [0.58124354]
# Cost validation = [0.58123855]
# Cost validation = [0.58123357]
# Cost validation = [0.58122859]
# Cost validation = [0.58122361]
# Cost validation = [0.58121864]
# Cost validation = [0.58121367]
# Cost validation = [0.5812087]
# Cost validation = [0.58120374]
# Cost validation = [0.58119878]
# Cost validation = [0.58119383]
# Cost validation = [0.58118888]
# Cost validation = [0.58118393]
# Cost validation = [0.58117899]
# Cost validation = [0.58117405]
# Cost validation = [0.58116911]
# Cost validation = [0.58116418]
# Cost validation = [0.58115926]
# Cost validation = [0.58115433]
# Cost validation = [0.58114941]
# Cost validation = [0.5811445]
# Cost validation = [0.58113959]
# Cost validation = [0.58113468]
# Cost validation = [0.58112977]
# Cost validation = [0.58112487]
# Cost validation = [0.58111998]
# Cost validation = [0.58111508]
# Cost validation = [0.5811102]
# Cost validation = [0.58110531]
# Cost validation = [0.58110043]
# Cost validation = [0.58109555]
# Cost validation = [0.58109068]
# Cost validation = [0.58108581]
# Cost validation = [0.58108094]
# Cost validation = [0.58107608]
# Cost validation = [0.58107122]
# Cost validation = [0.58106637]
# Cost validation = [0.58106152]
# Cost validation = [0.58105667]
# Cost validation = [0.58105183]
# Cost validation = [0.58104699]
# Cost validation = [0.58104215]
# Cost validation = [0.58103732]
# Cost validation = [0.58103249]
# Cost validation = [0.58102766]
# Cost validation = [0.58102284]
# Cost validation = [0.58101802]
# Cost validation = [0.58101321]
# Cost validation = [0.5810084]
# Cost validation = [0.58100359]
# Cost validation = [0.58099879]
# Cost validation = [0.58099399]
# Cost validation = [0.5809892]
# Cost validation = [0.58098441]
# Cost validation = [0.58097962]
# Cost validation = [0.58097483]
# Cost validation = [0.58097005]
# Cost validation = [0.58096527]
# Cost validation = [0.5809605]
# Cost validation = [0.58095573]
# Cost validation = [0.58095096]
# Cost validation = [0.5809462]
# Cost validation = [0.58094144]
# Cost validation = [0.58093669]
# Cost validation = [0.58093194]
# Cost validation = [0.58092719]
# Cost validation = [0.58092244]
# Cost validation = [0.5809177]
# Cost validation = [0.58091296]
# Cost validation = [0.58090823]
# Cost validation = [0.5809035]
# Cost validation = [0.58089877]
# Cost validation = [0.58089405]
# Cost validation = [0.58088933]
# Cost validation = [0.58088462]
# Cost validation = [0.5808799]
# Cost validation = [0.58087519]
# Cost validation = [0.58087049]
# Cost validation = [0.58086579]
# Cost validation = [0.58086109]
# Cost validation = [0.58085639]
# Cost validation = [0.5808517]
# Cost validation = [0.58084701]
# Cost validation = [0.58084233]
# Cost validation = [0.58083765]
# Cost validation = [0.58083297]
# Cost validation = [0.5808283]
# Cost validation = [0.58082363]
# Cost validation = [0.58081896]
# Cost validation = [0.5808143]
# Cost validation = [0.58080964]
# Cost validation = [0.58080498]
# Cost validation = [0.58080033]
# Cost validation = [0.58079568]
# Cost validation = [0.58079103]
# Cost validation = [0.58078639]
# Cost validation = [0.58078175]
# Cost validation = [0.58077712]
# Cost validation = [0.58077249]
# Cost validation = [0.58076786]
# Cost validation = [0.58076323]
# Cost validation = [0.58075861]
# Cost validation = [0.58075399]
# Cost validation = [0.58074938]
# Cost validation = [0.58074476]
# Cost validation = [0.58074016]
# Cost validation = [0.58073555]
# Cost validation = [0.58073095]
# Cost validation = [0.58072635]
# Cost validation = [0.58072176]
# Cost validation = [0.58071717]
# Cost validation = [0.58071258]
# Cost validation = [0.58070799]
# Cost validation = [0.58070341]
# Cost validation = [0.58069884]
# Cost validation = [0.58069426]
# Cost validation = [0.58068969]
# Cost validation = [0.58068512]
# Cost validation = [0.58068056]
# Cost validation = [0.580676]
# Cost validation = [0.58067144]
# Cost validation = [0.58066689]
# Cost validation = [0.58066233]
# Cost validation = [0.58065779]
# Cost validation = [0.58065324]
# Cost validation = [0.5806487]
# Cost validation = [0.58064416]
# Cost validation = [0.58063963]
# Cost validation = [0.5806351]
# Cost validation = [0.58063057]
# Cost validation = [0.58062605]
# Cost validation = [0.58062152]
# Cost validation = [0.58061701]
# Cost validation = [0.58061249]
# Cost validation = [0.58060798]
# Cost validation = [0.58060347]
# Cost validation = [0.58059897]
# Cost validation = [0.58059447]
# Cost validation = [0.58058997]
# Cost validation = [0.58058547]
# Cost validation = [0.58058098]
# Cost validation = [0.58057649]
# Cost validation = [0.58057201]
# Cost validation = [0.58056752]
# Cost validation = [0.58056305]
# Cost validation = [0.58055857]
# Cost validation = [0.5805541]
# Cost validation = [0.58054963]
# Cost validation = [0.58054516]
# Cost validation = [0.5805407]
# Cost validation = [0.58053624]
# Cost validation = [0.58053178]
# Cost validation = [0.58052733]
# Cost validation = [0.58052288]
# Cost validation = [0.58051843]
# Cost validation = [0.58051399]
# Cost validation = [0.58050955]
# Cost validation = [0.58050511]
# Cost validation = [0.58050068]
# Cost validation = [0.58049625]
# Cost validation = [0.58049182]
# Cost validation = [0.58048739]
# Cost validation = [0.58048297]
# Cost validation = [0.58047855]
# Cost validation = [0.58047414]
# Cost validation = [0.58046973]
# Cost validation = [0.58046532]
# Cost validation = [0.58046091]
# Cost validation = [0.58045651]
# Cost validation = [0.58045211]
# Cost validation = [0.58044771]
# Cost validation = [0.58044332]
# Cost validation = [0.58043893]
# Cost validation = [0.58043454]
# Cost validation = [0.58043016]
# Cost validation = [0.58042578]
# Cost validation = [0.5804214]
# Cost validation = [0.58041703]
# Cost validation = [0.58041265]
# Cost validation = [0.58040829]
# Cost validation = [0.58040392]
# Cost validation = [0.58039956]
# Cost validation = [0.5803952]
# Cost validation = [0.58039084]
# Cost validation = [0.58038649]
# Cost validation = [0.58038214]
# Cost validation = [0.58037779]
# Cost validation = [0.58037345]
# Cost validation = [0.58036911]
# Cost validation = [0.58036477]
# Cost validation = [0.58036043]
# Cost validation = [0.5803561]
# Cost validation = [0.58035177]
# Cost validation = [0.58034745]
# Cost validation = [0.58034312]
# Cost validation = [0.58033881]
# Cost validation = [0.58033449]
# Cost validation = [0.58033017]
# Cost validation = [0.58032586]
# Cost validation = [0.58032156]
# Cost validation = [0.58031725]
# Cost validation = [0.58031295]
# Cost validation = [0.58030865]
# Cost validation = [0.58030436]
# Cost validation = [0.58030006]
# Cost validation = [0.58029577]
# Cost validation = [0.58029149]
# Cost validation = [0.5802872]
# Cost validation = [0.58028292]
# Cost validation = [0.58027864]
# Cost validation = [0.58027437]
# Cost validation = [0.5802701]
# Cost validation = [0.58026583]
# Cost validation = [0.58026156]
# Cost validation = [0.5802573]
# Cost validation = [0.58025304]
# Cost validation = [0.58024878]
# Cost validation = [0.58024453]
# Cost validation = [0.58024028]
# Cost validation = [0.58023603]
# Cost validation = [0.58023178]
# Cost validation = [0.58022754]
# Cost validation = [0.5802233]
# Cost validation = [0.58021906]
# Cost validation = [0.58021483]
# Cost validation = [0.5802106]
# Cost validation = [0.58020637]
# Cost validation = [0.58020214]
# Cost validation = [0.58019792]
# Cost validation = [0.5801937]
# Cost validation = [0.58018949]
# Cost validation = [0.58018527]
# Cost validation = [0.58018106]
# Cost validation = [0.58017685]
# Cost validation = [0.58017265]
# Cost validation = [0.58016845]
# Cost validation = [0.58016425]
# Cost validation = [0.58016005]
# Cost validation = [0.58015586]
# Cost validation = [0.58015167]
# Cost validation = [0.58014748]
# Cost validation = [0.58014329]
# Cost validation = [0.58013911]
# Cost validation = [0.58013493]
# Cost validation = [0.58013076]
# Cost validation = [0.58012658]
# Cost validation = [0.58012241]
# Cost validation = [0.58011824]
# Cost validation = [0.58011408]
# Cost validation = [0.58010992]
# Cost validation = [0.58010576]
# Cost validation = [0.5801016]
# Cost validation = [0.58009745]
# Cost validation = [0.5800933]
# Cost validation = [0.58008915]
# Cost validation = [0.580085]
# Cost validation = [0.58008086]
# Cost validation = [0.58007672]
# Cost validation = [0.58007258]
# Cost validation = [0.58006845]
# Cost validation = [0.58006432]
# Cost validation = [0.58006019]
# Cost validation = [0.58005606]
# Cost validation = [0.58005194]
# Cost validation = [0.58004782]
# Cost validation = [0.5800437]
# Cost validation = [0.58003958]
# Cost validation = [0.58003547]
# Cost validation = [0.58003136]
# Cost validation = [0.58002726]
# Cost validation = [0.58002315]
# Cost validation = [0.58001905]
# Cost validation = [0.58001495]
# Cost validation = [0.58001086]
# Cost validation = [0.58000676]
# Cost validation = [0.58000267]
# Cost validation = [0.57999859]
# Cost validation = [0.5799945]
# Cost validation = [0.57999042]
# Cost validation = [0.57998634]
# Cost validation = [0.57998226]
# Cost validation = [0.57997819]
# Cost validation = [0.57997412]
# Cost validation = [0.57997005]
# Cost validation = [0.57996598]
# Cost validation = [0.57996192]
# Cost validation = [0.57995786]
# Cost validation = [0.5799538]
# Cost validation = [0.57994975]
# Cost validation = [0.57994569]
# Cost validation = [0.57994164]
# Cost validation = [0.5799376]
# Cost validation = [0.57993355]
# Cost validation = [0.57992951]
# Cost validation = [0.57992547]
# Cost validation = [0.57992144]
# Cost validation = [0.5799174]
# Cost validation = [0.57991337]
# Cost validation = [0.57990934]
# Cost validation = [0.57990532]
# Cost validation = [0.57990129]
# Cost validation = [0.57989727]
# Cost validation = [0.57989326]
# Cost validation = [0.57988924]
# Cost validation = [0.57988523]
# Cost validation = [0.57988122]
# Cost validation = [0.57987721]
# Cost validation = [0.57987321]
# Cost validation = [0.5798692]
# Cost validation = [0.5798652]
# Cost validation = [0.57986121]
# Cost validation = [0.57985721]
# Cost validation = [0.57985322]
# Cost validation = [0.57984923]
# Cost validation = [0.57984525]
# Cost validation = [0.57984126]
# Cost validation = [0.57983728]
# Cost validation = [0.5798333]
# Cost validation = [0.57982933]
# Cost validation = [0.57982535]
# Cost validation = [0.57982138]
# Cost validation = [0.57981741]
# Cost validation = [0.57981345]
# Cost validation = [0.57980948]
# Cost validation = [0.57980552]
# Cost validation = [0.57980157]
# Cost validation = [0.57979761]
# Cost validation = [0.57979366]
# Cost validation = [0.57978971]
# Cost validation = [0.57978576]
# Cost validation = [0.57978181]
# Cost validation = [0.57977787]
# Cost validation = [0.57977393]
# Cost validation = [0.57976999]
# Cost validation = [0.57976606]
# Cost validation = [0.57976213]
# Cost validation = [0.5797582]
# Cost validation = [0.57975427]
# Cost validation = [0.57975034]
# Cost validation = [0.57974642]
# Cost validation = [0.5797425]
# Cost validation = [0.57973858]
# Cost validation = [0.57973467]
# Cost validation = [0.57973076]
# Cost validation = [0.57972685]
# Cost validation = [0.57972294]
# Cost validation = [0.57971904]
# Cost validation = [0.57971513]
# Cost validation = [0.57971123]
# Cost validation = [0.57970734]
# Cost validation = [0.57970344]
# Cost validation = [0.57969955]
# Cost validation = [0.57969566]

# %%
plt.figure(figsize=([8,8]))
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
import seaborn as sns
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)

fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.82690909 0.17309091]
#  [0.42734375 0.57265625]]

# %% [markdown]
# # Accuracy.
# Både egen kode og tester med scikit.

# %%
classes = logreg.predict(xtrain)
print(100*np.sum(classes==ytrain)/len(classes),'% Training Accuracy')
print(f1_score(ytrain, classes))

classes = logreg.predict(xval)
print(100*np.sum(classes==yval)/len(classes),'% Validation Accuracy')
print(f1_score(yval, classes))


classes = logreg.predict(xtest)
print(100*np.sum(classes==ytest)/len(classes),'% Test Accuracy')
print(f1_score(ytest, classes))
# Out:
# 69.70610399397137 % Training Accuracy
# 0.6538745387453875
# 69.50301204819277 % Validation Accuracy
# 0.6650124069478909
# 70.4331450094162 % Test Accuracy
# 0.6512661039537984

# %% [markdown]
# # Egen logistisk regresjon med stokastisk gradient descent

# %%
# %matplotlib qt
import LogisticRegression as lr
Niter=2500
logreg = lr.LOGREG(eta=0.1, doplot = False, doprint=True)
cost_val, cost_train, axis = logreg.fit(xtrain, ytrain, xval, yval, Niter, solver='sgd', batch_size=500)
classified = logreg.predict(xtest)
# %matplotlib inline
# Out:
# Cost validation = [0.89630205]
# Cost validation = [0.88514654]
# Cost validation = [0.87722651]
# Cost validation = [0.86674623]
# Cost validation = [0.86100356]
# Cost validation = [0.85514767]
# Cost validation = [0.84676424]
# Cost validation = [0.84114201]
# Cost validation = [0.83576153]
# Cost validation = [0.83165323]
# Cost validation = [0.82909864]
# Cost validation = [0.82568216]
# Cost validation = [0.8222417]
# Cost validation = [0.81783582]
# Cost validation = [0.81360411]
# Cost validation = [0.81033135]
# Cost validation = [0.80763124]
# Cost validation = [0.80462037]
# Cost validation = [0.80216323]
# Cost validation = [0.79979323]
# Cost validation = [0.79762629]
# Cost validation = [0.79566077]
# Cost validation = [0.79296462]
# Cost validation = [0.7912794]
# Cost validation = [0.78947738]
# Cost validation = [0.78771537]
# Cost validation = [0.78607976]
# Cost validation = [0.78388694]
# Cost validation = [0.78126427]
# Cost validation = [0.77952159]
# Cost validation = [0.77815846]
# Cost validation = [0.7766642]
# Cost validation = [0.77515658]
# Cost validation = [0.77380684]
# Cost validation = [0.77239003]
# Cost validation = [0.77102042]
# Cost validation = [0.76932238]
# Cost validation = [0.76760185]
# Cost validation = [0.76650879]
# Cost validation = [0.76479611]
# Cost validation = [0.76363049]
# Cost validation = [0.76208259]
# Cost validation = [0.76053723]
# Cost validation = [0.7591468]
# Cost validation = [0.7579064]
# Cost validation = [0.75667853]
# Cost validation = [0.75536135]
# Cost validation = [0.75417993]
# Cost validation = [0.75284599]
# Cost validation = [0.75171074]
# Cost validation = [0.7500671]
# Cost validation = [0.74928512]
# Cost validation = [0.74832091]
# Cost validation = [0.7472779]
# Cost validation = [0.74624069]
# Cost validation = [0.74518691]
# Cost validation = [0.74378033]
# Cost validation = [0.74220436]
# Cost validation = [0.7410858]
# Cost validation = [0.74003398]
# Cost validation = [0.73874653]
# Cost validation = [0.73743684]
# Cost validation = [0.73648091]
# Cost validation = [0.73563638]
# Cost validation = [0.73461763]
# Cost validation = [0.73352492]
# Cost validation = [0.73246912]
# Cost validation = [0.73127427]
# Cost validation = [0.73009728]
# Cost validation = [0.72907175]
# Cost validation = [0.72817856]
# Cost validation = [0.72731712]
# Cost validation = [0.72646041]
# Cost validation = [0.72563842]
# Cost validation = [0.72464406]
# Cost validation = [0.72327086]
# Cost validation = [0.7224331]
# Cost validation = [0.72137532]
# Cost validation = [0.72017347]
# Cost validation = [0.71927056]
# Cost validation = [0.71814016]
# Cost validation = [0.71707978]
# Cost validation = [0.71633186]
# Cost validation = [0.7153366]
# Cost validation = [0.71440037]
# Cost validation = [0.71339757]
# Cost validation = [0.7126624]
# Cost validation = [0.71161969]
# Cost validation = [0.71050954]
# Cost validation = [0.70947404]
# Cost validation = [0.70885869]
# Cost validation = [0.70804068]
# Cost validation = [0.70712346]
# Cost validation = [0.70640828]
# Cost validation = [0.70559485]
# Cost validation = [0.7048291]
# Cost validation = [0.70398191]
# Cost validation = [0.70313978]
# Cost validation = [0.70227935]
# Cost validation = [0.70146126]
# Cost validation = [0.70064947]
# Cost validation = [0.69969865]
# Cost validation = [0.69891467]
# Cost validation = [0.69806263]
# Cost validation = [0.69735627]
# Cost validation = [0.69648246]
# Cost validation = [0.69567664]
# Cost validation = [0.69505316]
# Cost validation = [0.69417688]
# Cost validation = [0.69325325]
# Cost validation = [0.69266398]
# Cost validation = [0.69188303]
# Cost validation = [0.69115975]
# Cost validation = [0.69054537]
# Cost validation = [0.69004189]
# Cost validation = [0.68935173]
# Cost validation = [0.68864694]
# Cost validation = [0.68794317]
# Cost validation = [0.68744974]
# Cost validation = [0.68666039]
# Cost validation = [0.68628126]
# Cost validation = [0.68567873]
# Cost validation = [0.68509738]
# Cost validation = [0.68437894]
# Cost validation = [0.68391849]
# Cost validation = [0.68330234]
# Cost validation = [0.68276468]
# Cost validation = [0.68215136]
# Cost validation = [0.68150891]
# Cost validation = [0.68082944]
# Cost validation = [0.68033857]
# Cost validation = [0.67969523]
# Cost validation = [0.67882743]
# Cost validation = [0.67839982]
# Cost validation = [0.67784721]
# Cost validation = [0.67722036]
# Cost validation = [0.6767846]
# Cost validation = [0.67613002]
# Cost validation = [0.67556159]
# Cost validation = [0.67483789]
# Cost validation = [0.67434207]
# Cost validation = [0.67367422]
# Cost validation = [0.67329387]
# Cost validation = [0.67278877]
# Cost validation = [0.67207252]
# Cost validation = [0.67139855]
# Cost validation = [0.67087996]
# Cost validation = [0.67032729]
# Cost validation = [0.66979427]
# Cost validation = [0.66926073]
# Cost validation = [0.66857131]
# Cost validation = [0.6679517]
# Cost validation = [0.66744438]
# Cost validation = [0.66696164]
# Cost validation = [0.66659867]
# Cost validation = [0.66609118]
# Cost validation = [0.66564319]
# Cost validation = [0.66522669]
# Cost validation = [0.66461255]
# Cost validation = [0.66411315]
# Cost validation = [0.6636593]
# Cost validation = [0.66310758]
# Cost validation = [0.66263238]
# Cost validation = [0.66208357]
# Cost validation = [0.66154399]
# Cost validation = [0.66089571]
# Cost validation = [0.66039274]
# Cost validation = [0.6599309]
# Cost validation = [0.65944074]
# Cost validation = [0.65908664]
# Cost validation = [0.65868702]
# Cost validation = [0.65817927]
# Cost validation = [0.6576874]
# Cost validation = [0.65721293]
# Cost validation = [0.65670519]
# Cost validation = [0.65646727]
# Cost validation = [0.65595327]
# Cost validation = [0.65566992]
# Cost validation = [0.65515284]
# Cost validation = [0.6548059]
# Cost validation = [0.65423872]
# Cost validation = [0.65387085]
# Cost validation = [0.65336575]
# Cost validation = [0.65294609]
# Cost validation = [0.65276604]
# Cost validation = [0.65226781]
# Cost validation = [0.65185966]
# Cost validation = [0.65135131]
# Cost validation = [0.65108695]
# Cost validation = [0.65077572]
# Cost validation = [0.65031965]
# Cost validation = [0.64992551]
# Cost validation = [0.64940506]
# Cost validation = [0.64897397]
# Cost validation = [0.64869524]
# Cost validation = [0.64845572]
# Cost validation = [0.64813986]
# Cost validation = [0.64775649]
# Cost validation = [0.64760166]
# Cost validation = [0.64733434]
# Cost validation = [0.64690266]
# Cost validation = [0.64644582]
# Cost validation = [0.64607284]
# Cost validation = [0.64583802]
# Cost validation = [0.64548295]
# Cost validation = [0.6450079]
# Cost validation = [0.64457848]
# Cost validation = [0.64416035]
# Cost validation = [0.64379846]
# Cost validation = [0.64337664]
# Cost validation = [0.64306936]
# Cost validation = [0.64264974]
# Cost validation = [0.64234088]
# Cost validation = [0.64206496]
# Cost validation = [0.64178708]
# Cost validation = [0.64149507]
# Cost validation = [0.64115167]
# Cost validation = [0.64084389]
# Cost validation = [0.64051135]
# Cost validation = [0.64016123]
# Cost validation = [0.63983708]
# Cost validation = [0.63952627]
# Cost validation = [0.63916147]
# Cost validation = [0.63906066]
# Cost validation = [0.63869018]
# Cost validation = [0.63833711]
# Cost validation = [0.63787697]
# Cost validation = [0.63764371]
# Cost validation = [0.63743134]
# Cost validation = [0.63727822]
# Cost validation = [0.63698015]
# Cost validation = [0.63683833]
# Cost validation = [0.63654014]
# Cost validation = [0.63616953]
# Cost validation = [0.63606838]
# Cost validation = [0.63580677]
# Cost validation = [0.63565271]
# Cost validation = [0.63536249]
# Cost validation = [0.63520979]
# Cost validation = [0.63495514]
# Cost validation = [0.63474969]
# Cost validation = [0.6343228]
# Cost validation = [0.63403602]
# Cost validation = [0.63372685]
# Cost validation = [0.63349174]
# Cost validation = [0.63327948]
# Cost validation = [0.63289263]
# Cost validation = [0.63272455]
# Cost validation = [0.63252818]
# Cost validation = [0.63219653]
# Cost validation = [0.63189254]
# Cost validation = [0.63160976]
# Cost validation = [0.6313211]
# Cost validation = [0.63102789]
# Cost validation = [0.63063699]
# Cost validation = [0.63036663]
# Cost validation = [0.63020265]
# Cost validation = [0.63007757]
# Cost validation = [0.62983466]
# Cost validation = [0.62967569]
# Cost validation = [0.62935565]
# Cost validation = [0.62921061]
# Cost validation = [0.62897648]
# Cost validation = [0.62862741]
# Cost validation = [0.62839055]
# Cost validation = [0.62821539]
# Cost validation = [0.62782595]
# Cost validation = [0.6275848]
# Cost validation = [0.62734116]
# Cost validation = [0.62706663]
# Cost validation = [0.62685647]
# Cost validation = [0.62670454]
# Cost validation = [0.62652218]
# Cost validation = [0.6263362]
# Cost validation = [0.62618773]
# Cost validation = [0.62607048]
# Cost validation = [0.62597945]
# Cost validation = [0.62571521]
# Cost validation = [0.62554356]
# Cost validation = [0.62531049]
# Cost validation = [0.62524578]
# Cost validation = [0.62514352]
# Cost validation = [0.62512909]
# Cost validation = [0.62480687]
# Cost validation = [0.62459652]
# Cost validation = [0.62443542]
# Cost validation = [0.62420415]
# Cost validation = [0.62409654]
# Cost validation = [0.62382192]
# Cost validation = [0.62352683]
# Cost validation = [0.62337212]
# Cost validation = [0.6232123]
# Cost validation = [0.62315612]
# Cost validation = [0.6230121]
# Cost validation = [0.62280986]
# Cost validation = [0.62267198]
# Cost validation = [0.62255317]
# Cost validation = [0.62236174]
# Cost validation = [0.62215146]
# Cost validation = [0.62197566]
# Cost validation = [0.62177345]
# Cost validation = [0.62161841]
# Cost validation = [0.62149239]
# Cost validation = [0.62126082]
# Cost validation = [0.62109835]
# Cost validation = [0.62087339]
# Cost validation = [0.6207773]
# Cost validation = [0.62063168]
# Cost validation = [0.62046856]
# Cost validation = [0.62021737]
# Cost validation = [0.62004436]
# Cost validation = [0.61991539]
# Cost validation = [0.61977714]
# Cost validation = [0.61958252]
# Cost validation = [0.61940313]
# Cost validation = [0.61924734]
# Cost validation = [0.61911867]
# Cost validation = [0.61899036]
# Cost validation = [0.6187718]
# Cost validation = [0.61860866]
# Cost validation = [0.61851441]
# Cost validation = [0.61834282]
# Cost validation = [0.618199]
# Cost validation = [0.61801074]
# Cost validation = [0.61785064]
# Cost validation = [0.6177032]
# Cost validation = [0.61761441]
# Cost validation = [0.617486]
# Cost validation = [0.61739929]
# Cost validation = [0.61725528]
# Cost validation = [0.61710549]
# Cost validation = [0.61700994]
# Cost validation = [0.61692918]
# Cost validation = [0.61685847]
# Cost validation = [0.61670048]
# Cost validation = [0.61654872]
# Cost validation = [0.61654272]
# Cost validation = [0.61633785]
# Cost validation = [0.6161894]
# Cost validation = [0.61595362]
# Cost validation = [0.61581557]
# Cost validation = [0.61572034]
# Cost validation = [0.6157559]
# Cost validation = [0.61569402]
# Cost validation = [0.61560069]
# Cost validation = [0.61550794]
# Cost validation = [0.61536233]
# Cost validation = [0.61533029]
# Cost validation = [0.61533539]
# Cost validation = [0.61527897]
# Cost validation = [0.6150478]
# Cost validation = [0.61501404]
# Cost validation = [0.61496693]
# Cost validation = [0.61483752]
# Cost validation = [0.61462827]
# Cost validation = [0.61444847]
# Cost validation = [0.61450374]
# Cost validation = [0.61437763]
# Cost validation = [0.61426421]
# Cost validation = [0.61404005]
# Cost validation = [0.61390711]
# Cost validation = [0.61368055]
# Cost validation = [0.61348707]
# Cost validation = [0.61334048]
# Cost validation = [0.61328398]
# Cost validation = [0.6132966]
# Cost validation = [0.61324056]
# Cost validation = [0.61316602]
# Cost validation = [0.61303143]
# Cost validation = [0.61296775]
# Cost validation = [0.61284075]
# Cost validation = [0.61273973]
# Cost validation = [0.6126256]
# Cost validation = [0.61251816]
# Cost validation = [0.61232289]
# Cost validation = [0.61227341]
# Cost validation = [0.61220868]
# Cost validation = [0.6121148]
# Cost validation = [0.61196119]
# Cost validation = [0.61183753]
# Cost validation = [0.61172766]
# Cost validation = [0.61163561]
# Cost validation = [0.61155115]
# Cost validation = [0.61150316]
# Cost validation = [0.61145189]
# Cost validation = [0.61133029]
# Cost validation = [0.61123103]
# Cost validation = [0.61109904]
# Cost validation = [0.61101541]
# Cost validation = [0.61085878]
# Cost validation = [0.61079592]
# Cost validation = [0.61081755]
# Cost validation = [0.61063506]
# Cost validation = [0.61062756]
# Cost validation = [0.61048798]
# Cost validation = [0.6103972]
# Cost validation = [0.61031494]
# Cost validation = [0.61024664]
# Cost validation = [0.61012339]
# Cost validation = [0.61003114]
# Cost validation = [0.61002789]
# Cost validation = [0.60989642]
# Cost validation = [0.60982072]
# Cost validation = [0.60969023]
# Cost validation = [0.6096942]
# Cost validation = [0.60950736]
# Cost validation = [0.60944859]
# Cost validation = [0.60939222]
# Cost validation = [0.6093306]
# Cost validation = [0.6091895]
# Cost validation = [0.60919444]
# Cost validation = [0.60909269]
# Cost validation = [0.60888069]
# Cost validation = [0.60877699]
# Cost validation = [0.60874488]
# Cost validation = [0.60858047]
# Cost validation = [0.60848152]
# Cost validation = [0.60848013]
# Cost validation = [0.60848188]
# Cost validation = [0.60845201]
# Cost validation = [0.60847041]
# Cost validation = [0.60842539]
# Cost validation = [0.6083517]
# Cost validation = [0.60832108]
# Cost validation = [0.60828257]
# Cost validation = [0.6082419]
# Cost validation = [0.60824677]
# Cost validation = [0.60815045]
# Cost validation = [0.60799907]
# Cost validation = [0.60785229]
# Cost validation = [0.60793671]
# Cost validation = [0.60782497]
# Cost validation = [0.60766902]
# Cost validation = [0.60750591]
# Cost validation = [0.60750605]
# Cost validation = [0.60747535]
# Cost validation = [0.60736627]
# Cost validation = [0.60731084]
# Cost validation = [0.60727095]
# Cost validation = [0.60717]
# Cost validation = [0.60700809]
# Cost validation = [0.60690632]
# Cost validation = [0.60692707]
# Cost validation = [0.60684011]
# Cost validation = [0.60668729]
# Cost validation = [0.60666413]
# Cost validation = [0.60655569]
# Cost validation = [0.60643785]
# Cost validation = [0.60639195]
# Cost validation = [0.60631123]
# Cost validation = [0.60632956]
# Cost validation = [0.60624623]
# Cost validation = [0.60629713]
# Cost validation = [0.6063131]
# Cost validation = [0.60629008]
# Cost validation = [0.60614726]
# Cost validation = [0.60614005]
# Cost validation = [0.60589557]
# Cost validation = [0.60584393]
# Cost validation = [0.60571356]
# Cost validation = [0.60565883]
# Cost validation = [0.60549376]
# Cost validation = [0.60542661]
# Cost validation = [0.60535043]
# Cost validation = [0.60528026]
# Cost validation = [0.60521102]
# Cost validation = [0.60520826]
# Cost validation = [0.60511618]
# Cost validation = [0.60502828]
# Cost validation = [0.60503898]
# Cost validation = [0.60499333]
# Cost validation = [0.60491488]
# Cost validation = [0.60479053]
# Cost validation = [0.60474329]
# Cost validation = [0.60465334]
# Cost validation = [0.60461573]
# Cost validation = [0.60454448]
# Cost validation = [0.60447497]
# Cost validation = [0.60445456]
# Cost validation = [0.60428868]
# Cost validation = [0.6042403]
# Cost validation = [0.60419047]
# Cost validation = [0.60411499]
# Cost validation = [0.60407798]
# Cost validation = [0.60406068]
# Cost validation = [0.60399249]
# Cost validation = [0.6039623]
# Cost validation = [0.6039313]
# Cost validation = [0.60391484]
# Cost validation = [0.60385013]
# Cost validation = [0.60385521]
# Cost validation = [0.60378935]
# Cost validation = [0.60379588]
# Cost validation = [0.60371435]
# Cost validation = [0.60368525]
# Cost validation = [0.60360653]
# Cost validation = [0.60347844]
# Cost validation = [0.60352794]
# Cost validation = [0.60353294]
# Cost validation = [0.60338641]
# Cost validation = [0.60336187]
# Cost validation = [0.60331962]
# Cost validation = [0.6032508]
# Cost validation = [0.60318624]
# Cost validation = [0.6031746]
# Cost validation = [0.60307343]
# Cost validation = [0.60301708]
# Cost validation = [0.60296227]
# Cost validation = [0.60287399]
# Cost validation = [0.60273751]
# Cost validation = [0.60266572]
# Cost validation = [0.60270859]
# Cost validation = [0.60265152]
# Cost validation = [0.60258426]
# Cost validation = [0.60251015]
# Cost validation = [0.60250617]
# Cost validation = [0.60244264]
# Cost validation = [0.60246974]
# Cost validation = [0.6023648]
# Cost validation = [0.60226232]
# Cost validation = [0.60224506]
# Cost validation = [0.60219185]
# Cost validation = [0.60213757]
# Cost validation = [0.60206408]
# Cost validation = [0.6020393]
# Cost validation = [0.60201399]
# Cost validation = [0.6019349]
# Cost validation = [0.60186702]
# Cost validation = [0.60187209]
# Cost validation = [0.60185355]
# Cost validation = [0.60183307]
# Cost validation = [0.60188214]
# Cost validation = [0.60177278]
# Cost validation = [0.60172917]
# Cost validation = [0.60161786]
# Cost validation = [0.60149421]
# Cost validation = [0.60153832]
# Cost validation = [0.60151189]
# Cost validation = [0.60149221]
# Cost validation = [0.60145841]
# Cost validation = [0.60137109]
# Cost validation = [0.60132649]
# Cost validation = [0.60129415]
# Cost validation = [0.60124052]
# Cost validation = [0.60127364]
# Cost validation = [0.60117935]
# Cost validation = [0.60109243]
# Cost validation = [0.60103984]
# Cost validation = [0.60100327]
# Cost validation = [0.60095748]
# Cost validation = [0.60091233]
# Cost validation = [0.60086741]
# Cost validation = [0.60082109]
# Cost validation = [0.60079628]
# Cost validation = [0.60074936]
# Cost validation = [0.60078231]
# Cost validation = [0.60081332]
# Cost validation = [0.60081615]
# Cost validation = [0.60075215]
# Cost validation = [0.60080812]
# Cost validation = [0.60076329]
# Cost validation = [0.60071911]
# Cost validation = [0.60069326]
# Cost validation = [0.60059492]
# Cost validation = [0.60056694]
# Cost validation = [0.60052753]
# Cost validation = [0.60039319]
# Cost validation = [0.60032288]
# Cost validation = [0.60019245]
# Cost validation = [0.60021892]
# Cost validation = [0.6001926]
# Cost validation = [0.60020896]
# Cost validation = [0.60016703]
# Cost validation = [0.60018092]
# Cost validation = [0.60006743]
# Cost validation = [0.59994852]
# Cost validation = [0.59988412]
# Cost validation = [0.59989253]
# Cost validation = [0.59983433]
# Cost validation = [0.59976736]
# Cost validation = [0.59970425]
# Cost validation = [0.59963713]
# Cost validation = [0.59957155]
# Cost validation = [0.59955704]
# Cost validation = [0.59955718]
# Cost validation = [0.5994984]
# Cost validation = [0.5994935]
# Cost validation = [0.59941439]
# Cost validation = [0.59937999]
# Cost validation = [0.59932923]
# Cost validation = [0.59928228]
# Cost validation = [0.59926703]
# Cost validation = [0.59924662]
# Cost validation = [0.59928452]
# Cost validation = [0.59922843]
# Cost validation = [0.59918925]
# Cost validation = [0.5991532]
# Cost validation = [0.59910836]
# Cost validation = [0.59914661]
# Cost validation = [0.59910726]
# Cost validation = [0.59904106]
# Cost validation = [0.59904291]
# Cost validation = [0.59895045]
# Cost validation = [0.59895395]
# Cost validation = [0.59891573]
# Cost validation = [0.59884565]
# Cost validation = [0.59884276]
# Cost validation = [0.59881616]
# Cost validation = [0.59877979]
# Cost validation = [0.59875632]
# Cost validation = [0.59873336]
# Cost validation = [0.59868196]
# Cost validation = [0.59866867]
# Cost validation = [0.59861965]
# Cost validation = [0.59860299]
# Cost validation = [0.59859595]
# Cost validation = [0.59852323]
# Cost validation = [0.59850452]
# Cost validation = [0.59851092]
# Cost validation = [0.59841585]
# Cost validation = [0.59836016]
# Cost validation = [0.59837795]
# Cost validation = [0.59837557]
# Cost validation = [0.59846748]
# Cost validation = [0.59840786]
# Cost validation = [0.59840597]
# Cost validation = [0.59846345]
# Cost validation = [0.59839074]
# Cost validation = [0.59826124]
# Cost validation = [0.59825997]
# Cost validation = [0.59824825]
# Cost validation = [0.59833915]
# Cost validation = [0.59823231]
# Cost validation = [0.59835349]
# Cost validation = [0.59840961]
# Cost validation = [0.59841358]
# Cost validation = [0.59827072]
# Cost validation = [0.59830634]
# Cost validation = [0.59826272]
# Cost validation = [0.59847957]
# Cost validation = [0.59838099]
# Cost validation = [0.59844447]
# Cost validation = [0.59821143]
# Cost validation = [0.59809567]
# Cost validation = [0.597972]
# Cost validation = [0.59788142]
# Cost validation = [0.59793444]
# Cost validation = [0.59806525]
# Cost validation = [0.59795797]
# Cost validation = [0.59804612]
# Cost validation = [0.59790867]
# Cost validation = [0.59778911]
# Cost validation = [0.59780275]
# Cost validation = [0.5979905]
# Cost validation = [0.59795851]
# Cost validation = [0.5977246]
# Cost validation = [0.59767159]
# Cost validation = [0.59772488]
# Cost validation = [0.59787035]
# Cost validation = [0.5977147]
# Cost validation = [0.59753053]
# Cost validation = [0.5973264]
# Cost validation = [0.59734022]
# Cost validation = [0.59734139]
# Cost validation = [0.59734875]
# Cost validation = [0.59713526]
# Cost validation = [0.59716397]
# Cost validation = [0.59719012]
# Cost validation = [0.59710283]
# Cost validation = [0.59703512]
# Cost validation = [0.59694961]
# Cost validation = [0.59693019]
# Cost validation = [0.59697272]
# Cost validation = [0.59689471]
# Cost validation = [0.59690576]
# Cost validation = [0.59679655]
# Cost validation = [0.59685616]
# Cost validation = [0.59678886]
# Cost validation = [0.59672783]
# Cost validation = [0.59670523]
# Cost validation = [0.59677899]
# Cost validation = [0.59672822]
# Cost validation = [0.5966789]
# Cost validation = [0.59671433]
# Cost validation = [0.59654738]
# Cost validation = [0.59644812]
# Cost validation = [0.59643881]
# Cost validation = [0.59644268]
# Cost validation = [0.59645028]
# Cost validation = [0.5964239]
# Cost validation = [0.59635959]
# Cost validation = [0.59637209]
# Cost validation = [0.59628719]
# Cost validation = [0.59625118]
# Cost validation = [0.5962129]
# Cost validation = [0.59613909]
# Cost validation = [0.596103]
# Cost validation = [0.59611684]
# Cost validation = [0.59610841]
# Cost validation = [0.59610285]
# Cost validation = [0.5960934]
# Cost validation = [0.59600742]
# Cost validation = [0.59595671]
# Cost validation = [0.59595473]
# Cost validation = [0.59595752]
# Cost validation = [0.59590404]
# Cost validation = [0.59588123]
# Cost validation = [0.59587932]
# Cost validation = [0.59590512]
# Cost validation = [0.59583303]
# Cost validation = [0.59584046]
# Cost validation = [0.59584268]
# Cost validation = [0.59583976]
# Cost validation = [0.59589751]
# Cost validation = [0.59582809]
# Cost validation = [0.59571609]
# Cost validation = [0.5957167]
# Cost validation = [0.59558837]
# Cost validation = [0.59557915]
# Cost validation = [0.59559553]
# Cost validation = [0.59554682]
# Cost validation = [0.59558528]
# Cost validation = [0.59551947]
# Cost validation = [0.59554577]
# Cost validation = [0.59548752]
# Cost validation = [0.59541642]
# Cost validation = [0.59539621]
# Cost validation = [0.59538067]
# Cost validation = [0.59540059]
# Cost validation = [0.59542738]
# Cost validation = [0.59540889]
# Cost validation = [0.59544616]
# Cost validation = [0.59545131]
# Cost validation = [0.59536766]
# Cost validation = [0.59536098]
# Cost validation = [0.59530752]
# Cost validation = [0.59523054]
# Cost validation = [0.59519276]
# Cost validation = [0.59527395]
# Cost validation = [0.59512945]
# Cost validation = [0.59507831]
# Cost validation = [0.5950558]
# Cost validation = [0.59504817]
# Cost validation = [0.59508677]
# Cost validation = [0.59500678]
# Cost validation = [0.59488921]
# Cost validation = [0.59485724]
# Cost validation = [0.59483307]
# Cost validation = [0.59480582]
# Cost validation = [0.59482811]
# Cost validation = [0.59475539]
# Cost validation = [0.59467769]
# Cost validation = [0.5946909]
# Cost validation = [0.59468826]
# Cost validation = [0.59459393]
# Cost validation = [0.59455943]
# Cost validation = [0.59461279]
# Cost validation = [0.59458982]
# Cost validation = [0.59452066]
# Cost validation = [0.59454478]
# Cost validation = [0.59455883]
# Cost validation = [0.5945848]
# Cost validation = [0.59460136]
# Cost validation = [0.59464165]
# Cost validation = [0.59464779]
# Cost validation = [0.59463965]
# Cost validation = [0.59464973]
# Cost validation = [0.59472121]
# Cost validation = [0.59462891]
# Cost validation = [0.59463698]
# Cost validation = [0.59463661]
# Cost validation = [0.5945968]
# Cost validation = [0.59458331]
# Cost validation = [0.59448739]
# Cost validation = [0.59446842]
# Cost validation = [0.59435826]
# Cost validation = [0.59432526]
# Cost validation = [0.59422573]
# Cost validation = [0.59422391]
# Cost validation = [0.59416845]
# Cost validation = [0.59407343]
# Cost validation = [0.59403216]
# Cost validation = [0.59400183]
# Cost validation = [0.59397491]
# Cost validation = [0.59399985]
# Cost validation = [0.59397199]
# Cost validation = [0.59392993]
# Cost validation = [0.59397106]
# Cost validation = [0.59392288]
# Cost validation = [0.59385157]
# Cost validation = [0.59383077]
# Cost validation = [0.59378728]
# Cost validation = [0.59376577]
# Cost validation = [0.59374403]
# Cost validation = [0.5937251]
# Cost validation = [0.59370135]
# Cost validation = [0.59367764]
# Cost validation = [0.59366483]
# Cost validation = [0.59363513]
# Cost validation = [0.5936458]
# Cost validation = [0.59363704]
# Cost validation = [0.59358377]
# Cost validation = [0.59358337]
# Cost validation = [0.59358326]
# Cost validation = [0.59354959]
# Cost validation = [0.59352714]
# Cost validation = [0.59350153]
# Cost validation = [0.59351463]
# Cost validation = [0.59348947]
# Cost validation = [0.59346141]
# Cost validation = [0.59345004]
# Cost validation = [0.59342092]
# Cost validation = [0.59342973]
# Cost validation = [0.59343]
# Cost validation = [0.59341377]
# Cost validation = [0.59342301]
# Cost validation = [0.59339025]
# Cost validation = [0.59337526]
# Cost validation = [0.59335732]
# Cost validation = [0.59332329]
# Cost validation = [0.59329356]
# Cost validation = [0.59328485]
# Cost validation = [0.59326718]
# Cost validation = [0.59327684]
# Cost validation = [0.59327411]
# Cost validation = [0.59332425]
# Cost validation = [0.59330458]
# Cost validation = [0.59324326]
# Cost validation = [0.59318768]
# Cost validation = [0.59320388]
# Cost validation = [0.59316836]
# Cost validation = [0.59316046]
# Cost validation = [0.5930836]
# Cost validation = [0.59303943]
# Cost validation = [0.59300395]
# Cost validation = [0.59295616]
# Cost validation = [0.59297066]
# Cost validation = [0.59296003]
# Cost validation = [0.5929423]
# Cost validation = [0.59290718]
# Cost validation = [0.59288178]
# Cost validation = [0.59284359]
# Cost validation = [0.5928505]
# Cost validation = [0.59282691]
# Cost validation = [0.59280049]
# Cost validation = [0.59277507]
# Cost validation = [0.59272667]
# Cost validation = [0.59272461]
# Cost validation = [0.59276065]
# Cost validation = [0.59273799]
# Cost validation = [0.59266584]
# Cost validation = [0.5926411]
# Cost validation = [0.59259101]
# Cost validation = [0.59254989]
# Cost validation = [0.59255419]
# Cost validation = [0.5925564]
# Cost validation = [0.59252845]
# Cost validation = [0.59248768]
# Cost validation = [0.59247302]
# Cost validation = [0.59246668]
# Cost validation = [0.59244586]
# Cost validation = [0.59245783]
# Cost validation = [0.59246977]
# Cost validation = [0.59249882]
# Cost validation = [0.59246308]
# Cost validation = [0.59251125]
# Cost validation = [0.5925653]
# Cost validation = [0.59256692]
# Cost validation = [0.59257252]
# Cost validation = [0.59255528]
# Cost validation = [0.59252703]
# Cost validation = [0.5923477]
# Cost validation = [0.59234348]
# Cost validation = [0.59230095]
# Cost validation = [0.59226693]
# Cost validation = [0.59225893]
# Cost validation = [0.59225554]
# Cost validation = [0.59229122]
# Cost validation = [0.59231023]
# Cost validation = [0.59228868]
# Cost validation = [0.59219047]
# Cost validation = [0.59213885]
# Cost validation = [0.59210348]
# Cost validation = [0.59216102]
# Cost validation = [0.59216596]
# Cost validation = [0.5920971]
# Cost validation = [0.59209584]
# Cost validation = [0.59211558]
# Cost validation = [0.59212775]
# Cost validation = [0.59218474]
# Cost validation = [0.59235226]
# Cost validation = [0.59229423]
# Cost validation = [0.59221313]
# Cost validation = [0.59217335]
# Cost validation = [0.59220082]
# Cost validation = [0.59228394]
# Cost validation = [0.59237451]
# Cost validation = [0.59246271]
# Cost validation = [0.59252908]
# Cost validation = [0.59224708]
# Cost validation = [0.59214506]
# Cost validation = [0.59204765]
# Cost validation = [0.59206254]
# Cost validation = [0.59199659]
# Cost validation = [0.59200241]
# Cost validation = [0.59198116]
# Cost validation = [0.59186861]
# Cost validation = [0.59180397]
# Cost validation = [0.59179889]
# Cost validation = [0.59177736]
# Cost validation = [0.59173841]
# Cost validation = [0.59171366]
# Cost validation = [0.59177418]
# Cost validation = [0.59173981]
# Cost validation = [0.59171157]
# Cost validation = [0.59169914]
# Cost validation = [0.59166684]
# Cost validation = [0.59161646]
# Cost validation = [0.59159301]
# Cost validation = [0.59160615]
# Cost validation = [0.59160152]
# Cost validation = [0.59158482]
# Cost validation = [0.59157294]
# Cost validation = [0.59154003]
# Cost validation = [0.59147889]
# Cost validation = [0.59149354]
# Cost validation = [0.59144419]
# Cost validation = [0.59145874]
# Cost validation = [0.59145702]
# Cost validation = [0.59143561]
# Cost validation = [0.59140921]
# Cost validation = [0.59138182]
# Cost validation = [0.59137408]
# Cost validation = [0.59135592]
# Cost validation = [0.59137696]
# Cost validation = [0.59135401]
# Cost validation = [0.59127391]
# Cost validation = [0.59122447]
# Cost validation = [0.59120696]
# Cost validation = [0.59130276]
# Cost validation = [0.5913057]
# Cost validation = [0.5913213]
# Cost validation = [0.5912938]
# Cost validation = [0.59123032]
# Cost validation = [0.59123642]
# Cost validation = [0.59115979]
# Cost validation = [0.59114025]
# Cost validation = [0.59113199]
# Cost validation = [0.59108987]
# Cost validation = [0.5910464]
# Cost validation = [0.59108419]
# Cost validation = [0.59103445]
# Cost validation = [0.59111721]
# Cost validation = [0.59099946]
# Cost validation = [0.59104662]
# Cost validation = [0.59098056]
# Cost validation = [0.59087374]
# Cost validation = [0.59085216]
# Cost validation = [0.59084658]
# Cost validation = [0.59089459]
# Cost validation = [0.59083888]
# Cost validation = [0.59088955]
# Cost validation = [0.59090308]
# Cost validation = [0.59089633]
# Cost validation = [0.59092951]
# Cost validation = [0.59088553]
# Cost validation = [0.59096527]
# Cost validation = [0.59088112]
# Cost validation = [0.59080271]
# Cost validation = [0.59087268]
# Cost validation = [0.5908423]
# Cost validation = [0.59072234]
# Cost validation = [0.5907044]
# Cost validation = [0.59067428]
# Cost validation = [0.59070567]
# Cost validation = [0.59071362]
# Cost validation = [0.59052984]
# Cost validation = [0.59048031]
# Cost validation = [0.59045748]
# Cost validation = [0.59046703]
# Cost validation = [0.59049018]
# Cost validation = [0.59041747]
# Cost validation = [0.59038931]
# Cost validation = [0.59035235]
# Cost validation = [0.59033466]
# Cost validation = [0.59030087]
# Cost validation = [0.59027476]
# Cost validation = [0.59025176]
# Cost validation = [0.59024398]
# Cost validation = [0.59027331]
# Cost validation = [0.59022615]
# Cost validation = [0.59021866]
# Cost validation = [0.59021229]
# Cost validation = [0.59020848]
# Cost validation = [0.59020636]
# Cost validation = [0.59021762]
# Cost validation = [0.59016569]
# Cost validation = [0.59017531]
# Cost validation = [0.59017491]
# Cost validation = [0.5901516]
# Cost validation = [0.59014428]
# Cost validation = [0.59012155]
# Cost validation = [0.59010022]
# Cost validation = [0.59008332]
# Cost validation = [0.59006532]
# Cost validation = [0.59004115]
# Cost validation = [0.59001583]
# Cost validation = [0.59000902]
# Cost validation = [0.59002389]
# Cost validation = [0.5900096]
# Cost validation = [0.59000933]
# Cost validation = [0.58998809]
# Cost validation = [0.58996428]
# Cost validation = [0.58994766]
# Cost validation = [0.58991214]
# Cost validation = [0.58991068]
# Cost validation = [0.58989514]
# Cost validation = [0.58987677]
# Cost validation = [0.58986227]
# Cost validation = [0.58983887]
# Cost validation = [0.58986802]
# Cost validation = [0.58982795]
# Cost validation = [0.58980812]
# Cost validation = [0.58977202]
# Cost validation = [0.58973629]
# Cost validation = [0.58970165]
# Cost validation = [0.58969155]
# Cost validation = [0.58968659]
# Cost validation = [0.58966848]
# Cost validation = [0.58966213]
# Cost validation = [0.58965595]
# Cost validation = [0.58963251]
# Cost validation = [0.58963676]
# Cost validation = [0.58962388]
# Cost validation = [0.58960573]
# Cost validation = [0.58960008]
# Cost validation = [0.58960648]
# Cost validation = [0.58960343]
# Cost validation = [0.58954189]
# Cost validation = [0.58951193]
# Cost validation = [0.58949902]
# Cost validation = [0.58947302]
# Cost validation = [0.58944798]
# Cost validation = [0.58945489]
# Cost validation = [0.58947789]
# Cost validation = [0.58944319]
# Cost validation = [0.58943315]
# Cost validation = [0.58940734]
# Cost validation = [0.58940992]
# Cost validation = [0.5893638]
# Cost validation = [0.58929728]
# Cost validation = [0.58928487]
# Cost validation = [0.58929287]
# Cost validation = [0.58932277]
# Cost validation = [0.58936706]
# Cost validation = [0.58931979]
# Cost validation = [0.58928541]
# Cost validation = [0.58926929]
# Cost validation = [0.58923125]
# Cost validation = [0.58920326]
# Cost validation = [0.58917725]
# Cost validation = [0.58917525]
# Cost validation = [0.58916381]
# Cost validation = [0.58916177]
# Cost validation = [0.58916384]
# Cost validation = [0.58917479]
# Cost validation = [0.58921057]
# Cost validation = [0.58925569]
# Cost validation = [0.5892155]
# Cost validation = [0.5891771]
# Cost validation = [0.58926107]
# Cost validation = [0.58931962]
# Cost validation = [0.58933996]
# Cost validation = [0.58941385]
# Cost validation = [0.58930756]
# Cost validation = [0.58923759]
# Cost validation = [0.58920142]
# Cost validation = [0.58917765]
# Cost validation = [0.58913727]
# Cost validation = [0.58909019]
# Cost validation = [0.58907426]
# Cost validation = [0.58908107]
# Cost validation = [0.58906143]
# Cost validation = [0.58903197]
# Cost validation = [0.58901095]
# Cost validation = [0.58899784]
# Cost validation = [0.58898731]
# Cost validation = [0.588982]
# Cost validation = [0.58897566]
# Cost validation = [0.58897022]
# Cost validation = [0.58897207]
# Cost validation = [0.58898781]
# Cost validation = [0.58904679]
# Cost validation = [0.58905199]
# Cost validation = [0.58899306]
# Cost validation = [0.58892973]
# Cost validation = [0.58891596]
# Cost validation = [0.58888621]
# Cost validation = [0.58884484]
# Cost validation = [0.58882924]
# Cost validation = [0.58882467]
# Cost validation = [0.58880791]
# Cost validation = [0.58879599]
# Cost validation = [0.58879155]
# Cost validation = [0.58884703]
# Cost validation = [0.5888036]
# Cost validation = [0.58877224]
# Cost validation = [0.58879093]
# Cost validation = [0.58879082]
# Cost validation = [0.5887624]
# Cost validation = [0.58872341]
# Cost validation = [0.58883128]
# Cost validation = [0.58885353]
# Cost validation = [0.58882912]
# Cost validation = [0.58876778]
# Cost validation = [0.58874965]
# Cost validation = [0.58882984]
# Cost validation = [0.58886001]
# Cost validation = [0.58887958]
# Cost validation = [0.58901293]
# Cost validation = [0.58896853]
# Cost validation = [0.58887351]
# Cost validation = [0.58887275]
# Cost validation = [0.58888239]
# Cost validation = [0.58882722]
# Cost validation = [0.5889014]
# Cost validation = [0.58876409]
# Cost validation = [0.58872269]
# Cost validation = [0.58869283]
# Cost validation = [0.58860163]
# Cost validation = [0.58851657]
# Cost validation = [0.58847485]
# Cost validation = [0.58844499]
# Cost validation = [0.58847075]
# Cost validation = [0.58847467]
# Cost validation = [0.58840294]
# Cost validation = [0.58837817]
# Cost validation = [0.58836207]
# Cost validation = [0.58835438]
# Cost validation = [0.58832648]
# Cost validation = [0.58831617]
# Cost validation = [0.58833588]
# Cost validation = [0.58830637]
# Cost validation = [0.58829806]
# Cost validation = [0.58823705]
# Cost validation = [0.58822911]
# Cost validation = [0.58830093]
# Cost validation = [0.58831414]
# Cost validation = [0.58830136]
# Cost validation = [0.58839352]
# Cost validation = [0.58839131]
# Cost validation = [0.58847755]
# Cost validation = [0.58836873]
# Cost validation = [0.58848882]
# Cost validation = [0.58837838]
# Cost validation = [0.58849009]
# Cost validation = [0.58834769]
# Cost validation = [0.58828608]
# Cost validation = [0.58835727]
# Cost validation = [0.58831717]
# Cost validation = [0.58828229]
# Cost validation = [0.58820233]
# Cost validation = [0.58835484]
# Cost validation = [0.5883947]
# Cost validation = [0.58829641]
# Cost validation = [0.58826837]
# Cost validation = [0.5883256]
# Cost validation = [0.58832932]
# Cost validation = [0.58845057]
# Cost validation = [0.58850089]
# Cost validation = [0.58846591]
# Cost validation = [0.58835916]
# Cost validation = [0.58854026]
# Cost validation = [0.58845374]
# Cost validation = [0.58830249]
# Cost validation = [0.58846796]
# Cost validation = [0.58849633]
# Cost validation = [0.58850281]
# Cost validation = [0.58848237]
# Cost validation = [0.58840975]
# Cost validation = [0.58837578]
# Cost validation = [0.58826653]
# Cost validation = [0.5883166]
# Cost validation = [0.588232]
# Cost validation = [0.58814331]
# Cost validation = [0.58814753]
# Cost validation = [0.58817639]
# Cost validation = [0.58814896]
# Cost validation = [0.58799793]
# Cost validation = [0.58791937]
# Cost validation = [0.58794973]
# Cost validation = [0.58804657]
# Cost validation = [0.58798435]
# Cost validation = [0.58796023]
# Cost validation = [0.58799652]
# Cost validation = [0.58803926]
# Cost validation = [0.58796534]
# Cost validation = [0.58797066]
# Cost validation = [0.58789074]
# Cost validation = [0.58784416]
# Cost validation = [0.58786568]
# Cost validation = [0.58784765]
# Cost validation = [0.58787377]
# Cost validation = [0.58794044]
# Cost validation = [0.5879138]
# Cost validation = [0.5879094]
# Cost validation = [0.58780181]
# Cost validation = [0.58775399]
# Cost validation = [0.58774045]
# Cost validation = [0.587693]
# Cost validation = [0.58769165]
# Cost validation = [0.58769178]
# Cost validation = [0.58766908]
# Cost validation = [0.58763023]
# Cost validation = [0.58758312]
# Cost validation = [0.58756734]
# Cost validation = [0.58752766]
# Cost validation = [0.58754582]
# Cost validation = [0.5875623]
# Cost validation = [0.58756717]
# Cost validation = [0.58756321]
# Cost validation = [0.58753571]
# Cost validation = [0.58753219]
# Cost validation = [0.58760364]
# Cost validation = [0.58759086]
# Cost validation = [0.58755722]
# Cost validation = [0.58751374]
# Cost validation = [0.58745769]
# Cost validation = [0.58748461]
# Cost validation = [0.58745468]
# Cost validation = [0.58756608]
# Cost validation = [0.58754298]
# Cost validation = [0.58745088]
# Cost validation = [0.58747691]
# Cost validation = [0.5874818]
# Cost validation = [0.58742675]
# Cost validation = [0.58749521]
# Cost validation = [0.58752015]
# Cost validation = [0.58759469]
# Cost validation = [0.58755231]
# Cost validation = [0.58756316]
# Cost validation = [0.58759122]
# Cost validation = [0.58755851]
# Cost validation = [0.58747704]
# Cost validation = [0.58751498]
# Cost validation = [0.58740385]
# Cost validation = [0.58740092]
# Cost validation = [0.58740875]
# Cost validation = [0.5874715]
# Cost validation = [0.58748934]
# Cost validation = [0.58748571]
# Cost validation = [0.58743566]
# Cost validation = [0.58750109]
# Cost validation = [0.58765895]
# Cost validation = [0.58754764]
# Cost validation = [0.5875515]
# Cost validation = [0.58752021]
# Cost validation = [0.58746317]
# Cost validation = [0.58740558]
# Cost validation = [0.58750338]
# Cost validation = [0.58747089]
# Cost validation = [0.58741455]
# Cost validation = [0.58739047]
# Cost validation = [0.58741687]
# Cost validation = [0.5874821]
# Cost validation = [0.58738887]
# Cost validation = [0.58740809]
# Cost validation = [0.58724635]
# Cost validation = [0.5873131]
# Cost validation = [0.58729106]
# Cost validation = [0.58735909]
# Cost validation = [0.58727234]
# Cost validation = [0.5873239]
# Cost validation = [0.58736675]
# Cost validation = [0.58725851]
# Cost validation = [0.58725956]
# Cost validation = [0.58730819]
# Cost validation = [0.58729583]
# Cost validation = [0.58733126]
# Cost validation = [0.58733019]
# Cost validation = [0.58728932]
# Cost validation = [0.58731893]
# Cost validation = [0.58727949]
# Cost validation = [0.58733181]
# Cost validation = [0.58719463]
# Cost validation = [0.58718842]
# Cost validation = [0.58720095]
# Cost validation = [0.58706793]
# Cost validation = [0.5869507]
# Cost validation = [0.58691687]
# Cost validation = [0.58689015]
# Cost validation = [0.5868617]
# Cost validation = [0.58685135]
# Cost validation = [0.58684382]
# Cost validation = [0.58684964]
# Cost validation = [0.58683129]
# Cost validation = [0.58682091]
# Cost validation = [0.58686816]
# Cost validation = [0.58684524]
# Cost validation = [0.58683768]
# Cost validation = [0.58682029]
# Cost validation = [0.58680895]
# Cost validation = [0.58677509]
# Cost validation = [0.58674791]
# Cost validation = [0.58672243]
# Cost validation = [0.58672903]
# Cost validation = [0.58672753]
# Cost validation = [0.58672684]
# Cost validation = [0.5867354]
# Cost validation = [0.58670805]
# Cost validation = [0.5866903]
# Cost validation = [0.5866871]
# Cost validation = [0.58666344]
# Cost validation = [0.58663343]
# Cost validation = [0.5866281]
# Cost validation = [0.58661267]
# Cost validation = [0.5865661]
# Cost validation = [0.58656559]
# Cost validation = [0.58658605]
# Cost validation = [0.58657646]
# Cost validation = [0.58652707]
# Cost validation = [0.58650528]
# Cost validation = [0.58648878]
# Cost validation = [0.58646955]
# Cost validation = [0.58651896]
# Cost validation = [0.58648615]
# Cost validation = [0.58646005]
# Cost validation = [0.58650859]
# Cost validation = [0.5864841]
# Cost validation = [0.5865875]
# Cost validation = [0.58653807]
# Cost validation = [0.58647083]
# Cost validation = [0.58649031]
# Cost validation = [0.58646907]
# Cost validation = [0.58644857]
# Cost validation = [0.58640304]
# Cost validation = [0.58637203]
# Cost validation = [0.58636621]
# Cost validation = [0.58634667]
# Cost validation = [0.58637355]
# Cost validation = [0.58634902]
# Cost validation = [0.58642727]
# Cost validation = [0.58648204]
# Cost validation = [0.58643383]
# Cost validation = [0.58639417]
# Cost validation = [0.58631025]
# Cost validation = [0.58633558]
# Cost validation = [0.58633954]
# Cost validation = [0.58628788]
# Cost validation = [0.58624598]
# Cost validation = [0.58627433]
# Cost validation = [0.58632255]
# Cost validation = [0.58632127]
# Cost validation = [0.58628075]
# Cost validation = [0.58629014]
# Cost validation = [0.58631433]
# Cost validation = [0.58631826]
# Cost validation = [0.58639423]
# Cost validation = [0.58629543]
# Cost validation = [0.58628726]
# Cost validation = [0.58620805]
# Cost validation = [0.58621527]
# Cost validation = [0.58623191]
# Cost validation = [0.58616694]
# Cost validation = [0.58617152]
# Cost validation = [0.58610878]
# Cost validation = [0.58611798]
# Cost validation = [0.58611595]
# Cost validation = [0.58610143]
# Cost validation = [0.58612908]
# Cost validation = [0.58608751]
# Cost validation = [0.58607047]
# Cost validation = [0.58609001]
# Cost validation = [0.58608952]
# Cost validation = [0.58612119]
# Cost validation = [0.5860703]
# Cost validation = [0.58608739]
# Cost validation = [0.58605879]
# Cost validation = [0.58607741]
# Cost validation = [0.58600729]
# Cost validation = [0.58607085]
# Cost validation = [0.5861161]
# Cost validation = [0.5862212]
# Cost validation = [0.58617652]
# Cost validation = [0.58616911]
# Cost validation = [0.58608351]
# Cost validation = [0.5860567]
# Cost validation = [0.58604316]
# Cost validation = [0.5861699]
# Cost validation = [0.58614512]
# Cost validation = [0.58615327]
# Cost validation = [0.58609559]
# Cost validation = [0.58609558]
# Cost validation = [0.58598198]
# Cost validation = [0.58597271]
# Cost validation = [0.58593712]
# Cost validation = [0.58601389]
# Cost validation = [0.58601715]
# Cost validation = [0.58609991]
# Cost validation = [0.58610666]
# Cost validation = [0.58602336]
# Cost validation = [0.58597592]
# Cost validation = [0.58599816]
# Cost validation = [0.58593128]
# Cost validation = [0.58590602]
# Cost validation = [0.58602998]
# Cost validation = [0.5860479]
# Cost validation = [0.58602171]
# Cost validation = [0.58599664]
# Cost validation = [0.58597858]
# Cost validation = [0.58595142]
# Cost validation = [0.58597993]
# Cost validation = [0.58601027]
# Cost validation = [0.58605413]
# Cost validation = [0.58595831]
# Cost validation = [0.58590482]
# Cost validation = [0.58594906]
# Cost validation = [0.58593115]
# Cost validation = [0.58584747]
# Cost validation = [0.5858445]
# Cost validation = [0.58587841]
# Cost validation = [0.58577426]
# Cost validation = [0.58579435]
# Cost validation = [0.58580924]
# Cost validation = [0.58594442]
# Cost validation = [0.58588824]
# Cost validation = [0.58575618]
# Cost validation = [0.58569662]
# Cost validation = [0.58566725]
# Cost validation = [0.58565611]
# Cost validation = [0.58564158]
# Cost validation = [0.58563343]
# Cost validation = [0.58562454]
# Cost validation = [0.58563682]
# Cost validation = [0.58564472]
# Cost validation = [0.58566049]
# Cost validation = [0.58573851]
# Cost validation = [0.58571093]
# Cost validation = [0.58574207]
# Cost validation = [0.58571895]
# Cost validation = [0.58583754]
# Cost validation = [0.58578926]
# Cost validation = [0.58575733]
# Cost validation = [0.5856769]
# Cost validation = [0.58565978]
# Cost validation = [0.58561909]
# Cost validation = [0.58563846]
# Cost validation = [0.58561017]
# Cost validation = [0.58568887]
# Cost validation = [0.58570052]
# Cost validation = [0.58563836]
# Cost validation = [0.58558091]
# Cost validation = [0.58561813]
# Cost validation = [0.58564221]
# Cost validation = [0.58565424]
# Cost validation = [0.58564269]
# Cost validation = [0.58565578]
# Cost validation = [0.58557734]
# Cost validation = [0.58562112]
# Cost validation = [0.58569076]
# Cost validation = [0.5855818]
# Cost validation = [0.58559341]
# Cost validation = [0.58553808]
# Cost validation = [0.58551023]
# Cost validation = [0.58550225]
# Cost validation = [0.58548524]
# Cost validation = [0.58551351]
# Cost validation = [0.58549053]
# Cost validation = [0.58550515]
# Cost validation = [0.58549923]
# Cost validation = [0.58545318]
# Cost validation = [0.58547378]
# Cost validation = [0.58548115]
# Cost validation = [0.58546817]
# Cost validation = [0.58545111]
# Cost validation = [0.5854298]
# Cost validation = [0.5854609]
# Cost validation = [0.585442]
# Cost validation = [0.58545135]
# Cost validation = [0.58542952]
# Cost validation = [0.58539674]
# Cost validation = [0.58539529]
# Cost validation = [0.58542443]
# Cost validation = [0.58542055]
# Cost validation = [0.58541092]
# Cost validation = [0.58538085]
# Cost validation = [0.58540332]
# Cost validation = [0.58544232]
# Cost validation = [0.58549908]
# Cost validation = [0.585609]
# Cost validation = [0.58549078]
# Cost validation = [0.58548625]
# Cost validation = [0.58552541]
# Cost validation = [0.58554326]
# Cost validation = [0.58547324]
# Cost validation = [0.58548108]
# Cost validation = [0.58552592]
# Cost validation = [0.5854336]
# Cost validation = [0.58539982]
# Cost validation = [0.58539623]
# Cost validation = [0.58537986]
# Cost validation = [0.58539504]
# Cost validation = [0.58535849]
# Cost validation = [0.58536366]
# Cost validation = [0.58531997]
# Cost validation = [0.5853709]
# Cost validation = [0.58533106]
# Cost validation = [0.58529289]
# Cost validation = [0.58531661]
# Cost validation = [0.58529204]
# Cost validation = [0.58528844]
# Cost validation = [0.58530876]
# Cost validation = [0.58526654]
# Cost validation = [0.58533475]
# Cost validation = [0.58536311]
# Cost validation = [0.58543606]
# Cost validation = [0.58536372]
# Cost validation = [0.58539449]
# Cost validation = [0.58534629]
# Cost validation = [0.58533879]
# Cost validation = [0.58535921]
# Cost validation = [0.58533087]
# Cost validation = [0.58527719]
# Cost validation = [0.58522091]
# Cost validation = [0.58514412]
# Cost validation = [0.58513896]
# Cost validation = [0.58515213]
# Cost validation = [0.58519199]
# Cost validation = [0.58523578]
# Cost validation = [0.58537686]
# Cost validation = [0.58539822]
# Cost validation = [0.58525702]
# Cost validation = [0.5852785]
# Cost validation = [0.58528537]
# Cost validation = [0.58528842]
# Cost validation = [0.58527143]
# Cost validation = [0.58525563]
# Cost validation = [0.58526822]
# Cost validation = [0.58526235]
# Cost validation = [0.58516347]
# Cost validation = [0.58517276]
# Cost validation = [0.58511403]
# Cost validation = [0.58511036]
# Cost validation = [0.58513379]
# Cost validation = [0.58517575]
# Cost validation = [0.58513748]
# Cost validation = [0.58504671]
# Cost validation = [0.58501123]
# Cost validation = [0.58497877]
# Cost validation = [0.58504042]
# Cost validation = [0.58502284]
# Cost validation = [0.58504675]
# Cost validation = [0.58494679]
# ...
# Cost validation = [0.58289883]
# Cost validation = [0.58291924]
# Cost validation = [0.58289536]
# Cost validation = [0.58286867]
# Cost validation = [0.58289071]
# Cost validation = [0.58289463]
# Cost validation = [0.58285659]
# Cost validation = [0.58286557]
# Cost validation = [0.58286091]
# Cost validation = [0.58290598]
# Cost validation = [0.58289076]
# Cost validation = [0.58287547]
# Cost validation = [0.58289729]
# Cost validation = [0.58290936]
# Cost validation = [0.58291945]
# Cost validation = [0.58297067]
# Cost validation = [0.5830153]
# Cost validation = [0.5829516]
# Cost validation = [0.5829328]
# Cost validation = [0.58293828]
# Cost validation = [0.58294707]
# Cost validation = [0.5829757]
# Cost validation = [0.58301542]
# Cost validation = [0.58297896]
# Cost validation = [0.58303823]
# Cost validation = [0.58301315]
# Cost validation = [0.58307818]
# Cost validation = [0.58299724]
# Cost validation = [0.582942]
# Cost validation = [0.58289767]
# Cost validation = [0.58289554]
# Cost validation = [0.58296546]
# Cost validation = [0.58289724]
# Cost validation = [0.58285962]
# Cost validation = [0.58279774]
# Cost validation = [0.58282448]
# Cost validation = [0.58284775]
# Cost validation = [0.58285024]
# Cost validation = [0.58288147]
# Cost validation = [0.58288885]
# Cost validation = [0.58299008]
# Cost validation = [0.58299803]
# Cost validation = [0.58298804]
# Cost validation = [0.58299527]
# Cost validation = [0.58295248]
# Cost validation = [0.58289672]
# Cost validation = [0.58295117]
# Cost validation = [0.58298477]
# Cost validation = [0.5828724]
# Cost validation = [0.58291183]
# Cost validation = [0.58287574]
# Cost validation = [0.58291816]
# Cost validation = [0.58294206]
# Cost validation = [0.58300369]
# Cost validation = [0.58303075]
# Cost validation = [0.58307311]
# Cost validation = [0.58306363]
# Cost validation = [0.58306725]
# Cost validation = [0.58305561]
# Cost validation = [0.58291525]
# Cost validation = [0.58288454]
# Cost validation = [0.5829273]
# Cost validation = [0.58297804]
# Cost validation = [0.58282279]
# Cost validation = [0.58278098]
# Cost validation = [0.58274939]
# Cost validation = [0.58274622]
# Cost validation = [0.58276344]
# Cost validation = [0.58271608]
# Cost validation = [0.58273516]
# Cost validation = [0.58271788]
# Cost validation = [0.5827679]
# Cost validation = [0.58277087]
# Cost validation = [0.58276774]
# Cost validation = [0.5827426]
# Cost validation = [0.58277566]
# Cost validation = [0.58273236]
# Cost validation = [0.58270164]
# Cost validation = [0.58270258]
# Cost validation = [0.58268691]
# Cost validation = [0.58271928]
# Cost validation = [0.58269921]
# Cost validation = [0.58271044]
# Cost validation = [0.58268709]
# Cost validation = [0.58268484]
# Cost validation = [0.58268137]
# Cost validation = [0.58267959]
# Cost validation = [0.5826804]
# Cost validation = [0.58266626]
# Cost validation = [0.58268142]
# Cost validation = [0.58269427]
# Cost validation = [0.58269182]
# Cost validation = [0.58268276]
# Cost validation = [0.5827061]
# Cost validation = [0.58277178]
# Cost validation = [0.58277615]
# Cost validation = [0.58273131]
# Cost validation = [0.5827229]
# Cost validation = [0.58273228]
# Cost validation = [0.58281958]
# Cost validation = [0.58275509]
# Cost validation = [0.58281046]
# Cost validation = [0.58272864]
# Cost validation = [0.582666]
# Cost validation = [0.58267864]
# Cost validation = [0.58264356]
# Cost validation = [0.58267946]
# Cost validation = [0.58267854]
# Cost validation = [0.58274802]
# Cost validation = [0.58278876]
# Cost validation = [0.58270721]
# Cost validation = [0.58280406]
# Cost validation = [0.58269945]
# Cost validation = [0.58273734]
# Cost validation = [0.5827018]
# Cost validation = [0.58261362]
# Cost validation = [0.58259947]
# Cost validation = [0.58261091]
# Cost validation = [0.58267169]
# Cost validation = [0.58272122]
# Cost validation = [0.58266763]
# Cost validation = [0.58274035]
# Cost validation = [0.58281203]
# Cost validation = [0.58281342]
# Cost validation = [0.58283712]
# Cost validation = [0.582835]
# Cost validation = [0.58300452]
# Cost validation = [0.58304311]
# Cost validation = [0.58311245]
# Cost validation = [0.58320583]
# Cost validation = [0.58317086]
# Cost validation = [0.58321587]
# Cost validation = [0.58328896]
# Cost validation = [0.58318256]
# Cost validation = [0.58326339]
# Cost validation = [0.58315896]
# Cost validation = [0.583024]
# Cost validation = [0.58294727]
# Cost validation = [0.5831125]
# Cost validation = [0.58315155]
# Cost validation = [0.58316912]
# Cost validation = [0.58321247]
# Cost validation = [0.58330033]
# Cost validation = [0.58335609]
# Cost validation = [0.58318002]
# Cost validation = [0.5832252]
# Cost validation = [0.58326212]
# Cost validation = [0.58296504]
# Cost validation = [0.58278963]
# Cost validation = [0.58266108]
# Cost validation = [0.5826961]
# Cost validation = [0.5826004]
# Cost validation = [0.58260263]
# Cost validation = [0.5825977]
# Cost validation = [0.58254328]
# Cost validation = [0.58249158]
# Cost validation = [0.58248155]
# Cost validation = [0.58253803]
# Cost validation = [0.5825057]
# Cost validation = [0.58251093]
# Cost validation = [0.582477]
# Cost validation = [0.58253233]
# Cost validation = [0.58253032]
# Cost validation = [0.58251138]
# Cost validation = [0.58252207]
# Cost validation = [0.5825457]
# Cost validation = [0.58249589]
# Cost validation = [0.58245003]
# Cost validation = [0.58243869]
# Cost validation = [0.58242828]
# Cost validation = [0.58243349]
# Cost validation = [0.5824594]
# Cost validation = [0.58245734]
# Cost validation = [0.58243848]
# Cost validation = [0.58241674]
# Cost validation = [0.58242294]
# Cost validation = [0.58241109]
# Cost validation = [0.582406]
# Cost validation = [0.58242394]
# Cost validation = [0.58243956]
# Cost validation = [0.58247283]
# Cost validation = [0.58245338]
# Cost validation = [0.58251909]
# Cost validation = [0.5824679]
# Cost validation = [0.58241552]
# Cost validation = [0.58243708]
# Cost validation = [0.58245683]
# Cost validation = [0.5824138]
# Cost validation = [0.58239635]
# Cost validation = [0.58243581]
# Cost validation = [0.58240933]
# Cost validation = [0.5824593]
# Cost validation = [0.58244046]
# Cost validation = [0.58239061]
# Cost validation = [0.58237576]
# Cost validation = [0.58236396]
# Cost validation = [0.58236433]
# Cost validation = [0.58234306]
# Cost validation = [0.58231554]
# Cost validation = [0.58232666]
# Cost validation = [0.5823098]
# Cost validation = [0.58233715]
# Cost validation = [0.58231376]
# Cost validation = [0.58231999]
# Cost validation = [0.58236227]
# Cost validation = [0.58238048]
# Cost validation = [0.58238298]
# Cost validation = [0.58237597]
# Cost validation = [0.58238652]
# Cost validation = [0.58239602]
# Cost validation = [0.58239521]
# Cost validation = [0.58235412]
# Cost validation = [0.58236095]
# Cost validation = [0.58236154]
# Cost validation = [0.58232825]
# Cost validation = [0.5823232]
# Cost validation = [0.58231267]
# Cost validation = [0.58231856]
# Cost validation = [0.58232898]
# Cost validation = [0.58231671]
# Cost validation = [0.58233004]
# Cost validation = [0.58238418]
# Cost validation = [0.58234117]
# Cost validation = [0.58232559]
# Cost validation = [0.58239248]
# Cost validation = [0.58237139]
# Cost validation = [0.58235401]
# Cost validation = [0.58235564]
# Cost validation = [0.582322]
# Cost validation = [0.5823301]
# Cost validation = [0.58233419]
# Cost validation = [0.58232497]
# Cost validation = [0.58237251]
# Cost validation = [0.58237418]
# Cost validation = [0.58236271]
# Cost validation = [0.58237278]
# Cost validation = [0.58242911]
# Cost validation = [0.58237655]
# Cost validation = [0.58232568]
# Cost validation = [0.58229812]
# Cost validation = [0.5823049]
# Cost validation = [0.58226648]
# Cost validation = [0.58229872]
# Cost validation = [0.58227016]
# Cost validation = [0.58232084]
# Cost validation = [0.58223671]
# Cost validation = [0.58235358]
# Cost validation = [0.58232269]
# Cost validation = [0.58229379]
# Cost validation = [0.58231075]
# Cost validation = [0.58234367]
# Cost validation = [0.58237522]
# Cost validation = [0.58244375]
# Cost validation = [0.58252044]
# Cost validation = [0.58246637]
# Cost validation = [0.58237761]
# Cost validation = [0.5823944]
# Cost validation = [0.58244828]
# Cost validation = [0.58239437]
# Cost validation = [0.58228702]
# Cost validation = [0.58236848]
# Cost validation = [0.58235642]
# Cost validation = [0.58229618]
# Cost validation = [0.58225937]
# Cost validation = [0.58227254]
# Cost validation = [0.58217322]
# Cost validation = [0.58206935]
# Cost validation = [0.5821038]
# Cost validation = [0.5821724]
# Cost validation = [0.58215623]
# Cost validation = [0.58211744]
# Cost validation = [0.58209294]
# Cost validation = [0.58210242]
# Cost validation = [0.58208583]
# Cost validation = [0.58208167]
# Cost validation = [0.58206726]
# Cost validation = [0.5820666]
# Cost validation = [0.58207836]
# Cost validation = [0.58209101]
# Cost validation = [0.58209384]
# Cost validation = [0.58205337]
# Cost validation = [0.58206601]
# Cost validation = [0.58205405]
# Cost validation = [0.58216772]
# Cost validation = [0.58211333]
# Cost validation = [0.58209299]
# Cost validation = [0.58212636]
# Cost validation = [0.58213263]
# Cost validation = [0.58214344]
# Cost validation = [0.58207856]
# Cost validation = [0.58206172]
# Cost validation = [0.58206383]
# Cost validation = [0.58208349]
# Cost validation = [0.5820379]
# Cost validation = [0.58207442]
# Cost validation = [0.58207407]
# Cost validation = [0.58209643]
# Cost validation = [0.58203792]
# Cost validation = [0.58208045]
# Cost validation = [0.58210721]
# Cost validation = [0.58213848]
# Cost validation = [0.58207826]
# Cost validation = [0.58207135]
# Cost validation = [0.58206195]
# Cost validation = [0.58210329]
# Cost validation = [0.58203818]
# Cost validation = [0.58201815]
# Cost validation = [0.58202115]
# Cost validation = [0.58205298]
# Cost validation = [0.58199759]
# Cost validation = [0.58207013]
# Cost validation = [0.58209206]
# Cost validation = [0.58233484]
# Cost validation = [0.58262]
# Cost validation = [0.58250174]
# Cost validation = [0.58281424]
# Cost validation = [0.58265254]
# Cost validation = [0.58260815]
# Cost validation = [0.58256599]
# Cost validation = [0.582683]
# Cost validation = [0.58270952]
# Cost validation = [0.58247524]
# Cost validation = [0.58243885]
# Cost validation = [0.58240763]
# Cost validation = [0.58229852]
# Cost validation = [0.58215955]
# Cost validation = [0.58211061]
# Cost validation = [0.58212249]
# Cost validation = [0.58206619]
# Cost validation = [0.58200642]
# Cost validation = [0.58205877]
# Cost validation = [0.58205276]
# Cost validation = [0.58205637]
# Cost validation = [0.58207451]
# Cost validation = [0.58210672]
# Cost validation = [0.58204825]
# Cost validation = [0.58194225]
# Cost validation = [0.58191973]
# Cost validation = [0.58196526]
# Cost validation = [0.5820255]
# Cost validation = [0.58205137]
# Cost validation = [0.58204875]
# Cost validation = [0.5820681]
# Cost validation = [0.58216553]
# Cost validation = [0.58212408]
# Cost validation = [0.58204718]
# Cost validation = [0.58203776]
# Cost validation = [0.582019]
# Cost validation = [0.58210903]
# Cost validation = [0.58204972]
# Cost validation = [0.58209852]
# Cost validation = [0.58205309]
# Cost validation = [0.58201824]
# Cost validation = [0.58201873]
# Cost validation = [0.58199173]
# Cost validation = [0.58215768]
# Cost validation = [0.58225839]
# Cost validation = [0.58227727]
# Cost validation = [0.58229698]
# Cost validation = [0.58235443]
# Cost validation = [0.58237814]
# Cost validation = [0.58234437]
# Cost validation = [0.58228804]
# Cost validation = [0.58227299]
# Cost validation = [0.58211829]
# Cost validation = [0.58220368]
# Cost validation = [0.58229766]
# Cost validation = [0.58235266]
# Cost validation = [0.58238639]
# Cost validation = [0.58224977]
# Cost validation = [0.58227563]
# Cost validation = [0.58235146]
# Cost validation = [0.58250138]
# Cost validation = [0.58236123]
# Cost validation = [0.58235603]
# Cost validation = [0.58227923]
# Cost validation = [0.58225456]
# Cost validation = [0.58229998]
# Cost validation = [0.5823761]
# Cost validation = [0.58250134]
# Cost validation = [0.58241685]
# Cost validation = [0.582419]
# Cost validation = [0.58235207]
# Cost validation = [0.5822276]
# Cost validation = [0.58225133]
# Cost validation = [0.5821344]
# Cost validation = [0.58209733]
# Cost validation = [0.58214287]
# Cost validation = [0.58200328]
# Cost validation = [0.58192273]
# Cost validation = [0.5819635]
# Cost validation = [0.58192655]
# Cost validation = [0.58188431]
# Cost validation = [0.58193372]
# Cost validation = [0.58189725]
# Cost validation = [0.58187161]
# Cost validation = [0.5819254]
# Cost validation = [0.5818409]
# Cost validation = [0.58181056]
# Cost validation = [0.58183814]
# Cost validation = [0.58186397]
# Cost validation = [0.58192927]
# Cost validation = [0.58196864]
# Cost validation = [0.58202676]
# Cost validation = [0.58205432]
# Cost validation = [0.58208881]
# Cost validation = [0.58199014]
# Cost validation = [0.58212957]
# Cost validation = [0.58202861]
# Cost validation = [0.58199375]
# Cost validation = [0.58198624]
# Cost validation = [0.58205568]
# Cost validation = [0.58204392]
# Cost validation = [0.58194331]
# Cost validation = [0.58191021]
# Cost validation = [0.58190408]
# Cost validation = [0.5818923]
# Cost validation = [0.58184574]
# Cost validation = [0.5819406]
# Cost validation = [0.58198081]
# Cost validation = [0.58194776]
# Cost validation = [0.58188421]
# Cost validation = [0.58186415]
# Cost validation = [0.58185346]
# Cost validation = [0.58181361]
# Cost validation = [0.58185314]
# Cost validation = [0.58183067]
# Cost validation = [0.58173226]
# Cost validation = [0.5817753]
# Cost validation = [0.58176841]
# Cost validation = [0.58172105]
# Cost validation = [0.58171796]
# Cost validation = [0.58171732]
# Cost validation = [0.58169882]
# Cost validation = [0.58168414]
# Cost validation = [0.58169255]
# Cost validation = [0.58178008]
# Cost validation = [0.58174781]
# Cost validation = [0.58174841]
# Cost validation = [0.58172486]
# Cost validation = [0.58178341]
# Cost validation = [0.58181314]
# Cost validation = [0.58171908]
# Cost validation = [0.58176789]
# Cost validation = [0.58175493]
# Cost validation = [0.58176748]
# Cost validation = [0.5818675]
# Cost validation = [0.58184662]
# Cost validation = [0.5818029]
# Cost validation = [0.58177695]
# Cost validation = [0.58177133]
# Cost validation = [0.58168361]
# Cost validation = [0.58170035]
# Cost validation = [0.58167951]
# Cost validation = [0.58168912]
# Cost validation = [0.58168104]
# Cost validation = [0.5817449]
# Cost validation = [0.58179063]
# Cost validation = [0.58172478]
# Cost validation = [0.58173725]
# Cost validation = [0.58168998]
# Cost validation = [0.58164915]
# Cost validation = [0.58163484]
# Cost validation = [0.5816522]
# Cost validation = [0.58171889]
# Cost validation = [0.58172597]
# Cost validation = [0.5816717]
# Cost validation = [0.58165486]
# Cost validation = [0.58168112]
# Cost validation = [0.5816757]
# Cost validation = [0.58162697]
# Cost validation = [0.58169007]
# Cost validation = [0.58166332]
# Cost validation = [0.58159926]
# Cost validation = [0.58159113]
# Cost validation = [0.58163164]
# Cost validation = [0.58162368]
# Cost validation = [0.58160586]
# Cost validation = [0.58161587]
# Cost validation = [0.58163117]
# Cost validation = [0.58160888]
# Cost validation = [0.58159565]
# Cost validation = [0.58159395]
# Cost validation = [0.58160709]
# Cost validation = [0.58161876]
# Cost validation = [0.58165327]
# Cost validation = [0.58167305]
# Cost validation = [0.58176895]
# Cost validation = [0.5817497]
# Cost validation = [0.58173306]
# Cost validation = [0.58179468]
# Cost validation = [0.58178493]
# Cost validation = [0.58183923]
# Cost validation = [0.58193732]
# Cost validation = [0.58192136]
# Cost validation = [0.581836]
# Cost validation = [0.58171283]
# Cost validation = [0.5817215]
# Cost validation = [0.58169421]
# Cost validation = [0.58165005]
# Cost validation = [0.58168227]
# Cost validation = [0.58160256]
# Cost validation = [0.58162733]
# Cost validation = [0.58167881]
# Cost validation = [0.58168627]
# Cost validation = [0.58165252]
# Cost validation = [0.58153232]
# Cost validation = [0.58152207]
# Cost validation = [0.58150002]
# Cost validation = [0.58150902]
# Cost validation = [0.5815]
# Cost validation = [0.58155528]
# Cost validation = [0.58168478]
# Cost validation = [0.58160087]
# Cost validation = [0.58157003]
# Cost validation = [0.58156412]
# Cost validation = [0.58169788]
# Cost validation = [0.5816468]

# %%
plt.figure(figsize=([8,8]))
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
norm = fx.norm_confusion_matrix(ytest, classified, normalize=True)

fig=sns.heatmap(norm, annot=True, cmap=plt.cm.Blues,yticklabels=['0','1'], xticklabels=['0','1'])
fig.set_yticks([0, 2]) 
fig.set_xticks([0.5, 1.5])
fig.set(xlabel='Predicted label', ylabel='True label')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.83418182 0.16581818]
#  [0.42734375 0.57265625]]

# %%
classes = logreg.predict(xtrain)
print(100*np.sum(classes==ytrain)/len(classes),'% Training Accuracy')
print(f1_score(ytrain, classes))

classes = logreg.predict(xval)
print(100*np.sum(classes==yval)/len(classes),'% Validation Accuracy')
print(f1_score(yval, classes))


classes = logreg.predict(xtest)
print(100*np.sum(classes==ytest)/len(classes),'% Test Accuracy')
print(f1_score(ytest, classes))
# Out:
# 70.14748627408763 % Training Accuracy
# 0.6579499198223756
# 69.0512048192771 % Validation Accuracy
# 0.6600496277915632
# 70.80979284369114 % Test Accuracy
# 0.6541722445336904

# %%
import scikitplot as skplt
from sklearn.metrics import roc_auc_score

y_probas = classified

y_probas = y_probas.flatten()
y_temp = np.zeros((y_probas.shape[0], 2))
y_temp[:,0] = 1-y_probas
y_temp[:,1] = y_probas 
#y_probas = y_temp



y_temp2 = np.zeros((y_probas.shape[0], 2))
y_temp2[:,0] = (1-ytest).ravel()
y_temp2[:,1] = ytest.ravel() 


ting=roc_auc_score(ytest, y_probas)
ting2=roc_auc_score(ytest, ytest)

print(ting)
print(ting2)

skplt.metrics.plot_roc(ytest, y_temp)
skplt.metrics.plot_roc(ytest, y_temp2)
# ikke surr mer med det her
# Out:
# 0.7034190340909091
# 1.0

# %%
def bestCurve(y):
    defaults = sum(y == 1)
    total = len(y)
    x = np.linspace(0, 1, total)
    y1 = np.linspace(0, 1, defaults)
    y2 = np.ones(total-defaults)
    y3 = np.concatenate([y1,y2])
    return x, y3

# %%
model = LogisticRegression()
model.fit(xtrain, ytrain)
predicted_classes = model.predict(xtrain)
accuracy = accuracy_score(ytrain.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(ytrain, predicted_classes)

print(accuracy, '% Training Accuracy')

predicted_classes = model.predict(xval)
accuracy = accuracy_score(yval.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(yval, predicted_classes)

print(accuracy, '% Validation Accuracy')

predicted_classes = model.predict(xtest)
accuracy = accuracy_score(ytest.flatten(),predicted_classes)
accuracy = accuracy * 100
parameters = model.coef_
log_loss(ytest, predicted_classes)

print(accuracy, '% Test Accuracy')
# Out:
# 70.67499192593391 % Training Accuracy
# 69.80421686746988 % Validation Accuracy
# 71.33709981167608 % Test Accuracy
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # C)
# Neural Network.

# %%
epochs=1000
batch_size=int(len(ytrain)/3)
n_features=x.shape[1]
etavec = np.logspace(-4, -1, 4)
lmbvec = np.logspace(-4, 1, 6)
lmbvec[0]=0

activation = [lrf.relu, lrf.sigmoid, lrf.sigmoid]
derivative = [lrf.relu_deriv, lrf.sigmoid_deriv, lrf.sigmoid_deriv]

saved_net = np.zeros((len(etavec), len(lmbvec)), dtype=object)
train_accuracy = np.zeros((len(etavec), len(lmbvec)))
for i, etas in enumerate(etavec):
    for j, lmb in enumerate(lmbvec):
        np.random.seed(2019)
        neural_net = nn.ANN(lmb=lmb, bias=0, eta=etas,early_stop_tol = 0,\
                            early_stop_nochange=50, mode = 'classification')            
        neural_net.add_layers(n_features=[91,50,20], n_neurons = [50,20,1] , n_layers=3)
        
        neural_net.train(epochs, batch_size, xtrain,ytrain,activation,derivative \
                         ,xval,yval, verbose=False)

        pred = neural_net.feed_out(xval, activation)
        train_accuracy[i,j] =  lrf.cost_log_ols(pred.ravel(),yval.T)
        print('Validation loss for', '\u03B7 =', etas, '&', '\u03BB =', lmb, '=', train_accuracy [i,j])
# Out:
# Validation loss for η = 0.0001 & λ = 0.0 = 0.7448969370845803
# Validation loss for η = 0.0001 & λ = 0.001 = 0.7448967373323573
# Validation loss for η = 0.0001 & λ = 0.01 = 0.7448949394576877
# Validation loss for η = 0.0001 & λ = 0.1 = 0.7448769503585482
# Validation loss for η = 0.0001 & λ = 1.0 = 0.7416212504700338
# Validation loss for η = 0.0001 & λ = 10.0 = 0.7195922338637272
# Validation loss for η = 0.001 & λ = 0.0 = 0.745766729371044
# Validation loss for η = 0.001 & λ = 0.001 = 0.7457647037147692
# Validation loss for η = 0.001 & λ = 0.01 = 0.745746461048751
# Validation loss for η = 0.001 & λ = 0.1 = 0.7455628805435501
# Validation loss for η = 0.001 & λ = 1.0 = 0.7194057166607729
# Validation loss for η = 0.001 & λ = 10.0 = 0.7193970239737373
# Validation loss for η = 0.01 & λ = 0.0 = 0.682842732218783
# Validation loss for η = 0.01 & λ = 0.001 = 0.6830125882270615
# Validation loss for η = 0.01 & λ = 0.01 = 0.6853351160320752
# Validation loss for η = 0.01 & λ = 0.1 = 0.7010302342238893
# Validation loss for η = 0.01 & λ = 1.0 = 0.7196225937544954
# Validation loss for η = 0.01 & λ = 10.0 = 0.7196004192603348
# Validation loss for η = 0.1 & λ = 0.0 = 0.6793726936112183
# Validation loss for η = 0.1 & λ = 0.001 = 0.6795000720118928
# Validation loss for η = 0.1 & λ = 0.01 = 0.6787954753559282
# Validation loss for η = 0.1 & λ = 0.1 = 0.7013210220973831
# Validation loss for η = 0.1 & λ = 1.0 = 0.7196728746939607
# Validation loss for η = 0.1 & λ = 10.0 = 0.7196841913032569

# %%
import seaborn as sns
train_accuracy[np.isnan(train_accuracy)]=2

yticklabels = etavec
xticklabels = lmbvec
fig, ax = plt.subplots(figsize = (10, 12))
sns.heatmap(train_accuracy, annot=True, ax=ax, cmap="viridis",\
            yticklabels=yticklabels, xticklabels=xticklabels)
ax.set_title("Training Accuracy")
ax.set_ylabel("$\eta$")
ax.set_xlabel("$\lambda$")
tmp = np.arange(len(etavec))+0.5
tmp[0] = 0
tmp[-1]+=0.5
ax.set_yticks(tmp)
tmp = np.arange(len(lmbvec)) + 0.5
ax.set_xticks(tmp)
plt.show()

# %%
best_eta_index, best_lmb_index = np.where(train_accuracy == np.min(train_accuracy))
best_eta,best_lmb = etavec[best_eta_index], lmbvec[best_lmb_index] 

print('eta=',best_eta)
print('lmb=',best_lmb)
# Out:
# eta= [0.1]
# lmb= [0.01]

# %%
np.random.seed(2019)
epochs=10000
batch_size=int(len(ytrain)/3)
activation = [lrf.relu, lrf.sigmoid, lrf.sigmoid]
derivative = [lrf.relu_deriv, lrf.sigmoid_deriv, lrf.sigmoid_deriv]

neural_net = nn.ANN(lmb=best_lmb, bias=0.5, eta= best_eta,early_stop_tol = 0,\
                            early_stop_nochange=100, mode = 'classification')            
neural_net.add_layers(n_features=[xtrain.shape[1],50,20], n_neurons = [50,20,1] , n_layers=3)
neural_net.train(epochs, batch_size, xtrain,ytrain,activation,derivative ,xtrain,ytrain, verbose=True)
cost_val, cost_train = neural_net.costs()
# Out:
# Epoch 1 loss 0.7534087755981641
# Epoch 2 loss 0.7506658580274469
# Epoch 3 loss 0.7486408732176468
# Epoch 4 loss 0.7456174776711917
# Epoch 5 loss 0.7418671672406154
# Epoch 6 loss 0.7394835017725572
# Epoch 7 loss 0.7360825459793988
# Epoch 8 loss 0.733638766414345
# Epoch 9 loss 0.7311001018272404
# Epoch 10 loss 0.7284970360464532
# Epoch 11 loss 0.7264108833350278
# Epoch 12 loss 0.7244157204667868
# Epoch 13 loss 0.7222299711802926
# Epoch 14 loss 0.7204284205645999
# Epoch 15 loss 0.7190572912650357
# Epoch 16 loss 0.7170574500114174
# Epoch 17 loss 0.7153519987651729
# Epoch 18 loss 0.7134806309193596
# Epoch 19 loss 0.7119858323541989
# Epoch 20 loss 0.7106467989147413
# Epoch 21 loss 0.7094212800472911
# Epoch 22 loss 0.7081906412280706
# Epoch 23 loss 0.7067587031995763
# Epoch 24 loss 0.7059940590385625
# Epoch 25 loss 0.7056389077055883
# Epoch 26 loss 0.704106191269954
# Epoch 27 loss 0.7031453108936793
# Epoch 28 loss 0.7026471360404541
# Epoch 29 loss 0.7019637028288372
# Epoch 30 loss 0.7010964337268009
# Epoch 31 loss 0.7006622475000231
# Epoch 32 loss 0.700898339938428
# Epoch 33 loss 0.7003304898166091
# Epoch 34 loss 0.6993464670405174
# Epoch 35 loss 0.6993021999665392
# Epoch 36 loss 0.6983464950079145
# Epoch 37 loss 0.6983277978972102
# Epoch 38 loss 0.698131900030677
# Epoch 39 loss 0.6979059493293699
# Epoch 40 loss 0.6971484271052423
# Epoch 41 loss 0.6968578397638732
# Epoch 42 loss 0.6962372158509158
# Epoch 43 loss 0.6964607762672475
# Epoch 44 loss 0.6960458980658766
# Epoch 45 loss 0.6959090629634227
# Epoch 46 loss 0.6956401422698586
# Epoch 47 loss 0.6954408498482778
# Epoch 48 loss 0.6951391253464111
# Epoch 49 loss 0.6940629672143769
# Epoch 50 loss 0.6940682485202248
# Epoch 51 loss 0.6946704224357716
# Epoch 52 loss 0.694245583894875
# Epoch 53 loss 0.6940980249456631
# Epoch 54 loss 0.6940690181085715
# Epoch 55 loss 0.6938397722510988
# Epoch 56 loss 0.693193806363847
# Epoch 57 loss 0.69242579796208
# Epoch 58 loss 0.6933180448950949
# Epoch 59 loss 0.6928124762861901
# Epoch 60 loss 0.6920176882016829
# Epoch 61 loss 0.6919476974186916
# Epoch 62 loss 0.6921811889634839
# Epoch 63 loss 0.6920283125608079
# Epoch 64 loss 0.691229587385587
# Epoch 65 loss 0.6917462887241163
# Epoch 66 loss 0.6918889974733122
# Epoch 67 loss 0.6920103422429829
# Epoch 68 loss 0.6913052618380098
# Epoch 69 loss 0.6915165256308342
# Epoch 70 loss 0.691169867477946
# Epoch 71 loss 0.6910997856022596
# Epoch 72 loss 0.6907629001968865
# Epoch 73 loss 0.6911256856760641
# Epoch 74 loss 0.690734608987206
# Epoch 75 loss 0.6906166587386012
# Epoch 76 loss 0.6904783821976912
# Epoch 77 loss 0.6911166317484847
# Epoch 78 loss 0.6906444495973852
# Epoch 79 loss 0.6903835344671919
# Epoch 80 loss 0.6900976391982033
# Epoch 81 loss 0.6903260953789702
# Epoch 82 loss 0.6898772973942696
# Epoch 83 loss 0.6897480052698157
# Epoch 84 loss 0.6898394678284626
# Epoch 85 loss 0.6898416158274079
# Epoch 86 loss 0.6896398084630463
# Epoch 87 loss 0.6894703365087129
# Epoch 88 loss 0.6897121279892449
# Epoch 89 loss 0.6891760923288281
# Epoch 90 loss 0.6892261219478054
# Epoch 91 loss 0.6886539966293632
# Epoch 92 loss 0.6893471564637547
# Epoch 93 loss 0.6891765584061597
# Epoch 94 loss 0.6889045588003345
# Epoch 95 loss 0.6894842362315429
# Epoch 96 loss 0.6889874562993256
# Epoch 97 loss 0.6894222217080621
# Epoch 98 loss 0.6888055628671303
# Epoch 99 loss 0.688838161745971
# Epoch 100 loss 0.6889799010075395
# Epoch 101 loss 0.6889232344278707
# Epoch 102 loss 0.688778224783691
# Epoch 103 loss 0.6889689833129067
# Epoch 104 loss 0.6887419306928332
# Epoch 105 loss 0.688396696193232
# Epoch 106 loss 0.6882078724679509
# Epoch 107 loss 0.6892753031963179
# Epoch 108 loss 0.6879343838220259
# Epoch 109 loss 0.6882163803601871
# Epoch 110 loss 0.6873202609991231
# Epoch 111 loss 0.6879743945824116
# Epoch 112 loss 0.6873198958410853
# Epoch 113 loss 0.687609972242312
# Epoch 114 loss 0.687743154638915
# Epoch 115 loss 0.6878424222436756
# Epoch 116 loss 0.6875333910306836
# Epoch 117 loss 0.6873876058617686
# Epoch 118 loss 0.6876038649336531
# Epoch 119 loss 0.6875437443200713
# Epoch 120 loss 0.6879158805623468
# Epoch 121 loss 0.6876672917924331
# Epoch 122 loss 0.6875169123867108
# Epoch 123 loss 0.6874218126794371
# Epoch 124 loss 0.6875569044801967
# Epoch 125 loss 0.6874849758357771
# Epoch 126 loss 0.6874766790926008
# Epoch 127 loss 0.6878145511197503
# Epoch 128 loss 0.6873181040550782
# Epoch 129 loss 0.6872803736148898
# Epoch 130 loss 0.6871654035382134
# Epoch 131 loss 0.6874395196411045
# Epoch 132 loss 0.6871790934806572
# Epoch 133 loss 0.6870941674545908
# Epoch 134 loss 0.6871225312923591
# Epoch 135 loss 0.6868965119238268
# Epoch 136 loss 0.686367935595282
# Epoch 137 loss 0.686838856898252
# Epoch 138 loss 0.6862376151152424
# Epoch 139 loss 0.6865075611206387
# Epoch 140 loss 0.6870436432553634
# Epoch 141 loss 0.6868754688662532
# Epoch 142 loss 0.6870983511450078
# Epoch 143 loss 0.6862157764037299
# Epoch 144 loss 0.6870560881527518
# Epoch 145 loss 0.6865003742095306
# Epoch 146 loss 0.6865364846063197
# Epoch 147 loss 0.6863938575293212
# Epoch 148 loss 0.6872811422108777
# Epoch 149 loss 0.6872831647245339
# Epoch 150 loss 0.6872968306335215
# Epoch 151 loss 0.6869262731186173
# Epoch 152 loss 0.68609782432555
# Epoch 153 loss 0.6863575207955401
# Epoch 154 loss 0.6862614962521837
# Epoch 155 loss 0.6865727088589396
# Epoch 156 loss 0.6870106836289056
# Epoch 157 loss 0.6860042383220116
# Epoch 158 loss 0.6858842762601388
# Epoch 159 loss 0.6861890022895636
# Epoch 160 loss 0.6861161564766437
# Epoch 161 loss 0.686111523142062
# Epoch 162 loss 0.6870341596005868
# Epoch 163 loss 0.6863469372980698
# Epoch 164 loss 0.6865126433986
# Epoch 165 loss 0.6856682788227257
# Epoch 166 loss 0.68508983105884
# Epoch 167 loss 0.6851469138033067
# Epoch 168 loss 0.6857654294143887
# Epoch 169 loss 0.6862010099476022
# Epoch 170 loss 0.6861769364339252
# Epoch 171 loss 0.6860459752179282
# Epoch 172 loss 0.6857951762207322
# Epoch 173 loss 0.6859327864600091
# Epoch 174 loss 0.6856278860733686
# Epoch 175 loss 0.6857132844687847
# Epoch 176 loss 0.6858633254168457
# Epoch 177 loss 0.6858051380723669
# Epoch 178 loss 0.684777302507809
# Epoch 179 loss 0.6850106463199744
# Epoch 180 loss 0.6850422555983452
# Epoch 181 loss 0.6848356418238162
# Epoch 182 loss 0.6851926066459116
# Epoch 183 loss 0.6853792834190156
# Epoch 184 loss 0.6856374372708159
# Epoch 185 loss 0.6855948935468592
# Epoch 186 loss 0.685419921053072
# Epoch 187 loss 0.6852918436408449
# Epoch 188 loss 0.685312961394951
# Epoch 189 loss 0.6849111836830097
# Epoch 190 loss 0.684955838342455
# Epoch 191 loss 0.6845767342814969
# Epoch 192 loss 0.6851284803102273
# Epoch 193 loss 0.6852244588781202
# Epoch 194 loss 0.6849373187874004
# Epoch 195 loss 0.6853509519145218
# Epoch 196 loss 0.6852807125552441
# Epoch 197 loss 0.6846761760248834
# Epoch 198 loss 0.6842586962217813
# Epoch 199 loss 0.6850321370422312
# Epoch 200 loss 0.6847196280727629
# Epoch 201 loss 0.6845077706596888
# Epoch 202 loss 0.6848627432591188
# Epoch 203 loss 0.6847031491299435
# Epoch 204 loss 0.6847091809606408
# Epoch 205 loss 0.6848742752680891
# Epoch 206 loss 0.6847020974532922
# Epoch 207 loss 0.6846074115614392
# Epoch 208 loss 0.6843992904529633
# Epoch 209 loss 0.6847130933862241
# Epoch 210 loss 0.684720577680441
# Epoch 211 loss 0.6843196689273191
# Epoch 212 loss 0.6842569863206778
# Epoch 213 loss 0.6839793127215289
# Epoch 214 loss 0.6845258279900327
# Epoch 215 loss 0.684489112873423
# Epoch 216 loss 0.6851269744044918
# Epoch 217 loss 0.6843929890977113
# Epoch 218 loss 0.6845958496692834
# Epoch 219 loss 0.6836995089572636
# Epoch 220 loss 0.6844202619797786
# Epoch 221 loss 0.6841769070102972
# Epoch 222 loss 0.6841658179772291
# Epoch 223 loss 0.6845381614870867
# Epoch 224 loss 0.6847054348941845
# Epoch 225 loss 0.684444758518421
# Epoch 226 loss 0.6843270268586572
# Epoch 227 loss 0.6841866782347247
# Epoch 228 loss 0.6842900645153983
# Epoch 229 loss 0.6842648615874563
# Epoch 230 loss 0.6842341715582362
# Epoch 231 loss 0.684575040475326
# Epoch 232 loss 0.684445796682219
# Epoch 233 loss 0.6841268794970711
# Epoch 234 loss 0.6839987672264389
# Epoch 235 loss 0.684129300447808
# Epoch 236 loss 0.6838266970139856
# Epoch 237 loss 0.6837808079433316
# Epoch 238 loss 0.6840791885995732
# Epoch 239 loss 0.6840984654084455
# Epoch 240 loss 0.6840586615595349
# Epoch 241 loss 0.6846333712104052
# Epoch 242 loss 0.6846776505251759
# Epoch 243 loss 0.684006020133954
# Epoch 244 loss 0.6841626771775748
# Epoch 245 loss 0.6847172826816407
# Epoch 246 loss 0.6845849440676026
# Epoch 247 loss 0.6839889806966081
# Epoch 248 loss 0.683626748829428
# Epoch 249 loss 0.6836042657989522
# Epoch 250 loss 0.6836497786893696
# Epoch 251 loss 0.6838116770784267
# Epoch 252 loss 0.6840016563766683
# Epoch 253 loss 0.6841468005002166
# Epoch 254 loss 0.6841167810475721
# Epoch 255 loss 0.684477393642594
# Epoch 256 loss 0.6840868185482065
# Epoch 257 loss 0.6842647374735785
# Epoch 258 loss 0.683471496355843
# Epoch 259 loss 0.6836919706147283
# Epoch 260 loss 0.6838522675454003
# Epoch 261 loss 0.6833991877463617
# Epoch 262 loss 0.6839374124814975
# Epoch 263 loss 0.6837008165095372
# Epoch 264 loss 0.6837191485513451
# Epoch 265 loss 0.6837895404845357
# Epoch 266 loss 0.6837466200734189
# Epoch 267 loss 0.6835970201249809
# Epoch 268 loss 0.6827015328498487
# Epoch 269 loss 0.6834845867447142
# Epoch 270 loss 0.6837050407259951
# Epoch 271 loss 0.6843309505924916
# Epoch 272 loss 0.6839488313143381
# Epoch 273 loss 0.6833824037706766
# Epoch 274 loss 0.6833139202220538
# Epoch 275 loss 0.6832158160448218
# Epoch 276 loss 0.6838308660272228
# Epoch 277 loss 0.68393560055768
# Epoch 278 loss 0.6839771839758365
# Epoch 279 loss 0.6840426795980974
# Epoch 280 loss 0.6842095173294942
# Epoch 281 loss 0.6837284425871297
# Epoch 282 loss 0.6832601859892276
# Epoch 283 loss 0.6834571221810215
# Epoch 284 loss 0.6832525015481504
# Epoch 285 loss 0.6838346414244348
# Epoch 286 loss 0.6835285251987516
# Epoch 287 loss 0.6831349752905413
# Epoch 288 loss 0.6834679718087695
# Epoch 289 loss 0.6838838848662558
# Epoch 290 loss 0.6839367881616752
# Epoch 291 loss 0.6836572183327727
# Epoch 292 loss 0.683362471928154
# Epoch 293 loss 0.683661711732924
# Epoch 294 loss 0.6833470134487206
# Epoch 295 loss 0.6837222048937629
# Epoch 296 loss 0.6832975473047046
# Epoch 297 loss 0.6834045649446557
# Epoch 298 loss 0.6828542519333397
# Epoch 299 loss 0.6838552649761345
# Epoch 300 loss 0.6834433173144525
# Epoch 301 loss 0.6833301560419448
# Epoch 302 loss 0.6833266297461529
# Epoch 303 loss 0.683277301691457
# Epoch 304 loss 0.6832554063480323
# Epoch 305 loss 0.683242769133491
# Epoch 306 loss 0.6834700279254126
# Epoch 307 loss 0.6830692447992277
# Epoch 308 loss 0.6830510717004283
# Epoch 309 loss 0.6827221427040343
# Epoch 310 loss 0.6829626954002631
# Epoch 311 loss 0.6826263573647696
# Epoch 312 loss 0.6831442604189214
# Epoch 313 loss 0.6828210515756427
# Epoch 314 loss 0.6833780846219972
# Epoch 315 loss 0.6827630277000072
# Epoch 316 loss 0.6829451002547824
# Epoch 317 loss 0.6827522999055333
# Epoch 318 loss 0.6830874702394655
# Epoch 319 loss 0.6826807901986631
# Epoch 320 loss 0.6838089126080955
# Epoch 321 loss 0.6832472283917425
# Epoch 322 loss 0.6832892352333683
# Epoch 323 loss 0.6827787413503542
# Epoch 324 loss 0.6834685886636068
# Epoch 325 loss 0.6841399165222524
# Epoch 326 loss 0.6832336927696097
# Epoch 327 loss 0.6831371728763957
# Epoch 328 loss 0.6835378352836446
# Epoch 329 loss 0.6829959502975229
# Epoch 330 loss 0.6835616198427936
# Epoch 331 loss 0.6834881837656929
# Epoch 332 loss 0.6832289980941281
# Epoch 333 loss 0.6833714145349575
# Epoch 334 loss 0.6836716095429236
# Epoch 335 loss 0.6838287694676275
# Epoch 336 loss 0.6835678666165601
# Epoch 337 loss 0.6832273085518288
# Epoch 338 loss 0.6838044449656093

# %%
plt.figure(figsize=([8,8]))
axis = np.arange(len(cost_val))+1
plt.plot(axis, cost_train, 'b', label='Cost training', linewidth=2)
plt.plot(axis, cost_val, 'r', label='Cost validation', linewidth=2)
plt.legend(fontsize=20)
plt.ylabel('Log Loss',fontsize=20)
plt.xlabel('Iteration',fontsize=20)
plt.show()

# %%
activ=neural_net.feed_out(xtest, activation)
classes=np.round(activ)
print(100*np.sum(classes==ytest)/len(activ),'% Test Accuracy')
print(f1_score(ytest, classes)) 
cm = confusion_matrix(ytest , classes)
print(cm)
# Out:
# 69.37853107344633 % Test Accuracy
# 0.6469821971341728
# [[1097  278]
#  [ 535  745]]

# %%
activ=neural_net.feed_out(xtrain, activation)

classes=np.round(activ)

print(100*np.sum(classes==ytrain)/len(activ),'% training Accuracy')
print(f1_score(ytrain, classes)) 

cm = confusion_matrix(ytrain , classes)
print(cm)
# Out:
# 69.1785983421251 % training Accuracy
# 0.65855694692904
# [[3665  945]
#  [1918 2761]]

# %%
from sklearn.neural_network import MLPClassifier



#print("Test set score: %f" % mlp.score(xtest, ytest))
epochs=1000
batch_size=500
n_features=x.shape[1]
etavec = np.logspace(-4, -1, 4)
lmbvec = np.logspace(-7, -3, 5)
lmbvec[0]=0


train_accuracy = np.zeros((len(etavec), len(lmbvec)))
for i, etas in enumerate(etavec):
    for j, lmb in enumerate(lmbvec):
        mlp = MLPClassifier(hidden_layer_sizes=(50,20,), max_iter=2000, alpha=lmb,
                    solver='sgd', verbose=0, tol=1e-4,batch_size=500, random_state=1,
                    learning_rate_init=etas)

        mlp.fit(xtrain, ytrain.ravel())
        print("Training set score: %f" % mlp.score(xval, yval))
        pred = mlp.predict(xval)
        train_accuracy[i,j] =  lrf.cost_log_ols(pred.ravel(),yval.T)
        print('Validation f1_score for', '\u03B7 =', etas, '&', '\u03BB =', lmb, '=', train_accuracy [i,j])
# Out:
# Training set score: 0.701807
# Validation f1_score for η = 0.0001 & λ = 0.0 = 0.6379092358232562
# Training set score: 0.701807
# Validation f1_score for η = 0.0001 & λ = 1e-06 = 0.6379092358232562
# Training set score: 0.701807
# Validation f1_score for η = 0.0001 & λ = 1e-05 = 0.6379092358232562
# Training set score: 0.701807
# Validation f1_score for η = 0.0001 & λ = 0.0001 = 0.6379092358232562
# Training set score: 0.701807
# Validation f1_score for η = 0.0001 & λ = 0.001 = 0.6379092358232562
# Training set score: 0.716114
# Validation f1_score for η = 0.001 & λ = 0.0 = 0.6284944295928668
# Training set score: 0.716114
# Validation f1_score for η = 0.001 & λ = 1e-06 = 0.6284944295928668
# Training set score: 0.716114
# Validation f1_score for η = 0.001 & λ = 1e-05 = 0.6284944295928668
# Training set score: 0.716114
# Validation f1_score for η = 0.001 & λ = 0.0001 = 0.6284944295928668
# Training set score: 0.716114
# Validation f1_score for η = 0.001 & λ = 0.001 = 0.6284944295928668
# Training set score: 0.694277
# Validation f1_score for η = 0.01 & λ = 0.0 = 0.6413125053806107
# C:\Users\vemundst\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:568: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Training set score: 0.714608
# Validation f1_score for η = 0.01 & λ = 1e-06 = 0.6292474416410596

# %%
import seaborn as sns
train_accuracy[np.isnan(train_accuracy)]=2

yticklabels = etavec
xticklabels = lmbvec
fig, ax = plt.subplots(figsize = (10, 12))
sns.heatmap(train_accuracy, annot=True, ax=ax, cmap="viridis",\
            yticklabels=yticklabels, xticklabels=xticklabels)
ax.set_title("Training Accuracy")
ax.set_ylabel("$\eta$")
ax.set_xlabel("$\lambda$")
tmp = np.arange(len(etavec))+0.5
tmp[0] = 0
tmp[-1]+=0.5
ax.set_yticks(tmp)
tmp = np.arange(len(lmbvec)) + 0.5
ax.set_xticks(tmp)
plt.show()

# %%
pred = mlp.predict(xtest)
accuracy = accuracy_score(ytest.flatten(),pred)
accuracy = accuracy * 100
print(accuracy)
print(f1_score(ytest, pred)) 

cm = confusion_matrix(ytest , pred)
print(cm)
# Out:
# 67.38229755178907
# 0.6566217287866772
# [[961 414]
#  [452 828]]

# %%
pred = mlp.predict(xtrain)
accuracy = accuracy_score(ytrain.flatten(),pred)
accuracy = accuracy * 100
print(accuracy)

cm = confusion_matrix(ytrain , pred)
print(cm)
# Out:
# 78.18925610937669
# [[3704  906]
#  [1120 3559]]

# %% [markdown]
# # Cancer data

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import MinMaxScaler

xtrain,ytrain = load_breast_cancer(return_X_y=True)
scaler = MinMaxScaler()
indx = np.arange(xtrain.shape[1])
scaler.fit(xtrain[:,indx])
xtrain = scaler.transform(xtrain[:,indx])
ytrain=ytrain.reshape([len(ytrain),1])
